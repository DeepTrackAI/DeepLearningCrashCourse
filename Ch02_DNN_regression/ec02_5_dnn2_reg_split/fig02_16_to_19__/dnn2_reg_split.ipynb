# %% [markdown]
# # Training a Neural Network Splitting the Data
#
# This notebook provides you with a complete code example that loads the data contained in the `data_reg_2d_nonlinear.csv` file and splits them into a training, a validation, and a test set. Then, it trains a two-layer neural network using the training data, while monitoring the training and validation MSE. Finally, it uses the trained network to predict the values of the test data (test hold-out dataset) in the `data_reg_2d_linear_test.csv` file.

# %% [markdown]
# ## Loading and Splitting the Data

# %%
from loader import load_data

(x, y_gt) = load_data(filename="data_reg_2d_nonlinear.csv")

# %%
from numpy import delete, split
from numpy.random import choice

num_samples = len(x)
split = .70

num_samples_train = int(split * num_samples)
train_idx = choice(num_samples, num_samples_train, replace=False)

x_train = x[train_idx]  # Train inputs.
y_gt_train = y_gt[train_idx]  # Train ground truths.

x_val = delete(x, train_idx, axis=0)  # Validation inputs.
y_gt_val = delete(y_gt, train_idx, axis=0)  # Validation ground truths.

# %% [markdown]
# ## Implementing a Dense Neural Network
#
# Implement the sigmoidal function

# %%
from numpy import exp

def sigmoid(x):
    """Sigmoid function."""
    return 1 / (1 + exp(-x))

# %% [markdown]
# ... implement a function to define the neural network ...

# %%
def dnn2_reg(wa, wb, x):
    """Two-layer dense neural network for classification."""
    return sigmoid(x @ wa) @ wb

# %% [markdown]
# ... define the number of neurons of the first layer ...

# %%
num_neurons = 3

# %% [markdown]
# ... randomly initialize its weights ...

# %%
from numpy.random import default_rng

rng = default_rng()
wa = rng.standard_normal(size=(2, num_neurons)) # Input weights layer 1.
wb = rng.standard_normal(size=(num_neurons, 1)) # Input weights layer 2.

# %% [markdown]
# ... obtain its predictions for the training and validation datasets ...

# %%
y_p_train = dnn2_reg(wa, wb, x_train)
y_p_val = dnn2_reg(wa, wb, x_val)

# %% [markdown]
# ... and plot its predictions for the training dataset ...

# %%
from plotting import plot_pred_2d, plot_pred_vs_gt

plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train))
plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train))

# %% [markdown]
# ... and for the validation dataset.

# %%
plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val))
plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val))

# %% [markdown]
# ## Training and Validating the Neural Network
#
# Implement the first derivative of the sigmoid function ...

# %%
def d_sigmoid(x):
    """Derivative of sigmoid function."""
    return sigmoid(x) * (1 - sigmoid(x))

# %% [markdown]
# ... implement the backpropagation algorithm with mini-batches ...

# %%
from numpy import mean, reshape, sum, transpose, zeros
from numpy.random import permutation

num_samnum_samples_trainples = len(x_train)
num_batches = 7
batch_size = int(num_samples / num_batches)
num_epochs = 10 ** 4
eta = .1 # Learning rate.

mse_train = zeros((num_epochs,))
mse_val = zeros((num_epochs,))

for epoch in range(num_epochs):
    # Permute samples.
    permuted_order_samples = permutation(num_samples_train)
    x_permuted = x_train[permuted_order_samples]
    y_gt_permuted = y_gt_train[permuted_order_samples]

    for batch_start in range(0, num_samples_train, batch_size):
        dwa = zeros(wa.shape) # Initialize weight increments layer 1.
        dwb = zeros(wb.shape) # Initialize weight increments layer 2.
        
        for selected in range(batch_start, batch_start + batch_size):
            x_selected = reshape(x_permuted[selected], (1, -1))
            y_gt_selected = reshape(y_gt_permuted[selected], (1, -1))
            
            # Detailed neural network calculation.
            x_selected_a = x_selected # Input layer 1.
            p_a = x_selected_a @ wa # Activation potential layer 1.
            y_selected_a = sigmoid(p_a) # Output layer 1.

            x_selected_b = y_selected_a # Input layer 2.
            p_b = x_selected_b @ wb # Activation potential layer 2.
            y_selected_b = p_b # Output neuron layer 2 (output neuron).

            y_p_selected = y_selected_b
    
            # Update weights.
            error = y_p_selected - y_gt_selected
    
            delta_b = error * 1
            dwb -= eta * delta_b * transpose(x_selected_b)

            delta_a = sum(wb * delta_b, axis=1) * d_sigmoid(p_a)
            dwa -= eta * delta_a * transpose(x_selected_a)
    
        wa += dwa / batch_size # Update weights layer 1.
        wb += dwb / batch_size # Update weights layer 2.
        
    y_p_train = dnn2_reg(wa, wb, x_train)
    mse_train[epoch] = mean((y_p_train - y_gt_train) ** 2)
    
    y_p_val = dnn2_reg(wa, wb, x_val)
    mse_val[epoch] = mean((y_p_val - y_gt_val) ** 2)
    
    print(f"{epoch} MSE train={mse_train[epoch]:.4f} val={mse_val[epoch]:.4f}")
# Out:
# 0 MSE train=0.5078 val=0.7993
# 1 MSE train=0.4907 val=0.7806
# 2 MSE train=0.4809 val=0.7725
# 3 MSE train=0.4740 val=0.7680
# 4 MSE train=0.4698 val=0.7687
# 5 MSE train=0.4664 val=0.7704
# 6 MSE train=0.4635 val=0.7728
# 7 MSE train=0.4611 val=0.7762
# 8 MSE train=0.4589 val=0.7781
# 9 MSE train=0.4570 val=0.7805
# 10 MSE train=0.4552 val=0.7833
# 11 MSE train=0.4536 val=0.7861
# 12 MSE train=0.4521 val=0.7890
# 13 MSE train=0.4508 val=0.7916
# 14 MSE train=0.4496 val=0.7945
# 15 MSE train=0.4484 val=0.7955
# 16 MSE train=0.4474 val=0.7973
# 17 MSE train=0.4464 val=0.7987
# 18 MSE train=0.4455 val=0.8007
# 19 MSE train=0.4447 val=0.8017
# 20 MSE train=0.4441 val=0.8022
# 21 MSE train=0.4433 val=0.8036
# 22 MSE train=0.4427 val=0.8040
# 23 MSE train=0.4421 val=0.8052
# 24 MSE train=0.4415 val=0.8066
# 25 MSE train=0.4410 val=0.8075
# 26 MSE train=0.4404 val=0.8080
# 27 MSE train=0.4399 val=0.8088
# 28 MSE train=0.4395 val=0.8090
# 29 MSE train=0.4390 val=0.8098
# 30 MSE train=0.4386 val=0.8101
# 31 MSE train=0.4382 val=0.8110
# 32 MSE train=0.4378 val=0.8118
# 33 MSE train=0.4375 val=0.8113
# 34 MSE train=0.4371 val=0.8123
# 35 MSE train=0.4368 val=0.8123
# 36 MSE train=0.4365 val=0.8126
# 37 MSE train=0.4362 val=0.8130
# 38 MSE train=0.4359 val=0.8138
# 39 MSE train=0.4356 val=0.8136
# 40 MSE train=0.4353 val=0.8138
# 41 MSE train=0.4351 val=0.8135
# 42 MSE train=0.4348 val=0.8136
# 43 MSE train=0.4346 val=0.8137
# 44 MSE train=0.4343 val=0.8141
# 45 MSE train=0.4341 val=0.8142
# 46 MSE train=0.4339 val=0.8146
# 47 MSE train=0.4337 val=0.8141
# 48 MSE train=0.4334 val=0.8144
# 49 MSE train=0.4333 val=0.8140
# 50 MSE train=0.4330 val=0.8149
# 51 MSE train=0.4328 val=0.8148
# 52 MSE train=0.4326 val=0.8150
# 53 MSE train=0.4325 val=0.8150
# 54 MSE train=0.4323 val=0.8155
# 55 MSE train=0.4321 val=0.8147
# 56 MSE train=0.4319 val=0.8149
# 57 MSE train=0.4318 val=0.8150
# 58 MSE train=0.4316 val=0.8144
# 59 MSE train=0.4314 val=0.8136
# 60 MSE train=0.4313 val=0.8137
# 61 MSE train=0.4312 val=0.8138
# 62 MSE train=0.4310 val=0.8145
# 63 MSE train=0.4309 val=0.8143
# 64 MSE train=0.4307 val=0.8138
# 65 MSE train=0.4305 val=0.8142
# 66 MSE train=0.4305 val=0.8147
# 67 MSE train=0.4303 val=0.8142
# 68 MSE train=0.4301 val=0.8146
# 69 MSE train=0.4301 val=0.8156
# 70 MSE train=0.4299 val=0.8148
# 71 MSE train=0.4298 val=0.8150
# 72 MSE train=0.4296 val=0.8156
# 73 MSE train=0.4295 val=0.8152
# 74 MSE train=0.4294 val=0.8153
# 75 MSE train=0.4293 val=0.8150
# 76 MSE train=0.4292 val=0.8152
# 77 MSE train=0.4290 val=0.8147
# 78 MSE train=0.4289 val=0.8149
# 79 MSE train=0.4288 val=0.8149
# 80 MSE train=0.4287 val=0.8151
# 81 MSE train=0.4285 val=0.8146
# 82 MSE train=0.4284 val=0.8152
# 83 MSE train=0.4283 val=0.8152
# 84 MSE train=0.4282 val=0.8152
# 85 MSE train=0.4281 val=0.8149
# 86 MSE train=0.4280 val=0.8148
# 87 MSE train=0.4279 val=0.8153
# 88 MSE train=0.4278 val=0.8158
# 89 MSE train=0.4277 val=0.8159
# 90 MSE train=0.4276 val=0.8159
# 91 MSE train=0.4275 val=0.8159
# 92 MSE train=0.4273 val=0.8155
# 93 MSE train=0.4273 val=0.8155
# 94 MSE train=0.4271 val=0.8161
# 95 MSE train=0.4270 val=0.8159
# 96 MSE train=0.4270 val=0.8155
# 97 MSE train=0.4269 val=0.8156
# 98 MSE train=0.4268 val=0.8153
# 99 MSE train=0.4269 val=0.8150
# 100 MSE train=0.4267 val=0.8152
# 101 MSE train=0.4266 val=0.8151
# 102 MSE train=0.4264 val=0.8159
# 103 MSE train=0.4262 val=0.8164
# 104 MSE train=0.4261 val=0.8165
# 105 MSE train=0.4260 val=0.8169
# 106 MSE train=0.4259 val=0.8171
# 107 MSE train=0.4258 val=0.8175
# 108 MSE train=0.4257 val=0.8174
# 109 MSE train=0.4256 val=0.8177
# 110 MSE train=0.4255 val=0.8179
# 111 MSE train=0.4254 val=0.8181
# 112 MSE train=0.4254 val=0.8180
# 113 MSE train=0.4253 val=0.8178
# 114 MSE train=0.4252 val=0.8183
# 115 MSE train=0.4251 val=0.8188
# 116 MSE train=0.4250 val=0.8189
# 117 MSE train=0.4249 val=0.8188
# 118 MSE train=0.4248 val=0.8190
# 119 MSE train=0.4247 val=0.8193
# 120 MSE train=0.4246 val=0.8191
# 121 MSE train=0.4245 val=0.8190
# 122 MSE train=0.4244 val=0.8187
# 123 MSE train=0.4243 val=0.8185
# 124 MSE train=0.4243 val=0.8183
# 125 MSE train=0.4243 val=0.8180
# 126 MSE train=0.4240 val=0.8185
# 127 MSE train=0.4240 val=0.8185
# 128 MSE train=0.4238 val=0.8186
# 129 MSE train=0.4237 val=0.8191
# 130 MSE train=0.4237 val=0.8190
# 131 MSE train=0.4236 val=0.8193
# 132 MSE train=0.4234 val=0.8198
# 133 MSE train=0.4233 val=0.8199
# 134 MSE train=0.4232 val=0.8199
# 135 MSE train=0.4232 val=0.8201
# 136 MSE train=0.4230 val=0.8207
# 137 MSE train=0.4229 val=0.8213
# 138 MSE train=0.4228 val=0.8212
# 139 MSE train=0.4227 val=0.8221
# 140 MSE train=0.4226 val=0.8220
# 141 MSE train=0.4225 val=0.8227
# 142 MSE train=0.4224 val=0.8220
# 143 MSE train=0.4223 val=0.8220
# 144 MSE train=0.4222 val=0.8223
# 145 MSE train=0.4221 val=0.8230
# 146 MSE train=0.4220 val=0.8229
# 147 MSE train=0.4219 val=0.8229
# 148 MSE train=0.4218 val=0.8232
# 149 MSE train=0.4217 val=0.8236
# 150 MSE train=0.4216 val=0.8237
# 151 MSE train=0.4215 val=0.8234
# 152 MSE train=0.4213 val=0.8237
# 153 MSE train=0.4212 val=0.8238
# 154 MSE train=0.4211 val=0.8239
# 155 MSE train=0.4210 val=0.8237
# 156 MSE train=0.4209 val=0.8241
# 157 MSE train=0.4208 val=0.8235
# 158 MSE train=0.4207 val=0.8233
# 159 MSE train=0.4207 val=0.8235
# 160 MSE train=0.4205 val=0.8240
# 161 MSE train=0.4204 val=0.8245
# 162 MSE train=0.4203 val=0.8250
# 163 MSE train=0.4202 val=0.8260
# 164 MSE train=0.4201 val=0.8259
# 165 MSE train=0.4199 val=0.8251
# 166 MSE train=0.4198 val=0.8254
# 167 MSE train=0.4197 val=0.8256
# 168 MSE train=0.4196 val=0.8251
# 169 MSE train=0.4194 val=0.8256
# 170 MSE train=0.4193 val=0.8256
# 171 MSE train=0.4192 val=0.8259
# 172 MSE train=0.4191 val=0.8266
# 173 MSE train=0.4190 val=0.8275
# 174 MSE train=0.4189 val=0.8279
# 175 MSE train=0.4188 val=0.8283
# 176 MSE train=0.4186 val=0.8278
# 177 MSE train=0.4185 val=0.8269
# 178 MSE train=0.4184 val=0.8270
# 179 MSE train=0.4183 val=0.8272
# 180 MSE train=0.4181 val=0.8276
# 181 MSE train=0.4179 val=0.8284
# 182 MSE train=0.4178 val=0.8286
# 183 MSE train=0.4177 val=0.8289
# 184 MSE train=0.4176 val=0.8285
# 185 MSE train=0.4174 val=0.8288
# 186 MSE train=0.4173 val=0.8292
# 187 MSE train=0.4172 val=0.8292
# 188 MSE train=0.4170 val=0.8302
# 189 MSE train=0.4169 val=0.8300
# 190 MSE train=0.4167 val=0.8295
# 191 MSE train=0.4166 val=0.8293
# 192 MSE train=0.4165 val=0.8294
# 193 MSE train=0.4163 val=0.8294
# 194 MSE train=0.4162 val=0.8297
# 195 MSE train=0.4161 val=0.8304
# 196 MSE train=0.4159 val=0.8299
# 197 MSE train=0.4157 val=0.8302
# 198 MSE train=0.4156 val=0.8307
# 199 MSE train=0.4154 val=0.8308
# 200 MSE train=0.4153 val=0.8302
# 201 MSE train=0.4151 val=0.8306
# 202 MSE train=0.4150 val=0.8306
# 203 MSE train=0.4148 val=0.8308
# 204 MSE train=0.4147 val=0.8313
# 205 MSE train=0.4146 val=0.8323
# 206 MSE train=0.4145 val=0.8330
# 207 MSE train=0.4143 val=0.8325
# 208 MSE train=0.4141 val=0.8330
# 209 MSE train=0.4139 val=0.8319
# 210 MSE train=0.4138 val=0.8328
# 211 MSE train=0.4135 val=0.8326
# 212 MSE train=0.4134 val=0.8329
# 213 MSE train=0.4132 val=0.8327
# 214 MSE train=0.4130 val=0.8331
# 215 MSE train=0.4129 val=0.8335
# 216 MSE train=0.4126 val=0.8325
# 217 MSE train=0.4125 val=0.8328
# 218 MSE train=0.4123 val=0.8326
# 219 MSE train=0.4121 val=0.8328
# 220 MSE train=0.4119 val=0.8330
# 221 MSE train=0.4117 val=0.8332
# 222 MSE train=0.4115 val=0.8333
# 223 MSE train=0.4113 val=0.8336
# 224 MSE train=0.4114 val=0.8347
# 225 MSE train=0.4110 val=0.8337
# 226 MSE train=0.4108 val=0.8345
# 227 MSE train=0.4106 val=0.8345
# 228 MSE train=0.4103 val=0.8342
# 229 MSE train=0.4101 val=0.8343
# 230 MSE train=0.4099 val=0.8345
# 231 MSE train=0.4097 val=0.8344
# 232 MSE train=0.4095 val=0.8338
# 233 MSE train=0.4093 val=0.8337
# 234 MSE train=0.4091 val=0.8337
# 235 MSE train=0.4089 val=0.8332
# 236 MSE train=0.4087 val=0.8334
# 237 MSE train=0.4085 val=0.8331
# 238 MSE train=0.4082 val=0.8332
# 239 MSE train=0.4081 val=0.8345
# 240 MSE train=0.4078 val=0.8344
# 241 MSE train=0.4076 val=0.8341
# 242 MSE train=0.4074 val=0.8339
# 243 MSE train=0.4071 val=0.8338
# 244 MSE train=0.4068 val=0.8333
# 245 MSE train=0.4066 val=0.8333
# 246 MSE train=0.4063 val=0.8334
# 247 MSE train=0.4061 val=0.8330
# 248 MSE train=0.4058 val=0.8329
# 249 MSE train=0.4056 val=0.8324
# 250 MSE train=0.4053 val=0.8324
# 251 MSE train=0.4050 val=0.8325
# 252 MSE train=0.4048 val=0.8325
# 253 MSE train=0.4045 val=0.8325
# 254 MSE train=0.4043 val=0.8321
# 255 MSE train=0.4041 val=0.8319
# 256 MSE train=0.4037 val=0.8325
# 257 MSE train=0.4034 val=0.8327
# 258 MSE train=0.4033 val=0.8334
# 259 MSE train=0.4029 val=0.8332
# 260 MSE train=0.4026 val=0.8328
# 261 MSE train=0.4023 val=0.8325
# 262 MSE train=0.4020 val=0.8325
# 263 MSE train=0.4016 val=0.8322
# 264 MSE train=0.4014 val=0.8315
# 265 MSE train=0.4010 val=0.8318
# 266 MSE train=0.4007 val=0.8313
# 267 MSE train=0.4004 val=0.8318
# 268 MSE train=0.4001 val=0.8315
# 269 MSE train=0.3998 val=0.8311
# 270 MSE train=0.3995 val=0.8304
# 271 MSE train=0.3992 val=0.8298
# 272 MSE train=0.3988 val=0.8298
# 273 MSE train=0.3984 val=0.8292
# 274 MSE train=0.3981 val=0.8285
# 275 MSE train=0.3979 val=0.8278
# 276 MSE train=0.3975 val=0.8272
# 277 MSE train=0.3974 val=0.8267
# 278 MSE train=0.3967 val=0.8272
# 279 MSE train=0.3963 val=0.8279
# 280 MSE train=0.3959 val=0.8281
# 281 MSE train=0.3955 val=0.8272
# 282 MSE train=0.3951 val=0.8266
# 283 MSE train=0.3947 val=0.8256
# 284 MSE train=0.3943 val=0.8254
# 285 MSE train=0.3939 val=0.8253
# 286 MSE train=0.3935 val=0.8247
# 287 MSE train=0.3931 val=0.8234
# 288 MSE train=0.3927 val=0.8232
# 289 MSE train=0.3923 val=0.8227
# 290 MSE train=0.3919 val=0.8221
# 291 MSE train=0.3914 val=0.8214
# 292 MSE train=0.3910 val=0.8215
# 293 MSE train=0.3906 val=0.8202
# 294 MSE train=0.3902 val=0.8206
# 295 MSE train=0.3897 val=0.8200
# 296 MSE train=0.3892 val=0.8192
# 297 MSE train=0.3889 val=0.8193
# 298 MSE train=0.3883 val=0.8179
# 299 MSE train=0.3880 val=0.8184
# 300 MSE train=0.3875 val=0.8172
# 301 MSE train=0.3869 val=0.8157
# 302 MSE train=0.3864 val=0.8144
# 303 MSE train=0.3858 val=0.8130
# 304 MSE train=0.3853 val=0.8117
# 305 MSE train=0.3848 val=0.8113
# 306 MSE train=0.3843 val=0.8104
# 307 MSE train=0.3838 val=0.8091
# 308 MSE train=0.3833 val=0.8082
# 309 MSE train=0.3827 val=0.8071
# 310 MSE train=0.3822 val=0.8068
# 311 MSE train=0.3816 val=0.8045
# 312 MSE train=0.3810 val=0.8031
# 313 MSE train=0.3805 val=0.8028
# 314 MSE train=0.3799 val=0.8017
# 315 MSE train=0.3793 val=0.8004
# 316 MSE train=0.3787 val=0.7991
# 317 MSE train=0.3781 val=0.7988
# 318 MSE train=0.3775 val=0.7975
# 319 MSE train=0.3769 val=0.7960
# 320 MSE train=0.3764 val=0.7955
# 321 MSE train=0.3758 val=0.7940
# 322 MSE train=0.3751 val=0.7925
# 323 MSE train=0.3745 val=0.7904
# 324 MSE train=0.3739 val=0.7883
# 325 MSE train=0.3732 val=0.7874
# 326 MSE train=0.3726 val=0.7862
# 327 MSE train=0.3719 val=0.7858
# 328 MSE train=0.3712 val=0.7846
# 329 MSE train=0.3706 val=0.7835
# 330 MSE train=0.3699 val=0.7818
# 331 MSE train=0.3692 val=0.7795
# 332 MSE train=0.3685 val=0.7785
# 333 MSE train=0.3678 val=0.7763
# 334 MSE train=0.3671 val=0.7748
# 335 MSE train=0.3664 val=0.7728
# 336 MSE train=0.3657 val=0.7709
# 337 MSE train=0.3650 val=0.7699
# 338 MSE train=0.3643 val=0.7691
# 339 MSE train=0.3636 val=0.7672
# 340 MSE train=0.3628 val=0.7645
# 341 MSE train=0.3621 val=0.7625
# 342 MSE train=0.3613 val=0.7610
# 343 MSE train=0.3606 val=0.7593
# 344 MSE train=0.3599 val=0.7591
# 345 MSE train=0.3591 val=0.7562
# 346 MSE train=0.3583 val=0.7542
# 347 MSE train=0.3575 val=0.7528
# 348 MSE train=0.3568 val=0.7500
# 349 MSE train=0.3560 val=0.7469
# 350 MSE train=0.3552 val=0.7450
# 351 MSE train=0.3545 val=0.7427
# 352 MSE train=0.3536 val=0.7408
# 353 MSE train=0.3528 val=0.7396
# 354 MSE train=0.3520 val=0.7373
# 355 MSE train=0.3512 val=0.7345
# 356 MSE train=0.3504 val=0.7319
# 357 MSE train=0.3496 val=0.7298
# 358 MSE train=0.3488 val=0.7274
# 359 MSE train=0.3480 val=0.7246
# 360 MSE train=0.3471 val=0.7226
# 361 MSE train=0.3463 val=0.7205
# 362 MSE train=0.3455 val=0.7186
# 363 MSE train=0.3448 val=0.7148
# 364 MSE train=0.3438 val=0.7134
# 365 MSE train=0.3430 val=0.7112
# 366 MSE train=0.3421 val=0.7103
# 367 MSE train=0.3413 val=0.7080
# 368 MSE train=0.3405 val=0.7056
# 369 MSE train=0.3396 val=0.7031
# 370 MSE train=0.3388 val=0.7019
# 371 MSE train=0.3380 val=0.7007
# 372 MSE train=0.3371 val=0.6980
# 373 MSE train=0.3363 val=0.6974
# 374 MSE train=0.3354 val=0.6945
# 375 MSE train=0.3346 val=0.6927
# 376 MSE train=0.3337 val=0.6893
# 377 MSE train=0.3328 val=0.6874
# 378 MSE train=0.3320 val=0.6844
# 379 MSE train=0.3311 val=0.6833
# 380 MSE train=0.3303 val=0.6808
# 381 MSE train=0.3294 val=0.6790
# 382 MSE train=0.3285 val=0.6759
# 383 MSE train=0.3277 val=0.6734
# 384 MSE train=0.3268 val=0.6724
# 385 MSE train=0.3260 val=0.6686
# 386 MSE train=0.3251 val=0.6674
# 387 MSE train=0.3243 val=0.6665
# 388 MSE train=0.3234 val=0.6636
# 389 MSE train=0.3226 val=0.6626
# 390 MSE train=0.3217 val=0.6604
# 391 MSE train=0.3208 val=0.6579
# 392 MSE train=0.3200 val=0.6567
# 393 MSE train=0.3191 val=0.6540
# 394 MSE train=0.3182 val=0.6524
# 395 MSE train=0.3173 val=0.6495
# 396 MSE train=0.3166 val=0.6484
# 397 MSE train=0.3156 val=0.6452
# 398 MSE train=0.3147 val=0.6436
# 399 MSE train=0.3139 val=0.6421
# 400 MSE train=0.3129 val=0.6391
# 401 MSE train=0.3121 val=0.6371
# 402 MSE train=0.3112 val=0.6351
# 403 MSE train=0.3104 val=0.6319
# 404 MSE train=0.3095 val=0.6307
# 405 MSE train=0.3087 val=0.6276
# 406 MSE train=0.3078 val=0.6266
# 407 MSE train=0.3069 val=0.6248
# 408 MSE train=0.3060 val=0.6231
# 409 MSE train=0.3052 val=0.6197
# 410 MSE train=0.3042 val=0.6195
# 411 MSE train=0.3033 val=0.6182
# 412 MSE train=0.3026 val=0.6186
# 413 MSE train=0.3016 val=0.6150
# 414 MSE train=0.3007 val=0.6127
# 415 MSE train=0.2998 val=0.6099
# 416 MSE train=0.2990 val=0.6065
# 417 MSE train=0.2981 val=0.6048
# 418 MSE train=0.2972 val=0.6040
# 419 MSE train=0.2964 val=0.6024
# 420 MSE train=0.2955 val=0.6008
# 421 MSE train=0.2946 val=0.5986
# 422 MSE train=0.2937 val=0.5966
# 423 MSE train=0.2928 val=0.5949
# 424 MSE train=0.2920 val=0.5923
# 425 MSE train=0.2911 val=0.5905
# 426 MSE train=0.2902 val=0.5887
# 427 MSE train=0.2893 val=0.5889
# 428 MSE train=0.2885 val=0.5867
# 429 MSE train=0.2876 val=0.5840
# 430 MSE train=0.2867 val=0.5806
# 431 MSE train=0.2858 val=0.5794
# 432 MSE train=0.2850 val=0.5772
# 433 MSE train=0.2841 val=0.5752
# 434 MSE train=0.2832 val=0.5746
# 435 MSE train=0.2823 val=0.5736
# 436 MSE train=0.2815 val=0.5719
# 437 MSE train=0.2806 val=0.5699
# 438 MSE train=0.2797 val=0.5690
# 439 MSE train=0.2789 val=0.5667
# 440 MSE train=0.2780 val=0.5651
# 441 MSE train=0.2771 val=0.5649
# 442 MSE train=0.2762 val=0.5653
# 443 MSE train=0.2754 val=0.5641
# 444 MSE train=0.2745 val=0.5610
# 445 MSE train=0.2736 val=0.5606
# 446 MSE train=0.2728 val=0.5595
# 447 MSE train=0.2718 val=0.5568
# 448 MSE train=0.2710 val=0.5555
# 449 MSE train=0.2701 val=0.5520
# 450 MSE train=0.2693 val=0.5493
# 451 MSE train=0.2684 val=0.5480
# 452 MSE train=0.2675 val=0.5459
# 453 MSE train=0.2666 val=0.5444
# 454 MSE train=0.2658 val=0.5429
# 455 MSE train=0.2649 val=0.5409
# 456 MSE train=0.2640 val=0.5382
# 457 MSE train=0.2632 val=0.5378
# 458 MSE train=0.2623 val=0.5361
# 459 MSE train=0.2615 val=0.5329
# 460 MSE train=0.2606 val=0.5312
# 461 MSE train=0.2597 val=0.5279
# 462 MSE train=0.2589 val=0.5261
# 463 MSE train=0.2580 val=0.5253
# 464 MSE train=0.2572 val=0.5230
# 465 MSE train=0.2563 val=0.5220
# 466 MSE train=0.2555 val=0.5199
# 467 MSE train=0.2546 val=0.5186
# 468 MSE train=0.2538 val=0.5164
# 469 MSE train=0.2529 val=0.5157
# 470 MSE train=0.2521 val=0.5137
# 471 MSE train=0.2512 val=0.5118
# 472 MSE train=0.2504 val=0.5098
# 473 MSE train=0.2496 val=0.5081
# 474 MSE train=0.2487 val=0.5074
# 475 MSE train=0.2479 val=0.5074
# 476 MSE train=0.2471 val=0.5058
# 477 MSE train=0.2462 val=0.5048
# 478 MSE train=0.2454 val=0.5016
# 479 MSE train=0.2446 val=0.4999
# 480 MSE train=0.2437 val=0.4974
# 481 MSE train=0.2430 val=0.4949
# 482 MSE train=0.2421 val=0.4941
# 483 MSE train=0.2413 val=0.4926
# 484 MSE train=0.2405 val=0.4909
# 485 MSE train=0.2397 val=0.4889
# 486 MSE train=0.2389 val=0.4878
# 487 MSE train=0.2380 val=0.4881
# 488 MSE train=0.2372 val=0.4859
# 489 MSE train=0.2364 val=0.4832
# 490 MSE train=0.2356 val=0.4826
# 491 MSE train=0.2348 val=0.4804
# 492 MSE train=0.2339 val=0.4798
# 493 MSE train=0.2331 val=0.4791
# 494 MSE train=0.2323 val=0.4782
# 495 MSE train=0.2315 val=0.4765
# 496 MSE train=0.2307 val=0.4737
# 497 MSE train=0.2299 val=0.4710
# 498 MSE train=0.2291 val=0.4695
# 499 MSE train=0.2284 val=0.4685
# 500 MSE train=0.2275 val=0.4663
# 501 MSE train=0.2268 val=0.4647
# 502 MSE train=0.2260 val=0.4639
# 503 MSE train=0.2252 val=0.4620
# 504 MSE train=0.2244 val=0.4615
# 505 MSE train=0.2237 val=0.4596
# 506 MSE train=0.2230 val=0.4582
# 507 MSE train=0.2221 val=0.4576
# 508 MSE train=0.2213 val=0.4574
# 509 MSE train=0.2205 val=0.4558
# 510 MSE train=0.2198 val=0.4544
# 511 MSE train=0.2190 val=0.4527
# 512 MSE train=0.2182 val=0.4503
# 513 MSE train=0.2175 val=0.4486
# 514 MSE train=0.2167 val=0.4473
# 515 MSE train=0.2160 val=0.4447
# 516 MSE train=0.2152 val=0.4437
# 517 MSE train=0.2144 val=0.4428
# 518 MSE train=0.2137 val=0.4415
# 519 MSE train=0.2130 val=0.4391
# 520 MSE train=0.2123 val=0.4386
# 521 MSE train=0.2116 val=0.4376
# 522 MSE train=0.2109 val=0.4361
# 523 MSE train=0.2101 val=0.4329
# 524 MSE train=0.2093 val=0.4314
# 525 MSE train=0.2085 val=0.4297
# 526 MSE train=0.2078 val=0.4302
# 527 MSE train=0.2071 val=0.4283
# 528 MSE train=0.2064 val=0.4257
# 529 MSE train=0.2056 val=0.4247
# 530 MSE train=0.2049 val=0.4231
# 531 MSE train=0.2042 val=0.4215
# 532 MSE train=0.2035 val=0.4204
# 533 MSE train=0.2028 val=0.4186
# 534 MSE train=0.2021 val=0.4177
# 535 MSE train=0.2014 val=0.4157
# 536 MSE train=0.2007 val=0.4152
# 537 MSE train=0.2000 val=0.4129
# 538 MSE train=0.1993 val=0.4132
# 539 MSE train=0.1986 val=0.4094
# 540 MSE train=0.1979 val=0.4087
# 541 MSE train=0.1972 val=0.4058
# 542 MSE train=0.1965 val=0.4058
# 543 MSE train=0.1958 val=0.4049
# 544 MSE train=0.1952 val=0.4048
# 545 MSE train=0.1945 val=0.4027
# 546 MSE train=0.1939 val=0.4024
# 547 MSE train=0.1932 val=0.4013
# 548 MSE train=0.1925 val=0.3995
# 549 MSE train=0.1918 val=0.3977
# 550 MSE train=0.1911 val=0.3958
# 551 MSE train=0.1905 val=0.3940
# 552 MSE train=0.1898 val=0.3932
# 553 MSE train=0.1892 val=0.3922
# 554 MSE train=0.1885 val=0.3905
# 555 MSE train=0.1879 val=0.3894
# 556 MSE train=0.1872 val=0.3883
# 557 MSE train=0.1866 val=0.3853
# 558 MSE train=0.1859 val=0.3851
# 559 MSE train=0.1853 val=0.3842
# 560 MSE train=0.1846 val=0.3829
# 561 MSE train=0.1840 val=0.3819
# 562 MSE train=0.1834 val=0.3808
# 563 MSE train=0.1828 val=0.3804
# 564 MSE train=0.1821 val=0.3793
# 565 MSE train=0.1815 val=0.3787
# 566 MSE train=0.1809 val=0.3775
# 567 MSE train=0.1803 val=0.3764
# 568 MSE train=0.1797 val=0.3741
# 569 MSE train=0.1791 val=0.3731
# 570 MSE train=0.1785 val=0.3717
# 571 MSE train=0.1779 val=0.3709
# 572 MSE train=0.1773 val=0.3697
# 573 MSE train=0.1767 val=0.3676
# 574 MSE train=0.1761 val=0.3675
# 575 MSE train=0.1755 val=0.3666
# 576 MSE train=0.1749 val=0.3652
# 577 MSE train=0.1743 val=0.3645
# 578 MSE train=0.1737 val=0.3634
# 579 MSE train=0.1731 val=0.3641
# 580 MSE train=0.1725 val=0.3631
# 581 MSE train=0.1720 val=0.3623
# 582 MSE train=0.1714 val=0.3614
# 583 MSE train=0.1708 val=0.3602
# 584 MSE train=0.1703 val=0.3574
# 585 MSE train=0.1697 val=0.3561
# 586 MSE train=0.1691 val=0.3533
# 587 MSE train=0.1686 val=0.3519
# 588 MSE train=0.1680 val=0.3523
# 589 MSE train=0.1675 val=0.3510
# 590 MSE train=0.1669 val=0.3498
# 591 MSE train=0.1664 val=0.3477
# 592 MSE train=0.1658 val=0.3464
# 593 MSE train=0.1653 val=0.3444
# 594 MSE train=0.1648 val=0.3439
# 595 MSE train=0.1642 val=0.3438
# 596 MSE train=0.1637 val=0.3414
# 597 MSE train=0.1632 val=0.3406
# 598 MSE train=0.1626 val=0.3381
# 599 MSE train=0.1621 val=0.3380
# 600 MSE train=0.1616 val=0.3380
# 601 MSE train=0.1611 val=0.3375
# 602 MSE train=0.1605 val=0.3367
# 603 MSE train=0.1600 val=0.3355
# 604 MSE train=0.1595 val=0.3361
# 605 MSE train=0.1590 val=0.3362
# 606 MSE train=0.1585 val=0.3343
# 607 MSE train=0.1580 val=0.3332
# 608 MSE train=0.1575 val=0.3324
# 609 MSE train=0.1570 val=0.3293
# 610 MSE train=0.1565 val=0.3280
# 611 MSE train=0.1560 val=0.3272
# 612 MSE train=0.1555 val=0.3256
# 613 MSE train=0.1551 val=0.3241
# 614 MSE train=0.1546 val=0.3239
# 615 MSE train=0.1541 val=0.3231
# 616 MSE train=0.1536 val=0.3227
# 617 MSE train=0.1531 val=0.3227
# 618 MSE train=0.1527 val=0.3212
# 619 MSE train=0.1522 val=0.3198
# 620 MSE train=0.1517 val=0.3200
# 621 MSE train=0.1513 val=0.3189
# 622 MSE train=0.1508 val=0.3168
# 623 MSE train=0.1503 val=0.3156
# 624 MSE train=0.1499 val=0.3151
# 625 MSE train=0.1494 val=0.3131
# 626 MSE train=0.1490 val=0.3123
# 627 MSE train=0.1485 val=0.3118
# 628 MSE train=0.1481 val=0.3113
# 629 MSE train=0.1477 val=0.3119
# 630 MSE train=0.1472 val=0.3109
# 631 MSE train=0.1468 val=0.3094
# 632 MSE train=0.1463 val=0.3066
# 633 MSE train=0.1459 val=0.3059
# 634 MSE train=0.1455 val=0.3056
# 635 MSE train=0.1450 val=0.3044
# 636 MSE train=0.1446 val=0.3040
# 637 MSE train=0.1442 val=0.3043
# 638 MSE train=0.1438 val=0.3034
# 639 MSE train=0.1433 val=0.3020
# 640 MSE train=0.1429 val=0.3012
# 641 MSE train=0.1425 val=0.3002
# 642 MSE train=0.1421 val=0.2987
# 643 MSE train=0.1417 val=0.2997
# 644 MSE train=0.1413 val=0.2987
# 645 MSE train=0.1409 val=0.2967
# 646 MSE train=0.1405 val=0.2961
# 647 MSE train=0.1401 val=0.2947
# 648 MSE train=0.1397 val=0.2928
# 649 MSE train=0.1393 val=0.2919
# 650 MSE train=0.1389 val=0.2910
# 651 MSE train=0.1385 val=0.2903
# 652 MSE train=0.1381 val=0.2913
# 653 MSE train=0.1378 val=0.2902
# 654 MSE train=0.1374 val=0.2897
# 655 MSE train=0.1370 val=0.2900
# 656 MSE train=0.1367 val=0.2887
# 657 MSE train=0.1363 val=0.2859
# 658 MSE train=0.1359 val=0.2854
# 659 MSE train=0.1355 val=0.2841
# 660 MSE train=0.1351 val=0.2844
# 661 MSE train=0.1348 val=0.2830
# 662 MSE train=0.1344 val=0.2825
# 663 MSE train=0.1341 val=0.2821
# 664 MSE train=0.1337 val=0.2806
# 665 MSE train=0.1334 val=0.2797
# 666 MSE train=0.1330 val=0.2793
# 667 MSE train=0.1327 val=0.2782
# 668 MSE train=0.1323 val=0.2767
# 669 MSE train=0.1319 val=0.2766
# 670 MSE train=0.1316 val=0.2754
# 671 MSE train=0.1313 val=0.2745
# 672 MSE train=0.1309 val=0.2753
# 673 MSE train=0.1306 val=0.2742
# 674 MSE train=0.1302 val=0.2737
# 675 MSE train=0.1299 val=0.2738
# 676 MSE train=0.1296 val=0.2740
# 677 MSE train=0.1293 val=0.2722
# 678 MSE train=0.1289 val=0.2716
# 679 MSE train=0.1286 val=0.2711
# 680 MSE train=0.1283 val=0.2704
# 681 MSE train=0.1280 val=0.2702
# 682 MSE train=0.1276 val=0.2679
# 683 MSE train=0.1273 val=0.2660
# 684 MSE train=0.1270 val=0.2643
# 685 MSE train=0.1267 val=0.2656
# 686 MSE train=0.1264 val=0.2648
# 687 MSE train=0.1261 val=0.2628
# 688 MSE train=0.1258 val=0.2621
# 689 MSE train=0.1255 val=0.2622
# 690 MSE train=0.1252 val=0.2615
# 691 MSE train=0.1249 val=0.2606
# 692 MSE train=0.1246 val=0.2595
# 693 MSE train=0.1243 val=0.2594
# 694 MSE train=0.1240 val=0.2585
# 695 MSE train=0.1237 val=0.2590
# 696 MSE train=0.1234 val=0.2587
# 697 MSE train=0.1231 val=0.2578
# 698 MSE train=0.1228 val=0.2586
# 699 MSE train=0.1225 val=0.2569
# 700 MSE train=0.1223 val=0.2564
# 701 MSE train=0.1220 val=0.2569
# 702 MSE train=0.1217 val=0.2572
# 703 MSE train=0.1214 val=0.2558
# 704 MSE train=0.1211 val=0.2542
# 705 MSE train=0.1209 val=0.2549
# 706 MSE train=0.1206 val=0.2536
# 707 MSE train=0.1204 val=0.2516
# 708 MSE train=0.1201 val=0.2502
# 709 MSE train=0.1198 val=0.2511
# 710 MSE train=0.1195 val=0.2516
# 711 MSE train=0.1193 val=0.2499
# 712 MSE train=0.1190 val=0.2488
# 713 MSE train=0.1187 val=0.2489
# 714 MSE train=0.1185 val=0.2467
# 715 MSE train=0.1182 val=0.2462
# 716 MSE train=0.1180 val=0.2459
# 717 MSE train=0.1177 val=0.2447
# 718 MSE train=0.1175 val=0.2444
# 719 MSE train=0.1173 val=0.2444
# 720 MSE train=0.1170 val=0.2448
# 721 MSE train=0.1168 val=0.2435
# 722 MSE train=0.1165 val=0.2427
# 723 MSE train=0.1163 val=0.2411
# 724 MSE train=0.1160 val=0.2384
# 725 MSE train=0.1158 val=0.2394
# 726 MSE train=0.1155 val=0.2402
# 727 MSE train=0.1153 val=0.2395
# 728 MSE train=0.1151 val=0.2379
# 729 MSE train=0.1148 val=0.2385
# 730 MSE train=0.1146 val=0.2375
# 731 MSE train=0.1144 val=0.2382
# 732 MSE train=0.1142 val=0.2364
# 733 MSE train=0.1139 val=0.2356
# 734 MSE train=0.1137 val=0.2361
# 735 MSE train=0.1135 val=0.2358
# 736 MSE train=0.1133 val=0.2343
# 737 MSE train=0.1131 val=0.2335
# 738 MSE train=0.1129 val=0.2341
# 739 MSE train=0.1126 val=0.2328
# 740 MSE train=0.1124 val=0.2313
# 741 MSE train=0.1122 val=0.2295
# 742 MSE train=0.1120 val=0.2306
# 743 MSE train=0.1118 val=0.2292
# 744 MSE train=0.1116 val=0.2286
# 745 MSE train=0.1113 val=0.2290
# 746 MSE train=0.1111 val=0.2286
# 747 MSE train=0.1109 val=0.2282
# 748 MSE train=0.1107 val=0.2274
# 749 MSE train=0.1105 val=0.2266
# 750 MSE train=0.1103 val=0.2265
# 751 MSE train=0.1101 val=0.2266
# 752 MSE train=0.1099 val=0.2260
# 753 MSE train=0.1097 val=0.2264
# 754 MSE train=0.1096 val=0.2247
# 755 MSE train=0.1094 val=0.2234
# 756 MSE train=0.1092 val=0.2222
# 757 MSE train=0.1090 val=0.2224
# 758 MSE train=0.1088 val=0.2237
# 759 MSE train=0.1086 val=0.2225
# 760 MSE train=0.1084 val=0.2226
# 761 MSE train=0.1082 val=0.2212
# 762 MSE train=0.1081 val=0.2196
# 763 MSE train=0.1079 val=0.2186
# 764 MSE train=0.1077 val=0.2203
# 765 MSE train=0.1075 val=0.2203
# 766 MSE train=0.1073 val=0.2207
# 767 MSE train=0.1071 val=0.2185
# 768 MSE train=0.1070 val=0.2188
# 769 MSE train=0.1068 val=0.2180
# 770 MSE train=0.1066 val=0.2166
# 771 MSE train=0.1064 val=0.2166
# 772 MSE train=0.1063 val=0.2163
# 773 MSE train=0.1061 val=0.2148
# 774 MSE train=0.1060 val=0.2151
# 775 MSE train=0.1058 val=0.2155
# 776 MSE train=0.1056 val=0.2157
# 777 MSE train=0.1054 val=0.2138
# 778 MSE train=0.1053 val=0.2130
# 779 MSE train=0.1051 val=0.2131
# 780 MSE train=0.1049 val=0.2139
# 781 MSE train=0.1048 val=0.2134
# 782 MSE train=0.1046 val=0.2112
# 783 MSE train=0.1045 val=0.2118
# 784 MSE train=0.1043 val=0.2117
# 785 MSE train=0.1042 val=0.2111
# 786 MSE train=0.1040 val=0.2107
# 787 MSE train=0.1038 val=0.2096
# 788 MSE train=0.1037 val=0.2098
# 789 MSE train=0.1036 val=0.2092
# 790 MSE train=0.1034 val=0.2085
# 791 MSE train=0.1033 val=0.2081
# 792 MSE train=0.1031 val=0.2087
# 793 MSE train=0.1029 val=0.2083
# 794 MSE train=0.1028 val=0.2072
# 795 MSE train=0.1027 val=0.2064
# 796 MSE train=0.1025 val=0.2061
# 797 MSE train=0.1024 val=0.2054
# 798 MSE train=0.1022 val=0.2047
# 799 MSE train=0.1021 val=0.2049
# 800 MSE train=0.1019 val=0.2043
# 801 MSE train=0.1018 val=0.2033
# 802 MSE train=0.1017 val=0.2031
# 803 MSE train=0.1015 val=0.2032
# 804 MSE train=0.1014 val=0.2033
# 805 MSE train=0.1013 val=0.2024
# 806 MSE train=0.1011 val=0.2020
# 807 MSE train=0.1010 val=0.2021
# 808 MSE train=0.1009 val=0.2020
# 809 MSE train=0.1007 val=0.2015
# 810 MSE train=0.1006 val=0.2018
# 811 MSE train=0.1005 val=0.2001
# 812 MSE train=0.1004 val=0.1995
# 813 MSE train=0.1002 val=0.1996
# 814 MSE train=0.1001 val=0.1995
# 815 MSE train=0.1000 val=0.2003
# 816 MSE train=0.0999 val=0.1976
# 817 MSE train=0.0997 val=0.1992
# 818 MSE train=0.0996 val=0.1984
# 819 MSE train=0.0995 val=0.1964
# 820 MSE train=0.0994 val=0.1981
# 821 MSE train=0.0992 val=0.1968
# 822 MSE train=0.0991 val=0.1968
# 823 MSE train=0.0990 val=0.1983
# 824 MSE train=0.0989 val=0.1970
# 825 MSE train=0.0988 val=0.1961
# 826 MSE train=0.0987 val=0.1958
# 827 MSE train=0.0985 val=0.1940
# 828 MSE train=0.0984 val=0.1929
# 829 MSE train=0.0983 val=0.1928
# 830 MSE train=0.0982 val=0.1933
# 831 MSE train=0.0981 val=0.1921
# 832 MSE train=0.0980 val=0.1918
# 833 MSE train=0.0979 val=0.1919
# 834 MSE train=0.0978 val=0.1907
# 835 MSE train=0.0977 val=0.1909
# 836 MSE train=0.0975 val=0.1903
# 837 MSE train=0.0974 val=0.1911
# 838 MSE train=0.0973 val=0.1912
# 839 MSE train=0.0972 val=0.1911
# 840 MSE train=0.0971 val=0.1905
# 841 MSE train=0.0970 val=0.1892
# 842 MSE train=0.0969 val=0.1884
# 843 MSE train=0.0968 val=0.1882
# 844 MSE train=0.0967 val=0.1891
# 845 MSE train=0.0966 val=0.1889
# 846 MSE train=0.0965 val=0.1888
# 847 MSE train=0.0964 val=0.1901
# 848 MSE train=0.0964 val=0.1904
# 849 MSE train=0.0962 val=0.1892
# 850 MSE train=0.0961 val=0.1899
# 851 MSE train=0.0960 val=0.1890
# 852 MSE train=0.0959 val=0.1888
# 853 MSE train=0.0958 val=0.1877
# 854 MSE train=0.0957 val=0.1865
# 855 MSE train=0.0956 val=0.1855
# 856 MSE train=0.0955 val=0.1860
# 857 MSE train=0.0955 val=0.1861
# 858 MSE train=0.0954 val=0.1852
# 859 MSE train=0.0953 val=0.1849
# 860 MSE train=0.0953 val=0.1846
# 861 MSE train=0.0951 val=0.1846
# 862 MSE train=0.0950 val=0.1846
# 863 MSE train=0.0949 val=0.1843
# 864 MSE train=0.0949 val=0.1833
# 865 MSE train=0.0948 val=0.1811
# 866 MSE train=0.0947 val=0.1807
# 867 MSE train=0.0946 val=0.1814
# 868 MSE train=0.0945 val=0.1818
# 869 MSE train=0.0944 val=0.1804
# 870 MSE train=0.0943 val=0.1819
# 871 MSE train=0.0942 val=0.1819
# 872 MSE train=0.0941 val=0.1811
# 873 MSE train=0.0940 val=0.1814
# 874 MSE train=0.0940 val=0.1820
# 875 MSE train=0.0939 val=0.1822
# 876 MSE train=0.0938 val=0.1822
# 877 MSE train=0.0937 val=0.1807
# 878 MSE train=0.0937 val=0.1797
# 879 MSE train=0.0936 val=0.1782
# 880 MSE train=0.0935 val=0.1755
# 881 MSE train=0.0934 val=0.1763
# 882 MSE train=0.0933 val=0.1780
# 883 MSE train=0.0933 val=0.1771
# 884 MSE train=0.0932 val=0.1783
# 885 MSE train=0.0931 val=0.1796
# 886 MSE train=0.0930 val=0.1783
# 887 MSE train=0.0930 val=0.1766
# 888 MSE train=0.0929 val=0.1767
# 889 MSE train=0.0928 val=0.1755
# 890 MSE train=0.0927 val=0.1754
# 891 MSE train=0.0927 val=0.1743
# 892 MSE train=0.0926 val=0.1754
# 893 MSE train=0.0925 val=0.1765
# 894 MSE train=0.0924 val=0.1761
# 895 MSE train=0.0924 val=0.1768
# 896 MSE train=0.0923 val=0.1766
# 897 MSE train=0.0922 val=0.1762
# 898 MSE train=0.0922 val=0.1747
# 899 MSE train=0.0921 val=0.1750
# 900 MSE train=0.0920 val=0.1748
# 901 MSE train=0.0920 val=0.1750
# 902 MSE train=0.0919 val=0.1741
# 903 MSE train=0.0918 val=0.1730
# 904 MSE train=0.0918 val=0.1721
# 905 MSE train=0.0917 val=0.1731
# 906 MSE train=0.0916 val=0.1734
# 907 MSE train=0.0915 val=0.1732
# 908 MSE train=0.0915 val=0.1727
# 909 MSE train=0.0915 val=0.1722
# 910 MSE train=0.0914 val=0.1709
# 911 MSE train=0.0913 val=0.1702
# 912 MSE train=0.0913 val=0.1703
# 913 MSE train=0.0912 val=0.1704
# 914 MSE train=0.0911 val=0.1703
# 915 MSE train=0.0910 val=0.1704
# 916 MSE train=0.0910 val=0.1697
# 917 MSE train=0.0909 val=0.1688
# 918 MSE train=0.0909 val=0.1694
# 919 MSE train=0.0908 val=0.1689
# 920 MSE train=0.0907 val=0.1683
# 921 MSE train=0.0907 val=0.1674
# 922 MSE train=0.0906 val=0.1688
# 923 MSE train=0.0906 val=0.1688
# 924 MSE train=0.0905 val=0.1680
# 925 MSE train=0.0904 val=0.1696
# 926 MSE train=0.0904 val=0.1701
# 927 MSE train=0.0903 val=0.1695
# 928 MSE train=0.0903 val=0.1702
# 929 MSE train=0.0902 val=0.1699
# 930 MSE train=0.0902 val=0.1686
# 931 MSE train=0.0901 val=0.1669
# 932 MSE train=0.0901 val=0.1660
# 933 MSE train=0.0900 val=0.1662
# 934 MSE train=0.0899 val=0.1674
# 935 MSE train=0.0899 val=0.1654
# 936 MSE train=0.0898 val=0.1667
# 937 MSE train=0.0898 val=0.1665
# 938 MSE train=0.0897 val=0.1668
# 939 MSE train=0.0897 val=0.1665
# 940 MSE train=0.0896 val=0.1655
# 941 MSE train=0.0896 val=0.1668
# 942 MSE train=0.0895 val=0.1668
# 943 MSE train=0.0895 val=0.1658
# 944 MSE train=0.0894 val=0.1643
# 945 MSE train=0.0894 val=0.1639
# 946 MSE train=0.0893 val=0.1657
# 947 MSE train=0.0893 val=0.1659
# 948 MSE train=0.0892 val=0.1656
# 949 MSE train=0.0892 val=0.1646
# 950 MSE train=0.0891 val=0.1642
# 951 MSE train=0.0891 val=0.1649
# 952 MSE train=0.0890 val=0.1644
# 953 MSE train=0.0890 val=0.1628
# 954 MSE train=0.0889 val=0.1618
# 955 MSE train=0.0889 val=0.1628
# 956 MSE train=0.0888 val=0.1615
# 957 MSE train=0.0888 val=0.1612
# 958 MSE train=0.0888 val=0.1608
# 959 MSE train=0.0887 val=0.1622
# 960 MSE train=0.0886 val=0.1632
# 961 MSE train=0.0886 val=0.1625
# 962 MSE train=0.0886 val=0.1612
# 963 MSE train=0.0885 val=0.1604
# 964 MSE train=0.0884 val=0.1609
# 965 MSE train=0.0884 val=0.1608
# 966 MSE train=0.0884 val=0.1610
# 967 MSE train=0.0883 val=0.1607
# 968 MSE train=0.0883 val=0.1594
# 969 MSE train=0.0882 val=0.1603
# 970 MSE train=0.0882 val=0.1598
# 971 MSE train=0.0881 val=0.1599
# 972 MSE train=0.0881 val=0.1603
# 973 MSE train=0.0881 val=0.1605
# 974 MSE train=0.0880 val=0.1611
# 975 MSE train=0.0880 val=0.1610
# 976 MSE train=0.0879 val=0.1598
# 977 MSE train=0.0879 val=0.1587
# 978 MSE train=0.0878 val=0.1591
# 979 MSE train=0.0878 val=0.1596
# 980 MSE train=0.0878 val=0.1580
# 981 MSE train=0.0877 val=0.1588
# 982 MSE train=0.0877 val=0.1591
# 983 MSE train=0.0876 val=0.1585
# 984 MSE train=0.0876 val=0.1596
# 985 MSE train=0.0875 val=0.1588
# 986 MSE train=0.0875 val=0.1575
# 987 MSE train=0.0875 val=0.1578
# 988 MSE train=0.0874 val=0.1576
# 989 MSE train=0.0874 val=0.1564
# 990 MSE train=0.0874 val=0.1562
# 991 MSE train=0.0873 val=0.1577
# 992 MSE train=0.0873 val=0.1569
# 993 MSE train=0.0873 val=0.1579
# 994 MSE train=0.0872 val=0.1566
# 995 MSE train=0.0872 val=0.1564
# 996 MSE train=0.0871 val=0.1572
# 997 MSE train=0.0871 val=0.1566
# 998 MSE train=0.0871 val=0.1584
# 999 MSE train=0.0870 val=0.1567
# 1000 MSE train=0.0870 val=0.1549
# 1001 MSE train=0.0869 val=0.1551
# 1002 MSE train=0.0869 val=0.1557
# 1003 MSE train=0.0869 val=0.1562
# 1004 MSE train=0.0868 val=0.1567
# 1005 MSE train=0.0868 val=0.1550
# 1006 MSE train=0.0867 val=0.1548
# 1007 MSE train=0.0867 val=0.1555
# 1008 MSE train=0.0867 val=0.1557
# 1009 MSE train=0.0866 val=0.1557
# 1010 MSE train=0.0866 val=0.1559
# 1011 MSE train=0.0866 val=0.1552
# 1012 MSE train=0.0865 val=0.1556
# 1013 MSE train=0.0865 val=0.1540
# 1014 MSE train=0.0865 val=0.1528
# 1015 MSE train=0.0864 val=0.1541
# 1016 MSE train=0.0864 val=0.1544
# 1017 MSE train=0.0864 val=0.1545
# 1018 MSE train=0.0863 val=0.1537
# 1019 MSE train=0.0863 val=0.1544
# 1020 MSE train=0.0863 val=0.1537
# 1021 MSE train=0.0862 val=0.1527
# 1022 MSE train=0.0862 val=0.1535
# 1023 MSE train=0.0862 val=0.1528
# 1024 MSE train=0.0861 val=0.1539
# 1025 MSE train=0.0861 val=0.1532
# 1026 MSE train=0.0861 val=0.1535
# 1027 MSE train=0.0861 val=0.1532
# 1028 MSE train=0.0860 val=0.1522
# 1029 MSE train=0.0860 val=0.1524
# 1030 MSE train=0.0860 val=0.1516
# 1031 MSE train=0.0859 val=0.1530
# 1032 MSE train=0.0859 val=0.1536
# 1033 MSE train=0.0859 val=0.1509
# 1034 MSE train=0.0859 val=0.1512
# 1035 MSE train=0.0858 val=0.1514
# 1036 MSE train=0.0858 val=0.1506
# 1037 MSE train=0.0858 val=0.1512
# 1038 MSE train=0.0857 val=0.1511
# 1039 MSE train=0.0857 val=0.1524
# 1040 MSE train=0.0857 val=0.1528
# 1041 MSE train=0.0856 val=0.1512
# 1042 MSE train=0.0856 val=0.1499
# 1043 MSE train=0.0856 val=0.1496
# 1044 MSE train=0.0855 val=0.1487
# 1045 MSE train=0.0855 val=0.1492
# 1046 MSE train=0.0855 val=0.1493
# 1047 MSE train=0.0854 val=0.1500
# 1048 MSE train=0.0854 val=0.1506
# 1049 MSE train=0.0854 val=0.1497
# 1050 MSE train=0.0853 val=0.1500
# 1051 MSE train=0.0853 val=0.1513
# 1052 MSE train=0.0853 val=0.1497
# 1053 MSE train=0.0853 val=0.1495
# 1054 MSE train=0.0852 val=0.1508
# 1055 MSE train=0.0852 val=0.1495
# 1056 MSE train=0.0852 val=0.1489
# 1057 MSE train=0.0852 val=0.1497
# 1058 MSE train=0.0851 val=0.1499
# 1059 MSE train=0.0851 val=0.1497
# 1060 MSE train=0.0851 val=0.1497
# 1061 MSE train=0.0850 val=0.1491
# 1062 MSE train=0.0850 val=0.1499
# 1063 MSE train=0.0850 val=0.1483
# 1064 MSE train=0.0850 val=0.1464
# 1065 MSE train=0.0849 val=0.1475
# 1066 MSE train=0.0849 val=0.1484
# 1067 MSE train=0.0849 val=0.1468
# 1068 MSE train=0.0848 val=0.1476
# 1069 MSE train=0.0848 val=0.1485
# 1070 MSE train=0.0848 val=0.1483
# 1071 MSE train=0.0848 val=0.1481
# 1072 MSE train=0.0848 val=0.1491
# 1073 MSE train=0.0847 val=0.1479
# 1074 MSE train=0.0847 val=0.1489
# 1075 MSE train=0.0847 val=0.1475
# 1076 MSE train=0.0847 val=0.1486
# 1077 MSE train=0.0846 val=0.1482
# 1078 MSE train=0.0846 val=0.1460
# 1079 MSE train=0.0846 val=0.1466
# 1080 MSE train=0.0846 val=0.1474
# 1081 MSE train=0.0845 val=0.1484
# 1082 MSE train=0.0845 val=0.1469
# 1083 MSE train=0.0845 val=0.1462
# 1084 MSE train=0.0845 val=0.1447
# 1085 MSE train=0.0845 val=0.1441
# 1086 MSE train=0.0844 val=0.1453
# 1087 MSE train=0.0844 val=0.1458
# 1088 MSE train=0.0843 val=0.1460
# 1089 MSE train=0.0843 val=0.1458
# 1090 MSE train=0.0843 val=0.1448
# 1091 MSE train=0.0843 val=0.1456
# 1092 MSE train=0.0842 val=0.1447
# 1093 MSE train=0.0842 val=0.1451
# 1094 MSE train=0.0842 val=0.1440
# 1095 MSE train=0.0842 val=0.1464
# 1096 MSE train=0.0842 val=0.1465
# 1097 MSE train=0.0841 val=0.1460
# 1098 MSE train=0.0841 val=0.1453
# 1099 MSE train=0.0841 val=0.1444
# 1100 MSE train=0.0841 val=0.1436
# 1101 MSE train=0.0840 val=0.1439
# 1102 MSE train=0.0840 val=0.1436
# 1103 MSE train=0.0840 val=0.1427
# 1104 MSE train=0.0840 val=0.1420
# 1105 MSE train=0.0839 val=0.1442
# 1106 MSE train=0.0839 val=0.1441
# 1107 MSE train=0.0839 val=0.1455
# 1108 MSE train=0.0839 val=0.1430
# 1109 MSE train=0.0839 val=0.1437
# 1110 MSE train=0.0838 val=0.1434
# 1111 MSE train=0.0838 val=0.1441
# 1112 MSE train=0.0838 val=0.1430
# 1113 MSE train=0.0838 val=0.1423
# 1114 MSE train=0.0837 val=0.1441
# 1115 MSE train=0.0837 val=0.1438
# 1116 MSE train=0.0837 val=0.1432
# 1117 MSE train=0.0837 val=0.1448
# 1118 MSE train=0.0837 val=0.1453
# 1119 MSE train=0.0837 val=0.1446
# 1120 MSE train=0.0836 val=0.1433
# 1121 MSE train=0.0836 val=0.1423
# 1122 MSE train=0.0836 val=0.1425
# 1123 MSE train=0.0835 val=0.1424
# 1124 MSE train=0.0835 val=0.1426
# 1125 MSE train=0.0835 val=0.1428
# 1126 MSE train=0.0835 val=0.1418
# 1127 MSE train=0.0835 val=0.1422
# 1128 MSE train=0.0835 val=0.1406
# 1129 MSE train=0.0834 val=0.1409
# 1130 MSE train=0.0834 val=0.1412
# 1131 MSE train=0.0834 val=0.1412
# 1132 MSE train=0.0834 val=0.1435
# 1133 MSE train=0.0833 val=0.1419
# 1134 MSE train=0.0833 val=0.1414
# 1135 MSE train=0.0833 val=0.1417
# 1136 MSE train=0.0833 val=0.1431
# 1137 MSE train=0.0832 val=0.1421
# 1138 MSE train=0.0833 val=0.1410
# 1139 MSE train=0.0832 val=0.1406
# 1140 MSE train=0.0832 val=0.1401
# 1141 MSE train=0.0832 val=0.1402
# 1142 MSE train=0.0832 val=0.1398
# 1143 MSE train=0.0832 val=0.1391
# 1144 MSE train=0.0831 val=0.1391
# 1145 MSE train=0.0831 val=0.1380
# 1146 MSE train=0.0831 val=0.1378
# 1147 MSE train=0.0831 val=0.1381
# 1148 MSE train=0.0830 val=0.1389
# 1149 MSE train=0.0830 val=0.1388
# 1150 MSE train=0.0830 val=0.1400
# 1151 MSE train=0.0830 val=0.1399
# 1152 MSE train=0.0830 val=0.1407
# 1153 MSE train=0.0829 val=0.1410
# 1154 MSE train=0.0829 val=0.1393
# 1155 MSE train=0.0829 val=0.1390
# 1156 MSE train=0.0829 val=0.1403
# 1157 MSE train=0.0829 val=0.1416
# 1158 MSE train=0.0828 val=0.1410
# 1159 MSE train=0.0828 val=0.1412
# 1160 MSE train=0.0828 val=0.1409
# 1161 MSE train=0.0828 val=0.1412
# 1162 MSE train=0.0828 val=0.1404
# 1163 MSE train=0.0827 val=0.1414
# 1164 MSE train=0.0827 val=0.1410
# 1165 MSE train=0.0827 val=0.1405
# 1166 MSE train=0.0827 val=0.1398
# 1167 MSE train=0.0827 val=0.1398
# 1168 MSE train=0.0827 val=0.1402
# 1169 MSE train=0.0826 val=0.1389
# 1170 MSE train=0.0826 val=0.1400
# 1171 MSE train=0.0826 val=0.1391
# 1172 MSE train=0.0826 val=0.1384
# 1173 MSE train=0.0826 val=0.1405
# 1174 MSE train=0.0825 val=0.1395
# 1175 MSE train=0.0825 val=0.1394
# 1176 MSE train=0.0825 val=0.1395
# 1177 MSE train=0.0825 val=0.1395
# 1178 MSE train=0.0825 val=0.1384
# 1179 MSE train=0.0824 val=0.1387
# 1180 MSE train=0.0824 val=0.1381
# 1181 MSE train=0.0824 val=0.1382
# 1182 MSE train=0.0824 val=0.1381
# 1183 MSE train=0.0824 val=0.1385
# 1184 MSE train=0.0824 val=0.1375
# 1185 MSE train=0.0823 val=0.1380
# 1186 MSE train=0.0823 val=0.1375
# 1187 MSE train=0.0823 val=0.1368
# 1188 MSE train=0.0823 val=0.1388
# 1189 MSE train=0.0823 val=0.1379
# 1190 MSE train=0.0823 val=0.1386
# 1191 MSE train=0.0822 val=0.1379
# 1192 MSE train=0.0822 val=0.1385
# 1193 MSE train=0.0822 val=0.1404
# 1194 MSE train=0.0822 val=0.1393
# 1195 MSE train=0.0822 val=0.1374
# 1196 MSE train=0.0821 val=0.1384
# 1197 MSE train=0.0821 val=0.1383
# 1198 MSE train=0.0821 val=0.1366
# 1199 MSE train=0.0821 val=0.1361
# 1200 MSE train=0.0821 val=0.1367
# 1201 MSE train=0.0821 val=0.1367
# 1202 MSE train=0.0820 val=0.1363
# 1203 MSE train=0.0820 val=0.1361
# 1204 MSE train=0.0820 val=0.1367
# 1205 MSE train=0.0820 val=0.1365
# 1206 MSE train=0.0820 val=0.1365
# 1207 MSE train=0.0820 val=0.1381
# 1208 MSE train=0.0819 val=0.1379
# 1209 MSE train=0.0819 val=0.1387
# 1210 MSE train=0.0819 val=0.1377
# 1211 MSE train=0.0819 val=0.1391
# 1212 MSE train=0.0819 val=0.1390
# 1213 MSE train=0.0818 val=0.1364
# 1214 MSE train=0.0818 val=0.1369
# 1215 MSE train=0.0819 val=0.1360
# 1216 MSE train=0.0818 val=0.1368
# 1217 MSE train=0.0818 val=0.1354
# 1218 MSE train=0.0818 val=0.1340
# 1219 MSE train=0.0818 val=0.1351
# 1220 MSE train=0.0817 val=0.1349
# 1221 MSE train=0.0817 val=0.1345
# 1222 MSE train=0.0817 val=0.1353
# 1223 MSE train=0.0817 val=0.1361
# 1224 MSE train=0.0817 val=0.1345
# 1225 MSE train=0.0817 val=0.1343
# 1226 MSE train=0.0816 val=0.1347
# 1227 MSE train=0.0816 val=0.1360
# 1228 MSE train=0.0816 val=0.1358
# 1229 MSE train=0.0816 val=0.1346
# 1230 MSE train=0.0816 val=0.1344
# 1231 MSE train=0.0816 val=0.1332
# 1232 MSE train=0.0816 val=0.1336
# 1233 MSE train=0.0815 val=0.1335
# 1234 MSE train=0.0815 val=0.1342
# 1235 MSE train=0.0815 val=0.1340
# 1236 MSE train=0.0815 val=0.1336
# 1237 MSE train=0.0815 val=0.1355
# 1238 MSE train=0.0814 val=0.1345
# 1239 MSE train=0.0814 val=0.1348
# 1240 MSE train=0.0815 val=0.1337
# 1241 MSE train=0.0814 val=0.1343
# 1242 MSE train=0.0814 val=0.1342
# 1243 MSE train=0.0814 val=0.1343
# 1244 MSE train=0.0814 val=0.1337
# 1245 MSE train=0.0813 val=0.1338
# 1246 MSE train=0.0813 val=0.1328
# 1247 MSE train=0.0813 val=0.1333
# 1248 MSE train=0.0813 val=0.1347
# 1249 MSE train=0.0813 val=0.1354
# 1250 MSE train=0.0813 val=0.1358
# 1251 MSE train=0.0813 val=0.1359
# 1252 MSE train=0.0813 val=0.1358
# 1253 MSE train=0.0813 val=0.1366
# 1254 MSE train=0.0812 val=0.1358
# 1255 MSE train=0.0812 val=0.1360
# 1256 MSE train=0.0812 val=0.1334
# 1257 MSE train=0.0812 val=0.1324
# 1258 MSE train=0.0811 val=0.1326
# 1259 MSE train=0.0811 val=0.1321
# 1260 MSE train=0.0811 val=0.1323
# 1261 MSE train=0.0811 val=0.1330
# 1262 MSE train=0.0811 val=0.1335
# 1263 MSE train=0.0811 val=0.1327
# 1264 MSE train=0.0810 val=0.1326
# 1265 MSE train=0.0810 val=0.1346
# 1266 MSE train=0.0810 val=0.1328
# 1267 MSE train=0.0810 val=0.1331
# 1268 MSE train=0.0810 val=0.1318
# 1269 MSE train=0.0810 val=0.1315
# 1270 MSE train=0.0810 val=0.1335
# 1271 MSE train=0.0809 val=0.1327
# 1272 MSE train=0.0810 val=0.1316
# 1273 MSE train=0.0809 val=0.1323
# 1274 MSE train=0.0809 val=0.1329
# 1275 MSE train=0.0809 val=0.1336
# 1276 MSE train=0.0809 val=0.1330
# 1277 MSE train=0.0809 val=0.1329
# 1278 MSE train=0.0809 val=0.1345
# 1279 MSE train=0.0808 val=0.1344
# 1280 MSE train=0.0808 val=0.1338
# 1281 MSE train=0.0808 val=0.1343
# 1282 MSE train=0.0808 val=0.1327
# 1283 MSE train=0.0808 val=0.1322
# 1284 MSE train=0.0807 val=0.1323
# 1285 MSE train=0.0807 val=0.1329
# 1286 MSE train=0.0807 val=0.1329
# 1287 MSE train=0.0807 val=0.1330
# 1288 MSE train=0.0807 val=0.1317
# 1289 MSE train=0.0807 val=0.1324
# 1290 MSE train=0.0807 val=0.1330
# 1291 MSE train=0.0807 val=0.1338
# 1292 MSE train=0.0806 val=0.1320
# 1293 MSE train=0.0806 val=0.1313
# 1294 MSE train=0.0806 val=0.1313
# 1295 MSE train=0.0806 val=0.1329
# 1296 MSE train=0.0806 val=0.1323
# 1297 MSE train=0.0806 val=0.1325
# 1298 MSE train=0.0805 val=0.1312
# 1299 MSE train=0.0805 val=0.1317
# 1300 MSE train=0.0805 val=0.1308
# 1301 MSE train=0.0805 val=0.1320
# 1302 MSE train=0.0805 val=0.1316
# 1303 MSE train=0.0805 val=0.1324
# 1304 MSE train=0.0805 val=0.1322
# 1305 MSE train=0.0804 val=0.1314
# 1306 MSE train=0.0804 val=0.1320
# 1307 MSE train=0.0804 val=0.1301
# 1308 MSE train=0.0804 val=0.1308
# 1309 MSE train=0.0804 val=0.1323
# 1310 MSE train=0.0804 val=0.1320
# 1311 MSE train=0.0804 val=0.1296
# 1312 MSE train=0.0804 val=0.1296
# 1313 MSE train=0.0803 val=0.1300
# 1314 MSE train=0.0803 val=0.1298
# 1315 MSE train=0.0803 val=0.1302
# 1316 MSE train=0.0803 val=0.1298
# 1317 MSE train=0.0803 val=0.1303
# 1318 MSE train=0.0803 val=0.1290
# 1319 MSE train=0.0802 val=0.1304
# 1320 MSE train=0.0802 val=0.1296
# 1321 MSE train=0.0802 val=0.1294
# 1322 MSE train=0.0802 val=0.1308
# 1323 MSE train=0.0802 val=0.1301
# 1324 MSE train=0.0802 val=0.1311
# 1325 MSE train=0.0802 val=0.1314
# 1326 MSE train=0.0802 val=0.1318
# 1327 MSE train=0.0802 val=0.1317
# 1328 MSE train=0.0801 val=0.1314
# 1329 MSE train=0.0801 val=0.1303
# 1330 MSE train=0.0801 val=0.1316
# 1331 MSE train=0.0801 val=0.1305
# 1332 MSE train=0.0801 val=0.1295
# 1333 MSE train=0.0801 val=0.1285
# 1334 MSE train=0.0800 val=0.1291
# 1335 MSE train=0.0800 val=0.1302
# 1336 MSE train=0.0800 val=0.1321
# 1337 MSE train=0.0800 val=0.1303
# 1338 MSE train=0.0800 val=0.1299
# 1339 MSE train=0.0800 val=0.1293
# 1340 MSE train=0.0800 val=0.1287
# 1341 MSE train=0.0800 val=0.1282
# 1342 MSE train=0.0799 val=0.1297
# 1343 MSE train=0.0799 val=0.1284
# 1344 MSE train=0.0799 val=0.1290
# 1345 MSE train=0.0799 val=0.1295
# 1346 MSE train=0.0799 val=0.1315
# 1347 MSE train=0.0799 val=0.1298
# 1348 MSE train=0.0799 val=0.1320
# 1349 MSE train=0.0799 val=0.1308
# 1350 MSE train=0.0798 val=0.1288
# 1351 MSE train=0.0798 val=0.1293
# 1352 MSE train=0.0798 val=0.1312
# 1353 MSE train=0.0798 val=0.1306
# 1354 MSE train=0.0798 val=0.1287
# 1355 MSE train=0.0797 val=0.1286
# 1356 MSE train=0.0797 val=0.1295
# 1357 MSE train=0.0797 val=0.1301
# 1358 MSE train=0.0797 val=0.1278
# 1359 MSE train=0.0797 val=0.1286
# 1360 MSE train=0.0798 val=0.1267
# 1361 MSE train=0.0797 val=0.1268
# 1362 MSE train=0.0797 val=0.1270
# 1363 MSE train=0.0797 val=0.1275
# 1364 MSE train=0.0796 val=0.1287
# 1365 MSE train=0.0796 val=0.1302
# 1366 MSE train=0.0796 val=0.1296
# 1367 MSE train=0.0796 val=0.1307
# 1368 MSE train=0.0796 val=0.1300
# 1369 MSE train=0.0796 val=0.1285
# 1370 MSE train=0.0795 val=0.1281
# 1371 MSE train=0.0796 val=0.1272
# 1372 MSE train=0.0795 val=0.1285
# 1373 MSE train=0.0796 val=0.1283
# 1374 MSE train=0.0795 val=0.1306
# 1375 MSE train=0.0795 val=0.1300
# 1376 MSE train=0.0795 val=0.1290
# 1377 MSE train=0.0795 val=0.1307
# 1378 MSE train=0.0795 val=0.1306
# 1379 MSE train=0.0794 val=0.1288
# 1380 MSE train=0.0794 val=0.1266
# 1381 MSE train=0.0794 val=0.1270
# 1382 MSE train=0.0794 val=0.1277
# 1383 MSE train=0.0794 val=0.1275
# 1384 MSE train=0.0794 val=0.1273
# 1385 MSE train=0.0794 val=0.1273
# 1386 MSE train=0.0793 val=0.1281
# 1387 MSE train=0.0793 val=0.1298
# 1388 MSE train=0.0793 val=0.1287
# 1389 MSE train=0.0793 val=0.1266
# 1390 MSE train=0.0793 val=0.1271
# 1391 MSE train=0.0793 val=0.1279
# 1392 MSE train=0.0793 val=0.1281
# 1393 MSE train=0.0793 val=0.1273
# 1394 MSE train=0.0793 val=0.1270
# 1395 MSE train=0.0792 val=0.1291
# 1396 MSE train=0.0792 val=0.1288
# 1397 MSE train=0.0792 val=0.1289
# 1398 MSE train=0.0792 val=0.1292
# 1399 MSE train=0.0792 val=0.1274
# 1400 MSE train=0.0792 val=0.1270
# 1401 MSE train=0.0792 val=0.1269
# 1402 MSE train=0.0791 val=0.1285
# 1403 MSE train=0.0791 val=0.1280
# 1404 MSE train=0.0791 val=0.1293
# 1405 MSE train=0.0791 val=0.1269
# 1406 MSE train=0.0791 val=0.1259
# 1407 MSE train=0.0791 val=0.1271
# 1408 MSE train=0.0791 val=0.1257
# 1409 MSE train=0.0790 val=0.1272
# 1410 MSE train=0.0791 val=0.1285
# 1411 MSE train=0.0790 val=0.1263
# 1412 MSE train=0.0790 val=0.1271
# 1413 MSE train=0.0790 val=0.1275
# 1414 MSE train=0.0790 val=0.1287
# 1415 MSE train=0.0790 val=0.1285
# 1416 MSE train=0.0790 val=0.1275
# 1417 MSE train=0.0790 val=0.1259
# 1418 MSE train=0.0789 val=0.1262
# 1419 MSE train=0.0790 val=0.1244
# 1420 MSE train=0.0789 val=0.1259
# 1421 MSE train=0.0789 val=0.1265
# 1422 MSE train=0.0789 val=0.1264
# 1423 MSE train=0.0789 val=0.1268
# 1424 MSE train=0.0789 val=0.1279
# 1425 MSE train=0.0788 val=0.1268
# 1426 MSE train=0.0788 val=0.1267
# 1427 MSE train=0.0788 val=0.1275
# 1428 MSE train=0.0788 val=0.1279
# 1429 MSE train=0.0788 val=0.1271
# 1430 MSE train=0.0788 val=0.1280
# 1431 MSE train=0.0788 val=0.1268
# 1432 MSE train=0.0788 val=0.1274
# 1433 MSE train=0.0787 val=0.1266
# 1434 MSE train=0.0788 val=0.1255
# 1435 MSE train=0.0787 val=0.1262
# 1436 MSE train=0.0787 val=0.1270
# 1437 MSE train=0.0787 val=0.1264
# 1438 MSE train=0.0787 val=0.1250
# 1439 MSE train=0.0787 val=0.1262
# 1440 MSE train=0.0787 val=0.1266
# 1441 MSE train=0.0787 val=0.1269
# 1442 MSE train=0.0786 val=0.1267
# 1443 MSE train=0.0786 val=0.1252
# 1444 MSE train=0.0786 val=0.1252
# 1445 MSE train=0.0786 val=0.1263
# 1446 MSE train=0.0786 val=0.1262
# 1447 MSE train=0.0786 val=0.1265
# 1448 MSE train=0.0786 val=0.1253
# 1449 MSE train=0.0786 val=0.1256
# 1450 MSE train=0.0786 val=0.1247
# 1451 MSE train=0.0785 val=0.1255
# 1452 MSE train=0.0785 val=0.1267
# 1453 MSE train=0.0785 val=0.1263
# 1454 MSE train=0.0785 val=0.1260
# 1455 MSE train=0.0785 val=0.1266
# 1456 MSE train=0.0785 val=0.1260
# 1457 MSE train=0.0785 val=0.1261
# 1458 MSE train=0.0785 val=0.1264
# 1459 MSE train=0.0784 val=0.1249
# 1460 MSE train=0.0784 val=0.1249
# 1461 MSE train=0.0784 val=0.1243
# 1462 MSE train=0.0784 val=0.1237
# 1463 MSE train=0.0784 val=0.1241
# 1464 MSE train=0.0784 val=0.1236
# 1465 MSE train=0.0784 val=0.1236
# 1466 MSE train=0.0784 val=0.1233
# 1467 MSE train=0.0784 val=0.1234
# 1468 MSE train=0.0783 val=0.1248
# 1469 MSE train=0.0783 val=0.1254
# 1470 MSE train=0.0783 val=0.1247
# 1471 MSE train=0.0783 val=0.1256
# 1472 MSE train=0.0783 val=0.1260
# 1473 MSE train=0.0783 val=0.1260
# 1474 MSE train=0.0783 val=0.1258
# 1475 MSE train=0.0783 val=0.1251
# 1476 MSE train=0.0782 val=0.1254
# 1477 MSE train=0.0782 val=0.1250
# 1478 MSE train=0.0782 val=0.1240
# 1479 MSE train=0.0782 val=0.1248
# 1480 MSE train=0.0782 val=0.1257
# 1481 MSE train=0.0782 val=0.1239
# 1482 MSE train=0.0782 val=0.1247
# 1483 MSE train=0.0782 val=0.1227
# 1484 MSE train=0.0782 val=0.1236
# 1485 MSE train=0.0782 val=0.1235
# 1486 MSE train=0.0782 val=0.1244
# 1487 MSE train=0.0781 val=0.1255
# ...
# 9516 MSE train=0.0589 val=0.0714
# 9517 MSE train=0.0589 val=0.0717
# 9518 MSE train=0.0591 val=0.0704
# 9519 MSE train=0.0590 val=0.0748
# 9520 MSE train=0.0589 val=0.0722
# 9521 MSE train=0.0589 val=0.0727
# 9522 MSE train=0.0589 val=0.0728
# 9523 MSE train=0.0590 val=0.0715
# 9524 MSE train=0.0589 val=0.0735
# 9525 MSE train=0.0589 val=0.0737
# 9526 MSE train=0.0593 val=0.0706
# 9527 MSE train=0.0589 val=0.0738
# 9528 MSE train=0.0589 val=0.0727
# 9529 MSE train=0.0589 val=0.0731
# 9530 MSE train=0.0590 val=0.0710
# 9531 MSE train=0.0593 val=0.0697
# 9532 MSE train=0.0590 val=0.0708
# 9533 MSE train=0.0590 val=0.0738
# 9534 MSE train=0.0589 val=0.0723
# 9535 MSE train=0.0598 val=0.0783
# 9536 MSE train=0.0590 val=0.0712
# 9537 MSE train=0.0593 val=0.0763
# 9538 MSE train=0.0590 val=0.0717
# 9539 MSE train=0.0593 val=0.0768
# 9540 MSE train=0.0591 val=0.0707
# 9541 MSE train=0.0589 val=0.0737
# 9542 MSE train=0.0589 val=0.0726
# 9543 MSE train=0.0590 val=0.0715
# 9544 MSE train=0.0589 val=0.0735
# 9545 MSE train=0.0591 val=0.0706
# 9546 MSE train=0.0589 val=0.0733
# 9547 MSE train=0.0589 val=0.0732
# 9548 MSE train=0.0589 val=0.0735
# 9549 MSE train=0.0589 val=0.0723
# 9550 MSE train=0.0592 val=0.0703
# 9551 MSE train=0.0589 val=0.0732
# 9552 MSE train=0.0589 val=0.0718
# 9553 MSE train=0.0595 val=0.0774
# 9554 MSE train=0.0589 val=0.0728
# 9555 MSE train=0.0589 val=0.0720
# 9556 MSE train=0.0594 val=0.0768
# 9557 MSE train=0.0589 val=0.0721
# 9558 MSE train=0.0593 val=0.0754
# 9559 MSE train=0.0589 val=0.0707
# 9560 MSE train=0.0589 val=0.0716
# 9561 MSE train=0.0591 val=0.0698
# 9562 MSE train=0.0590 val=0.0732
# 9563 MSE train=0.0601 val=0.0670
# 9564 MSE train=0.0589 val=0.0729
# 9565 MSE train=0.0589 val=0.0732
# 9566 MSE train=0.0590 val=0.0704
# 9567 MSE train=0.0593 val=0.0759
# 9568 MSE train=0.0594 val=0.0698
# 9569 MSE train=0.0589 val=0.0740
# 9570 MSE train=0.0589 val=0.0736
# 9571 MSE train=0.0590 val=0.0757
# 9572 MSE train=0.0589 val=0.0723
# 9573 MSE train=0.0589 val=0.0736
# 9574 MSE train=0.0598 val=0.0787
# 9575 MSE train=0.0589 val=0.0733
# 9576 MSE train=0.0589 val=0.0737
# 9577 MSE train=0.0589 val=0.0739
# 9578 MSE train=0.0590 val=0.0707
# 9579 MSE train=0.0589 val=0.0716
# 9580 MSE train=0.0590 val=0.0712
# 9581 MSE train=0.0589 val=0.0725
# 9582 MSE train=0.0590 val=0.0708
# 9583 MSE train=0.0589 val=0.0736
# 9584 MSE train=0.0591 val=0.0706
# 9585 MSE train=0.0590 val=0.0757
# 9586 MSE train=0.0589 val=0.0741
# 9587 MSE train=0.0600 val=0.0685
# 9588 MSE train=0.0589 val=0.0731
# 9589 MSE train=0.0589 val=0.0719
# 9590 MSE train=0.0589 val=0.0716
# 9591 MSE train=0.0592 val=0.0759
# 9592 MSE train=0.0594 val=0.0694
# 9593 MSE train=0.0589 val=0.0743
# 9594 MSE train=0.0589 val=0.0725
# 9595 MSE train=0.0592 val=0.0702
# 9596 MSE train=0.0589 val=0.0733
# 9597 MSE train=0.0589 val=0.0740
# 9598 MSE train=0.0589 val=0.0725
# 9599 MSE train=0.0589 val=0.0733
# 9600 MSE train=0.0590 val=0.0711
# 9601 MSE train=0.0595 val=0.0698
# 9602 MSE train=0.0592 val=0.0762
# 9603 MSE train=0.0589 val=0.0729
# 9604 MSE train=0.0590 val=0.0717
# 9605 MSE train=0.0591 val=0.0767
# 9606 MSE train=0.0599 val=0.0693
# 9607 MSE train=0.0591 val=0.0760
# 9608 MSE train=0.0591 val=0.0708
# 9609 MSE train=0.0589 val=0.0732
# 9610 MSE train=0.0588 val=0.0727
# 9611 MSE train=0.0590 val=0.0714
# 9612 MSE train=0.0595 val=0.0695
# 9613 MSE train=0.0590 val=0.0751
# 9614 MSE train=0.0589 val=0.0717
# 9615 MSE train=0.0589 val=0.0739
# 9616 MSE train=0.0588 val=0.0731
# 9617 MSE train=0.0588 val=0.0724
# 9618 MSE train=0.0588 val=0.0727
# 9619 MSE train=0.0594 val=0.0696
# 9620 MSE train=0.0589 val=0.0739
# 9621 MSE train=0.0589 val=0.0742
# 9622 MSE train=0.0589 val=0.0749
# 9623 MSE train=0.0589 val=0.0747
# 9624 MSE train=0.0589 val=0.0732
# 9625 MSE train=0.0589 val=0.0751
# 9626 MSE train=0.0589 val=0.0726
# 9627 MSE train=0.0593 val=0.0707
# 9628 MSE train=0.0589 val=0.0752
# 9629 MSE train=0.0589 val=0.0748
# 9630 MSE train=0.0589 val=0.0727
# 9631 MSE train=0.0596 val=0.0788
# 9632 MSE train=0.0588 val=0.0736
# 9633 MSE train=0.0588 val=0.0743
# 9634 MSE train=0.0588 val=0.0734
# 9635 MSE train=0.0589 val=0.0734
# 9636 MSE train=0.0592 val=0.0700
# 9637 MSE train=0.0589 val=0.0713
# 9638 MSE train=0.0588 val=0.0723
# 9639 MSE train=0.0589 val=0.0720
# 9640 MSE train=0.0589 val=0.0743
# 9641 MSE train=0.0589 val=0.0748
# 9642 MSE train=0.0590 val=0.0760
# 9643 MSE train=0.0590 val=0.0710
# 9644 MSE train=0.0595 val=0.0779
# 9645 MSE train=0.0591 val=0.0762
# 9646 MSE train=0.0589 val=0.0729
# 9647 MSE train=0.0589 val=0.0745
# 9648 MSE train=0.0590 val=0.0711
# 9649 MSE train=0.0589 val=0.0745
# 9650 MSE train=0.0591 val=0.0704
# 9651 MSE train=0.0589 val=0.0745
# 9652 MSE train=0.0588 val=0.0728
# 9653 MSE train=0.0589 val=0.0741
# 9654 MSE train=0.0590 val=0.0712
# 9655 MSE train=0.0596 val=0.0690
# 9656 MSE train=0.0589 val=0.0743
# 9657 MSE train=0.0589 val=0.0736
# 9658 MSE train=0.0595 val=0.0691
# 9659 MSE train=0.0589 val=0.0712
# 9660 MSE train=0.0590 val=0.0708
# 9661 MSE train=0.0589 val=0.0709
# 9662 MSE train=0.0588 val=0.0725
# 9663 MSE train=0.0590 val=0.0702
# 9664 MSE train=0.0589 val=0.0736
# 9665 MSE train=0.0593 val=0.0696
# 9666 MSE train=0.0590 val=0.0754
# 9667 MSE train=0.0599 val=0.0790
# 9668 MSE train=0.0589 val=0.0720
# 9669 MSE train=0.0594 val=0.0695
# 9670 MSE train=0.0590 val=0.0756
# 9671 MSE train=0.0593 val=0.0702
# 9672 MSE train=0.0590 val=0.0753
# 9673 MSE train=0.0588 val=0.0725
# 9674 MSE train=0.0589 val=0.0708
# 9675 MSE train=0.0592 val=0.0691
# 9676 MSE train=0.0591 val=0.0751
# 9677 MSE train=0.0588 val=0.0724
# 9678 MSE train=0.0592 val=0.0709
# 9679 MSE train=0.0588 val=0.0725
# 9680 MSE train=0.0589 val=0.0716
# 9681 MSE train=0.0589 val=0.0732
# 9682 MSE train=0.0589 val=0.0752
# 9683 MSE train=0.0588 val=0.0736
# 9684 MSE train=0.0590 val=0.0752
# 9685 MSE train=0.0590 val=0.0709
# 9686 MSE train=0.0589 val=0.0741
# 9687 MSE train=0.0589 val=0.0715
# 9688 MSE train=0.0589 val=0.0717
# 9689 MSE train=0.0588 val=0.0735
# 9690 MSE train=0.0588 val=0.0718
# 9691 MSE train=0.0589 val=0.0707
# 9692 MSE train=0.0589 val=0.0742
# 9693 MSE train=0.0589 val=0.0741
# 9694 MSE train=0.0588 val=0.0714
# 9695 MSE train=0.0590 val=0.0747
# 9696 MSE train=0.0588 val=0.0730
# 9697 MSE train=0.0589 val=0.0717
# 9698 MSE train=0.0588 val=0.0734
# 9699 MSE train=0.0588 val=0.0738
# 9700 MSE train=0.0588 val=0.0726
# 9701 MSE train=0.0589 val=0.0715
# 9702 MSE train=0.0589 val=0.0732
# 9703 MSE train=0.0591 val=0.0700
# 9704 MSE train=0.0589 val=0.0743
# 9705 MSE train=0.0588 val=0.0725
# 9706 MSE train=0.0589 val=0.0748
# 9707 MSE train=0.0590 val=0.0754
# 9708 MSE train=0.0590 val=0.0749
# 9709 MSE train=0.0592 val=0.0761
# 9710 MSE train=0.0588 val=0.0725
# 9711 MSE train=0.0588 val=0.0718
# 9712 MSE train=0.0588 val=0.0724
# 9713 MSE train=0.0590 val=0.0744
# 9714 MSE train=0.0592 val=0.0691
# 9715 MSE train=0.0589 val=0.0739
# 9716 MSE train=0.0588 val=0.0723
# 9717 MSE train=0.0588 val=0.0714
# 9718 MSE train=0.0588 val=0.0711
# 9719 MSE train=0.0588 val=0.0735
# 9720 MSE train=0.0588 val=0.0723
# 9721 MSE train=0.0589 val=0.0710
# 9722 MSE train=0.0588 val=0.0738
# 9723 MSE train=0.0589 val=0.0741
# 9724 MSE train=0.0589 val=0.0713
# 9725 MSE train=0.0588 val=0.0739
# 9726 MSE train=0.0589 val=0.0739
# 9727 MSE train=0.0589 val=0.0736
# 9728 MSE train=0.0590 val=0.0701
# 9729 MSE train=0.0588 val=0.0720
# 9730 MSE train=0.0588 val=0.0737
# 9731 MSE train=0.0588 val=0.0737
# 9732 MSE train=0.0588 val=0.0724
# 9733 MSE train=0.0588 val=0.0719
# 9734 MSE train=0.0589 val=0.0706
# 9735 MSE train=0.0588 val=0.0726
# 9736 MSE train=0.0590 val=0.0710
# 9737 MSE train=0.0588 val=0.0735
# 9738 MSE train=0.0589 val=0.0729
# 9739 MSE train=0.0588 val=0.0732
# 9740 MSE train=0.0588 val=0.0736
# 9741 MSE train=0.0589 val=0.0729
# 9742 MSE train=0.0590 val=0.0752
# 9743 MSE train=0.0596 val=0.0687
# 9744 MSE train=0.0589 val=0.0745
# 9745 MSE train=0.0588 val=0.0724
# 9746 MSE train=0.0589 val=0.0712
# 9747 MSE train=0.0588 val=0.0739
# 9748 MSE train=0.0588 val=0.0734
# 9749 MSE train=0.0596 val=0.0685
# 9750 MSE train=0.0589 val=0.0741
# 9751 MSE train=0.0590 val=0.0753
# 9752 MSE train=0.0593 val=0.0699
# 9753 MSE train=0.0591 val=0.0760
# 9754 MSE train=0.0588 val=0.0715
# 9755 MSE train=0.0591 val=0.0759
# 9756 MSE train=0.0589 val=0.0712
# 9757 MSE train=0.0593 val=0.0700
# 9758 MSE train=0.0588 val=0.0730
# 9759 MSE train=0.0589 val=0.0705
# 9760 MSE train=0.0594 val=0.0773
# 9761 MSE train=0.0590 val=0.0713
# 9762 MSE train=0.0599 val=0.0689
# 9763 MSE train=0.0588 val=0.0743
# 9764 MSE train=0.0588 val=0.0723
# 9765 MSE train=0.0588 val=0.0730
# 9766 MSE train=0.0592 val=0.0701
# 9767 MSE train=0.0588 val=0.0724
# 9768 MSE train=0.0591 val=0.0708
# 9769 MSE train=0.0589 val=0.0715
# 9770 MSE train=0.0593 val=0.0696
# 9771 MSE train=0.0588 val=0.0725
# 9772 MSE train=0.0588 val=0.0740
# 9773 MSE train=0.0589 val=0.0710
# 9774 MSE train=0.0614 val=0.0832
# 9775 MSE train=0.0588 val=0.0720
# 9776 MSE train=0.0588 val=0.0734
# 9777 MSE train=0.0588 val=0.0727
# 9778 MSE train=0.0588 val=0.0720
# 9779 MSE train=0.0588 val=0.0746
# 9780 MSE train=0.0588 val=0.0726
# 9781 MSE train=0.0588 val=0.0733
# 9782 MSE train=0.0588 val=0.0732
# 9783 MSE train=0.0588 val=0.0741
# 9784 MSE train=0.0588 val=0.0720
# 9785 MSE train=0.0588 val=0.0715
# 9786 MSE train=0.0591 val=0.0763
# 9787 MSE train=0.0588 val=0.0747
# 9788 MSE train=0.0588 val=0.0730
# 9789 MSE train=0.0591 val=0.0706
# 9790 MSE train=0.0589 val=0.0752
# 9791 MSE train=0.0594 val=0.0692
# 9792 MSE train=0.0588 val=0.0747
# 9793 MSE train=0.0588 val=0.0729
# 9794 MSE train=0.0590 val=0.0754
# 9795 MSE train=0.0588 val=0.0726
# 9796 MSE train=0.0588 val=0.0743
# 9797 MSE train=0.0588 val=0.0734
# 9798 MSE train=0.0604 val=0.0677
# 9799 MSE train=0.0591 val=0.0759
# 9800 MSE train=0.0588 val=0.0724
# 9801 MSE train=0.0588 val=0.0740
# 9802 MSE train=0.0589 val=0.0713
# 9803 MSE train=0.0589 val=0.0750
# 9804 MSE train=0.0588 val=0.0736
# 9805 MSE train=0.0590 val=0.0755
# 9806 MSE train=0.0588 val=0.0737
# 9807 MSE train=0.0588 val=0.0740
# 9808 MSE train=0.0588 val=0.0711
# 9809 MSE train=0.0594 val=0.0693
# 9810 MSE train=0.0588 val=0.0736
# 9811 MSE train=0.0588 val=0.0713
# 9812 MSE train=0.0587 val=0.0723
# 9813 MSE train=0.0595 val=0.0691
# 9814 MSE train=0.0588 val=0.0724
# 9815 MSE train=0.0589 val=0.0720
# 9816 MSE train=0.0590 val=0.0716
# 9817 MSE train=0.0590 val=0.0718
# 9818 MSE train=0.0588 val=0.0732
# 9819 MSE train=0.0592 val=0.0773
# 9820 MSE train=0.0592 val=0.0702
# 9821 MSE train=0.0589 val=0.0755
# 9822 MSE train=0.0588 val=0.0720
# 9823 MSE train=0.0591 val=0.0705
# 9824 MSE train=0.0588 val=0.0718
# 9825 MSE train=0.0588 val=0.0738
# 9826 MSE train=0.0588 val=0.0715
# 9827 MSE train=0.0589 val=0.0743
# 9828 MSE train=0.0588 val=0.0707
# 9829 MSE train=0.0588 val=0.0717
# 9830 MSE train=0.0588 val=0.0737
# 9831 MSE train=0.0588 val=0.0712
# 9832 MSE train=0.0592 val=0.0691
# 9833 MSE train=0.0593 val=0.0766
# 9834 MSE train=0.0588 val=0.0714
# 9835 MSE train=0.0590 val=0.0745
# 9836 MSE train=0.0588 val=0.0710
# 9837 MSE train=0.0588 val=0.0732
# 9838 MSE train=0.0587 val=0.0725
# 9839 MSE train=0.0589 val=0.0705
# 9840 MSE train=0.0589 val=0.0745
# 9841 MSE train=0.0589 val=0.0750
# 9842 MSE train=0.0590 val=0.0755
# 9843 MSE train=0.0587 val=0.0732
# 9844 MSE train=0.0587 val=0.0728
# 9845 MSE train=0.0588 val=0.0712
# 9846 MSE train=0.0588 val=0.0709
# 9847 MSE train=0.0587 val=0.0729
# 9848 MSE train=0.0588 val=0.0733
# 9849 MSE train=0.0588 val=0.0729
# 9850 MSE train=0.0589 val=0.0702
# 9851 MSE train=0.0593 val=0.0690
# 9852 MSE train=0.0588 val=0.0739
# 9853 MSE train=0.0594 val=0.0685
# 9854 MSE train=0.0588 val=0.0710
# 9855 MSE train=0.0591 val=0.0697
# 9856 MSE train=0.0590 val=0.0698
# 9857 MSE train=0.0588 val=0.0729
# 9858 MSE train=0.0589 val=0.0752
# 9859 MSE train=0.0588 val=0.0745
# 9860 MSE train=0.0587 val=0.0723
# 9861 MSE train=0.0588 val=0.0746
# 9862 MSE train=0.0588 val=0.0717
# 9863 MSE train=0.0588 val=0.0720
# 9864 MSE train=0.0598 val=0.0795
# 9865 MSE train=0.0587 val=0.0737
# 9866 MSE train=0.0595 val=0.0695
# 9867 MSE train=0.0588 val=0.0739
# 9868 MSE train=0.0591 val=0.0704
# 9869 MSE train=0.0588 val=0.0727
# 9870 MSE train=0.0593 val=0.0695
# 9871 MSE train=0.0597 val=0.0786
# 9872 MSE train=0.0587 val=0.0727
# 9873 MSE train=0.0587 val=0.0734
# 9874 MSE train=0.0591 val=0.0699
# 9875 MSE train=0.0587 val=0.0726
# 9876 MSE train=0.0587 val=0.0720
# 9877 MSE train=0.0587 val=0.0731
# 9878 MSE train=0.0587 val=0.0722
# 9879 MSE train=0.0588 val=0.0745
# 9880 MSE train=0.0587 val=0.0730
# 9881 MSE train=0.0594 val=0.0773
# 9882 MSE train=0.0587 val=0.0717
# 9883 MSE train=0.0590 val=0.0697
# 9884 MSE train=0.0588 val=0.0741
# 9885 MSE train=0.0587 val=0.0723
# 9886 MSE train=0.0588 val=0.0707
# 9887 MSE train=0.0599 val=0.0677
# 9888 MSE train=0.0587 val=0.0711
# 9889 MSE train=0.0587 val=0.0729
# 9890 MSE train=0.0587 val=0.0739
# 9891 MSE train=0.0589 val=0.0710
# 9892 MSE train=0.0587 val=0.0733
# 9893 MSE train=0.0587 val=0.0731
# 9894 MSE train=0.0587 val=0.0731
# 9895 MSE train=0.0588 val=0.0708
# 9896 MSE train=0.0587 val=0.0712
# 9897 MSE train=0.0589 val=0.0749
# 9898 MSE train=0.0587 val=0.0713
# 9899 MSE train=0.0587 val=0.0718
# 9900 MSE train=0.0587 val=0.0728
# 9901 MSE train=0.0587 val=0.0712
# 9902 MSE train=0.0588 val=0.0734
# 9903 MSE train=0.0587 val=0.0723
# 9904 MSE train=0.0587 val=0.0718
# 9905 MSE train=0.0599 val=0.0676
# 9906 MSE train=0.0587 val=0.0728
# 9907 MSE train=0.0588 val=0.0742
# 9908 MSE train=0.0590 val=0.0708
# 9909 MSE train=0.0589 val=0.0753
# 9910 MSE train=0.0587 val=0.0716
# 9911 MSE train=0.0587 val=0.0736
# 9912 MSE train=0.0621 val=0.0659
# 9913 MSE train=0.0593 val=0.0772
# 9914 MSE train=0.0587 val=0.0729
# 9915 MSE train=0.0587 val=0.0727
# 9916 MSE train=0.0587 val=0.0722
# 9917 MSE train=0.0589 val=0.0747
# 9918 MSE train=0.0588 val=0.0742
# 9919 MSE train=0.0590 val=0.0755
# 9920 MSE train=0.0587 val=0.0721
# 9921 MSE train=0.0588 val=0.0740
# 9922 MSE train=0.0587 val=0.0722
# 9923 MSE train=0.0592 val=0.0691
# 9924 MSE train=0.0601 val=0.0799
# 9925 MSE train=0.0590 val=0.0703
# 9926 MSE train=0.0587 val=0.0738
# 9927 MSE train=0.0587 val=0.0728
# 9928 MSE train=0.0587 val=0.0731
# 9929 MSE train=0.0588 val=0.0745
# 9930 MSE train=0.0587 val=0.0732
# 9931 MSE train=0.0587 val=0.0727
# 9932 MSE train=0.0587 val=0.0731
# 9933 MSE train=0.0592 val=0.0686
# 9934 MSE train=0.0587 val=0.0723
# 9935 MSE train=0.0589 val=0.0747
# 9936 MSE train=0.0587 val=0.0727
# 9937 MSE train=0.0595 val=0.0691
# 9938 MSE train=0.0588 val=0.0742
# 9939 MSE train=0.0587 val=0.0731
# 9940 MSE train=0.0587 val=0.0740
# 9941 MSE train=0.0589 val=0.0704
# 9942 MSE train=0.0590 val=0.0701
# 9943 MSE train=0.0593 val=0.0689
# 9944 MSE train=0.0589 val=0.0758
# 9945 MSE train=0.0587 val=0.0743
# 9946 MSE train=0.0589 val=0.0717
# 9947 MSE train=0.0587 val=0.0730
# 9948 MSE train=0.0587 val=0.0738
# 9949 MSE train=0.0587 val=0.0730
# 9950 MSE train=0.0587 val=0.0722
# 9951 MSE train=0.0588 val=0.0712
# 9952 MSE train=0.0587 val=0.0716
# 9953 MSE train=0.0587 val=0.0736
# 9954 MSE train=0.0588 val=0.0747
# 9955 MSE train=0.0587 val=0.0726
# 9956 MSE train=0.0587 val=0.0738
# 9957 MSE train=0.0587 val=0.0730
# 9958 MSE train=0.0604 val=0.0672
# 9959 MSE train=0.0587 val=0.0728
# 9960 MSE train=0.0588 val=0.0742
# 9961 MSE train=0.0587 val=0.0713
# 9962 MSE train=0.0590 val=0.0702
# 9963 MSE train=0.0589 val=0.0706
# 9964 MSE train=0.0589 val=0.0749
# 9965 MSE train=0.0588 val=0.0709
# 9966 MSE train=0.0591 val=0.0763
# 9967 MSE train=0.0587 val=0.0726
# 9968 MSE train=0.0589 val=0.0752
# 9969 MSE train=0.0587 val=0.0734
# 9970 MSE train=0.0587 val=0.0730
# 9971 MSE train=0.0591 val=0.0696
# 9972 MSE train=0.0587 val=0.0712
# 9973 MSE train=0.0605 val=0.0674
# 9974 MSE train=0.0587 val=0.0717
# 9975 MSE train=0.0588 val=0.0702
# 9976 MSE train=0.0587 val=0.0733
# 9977 MSE train=0.0587 val=0.0729
# 9978 MSE train=0.0591 val=0.0698
# 9979 MSE train=0.0587 val=0.0727
# 9980 MSE train=0.0590 val=0.0754
# 9981 MSE train=0.0588 val=0.0743
# 9982 MSE train=0.0587 val=0.0717
# 9983 MSE train=0.0588 val=0.0710
# 9984 MSE train=0.0589 val=0.0757
# 9985 MSE train=0.0587 val=0.0720
# 9986 MSE train=0.0587 val=0.0719
# 9987 MSE train=0.0593 val=0.0766
# 9988 MSE train=0.0587 val=0.0712
# 9989 MSE train=0.0590 val=0.0703
# 9990 MSE train=0.0588 val=0.0749
# 9991 MSE train=0.0587 val=0.0717
# 9992 MSE train=0.0598 val=0.0682
# 9993 MSE train=0.0588 val=0.0744
# 9994 MSE train=0.0587 val=0.0728
# 9995 MSE train=0.0589 val=0.0744
# 9996 MSE train=0.0587 val=0.0718
# 9997 MSE train=0.0587 val=0.0735
# 9998 MSE train=0.0587 val=0.0723
# 9999 MSE train=0.0587 val=0.0728

# %% [markdown]
# ... and plot the training metrics (which feature overfitting) ...

# %%
from plotting import plot_mse_train_vs_val

plot_mse_train_vs_val(mse_train, mse_val)

# %% [markdown]
# ... and the predictions for the training set ...

# %%
plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train))
plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train))

# %% [markdown]
# ... the predictions for the validation set ...

# %%
plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val))
plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val))

# %% [markdown]
# ... and the predictions for the test set.

# %%
(x_test, y_gt_test) = load_data(filename="data_reg_2d_nonlinear_test.csv")

plot_pred_2d(x_test, y_gt_test, y_p=dnn2_reg(wa, wb, x_test))
plot_pred_vs_gt(y_gt_test, y_p=dnn2_reg(wa, wb, x_test))
