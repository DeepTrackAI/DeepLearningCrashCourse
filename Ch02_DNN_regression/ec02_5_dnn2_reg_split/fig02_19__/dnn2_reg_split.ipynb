# %% [markdown]
# # Training a Neural Network Splitting the Data
#
# This notebook provides you with a complete code example that loads the data contained in the `data_reg_2d_nonlinear.csv` file and splits them into a training, a validation, and a test set. Then, it trains a two-layer neural network using the training data, while monitoring the training and validation MSE. Finally, it uses the trained network to predict the values of the test data (test hold-out dataset) in the `data_reg_2d_linear_test.csv` file.

# %% [markdown]
# ## Loading and Splitting the Data

# %%
from loader import load_data

(x, y_gt) = load_data(filename="data_reg_2d_nonlinear.csv")

# %%
from numpy import delete, split
from numpy.random import choice

num_samples = len(x)
split = .70

num_samples_train = int(split * num_samples)
train_idx = choice(num_samples, num_samples_train, replace=False)

x_train = x[train_idx]  # Train inputs.
y_gt_train = y_gt[train_idx]  # Train ground truths.

x_val = delete(x, train_idx, axis=0)  # Validation inputs.
y_gt_val = delete(y_gt, train_idx, axis=0)  # Validation ground truths.

# %% [markdown]
# ## Implementing a Dense Neural Network
#
# Implement the sigmoidal function

# %%
from numpy import exp

def sigmoid(x):
    """Sigmoid function."""
    return 1 / (1 + exp(-x))

# %% [markdown]
# ... implement a function to define the neural network ...

# %%
def dnn2_reg(wa, wb, x):
    """Two-layer dense neural network for classification."""
    return sigmoid(x @ wa) @ wb

# %% [markdown]
# ... define the number of neurons of the first layer ...

# %%
num_neurons = 10

# %% [markdown]
# ... randomly initialize its weights ...

# %%
from numpy.random import default_rng

rng = default_rng()
wa = rng.standard_normal(size=(2, num_neurons)) # Input weights layer 1.
wb = rng.standard_normal(size=(num_neurons, 1)) # Input weights layer 2.

# %% [markdown]
# ... obtain its predictions for the training and validation datasets ...

# %%
y_p_train = dnn2_reg(wa, wb, x_train)
y_p_val = dnn2_reg(wa, wb, x_val)

# %% [markdown]
# ... and plot its predictions for the training dataset ...

# %%
from plotting import plot_pred_2d, plot_pred_vs_gt

### plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train))
### plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train))

# %% [markdown]
# ... and for the validation dataset.

# %%
### plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val))
### plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val))

# %% [markdown]
# ## Training and Validating the Neural Network
#
# Implement the first derivative of the sigmoid function ...

# %%
def d_sigmoid(x):
    """Derivative of sigmoid function."""
    return sigmoid(x) * (1 - sigmoid(x))

# %% [markdown]
# ... implement the backpropagation algorithm with mini-batches ...

# %%
from numpy import mean, reshape, sum, transpose, zeros
from numpy.random import permutation

num_samnum_samples_trainples = len(x_train)
num_batches = 7
batch_size = int(num_samples / num_batches)
num_epochs = 10 ** 3
eta = .1 # Learning rate.

mse_train = zeros((num_epochs,))
mse_val = zeros((num_epochs,))

for epoch in range(num_epochs):
    # Permute samples.
    permuted_order_samples = permutation(num_samples_train)
    x_permuted = x_train[permuted_order_samples]
    y_gt_permuted = y_gt_train[permuted_order_samples]

    for batch_start in range(0, num_samples_train, batch_size):
        dwa = zeros(wa.shape) # Initialize weight increments layer 1.
        dwb = zeros(wb.shape) # Initialize weight increments layer 2.
        
        for selected in range(batch_start, batch_start + batch_size):
            x_selected = reshape(x_permuted[selected], (1, -1))
            y_gt_selected = reshape(y_gt_permuted[selected], (1, -1))
            
            # Detailed neural network calculation.
            x_selected_a = x_selected # Input layer 1.
            p_a = x_selected_a @ wa # Activation potential layer 1.
            y_selected_a = sigmoid(p_a) # Output layer 1.

            x_selected_b = y_selected_a # Input layer 2.
            p_b = x_selected_b @ wb # Activation potential layer 2.
            y_selected_b = p_b # Output neuron layer 2 (output neuron).

            y_p_selected = y_selected_b
    
            # Update weights.
            error = y_p_selected - y_gt_selected
    
            delta_b = error * 1
            dwb -= eta * delta_b * transpose(x_selected_b)

            delta_a = sum(wb * delta_b, axis=1) * d_sigmoid(p_a)
            dwa -= eta * delta_a * transpose(x_selected_a)
    
        wa += dwa / batch_size # Update weights layer 1.
        wb += dwb / batch_size # Update weights layer 2.
        
    y_p_train = dnn2_reg(wa, wb, x_train)
    mse_train[epoch] = mean((y_p_train - y_gt_train) ** 2)
    
    y_p_val = dnn2_reg(wa, wb, x_val)
    mse_val[epoch] = mean((y_p_val - y_gt_val) ** 2)
    
    print(f"{epoch} MSE train={mse_train[epoch]:.4f} val={mse_val[epoch]:.4f}")
# Out:
# 0 MSE train=1.3616 val=0.7511
# 1 MSE train=0.9466 val=0.6703
# 2 MSE train=0.7312 val=0.6647
# 3 MSE train=0.6036 val=0.6935
# 4 MSE train=0.5277 val=0.6990
# 5 MSE train=0.4861 val=0.7438
# 6 MSE train=0.4620 val=0.7788
# 7 MSE train=0.4441 val=0.7624
# 8 MSE train=0.4341 val=0.8037
# 9 MSE train=0.4276 val=0.8042
# 10 MSE train=0.4237 val=0.8319
# 11 MSE train=0.4208 val=0.8382
# 12 MSE train=0.4247 val=0.8779
# 13 MSE train=0.4173 val=0.8458
# 14 MSE train=0.4162 val=0.8471
# 15 MSE train=0.4153 val=0.8580
# 16 MSE train=0.4141 val=0.8522
# 17 MSE train=0.4171 val=0.8802
# 18 MSE train=0.4125 val=0.8621
# 19 MSE train=0.4118 val=0.8671
# 20 MSE train=0.4111 val=0.8635
# 21 MSE train=0.4110 val=0.8336
# 22 MSE train=0.4105 val=0.8238
# 23 MSE train=0.4083 val=0.8317
# 24 MSE train=0.4084 val=0.8537
# 25 MSE train=0.4068 val=0.8475
# 26 MSE train=0.4065 val=0.8527
# 27 MSE train=0.4055 val=0.8488
# 28 MSE train=0.4047 val=0.8426
# 29 MSE train=0.4045 val=0.8291
# 30 MSE train=0.4046 val=0.8486
# 31 MSE train=0.4062 val=0.8574
# 32 MSE train=0.4027 val=0.8398
# 33 MSE train=0.4022 val=0.8389
# 34 MSE train=0.4014 val=0.8366
# 35 MSE train=0.4012 val=0.8411
# 36 MSE train=0.4008 val=0.8411
# 37 MSE train=0.4005 val=0.8148
# 38 MSE train=0.4004 val=0.8105
# 39 MSE train=0.3990 val=0.8213
# 40 MSE train=0.3995 val=0.8366
# 41 MSE train=0.3982 val=0.8134
# 42 MSE train=0.3976 val=0.8145
# 43 MSE train=0.3985 val=0.8303
# 44 MSE train=0.3967 val=0.8111
# 45 MSE train=0.3965 val=0.8237
# 46 MSE train=0.3962 val=0.8092
# 47 MSE train=0.3981 val=0.7976
# 48 MSE train=0.3971 val=0.7958
# 49 MSE train=0.3951 val=0.8060
# 50 MSE train=0.3973 val=0.8322
# 51 MSE train=0.3941 val=0.8151
# 52 MSE train=0.3940 val=0.8141
# 53 MSE train=0.3935 val=0.8056
# 54 MSE train=0.3968 val=0.7925
# 55 MSE train=0.4011 val=0.7839
# 56 MSE train=0.3928 val=0.7992
# 57 MSE train=0.3925 val=0.8026
# 58 MSE train=0.3934 val=0.7892
# 59 MSE train=0.3922 val=0.7975
# 60 MSE train=0.3925 val=0.8175
# 61 MSE train=0.3914 val=0.8067
# 62 MSE train=0.3923 val=0.8187
# 63 MSE train=0.3926 val=0.8222
# 64 MSE train=0.3907 val=0.8078
# 65 MSE train=0.3907 val=0.8114
# 66 MSE train=0.3905 val=0.8135
# 67 MSE train=0.3908 val=0.8193
# 68 MSE train=0.3900 val=0.8033
# 69 MSE train=0.3900 val=0.8004
# 70 MSE train=0.3895 val=0.8067
# 71 MSE train=0.3907 val=0.7912
# 72 MSE train=0.3934 val=0.7818
# 73 MSE train=0.3888 val=0.8017
# 74 MSE train=0.3888 val=0.7886
# 75 MSE train=0.3901 val=0.7768
# 76 MSE train=0.3884 val=0.7885
# 77 MSE train=0.3894 val=0.8125
# 78 MSE train=0.3884 val=0.7937
# 79 MSE train=0.3884 val=0.8063
# 80 MSE train=0.3877 val=0.7970
# 81 MSE train=0.3877 val=0.7908
# 82 MSE train=0.3874 val=0.7993
# 83 MSE train=0.3882 val=0.8067
# 84 MSE train=0.3876 val=0.8041
# 85 MSE train=0.3940 val=0.8320
# 86 MSE train=0.3870 val=0.7894
# 87 MSE train=0.3866 val=0.7950
# 88 MSE train=0.3922 val=0.7732
# 89 MSE train=0.3864 val=0.7918
# 90 MSE train=0.3871 val=0.8060
# 91 MSE train=0.3870 val=0.8062
# 92 MSE train=0.3862 val=0.7944
# 93 MSE train=0.3860 val=0.7992
# 94 MSE train=0.3872 val=0.7779
# 95 MSE train=0.3883 val=0.7705
# 96 MSE train=0.3915 val=0.7616
# 97 MSE train=0.3861 val=0.7752
# 98 MSE train=0.3855 val=0.7907
# 99 MSE train=0.3864 val=0.7692
# 100 MSE train=0.3851 val=0.7758
# 101 MSE train=0.3850 val=0.7772
# 102 MSE train=0.3856 val=0.7911
# 103 MSE train=0.3864 val=0.8009
# 104 MSE train=0.3870 val=0.8051
# 105 MSE train=0.3878 val=0.8152
# 106 MSE train=0.3876 val=0.8127
# 107 MSE train=0.3873 val=0.8129
# 108 MSE train=0.3908 val=0.8267
# 109 MSE train=0.3865 val=0.7731
# 110 MSE train=0.3871 val=0.7695
# 111 MSE train=0.3839 val=0.7763
# 112 MSE train=0.3860 val=0.7661
# 113 MSE train=0.3837 val=0.7803
# 114 MSE train=0.3837 val=0.7746
# 115 MSE train=0.3837 val=0.7804
# 116 MSE train=0.3845 val=0.7984
# 117 MSE train=0.3833 val=0.7800
# 118 MSE train=0.3832 val=0.7786
# 119 MSE train=0.3832 val=0.7843
# 120 MSE train=0.3850 val=0.7921
# 121 MSE train=0.3864 val=0.8005
# 122 MSE train=0.3832 val=0.7823
# 123 MSE train=0.3845 val=0.7950
# 124 MSE train=0.3874 val=0.8073
# 125 MSE train=0.3861 val=0.8005
# 126 MSE train=0.3826 val=0.7725
# 127 MSE train=0.3825 val=0.7792
# 128 MSE train=0.3824 val=0.7785
# 129 MSE train=0.3821 val=0.7719
# 130 MSE train=0.3831 val=0.7859
# 131 MSE train=0.3822 val=0.7802
# 132 MSE train=0.3824 val=0.7818
# 133 MSE train=0.3825 val=0.7811
# 134 MSE train=0.3817 val=0.7699
# 135 MSE train=0.3871 val=0.7541
# 136 MSE train=0.3815 val=0.7742
# 137 MSE train=0.3816 val=0.7761
# 138 MSE train=0.3840 val=0.7546
# 139 MSE train=0.3834 val=0.7517
# 140 MSE train=0.3838 val=0.7887
# 141 MSE train=0.3813 val=0.7766
# 142 MSE train=0.3809 val=0.7718
# 143 MSE train=0.3811 val=0.7636
# 144 MSE train=0.3808 val=0.7654
# 145 MSE train=0.3807 val=0.7638
# 146 MSE train=0.3806 val=0.7720
# 147 MSE train=0.3851 val=0.7483
# 148 MSE train=0.3803 val=0.7687
# 149 MSE train=0.3818 val=0.7576
# 150 MSE train=0.3806 val=0.7609
# 151 MSE train=0.3818 val=0.7868
# 152 MSE train=0.3808 val=0.7843
# 153 MSE train=0.3807 val=0.7815
# 154 MSE train=0.3799 val=0.7649
# 155 MSE train=0.3797 val=0.7674
# 156 MSE train=0.3809 val=0.7542
# 157 MSE train=0.3796 val=0.7770
# 158 MSE train=0.3794 val=0.7673
# 159 MSE train=0.3810 val=0.7821
# 160 MSE train=0.3804 val=0.7734
# 161 MSE train=0.3791 val=0.7581
# 162 MSE train=0.3795 val=0.7495
# 163 MSE train=0.3808 val=0.7431
# 164 MSE train=0.3794 val=0.7660
# 165 MSE train=0.3786 val=0.7613
# 166 MSE train=0.3850 val=0.7954
# 167 MSE train=0.3797 val=0.7751
# 168 MSE train=0.3785 val=0.7535
# 169 MSE train=0.3783 val=0.7501
# 170 MSE train=0.3797 val=0.7720
# 171 MSE train=0.3791 val=0.7677
# 172 MSE train=0.3786 val=0.7488
# 173 MSE train=0.3787 val=0.7688
# 174 MSE train=0.3797 val=0.7430
# 175 MSE train=0.3801 val=0.7422
# 176 MSE train=0.3801 val=0.7431
# 177 MSE train=0.3778 val=0.7532
# 178 MSE train=0.3772 val=0.7641
# 179 MSE train=0.3784 val=0.7473
# 180 MSE train=0.3778 val=0.7663
# 181 MSE train=0.3768 val=0.7525
# 182 MSE train=0.3775 val=0.7618
# 183 MSE train=0.3769 val=0.7486
# 184 MSE train=0.3765 val=0.7511
# 185 MSE train=0.3767 val=0.7681
# 186 MSE train=0.3789 val=0.7776
# 187 MSE train=0.3767 val=0.7460
# 188 MSE train=0.3762 val=0.7495
# 189 MSE train=0.3759 val=0.7588
# 190 MSE train=0.3771 val=0.7402
# 191 MSE train=0.3771 val=0.7627
# 192 MSE train=0.3757 val=0.7526
# 193 MSE train=0.3768 val=0.7348
# 194 MSE train=0.3755 val=0.7392
# 195 MSE train=0.3756 val=0.7356
# 196 MSE train=0.3757 val=0.7584
# 197 MSE train=0.3747 val=0.7496
# 198 MSE train=0.3756 val=0.7605
# 199 MSE train=0.3745 val=0.7431
# 200 MSE train=0.3742 val=0.7495
# 201 MSE train=0.3740 val=0.7478
# 202 MSE train=0.3741 val=0.7577
# 203 MSE train=0.3751 val=0.7637
# 204 MSE train=0.3736 val=0.7447
# 205 MSE train=0.3744 val=0.7313
# 206 MSE train=0.3733 val=0.7450
# 207 MSE train=0.3731 val=0.7519
# 208 MSE train=0.3740 val=0.7657
# 209 MSE train=0.3732 val=0.7588
# 210 MSE train=0.3727 val=0.7517
# 211 MSE train=0.3727 val=0.7573
# 212 MSE train=0.3754 val=0.7367
# 213 MSE train=0.3721 val=0.7498
# 214 MSE train=0.3742 val=0.7663
# 215 MSE train=0.3732 val=0.7616
# 216 MSE train=0.3722 val=0.7544
# 217 MSE train=0.3715 val=0.7350
# 218 MSE train=0.3731 val=0.7566
# 219 MSE train=0.3712 val=0.7449
# 220 MSE train=0.3721 val=0.7549
# 221 MSE train=0.3706 val=0.7403
# 222 MSE train=0.3707 val=0.7377
# 223 MSE train=0.3705 val=0.7454
# 224 MSE train=0.3699 val=0.7368
# 225 MSE train=0.3702 val=0.7267
# 226 MSE train=0.3705 val=0.7237
# 227 MSE train=0.3692 val=0.7352
# 228 MSE train=0.3693 val=0.7376
# 229 MSE train=0.3686 val=0.7369
# 230 MSE train=0.3685 val=0.7387
# 231 MSE train=0.3681 val=0.7308
# 232 MSE train=0.3700 val=0.7484
# 233 MSE train=0.3677 val=0.7282
# 234 MSE train=0.3674 val=0.7238
# 235 MSE train=0.3674 val=0.7322
# 236 MSE train=0.3679 val=0.7191
# 237 MSE train=0.3668 val=0.7323
# 238 MSE train=0.3664 val=0.7306
# 239 MSE train=0.3661 val=0.7339
# 240 MSE train=0.3658 val=0.7241
# 241 MSE train=0.3668 val=0.7400
# 242 MSE train=0.3657 val=0.7189
# 243 MSE train=0.3702 val=0.7059
# 244 MSE train=0.3648 val=0.7209
# 245 MSE train=0.3643 val=0.7266
# 246 MSE train=0.3641 val=0.7233
# 247 MSE train=0.3649 val=0.7358
# 248 MSE train=0.3649 val=0.7077
# 249 MSE train=0.3636 val=0.7298
# 250 MSE train=0.3688 val=0.7528
# 251 MSE train=0.3635 val=0.7289
# 252 MSE train=0.3628 val=0.7328
# 253 MSE train=0.3618 val=0.7173
# 254 MSE train=0.3616 val=0.7162
# 255 MSE train=0.3610 val=0.7138
# 256 MSE train=0.3610 val=0.7106
# 257 MSE train=0.3623 val=0.7053
# 258 MSE train=0.3602 val=0.7101
# 259 MSE train=0.3599 val=0.7183
# 260 MSE train=0.3645 val=0.7410
# 261 MSE train=0.3607 val=0.7299
# 262 MSE train=0.3585 val=0.7128
# 263 MSE train=0.3589 val=0.6938
# 264 MSE train=0.3579 val=0.6968
# 265 MSE train=0.3574 val=0.6940
# 266 MSE train=0.3573 val=0.6903
# 267 MSE train=0.3597 val=0.6783
# 268 MSE train=0.3561 val=0.6904
# 269 MSE train=0.3555 val=0.6918
# 270 MSE train=0.3587 val=0.7188
# 271 MSE train=0.3563 val=0.6840
# 272 MSE train=0.3576 val=0.6784
# 273 MSE train=0.3544 val=0.6864
# 274 MSE train=0.3533 val=0.6881
# 275 MSE train=0.3546 val=0.6806
# 276 MSE train=0.3525 val=0.6848
# 277 MSE train=0.3517 val=0.6934
# 278 MSE train=0.3538 val=0.7119
# 279 MSE train=0.3505 val=0.6892
# 280 MSE train=0.3512 val=0.6761
# 281 MSE train=0.3499 val=0.6923
# 282 MSE train=0.3506 val=0.6770
# 283 MSE train=0.3485 val=0.6831
# 284 MSE train=0.3489 val=0.6904
# 285 MSE train=0.3474 val=0.6760
# 286 MSE train=0.3470 val=0.6703
# 287 MSE train=0.3481 val=0.6635
# 288 MSE train=0.3474 val=0.6611
# 289 MSE train=0.3509 val=0.6552
# 290 MSE train=0.3481 val=0.6554
# 291 MSE train=0.3439 val=0.6632
# 292 MSE train=0.3435 val=0.6733
# 293 MSE train=0.3429 val=0.6646
# 294 MSE train=0.3422 val=0.6658
# 295 MSE train=0.3414 val=0.6735
# 296 MSE train=0.3424 val=0.6820
# 297 MSE train=0.3404 val=0.6777
# 298 MSE train=0.3393 val=0.6711
# 299 MSE train=0.3387 val=0.6610
# 300 MSE train=0.3380 val=0.6596
# 301 MSE train=0.3374 val=0.6603
# 302 MSE train=0.3393 val=0.6766
# 303 MSE train=0.3358 val=0.6527
# 304 MSE train=0.3397 val=0.6378
# 305 MSE train=0.3351 val=0.6462
# 306 MSE train=0.3341 val=0.6477
# 307 MSE train=0.3329 val=0.6572
# 308 MSE train=0.3333 val=0.6408
# 309 MSE train=0.3321 val=0.6420
# 310 MSE train=0.3312 val=0.6397
# 311 MSE train=0.3300 val=0.6553
# 312 MSE train=0.3290 val=0.6450
# 313 MSE train=0.3294 val=0.6297
# 314 MSE train=0.3279 val=0.6331
# 315 MSE train=0.3268 val=0.6285
# 316 MSE train=0.3285 val=0.6157
# 317 MSE train=0.3251 val=0.6248
# 318 MSE train=0.3248 val=0.6390
# 319 MSE train=0.3235 val=0.6325
# 320 MSE train=0.3228 val=0.6222
# 321 MSE train=0.3225 val=0.6171
# 322 MSE train=0.3216 val=0.6387
# 323 MSE train=0.3206 val=0.6198
# 324 MSE train=0.3190 val=0.6213
# 325 MSE train=0.3183 val=0.6274
# 326 MSE train=0.3173 val=0.6187
# 327 MSE train=0.3169 val=0.6147
# 328 MSE train=0.3155 val=0.6120
# 329 MSE train=0.3145 val=0.6168
# 330 MSE train=0.3135 val=0.6117
# 331 MSE train=0.3163 val=0.5923
# 332 MSE train=0.3117 val=0.6023
# 333 MSE train=0.3173 val=0.6343
# 334 MSE train=0.3099 val=0.6069
# 335 MSE train=0.3100 val=0.6128
# 336 MSE train=0.3078 val=0.6005
# 337 MSE train=0.3069 val=0.5939
# 338 MSE train=0.3068 val=0.5811
# 339 MSE train=0.3070 val=0.6047
# 340 MSE train=0.3040 val=0.5892
# 341 MSE train=0.3031 val=0.5857
# 342 MSE train=0.3027 val=0.5968
# 343 MSE train=0.3009 val=0.5856
# 344 MSE train=0.3002 val=0.5751
# 345 MSE train=0.2999 val=0.5686
# 346 MSE train=0.2982 val=0.5760
# 347 MSE train=0.2968 val=0.5807
# 348 MSE train=0.2959 val=0.5738
# 349 MSE train=0.2968 val=0.5878
# 350 MSE train=0.2937 val=0.5761
# 351 MSE train=0.2929 val=0.5803
# 352 MSE train=0.2916 val=0.5732
# 353 MSE train=0.2912 val=0.5632
# 354 MSE train=0.2897 val=0.5667
# 355 MSE train=0.2892 val=0.5755
# 356 MSE train=0.2877 val=0.5688
# 357 MSE train=0.2871 val=0.5694
# 358 MSE train=0.2855 val=0.5629
# 359 MSE train=0.2871 val=0.5430
# 360 MSE train=0.2831 val=0.5544
# 361 MSE train=0.2826 val=0.5600
# 362 MSE train=0.2817 val=0.5564
# 363 MSE train=0.2808 val=0.5386
# 364 MSE train=0.2795 val=0.5546
# 365 MSE train=0.2786 val=0.5523
# 366 MSE train=0.2767 val=0.5432
# 367 MSE train=0.2757 val=0.5377
# 368 MSE train=0.2746 val=0.5391
# 369 MSE train=0.2743 val=0.5273
# 370 MSE train=0.2724 val=0.5322
# 371 MSE train=0.2730 val=0.5435
# 372 MSE train=0.2702 val=0.5332
# 373 MSE train=0.2716 val=0.5178
# 374 MSE train=0.2725 val=0.5157
# 375 MSE train=0.2679 val=0.5401
# 376 MSE train=0.2660 val=0.5321
# 377 MSE train=0.2649 val=0.5263
# 378 MSE train=0.2640 val=0.5188
# 379 MSE train=0.2628 val=0.5147
# 380 MSE train=0.2618 val=0.5083
# 381 MSE train=0.2605 val=0.5108
# 382 MSE train=0.2613 val=0.5284
# 383 MSE train=0.2601 val=0.5246
# 384 MSE train=0.2572 val=0.5104
# 385 MSE train=0.2571 val=0.5155
# 386 MSE train=0.2550 val=0.5030
# 387 MSE train=0.2539 val=0.4988
# 388 MSE train=0.2536 val=0.4887
# 389 MSE train=0.2519 val=0.4853
# 390 MSE train=0.2509 val=0.4911
# 391 MSE train=0.2498 val=0.4872
# 392 MSE train=0.2489 val=0.4808
# 393 MSE train=0.2476 val=0.4783
# 394 MSE train=0.2466 val=0.4731
# 395 MSE train=0.2476 val=0.4923
# 396 MSE train=0.2444 val=0.4746
# 397 MSE train=0.2433 val=0.4737
# 398 MSE train=0.2423 val=0.4706
# 399 MSE train=0.2432 val=0.4599
# 400 MSE train=0.2426 val=0.4826
# 401 MSE train=0.2393 val=0.4735
# 402 MSE train=0.2383 val=0.4705
# 403 MSE train=0.2384 val=0.4748
# 404 MSE train=0.2373 val=0.4506
# 405 MSE train=0.2350 val=0.4546
# 406 MSE train=0.2342 val=0.4587
# 407 MSE train=0.2330 val=0.4549
# 408 MSE train=0.2335 val=0.4433
# 409 MSE train=0.2312 val=0.4424
# 410 MSE train=0.2301 val=0.4511
# 411 MSE train=0.2288 val=0.4550
# 412 MSE train=0.2282 val=0.4441
# 413 MSE train=0.2268 val=0.4450
# 414 MSE train=0.2265 val=0.4360
# 415 MSE train=0.2252 val=0.4354
# 416 MSE train=0.2237 val=0.4357
# 417 MSE train=0.2234 val=0.4291
# 418 MSE train=0.2220 val=0.4308
# 419 MSE train=0.2220 val=0.4440
# 420 MSE train=0.2200 val=0.4359
# 421 MSE train=0.2189 val=0.4324
# 422 MSE train=0.2179 val=0.4326
# 423 MSE train=0.2174 val=0.4385
# 424 MSE train=0.2159 val=0.4327
# 425 MSE train=0.2150 val=0.4302
# 426 MSE train=0.2141 val=0.4199
# 427 MSE train=0.2132 val=0.4170
# 428 MSE train=0.2125 val=0.4105
# 429 MSE train=0.2143 val=0.4028
# 430 MSE train=0.2104 val=0.4067
# 431 MSE train=0.2093 val=0.4109
# 432 MSE train=0.2087 val=0.4123
# 433 MSE train=0.2074 val=0.4052
# 434 MSE train=0.2068 val=0.4086
# 435 MSE train=0.2057 val=0.4004
# 436 MSE train=0.2049 val=0.3975
# 437 MSE train=0.2040 val=0.4026
# 438 MSE train=0.2036 val=0.4055
# 439 MSE train=0.2022 val=0.4001
# 440 MSE train=0.2014 val=0.3892
# 441 MSE train=0.2010 val=0.4007
# 442 MSE train=0.1999 val=0.3862
# 443 MSE train=0.1995 val=0.3994
# 444 MSE train=0.1984 val=0.3985
# 445 MSE train=0.1974 val=0.3956
# 446 MSE train=0.1961 val=0.3868
# 447 MSE train=0.1955 val=0.3815
# 448 MSE train=0.1943 val=0.3841
# 449 MSE train=0.1964 val=0.3715
# 450 MSE train=0.1927 val=0.3822
# 451 MSE train=0.1917 val=0.3763
# 452 MSE train=0.1916 val=0.3692
# 453 MSE train=0.1903 val=0.3726
# 454 MSE train=0.1893 val=0.3767
# 455 MSE train=0.1889 val=0.3822
# 456 MSE train=0.1880 val=0.3679
# 457 MSE train=0.1871 val=0.3737
# 458 MSE train=0.1861 val=0.3666
# 459 MSE train=0.1854 val=0.3668
# 460 MSE train=0.1846 val=0.3636
# 461 MSE train=0.1849 val=0.3592
# 462 MSE train=0.1829 val=0.3593
# 463 MSE train=0.1824 val=0.3537
# 464 MSE train=0.1816 val=0.3627
# 465 MSE train=0.1807 val=0.3532
# 466 MSE train=0.1799 val=0.3566
# 467 MSE train=0.1791 val=0.3580
# 468 MSE train=0.1786 val=0.3495
# 469 MSE train=0.1776 val=0.3471
# 470 MSE train=0.1784 val=0.3414
# 471 MSE train=0.1765 val=0.3428
# 472 MSE train=0.1755 val=0.3450
# 473 MSE train=0.1747 val=0.3462
# 474 MSE train=0.1742 val=0.3482
# 475 MSE train=0.1735 val=0.3371
# 476 MSE train=0.1725 val=0.3409
# 477 MSE train=0.1718 val=0.3372
# 478 MSE train=0.1711 val=0.3342
# 479 MSE train=0.1709 val=0.3359
# 480 MSE train=0.1698 val=0.3348
# 481 MSE train=0.1690 val=0.3297
# 482 MSE train=0.1689 val=0.3243
# 483 MSE train=0.1692 val=0.3210
# 484 MSE train=0.1675 val=0.3205
# 485 MSE train=0.1667 val=0.3222
# 486 MSE train=0.1665 val=0.3206
# 487 MSE train=0.1651 val=0.3211
# 488 MSE train=0.1644 val=0.3242
# 489 MSE train=0.1639 val=0.3237
# 490 MSE train=0.1630 val=0.3199
# 491 MSE train=0.1624 val=0.3197
# 492 MSE train=0.1627 val=0.3089
# 493 MSE train=0.1625 val=0.3062
# 494 MSE train=0.1605 val=0.3069
# 495 MSE train=0.1598 val=0.3080
# 496 MSE train=0.1591 val=0.3068
# 497 MSE train=0.1587 val=0.3034
# 498 MSE train=0.1584 val=0.3012
# 499 MSE train=0.1574 val=0.3042
# 500 MSE train=0.1570 val=0.3091
# 501 MSE train=0.1561 val=0.3049
# 502 MSE train=0.1556 val=0.2999
# 503 MSE train=0.1556 val=0.3089
# 504 MSE train=0.1545 val=0.2975
# 505 MSE train=0.1542 val=0.3055
# 506 MSE train=0.1533 val=0.3023
# 507 MSE train=0.1527 val=0.2994
# 508 MSE train=0.1520 val=0.2963
# 509 MSE train=0.1521 val=0.2889
# 510 MSE train=0.1508 val=0.2928
# 511 MSE train=0.1507 val=0.2961
# 512 MSE train=0.1506 val=0.2989
# 513 MSE train=0.1509 val=0.2996
# 514 MSE train=0.1485 val=0.2889
# 515 MSE train=0.1493 val=0.2813
# 516 MSE train=0.1476 val=0.2892
# 517 MSE train=0.1470 val=0.2874
# 518 MSE train=0.1463 val=0.2822
# 519 MSE train=0.1459 val=0.2803
# 520 MSE train=0.1453 val=0.2800
# 521 MSE train=0.1460 val=0.2731
# 522 MSE train=0.1452 val=0.2708
# 523 MSE train=0.1443 val=0.2682
# 524 MSE train=0.1437 val=0.2772
# 525 MSE train=0.1427 val=0.2684
# 526 MSE train=0.1424 val=0.2703
# 527 MSE train=0.1420 val=0.2625
# 528 MSE train=0.1411 val=0.2653
# 529 MSE train=0.1406 val=0.2642
# 530 MSE train=0.1409 val=0.2697
# 531 MSE train=0.1400 val=0.2681
# 532 MSE train=0.1393 val=0.2634
# 533 MSE train=0.1387 val=0.2641
# 534 MSE train=0.1397 val=0.2554
# 535 MSE train=0.1378 val=0.2622
# 536 MSE train=0.1372 val=0.2609
# 537 MSE train=0.1386 val=0.2512
# 538 MSE train=0.1384 val=0.2479
# 539 MSE train=0.1359 val=0.2502
# 540 MSE train=0.1361 val=0.2608
# 541 MSE train=0.1349 val=0.2561
# 542 MSE train=0.1346 val=0.2504
# 543 MSE train=0.1347 val=0.2478
# 544 MSE train=0.1334 val=0.2494
# 545 MSE train=0.1331 val=0.2491
# 546 MSE train=0.1332 val=0.2514
# 547 MSE train=0.1321 val=0.2464
# 548 MSE train=0.1317 val=0.2468
# 549 MSE train=0.1323 val=0.2537
# 550 MSE train=0.1310 val=0.2503
# 551 MSE train=0.1311 val=0.2394
# 552 MSE train=0.1300 val=0.2439
# 553 MSE train=0.1299 val=0.2412
# 554 MSE train=0.1291 val=0.2422
# 555 MSE train=0.1296 val=0.2361
# 556 MSE train=0.1288 val=0.2352
# 557 MSE train=0.1280 val=0.2364
# 558 MSE train=0.1277 val=0.2417
# 559 MSE train=0.1271 val=0.2377
# 560 MSE train=0.1271 val=0.2331
# 561 MSE train=0.1264 val=0.2297
# 562 MSE train=0.1261 val=0.2327
# 563 MSE train=0.1259 val=0.2362
# 564 MSE train=0.1250 val=0.2291
# 565 MSE train=0.1247 val=0.2301
# 566 MSE train=0.1243 val=0.2271
# 567 MSE train=0.1245 val=0.2315
# 568 MSE train=0.1237 val=0.2285
# 569 MSE train=0.1232 val=0.2277
# 570 MSE train=0.1229 val=0.2285
# 571 MSE train=0.1224 val=0.2268
# 572 MSE train=0.1220 val=0.2243
# 573 MSE train=0.1216 val=0.2231
# 574 MSE train=0.1214 val=0.2211
# 575 MSE train=0.1210 val=0.2249
# 576 MSE train=0.1205 val=0.2221
# 577 MSE train=0.1202 val=0.2190
# 578 MSE train=0.1199 val=0.2229
# 579 MSE train=0.1195 val=0.2198
# 580 MSE train=0.1199 val=0.2231
# 581 MSE train=0.1198 val=0.2229
# 582 MSE train=0.1188 val=0.2158
# 583 MSE train=0.1192 val=0.2138
# 584 MSE train=0.1178 val=0.2174
# 585 MSE train=0.1175 val=0.2179
# 586 MSE train=0.1175 val=0.2114
# 587 MSE train=0.1168 val=0.2134
# 588 MSE train=0.1165 val=0.2120
# 589 MSE train=0.1161 val=0.2097
# 590 MSE train=0.1158 val=0.2108
# 591 MSE train=0.1156 val=0.2108
# 592 MSE train=0.1151 val=0.2079
# 593 MSE train=0.1150 val=0.2031
# 594 MSE train=0.1145 val=0.2050
# 595 MSE train=0.1142 val=0.2061
# 596 MSE train=0.1139 val=0.2082
# 597 MSE train=0.1136 val=0.2073
# 598 MSE train=0.1134 val=0.2056
# 599 MSE train=0.1130 val=0.2000
# 600 MSE train=0.1128 val=0.1977
# 601 MSE train=0.1125 val=0.1996
# 602 MSE train=0.1122 val=0.1976
# 603 MSE train=0.1118 val=0.1998
# 604 MSE train=0.1122 val=0.2015
# 605 MSE train=0.1112 val=0.1960
# 606 MSE train=0.1114 val=0.1931
# 607 MSE train=0.1107 val=0.1956
# 608 MSE train=0.1106 val=0.1931
# 609 MSE train=0.1102 val=0.1946
# 610 MSE train=0.1100 val=0.1927
# 611 MSE train=0.1095 val=0.1932
# 612 MSE train=0.1094 val=0.1947
# 613 MSE train=0.1099 val=0.1982
# 614 MSE train=0.1096 val=0.1982
# 615 MSE train=0.1086 val=0.1900
# 616 MSE train=0.1082 val=0.1918
# 617 MSE train=0.1079 val=0.1909
# 618 MSE train=0.1079 val=0.1941
# 619 MSE train=0.1075 val=0.1923
# 620 MSE train=0.1074 val=0.1921
# 621 MSE train=0.1073 val=0.1926
# 622 MSE train=0.1068 val=0.1882
# 623 MSE train=0.1065 val=0.1864
# 624 MSE train=0.1063 val=0.1834
# 625 MSE train=0.1062 val=0.1866
# 626 MSE train=0.1065 val=0.1815
# 627 MSE train=0.1056 val=0.1828
# 628 MSE train=0.1053 val=0.1819
# 629 MSE train=0.1057 val=0.1797
# 630 MSE train=0.1048 val=0.1832
# 631 MSE train=0.1045 val=0.1821
# 632 MSE train=0.1043 val=0.1813
# 633 MSE train=0.1040 val=0.1832
# 634 MSE train=0.1038 val=0.1807
# 635 MSE train=0.1036 val=0.1814
# 636 MSE train=0.1034 val=0.1788
# 637 MSE train=0.1032 val=0.1790
# 638 MSE train=0.1029 val=0.1787
# 639 MSE train=0.1027 val=0.1807
# 640 MSE train=0.1024 val=0.1784
# 641 MSE train=0.1023 val=0.1799
# 642 MSE train=0.1021 val=0.1771
# 643 MSE train=0.1018 val=0.1763
# 644 MSE train=0.1016 val=0.1768
# 645 MSE train=0.1014 val=0.1750
# 646 MSE train=0.1012 val=0.1740
# 647 MSE train=0.1012 val=0.1722
# 648 MSE train=0.1008 val=0.1742
# 649 MSE train=0.1011 val=0.1773
# 650 MSE train=0.1003 val=0.1749
# 651 MSE train=0.1006 val=0.1745
# 652 MSE train=0.1001 val=0.1744
# 653 MSE train=0.1010 val=0.1667
# 654 MSE train=0.0996 val=0.1707
# 655 MSE train=0.0993 val=0.1695
# 656 MSE train=0.1000 val=0.1743
# 657 MSE train=0.0994 val=0.1731
# 658 MSE train=0.0989 val=0.1720
# 659 MSE train=0.0988 val=0.1727
# 660 MSE train=0.0984 val=0.1707
# 661 MSE train=0.0984 val=0.1650
# 662 MSE train=0.0983 val=0.1640
# 663 MSE train=0.0979 val=0.1648
# 664 MSE train=0.0978 val=0.1650
# 665 MSE train=0.0975 val=0.1670
# 666 MSE train=0.0974 val=0.1644
# 667 MSE train=0.0974 val=0.1622
# 668 MSE train=0.0969 val=0.1653
# 669 MSE train=0.0971 val=0.1666
# 670 MSE train=0.0967 val=0.1624
# 671 MSE train=0.0964 val=0.1637
# 672 MSE train=0.0966 val=0.1671
# 673 MSE train=0.0961 val=0.1642
# 674 MSE train=0.0961 val=0.1628
# 675 MSE train=0.0964 val=0.1607
# 676 MSE train=0.0958 val=0.1642
# 677 MSE train=0.0957 val=0.1632
# 678 MSE train=0.0953 val=0.1638
# 679 MSE train=0.0955 val=0.1579
# 680 MSE train=0.0950 val=0.1596
# 681 MSE train=0.0950 val=0.1613
# 682 MSE train=0.0949 val=0.1604
# 683 MSE train=0.0945 val=0.1564
# 684 MSE train=0.0943 val=0.1574
# 685 MSE train=0.0941 val=0.1571
# 686 MSE train=0.0940 val=0.1595
# 687 MSE train=0.0942 val=0.1585
# 688 MSE train=0.0940 val=0.1567
# 689 MSE train=0.0936 val=0.1594
# 690 MSE train=0.0934 val=0.1589
# 691 MSE train=0.0933 val=0.1555
# 692 MSE train=0.0931 val=0.1562
# 693 MSE train=0.0930 val=0.1566
# 694 MSE train=0.0928 val=0.1574
# 695 MSE train=0.0927 val=0.1565
# 696 MSE train=0.0927 val=0.1580
# 697 MSE train=0.0926 val=0.1528
# 698 MSE train=0.0926 val=0.1580
# 699 MSE train=0.0921 val=0.1547
# 700 MSE train=0.0922 val=0.1566
# 701 MSE train=0.0922 val=0.1525
# 702 MSE train=0.0930 val=0.1512
# 703 MSE train=0.0916 val=0.1535
# 704 MSE train=0.0915 val=0.1524
# 705 MSE train=0.0913 val=0.1539
# 706 MSE train=0.0914 val=0.1560
# 707 MSE train=0.0913 val=0.1531
# 708 MSE train=0.0909 val=0.1532
# 709 MSE train=0.0908 val=0.1522
# 710 MSE train=0.0906 val=0.1506
# 711 MSE train=0.0914 val=0.1483
# 712 MSE train=0.0904 val=0.1501
# 713 MSE train=0.0905 val=0.1512
# 714 MSE train=0.0901 val=0.1489
# 715 MSE train=0.0906 val=0.1533
# 716 MSE train=0.0901 val=0.1518
# 717 MSE train=0.0902 val=0.1467
# 718 MSE train=0.0897 val=0.1480
# 719 MSE train=0.0896 val=0.1498
# 720 MSE train=0.0896 val=0.1505
# 721 MSE train=0.0893 val=0.1480
# 722 MSE train=0.0892 val=0.1490
# 723 MSE train=0.0894 val=0.1495
# 724 MSE train=0.0889 val=0.1466
# 725 MSE train=0.0896 val=0.1492
# 726 MSE train=0.0888 val=0.1449
# 727 MSE train=0.0889 val=0.1464
# 728 MSE train=0.0885 val=0.1484
# 729 MSE train=0.0884 val=0.1455
# 730 MSE train=0.0884 val=0.1471
# 731 MSE train=0.0894 val=0.1517
# 732 MSE train=0.0880 val=0.1456
# 733 MSE train=0.0883 val=0.1424
# 734 MSE train=0.0878 val=0.1427
# 735 MSE train=0.0881 val=0.1420
# 736 MSE train=0.0876 val=0.1428
# 737 MSE train=0.0878 val=0.1453
# 738 MSE train=0.0875 val=0.1469
# 739 MSE train=0.0881 val=0.1419
# 740 MSE train=0.0880 val=0.1394
# 741 MSE train=0.0871 val=0.1421
# 742 MSE train=0.0870 val=0.1425
# 743 MSE train=0.0869 val=0.1423
# 744 MSE train=0.0868 val=0.1427
# 745 MSE train=0.0867 val=0.1415
# 746 MSE train=0.0868 val=0.1389
# 747 MSE train=0.0869 val=0.1382
# 748 MSE train=0.0864 val=0.1386
# 749 MSE train=0.0865 val=0.1380
# 750 MSE train=0.0862 val=0.1398
# 751 MSE train=0.0861 val=0.1399
# 752 MSE train=0.0865 val=0.1430
# 753 MSE train=0.0861 val=0.1419
# 754 MSE train=0.0862 val=0.1427
# 755 MSE train=0.0858 val=0.1416
# 756 MSE train=0.0857 val=0.1403
# 757 MSE train=0.0857 val=0.1409
# 758 MSE train=0.0855 val=0.1384
# 759 MSE train=0.0855 val=0.1390
# 760 MSE train=0.0855 val=0.1418
# 761 MSE train=0.0852 val=0.1391
# 762 MSE train=0.0852 val=0.1390
# 763 MSE train=0.0859 val=0.1400
# 764 MSE train=0.0850 val=0.1368
# 765 MSE train=0.0849 val=0.1365
# 766 MSE train=0.0849 val=0.1347
# 767 MSE train=0.0848 val=0.1363
# 768 MSE train=0.0850 val=0.1400
# 769 MSE train=0.0849 val=0.1353
# 770 MSE train=0.0845 val=0.1348
# 771 MSE train=0.0846 val=0.1376
# 772 MSE train=0.0846 val=0.1363
# 773 MSE train=0.0847 val=0.1388
# 774 MSE train=0.0844 val=0.1380
# 775 MSE train=0.0841 val=0.1367
# 776 MSE train=0.0841 val=0.1360
# 777 MSE train=0.0840 val=0.1369
# 778 MSE train=0.0841 val=0.1344
# 779 MSE train=0.0841 val=0.1339
# 780 MSE train=0.0839 val=0.1379
# 781 MSE train=0.0840 val=0.1349
# 782 MSE train=0.0842 val=0.1349
# 783 MSE train=0.0835 val=0.1370
# 784 MSE train=0.0836 val=0.1352
# 785 MSE train=0.0838 val=0.1330
# 786 MSE train=0.0832 val=0.1335
# 787 MSE train=0.0835 val=0.1343
# 788 MSE train=0.0832 val=0.1343
# 789 MSE train=0.0832 val=0.1361
# 790 MSE train=0.0831 val=0.1356
# 791 MSE train=0.0829 val=0.1339
# 792 MSE train=0.0829 val=0.1307
# 793 MSE train=0.0829 val=0.1332
# 794 MSE train=0.0830 val=0.1333
# 795 MSE train=0.0827 val=0.1318
# 796 MSE train=0.0826 val=0.1338
# 797 MSE train=0.0832 val=0.1372
# 798 MSE train=0.0825 val=0.1355
# 799 MSE train=0.0829 val=0.1382
# 800 MSE train=0.0823 val=0.1353
# 801 MSE train=0.0823 val=0.1336
# 802 MSE train=0.0822 val=0.1317
# 803 MSE train=0.0822 val=0.1335
# 804 MSE train=0.0821 val=0.1331
# 805 MSE train=0.0820 val=0.1321
# 806 MSE train=0.0825 val=0.1300
# 807 MSE train=0.0818 val=0.1308
# 808 MSE train=0.0818 val=0.1329
# 809 MSE train=0.0819 val=0.1320
# 810 MSE train=0.0818 val=0.1296
# 811 MSE train=0.0816 val=0.1308
# 812 MSE train=0.0819 val=0.1329
# 813 MSE train=0.0819 val=0.1321
# 814 MSE train=0.0816 val=0.1312
# 815 MSE train=0.0814 val=0.1310
# 816 MSE train=0.0813 val=0.1305
# 817 MSE train=0.0813 val=0.1324
# 818 MSE train=0.0814 val=0.1293
# 819 MSE train=0.0821 val=0.1334
# 820 MSE train=0.0817 val=0.1346
# 821 MSE train=0.0810 val=0.1309
# 822 MSE train=0.0809 val=0.1310
# 823 MSE train=0.0809 val=0.1317
# 824 MSE train=0.0810 val=0.1319
# 825 MSE train=0.0810 val=0.1295
# 826 MSE train=0.0811 val=0.1276
# 827 MSE train=0.0807 val=0.1301
# 828 MSE train=0.0806 val=0.1288
# 829 MSE train=0.0806 val=0.1288
# 830 MSE train=0.0806 val=0.1273
# 831 MSE train=0.0804 val=0.1281
# 832 MSE train=0.0804 val=0.1302
# 833 MSE train=0.0811 val=0.1325
# 834 MSE train=0.0803 val=0.1311
# 835 MSE train=0.0803 val=0.1306
# 836 MSE train=0.0802 val=0.1311
# 837 MSE train=0.0804 val=0.1274
# 838 MSE train=0.0801 val=0.1293
# 839 MSE train=0.0801 val=0.1287
# 840 MSE train=0.0801 val=0.1296
# 841 MSE train=0.0799 val=0.1286
# 842 MSE train=0.0799 val=0.1292
# 843 MSE train=0.0798 val=0.1282
# 844 MSE train=0.0798 val=0.1291
# 845 MSE train=0.0797 val=0.1274
# 846 MSE train=0.0798 val=0.1282
# 847 MSE train=0.0799 val=0.1263
# 848 MSE train=0.0797 val=0.1257
# 849 MSE train=0.0798 val=0.1254
# 850 MSE train=0.0799 val=0.1283
# 851 MSE train=0.0799 val=0.1280
# 852 MSE train=0.0801 val=0.1302
# 853 MSE train=0.0800 val=0.1292
# 854 MSE train=0.0793 val=0.1258
# 855 MSE train=0.0796 val=0.1257
# 856 MSE train=0.0794 val=0.1237
# 857 MSE train=0.0793 val=0.1245
# 858 MSE train=0.0791 val=0.1262
# 859 MSE train=0.0800 val=0.1285
# 860 MSE train=0.0791 val=0.1246
# 861 MSE train=0.0790 val=0.1269
# 862 MSE train=0.0790 val=0.1262
# 863 MSE train=0.0791 val=0.1290
# 864 MSE train=0.0788 val=0.1264
# 865 MSE train=0.0789 val=0.1278
# 866 MSE train=0.0788 val=0.1254
# 867 MSE train=0.0790 val=0.1280
# 868 MSE train=0.0787 val=0.1266
# 869 MSE train=0.0786 val=0.1260
# 870 MSE train=0.0786 val=0.1270
# 871 MSE train=0.0787 val=0.1265
# 872 MSE train=0.0785 val=0.1248
# 873 MSE train=0.0785 val=0.1249
# 874 MSE train=0.0785 val=0.1234
# 875 MSE train=0.0784 val=0.1250
# 876 MSE train=0.0785 val=0.1264
# 877 MSE train=0.0783 val=0.1242
# 878 MSE train=0.0785 val=0.1246
# 879 MSE train=0.0783 val=0.1271
# 880 MSE train=0.0783 val=0.1263
# 881 MSE train=0.0782 val=0.1261
# 882 MSE train=0.0783 val=0.1270
# 883 MSE train=0.0781 val=0.1263
# 884 MSE train=0.0791 val=0.1306
# 885 MSE train=0.0785 val=0.1295
# 886 MSE train=0.0783 val=0.1276
# 887 MSE train=0.0779 val=0.1252
# 888 MSE train=0.0779 val=0.1238
# 889 MSE train=0.0778 val=0.1237
# 890 MSE train=0.0778 val=0.1240
# 891 MSE train=0.0780 val=0.1263
# 892 MSE train=0.0779 val=0.1263
# 893 MSE train=0.0777 val=0.1245
# 894 MSE train=0.0777 val=0.1243
# 895 MSE train=0.0776 val=0.1258
# 896 MSE train=0.0776 val=0.1256
# 897 MSE train=0.0776 val=0.1258
# 898 MSE train=0.0776 val=0.1255
# 899 MSE train=0.0776 val=0.1254
# 900 MSE train=0.0780 val=0.1284
# 901 MSE train=0.0775 val=0.1274
# 902 MSE train=0.0774 val=0.1257
# 903 MSE train=0.0774 val=0.1251
# 904 MSE train=0.0773 val=0.1237
# 905 MSE train=0.0777 val=0.1210
# 906 MSE train=0.0774 val=0.1235
# 907 MSE train=0.0773 val=0.1257
# 908 MSE train=0.0777 val=0.1216
# 909 MSE train=0.0771 val=0.1220
# 910 MSE train=0.0773 val=0.1202
# 911 MSE train=0.0771 val=0.1211
# 912 MSE train=0.0773 val=0.1227
# 913 MSE train=0.0772 val=0.1206
# 914 MSE train=0.0770 val=0.1240
# 915 MSE train=0.0772 val=0.1249
# 916 MSE train=0.0770 val=0.1255
# 917 MSE train=0.0769 val=0.1219
# 918 MSE train=0.0769 val=0.1219
# 919 MSE train=0.0768 val=0.1213
# 920 MSE train=0.0770 val=0.1193
# 921 MSE train=0.0770 val=0.1209
# 922 MSE train=0.0770 val=0.1209
# 923 MSE train=0.0778 val=0.1193
# 924 MSE train=0.0767 val=0.1213
# 925 MSE train=0.0766 val=0.1231
# 926 MSE train=0.0766 val=0.1206
# 927 MSE train=0.0766 val=0.1205
# 928 MSE train=0.0766 val=0.1189
# 929 MSE train=0.0766 val=0.1224
# 930 MSE train=0.0765 val=0.1203
# 931 MSE train=0.0764 val=0.1222
# 932 MSE train=0.0765 val=0.1229
# 933 MSE train=0.0764 val=0.1240
# 934 MSE train=0.0767 val=0.1228
# 935 MSE train=0.0763 val=0.1226
# 936 MSE train=0.0764 val=0.1229
# 937 MSE train=0.0763 val=0.1226
# 938 MSE train=0.0769 val=0.1195
# 939 MSE train=0.0762 val=0.1208
# 940 MSE train=0.0761 val=0.1213
# 941 MSE train=0.0762 val=0.1215
# 942 MSE train=0.0761 val=0.1202
# 943 MSE train=0.0761 val=0.1208
# 944 MSE train=0.0761 val=0.1202
# 945 MSE train=0.0760 val=0.1192
# 946 MSE train=0.0760 val=0.1205
# 947 MSE train=0.0765 val=0.1222
# 948 MSE train=0.0760 val=0.1221
# 949 MSE train=0.0762 val=0.1234
# 950 MSE train=0.0763 val=0.1249
# 951 MSE train=0.0759 val=0.1230
# 952 MSE train=0.0758 val=0.1226
# 953 MSE train=0.0765 val=0.1253
# 954 MSE train=0.0759 val=0.1231
# 955 MSE train=0.0762 val=0.1242
# 956 MSE train=0.0764 val=0.1258
# 957 MSE train=0.0760 val=0.1252
# 958 MSE train=0.0757 val=0.1215
# 959 MSE train=0.0758 val=0.1211
# 960 MSE train=0.0756 val=0.1233
# 961 MSE train=0.0759 val=0.1246
# 962 MSE train=0.0756 val=0.1211
# 963 MSE train=0.0755 val=0.1194
# 964 MSE train=0.0756 val=0.1210
# 965 MSE train=0.0756 val=0.1218
# 966 MSE train=0.0758 val=0.1176
# 967 MSE train=0.0756 val=0.1177
# 968 MSE train=0.0758 val=0.1220
# 969 MSE train=0.0754 val=0.1189
# 970 MSE train=0.0754 val=0.1196
# 971 MSE train=0.0755 val=0.1224
# 972 MSE train=0.0753 val=0.1208
# 973 MSE train=0.0754 val=0.1212
# 974 MSE train=0.0752 val=0.1205
# 975 MSE train=0.0761 val=0.1247
# 976 MSE train=0.0754 val=0.1231
# 977 MSE train=0.0754 val=0.1231
# 978 MSE train=0.0752 val=0.1233
# 979 MSE train=0.0752 val=0.1232
# 980 MSE train=0.0751 val=0.1225
# 981 MSE train=0.0751 val=0.1228
# 982 MSE train=0.0753 val=0.1193
# 983 MSE train=0.0751 val=0.1197
# 984 MSE train=0.0751 val=0.1178
# 985 MSE train=0.0750 val=0.1201
# 986 MSE train=0.0750 val=0.1204
# 987 MSE train=0.0750 val=0.1202
# 988 MSE train=0.0750 val=0.1193
# 989 MSE train=0.0749 val=0.1209
# 990 MSE train=0.0749 val=0.1189
# 991 MSE train=0.0748 val=0.1181
# 992 MSE train=0.0753 val=0.1176
# 993 MSE train=0.0748 val=0.1183
# 994 MSE train=0.0748 val=0.1189
# 995 MSE train=0.0748 val=0.1172
# 996 MSE train=0.0747 val=0.1185
# 997 MSE train=0.0747 val=0.1195
# 998 MSE train=0.0749 val=0.1204
# 999 MSE train=0.0746 val=0.1181

# %% [markdown]
# ... and plot the training metrics (which feature overfitting) ...

# %%
from plotting import plot_mse_train_vs_val

### plot_mse_train_vs_val(mse_train, mse_val)

# %% [markdown]
# ... and the predictions for the training set ...

# %%
plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train), fig_name="fig_02_19a.pdf")  ### plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train))

# %%
plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train), fig_name="fig_02_19b.pdf")  ### plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train))

# %% [markdown]
# ... the predictions for the validation set ...

# %%
plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val), fig_name="fig_02_19c.pdf")  ### plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val))

# %%
plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val), fig_name="fig_02_19d.pdf")  ### plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val))

# %% [markdown]
# ... and the predictions for the test set.

# %%
(x_test, y_gt_test) = load_data(filename="data_reg_2d_nonlinear_test.csv")

plot_pred_2d(x_test, y_gt_test, y_p=dnn2_reg(wa, wb, x_test), fig_name="fig_02_19e.pdf")  ### plot_pred_2d(x_test, y_gt_test, y_p=dnn2_reg(wa, wb, x_test))

# %%
plot_pred_vs_gt(y_gt_test, y_p=dnn2_reg(wa, wb, x_test), fig_name="fig_02_19f.pdf")  ### plot_pred_vs_gt(y_gt_test, y_p=dnn2_reg(wa, wb, x_test))
