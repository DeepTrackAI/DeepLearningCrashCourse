# %% [markdown]
# # Training a Neural Network Splitting the Data
#
# This notebook provides you with a complete code example that loads the data contained in the `data_reg_2d_nonlinear.csv` file and splits them into a training, a validation, and a test set. Then, it trains a two-layer neural network using the training data, while monitoring the training and validation MSE. Finally, it uses the trained network to predict the values of the test data (test hold-out dataset) in the `data_reg_2d_linear_test.csv` file.

# %% [markdown]
# ## Loading and Splitting the Data

# %%
from loader import load_data

(x, y_gt) = load_data(filename="data_reg_2d_nonlinear.csv")

# %%
from numpy import delete, split
from numpy.random import choice

num_samples = len(x)
split = .70

num_samples_train = int(split * num_samples)
train_idx = choice(num_samples, num_samples_train, replace=False)

x_train = x[train_idx]  # Train inputs.
y_gt_train = y_gt[train_idx]  # Train ground truths.

x_val = delete(x, train_idx, axis=0)  # Validation inputs.
y_gt_val = delete(y_gt, train_idx, axis=0)  # Validation ground truths.

# %% [markdown]
# ## Implementing a Dense Neural Network
#
# Implement the sigmoidal function

# %%
from numpy import exp

def sigmoid(x):
    """Sigmoid function."""
    return 1 / (1 + exp(-x))

# %% [markdown]
# ... implement a function to define the neural network ...

# %%
def dnn2_reg(wa, wb, x):
    """Two-layer dense neural network for classification."""
    return sigmoid(x @ wa) @ wb

# %% [markdown]
# ... define the number of neurons of the first layer ...

# %%
num_neurons = 10

# %% [markdown]
# ... randomly initialize its weights ...

# %%
from numpy.random import default_rng

rng = default_rng()
wa = rng.standard_normal(size=(2, num_neurons)) # Input weights layer 1.
wb = rng.standard_normal(size=(num_neurons, 1)) # Input weights layer 2.

# %% [markdown]
# ... obtain its predictions for the training and validation datasets ...

# %%
y_p_train = dnn2_reg(wa, wb, x_train)
y_p_val = dnn2_reg(wa, wb, x_val)

# %% [markdown]
# ... and plot its predictions for the training dataset ...

# %%
from plotting import plot_pred_2d, plot_pred_vs_gt

### plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train))
### plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train))

# %% [markdown]
# ... and for the validation dataset.

# %%
### plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val))
### plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val))

# %% [markdown]
# ## Training and Validating the Neural Network
#
# Implement the first derivative of the sigmoid function ...

# %%
def d_sigmoid(x):
    """Derivative of sigmoid function."""
    return sigmoid(x) * (1 - sigmoid(x))

# %% [markdown]
# ... implement the backpropagation algorithm with mini-batches ...

# %%
from numpy import mean, reshape, sum, transpose, zeros
from numpy.random import permutation

num_samnum_samples_trainples = len(x_train)
num_batches = 7
batch_size = int(num_samples / num_batches)
num_epochs = 10 ** 3
eta = .1 # Learning rate.

mse_train = zeros((num_epochs,))
mse_val = zeros((num_epochs,))

for epoch in range(num_epochs):
    # Permute samples.
    permuted_order_samples = permutation(num_samples_train)
    x_permuted = x_train[permuted_order_samples]
    y_gt_permuted = y_gt_train[permuted_order_samples]

    for batch_start in range(0, num_samples_train, batch_size):
        dwa = zeros(wa.shape) # Initialize weight increments layer 1.
        dwb = zeros(wb.shape) # Initialize weight increments layer 2.
        
        for selected in range(batch_start, batch_start + batch_size):
            x_selected = reshape(x_permuted[selected], (1, -1))
            y_gt_selected = reshape(y_gt_permuted[selected], (1, -1))
            
            # Detailed neural network calculation.
            x_selected_a = x_selected # Input layer 1.
            p_a = x_selected_a @ wa # Activation potential layer 1.
            y_selected_a = sigmoid(p_a) # Output layer 1.

            x_selected_b = y_selected_a # Input layer 2.
            p_b = x_selected_b @ wb # Activation potential layer 2.
            y_selected_b = p_b # Output neuron layer 2 (output neuron).

            y_p_selected = y_selected_b
    
            # Update weights.
            error = y_p_selected - y_gt_selected
    
            delta_b = error * 1
            dwb -= eta * delta_b * transpose(x_selected_b)

            delta_a = sum(wb * delta_b, axis=1) * d_sigmoid(p_a)
            dwa -= eta * delta_a * transpose(x_selected_a)
    
        wa += dwa / batch_size # Update weights layer 1.
        wb += dwb / batch_size # Update weights layer 2.
        
    y_p_train = dnn2_reg(wa, wb, x_train)
    mse_train[epoch] = mean((y_p_train - y_gt_train) ** 2)
    
    y_p_val = dnn2_reg(wa, wb, x_val)
    mse_val[epoch] = mean((y_p_val - y_gt_val) ** 2)
    
    print(f"{epoch} MSE train={mse_train[epoch]:.4f} val={mse_val[epoch]:.4f}")
# Out:
# 0 MSE train=0.6412 val=0.7371
# 1 MSE train=0.5965 val=0.6950
# 2 MSE train=0.5694 val=0.5949
# 3 MSE train=0.5403 val=0.5908
# 4 MSE train=0.5264 val=0.5626
# 5 MSE train=0.5144 val=0.5650
# 6 MSE train=0.5145 val=0.5267
# 7 MSE train=0.5024 val=0.5342
# 8 MSE train=0.4983 val=0.5461
# 9 MSE train=0.4957 val=0.5272
# 10 MSE train=0.4992 val=0.5127
# 11 MSE train=0.4927 val=0.5175
# 12 MSE train=0.4896 val=0.5300
# 13 MSE train=0.4884 val=0.5214
# 14 MSE train=0.4890 val=0.5355
# 15 MSE train=0.4882 val=0.5330
# 16 MSE train=0.4869 val=0.5143
# 17 MSE train=0.4857 val=0.5204
# 18 MSE train=0.4853 val=0.5219
# 19 MSE train=0.4928 val=0.5490
# 20 MSE train=0.5035 val=0.5716
# 21 MSE train=0.4915 val=0.5453
# 22 MSE train=0.4847 val=0.5233
# 23 MSE train=0.4837 val=0.5164
# 24 MSE train=0.4885 val=0.5373
# 25 MSE train=0.4881 val=0.5362
# 26 MSE train=0.4833 val=0.5176
# 27 MSE train=0.4847 val=0.5255
# 28 MSE train=0.4830 val=0.5087
# 29 MSE train=0.4865 val=0.5011
# 30 MSE train=0.4827 val=0.5079
# 31 MSE train=0.4832 val=0.5054
# 32 MSE train=0.4828 val=0.5187
# 33 MSE train=0.4826 val=0.5056
# 34 MSE train=0.4865 val=0.5319
# 35 MSE train=0.4828 val=0.5037
# 36 MSE train=0.4837 val=0.5233
# 37 MSE train=0.4836 val=0.5230
# 38 MSE train=0.4818 val=0.5152
# 39 MSE train=0.4816 val=0.5048
# 40 MSE train=0.4812 val=0.5117
# 41 MSE train=0.4810 val=0.5098
# 42 MSE train=0.4821 val=0.5016
# 43 MSE train=0.4807 val=0.5083
# 44 MSE train=0.4884 val=0.5367
# 45 MSE train=0.4807 val=0.5051
# 46 MSE train=0.4813 val=0.5018
# 47 MSE train=0.4803 val=0.5083
# 48 MSE train=0.4805 val=0.5035
# 49 MSE train=0.4809 val=0.5017
# 50 MSE train=0.4813 val=0.5000
# 51 MSE train=0.4812 val=0.5000
# 52 MSE train=0.4831 val=0.5233
# 53 MSE train=0.4807 val=0.5152
# 54 MSE train=0.4797 val=0.5059
# 55 MSE train=0.4814 val=0.4986
# 56 MSE train=0.4805 val=0.5153
# 57 MSE train=0.4795 val=0.5095
# 58 MSE train=0.4795 val=0.5101
# 59 MSE train=0.4855 val=0.5313
# 60 MSE train=0.4792 val=0.5087
# 61 MSE train=0.4821 val=0.4959
# 62 MSE train=0.4934 val=0.4919
# 63 MSE train=0.4809 val=0.5187
# 64 MSE train=0.4814 val=0.5205
# 65 MSE train=0.4790 val=0.5105
# 66 MSE train=0.4787 val=0.5089
# 67 MSE train=0.4788 val=0.5010
# 68 MSE train=0.4789 val=0.4999
# 69 MSE train=0.4798 val=0.4971
# 70 MSE train=0.4788 val=0.5117
# 71 MSE train=0.4862 val=0.5344
# 72 MSE train=0.4837 val=0.5285
# 73 MSE train=0.4780 val=0.5021
# 74 MSE train=0.4782 val=0.5093
# 75 MSE train=0.4782 val=0.4995
# 76 MSE train=0.4776 val=0.5050
# 77 MSE train=0.4793 val=0.5161
# 78 MSE train=0.4777 val=0.5003
# 79 MSE train=0.4800 val=0.5189
# 80 MSE train=0.4816 val=0.5239
# 81 MSE train=0.4772 val=0.5046
# 82 MSE train=0.4780 val=0.5120
# 83 MSE train=0.4775 val=0.5096
# 84 MSE train=0.4780 val=0.5127
# 85 MSE train=0.4817 val=0.4918
# 86 MSE train=0.4780 val=0.4962
# 87 MSE train=0.4785 val=0.4949
# 88 MSE train=0.4798 val=0.5199
# 89 MSE train=0.4765 val=0.5012
# 90 MSE train=0.4778 val=0.5133
# 91 MSE train=0.4775 val=0.5121
# 92 MSE train=0.4763 val=0.5054
# 93 MSE train=0.4780 val=0.4945
# 94 MSE train=0.4761 val=0.5047
# 95 MSE train=0.4838 val=0.5313
# 96 MSE train=0.4764 val=0.5082
# 97 MSE train=0.4773 val=0.5128
# 98 MSE train=0.4872 val=0.5394
# 99 MSE train=0.4791 val=0.5195
# 100 MSE train=0.4775 val=0.4933
# 101 MSE train=0.4755 val=0.5042
# 102 MSE train=0.4762 val=0.5093
# 103 MSE train=0.4822 val=0.5282
# 104 MSE train=0.4756 val=0.4968
# 105 MSE train=0.4761 val=0.4948
# 106 MSE train=0.4751 val=0.4998
# 107 MSE train=0.4751 val=0.4986
# 108 MSE train=0.4749 val=0.5012
# 109 MSE train=0.4749 val=0.5039
# 110 MSE train=0.4747 val=0.5018
# 111 MSE train=0.4825 val=0.4877
# 112 MSE train=0.4789 val=0.4894
# 113 MSE train=0.4756 val=0.5101
# 114 MSE train=0.4747 val=0.4970
# 115 MSE train=0.4744 val=0.5033
# 116 MSE train=0.4743 val=0.4992
# 117 MSE train=0.4756 val=0.5115
# 118 MSE train=0.4755 val=0.5110
# 119 MSE train=0.4740 val=0.5005
# 120 MSE train=0.4739 val=0.4998
# 121 MSE train=0.4739 val=0.4977
# 122 MSE train=0.4749 val=0.4933
# 123 MSE train=0.4740 val=0.4957
# 124 MSE train=0.4739 val=0.4958
# 125 MSE train=0.4770 val=0.5183
# 126 MSE train=0.4735 val=0.5030
# 127 MSE train=0.4734 val=0.4972
# 128 MSE train=0.4770 val=0.5186
# 129 MSE train=0.4740 val=0.4938
# 130 MSE train=0.4754 val=0.4904
# 131 MSE train=0.4733 val=0.4954
# 132 MSE train=0.4768 val=0.4889
# 133 MSE train=0.4754 val=0.5149
# 134 MSE train=0.4728 val=0.5030
# 135 MSE train=0.4732 val=0.4941
# 136 MSE train=0.4730 val=0.4943
# 137 MSE train=0.4737 val=0.4920
# 138 MSE train=0.4724 val=0.5021
# 139 MSE train=0.4726 val=0.4949
# 140 MSE train=0.4722 val=0.5011
# 141 MSE train=0.4724 val=0.4947
# 142 MSE train=0.4721 val=0.4954
# 143 MSE train=0.4732 val=0.5092
# 144 MSE train=0.4741 val=0.5131
# 145 MSE train=0.4718 val=0.5019
# 146 MSE train=0.4716 val=0.4989
# 147 MSE train=0.4725 val=0.4920
# 148 MSE train=0.4727 val=0.4912
# 149 MSE train=0.4731 val=0.4898
# 150 MSE train=0.4714 val=0.4949
# 151 MSE train=0.4716 val=0.4937
# 152 MSE train=0.4711 val=0.5012
# 153 MSE train=0.4735 val=0.5129
# 154 MSE train=0.4750 val=0.5180
# 155 MSE train=0.4762 val=0.5215
# 156 MSE train=0.4727 val=0.5110
# 157 MSE train=0.4706 val=0.4967
# 158 MSE train=0.4709 val=0.4929
# 159 MSE train=0.4725 val=0.5113
# 160 MSE train=0.4704 val=0.4943
# 161 MSE train=0.4733 val=0.5145
# 162 MSE train=0.4703 val=0.5018
# 163 MSE train=0.4705 val=0.5038
# 164 MSE train=0.4699 val=0.4946
# 165 MSE train=0.4697 val=0.4967
# 166 MSE train=0.4701 val=0.4923
# 167 MSE train=0.4719 val=0.5113
# 168 MSE train=0.4698 val=0.4922
# 169 MSE train=0.4703 val=0.5060
# 170 MSE train=0.4803 val=0.5342
# 171 MSE train=0.4695 val=0.5027
# 172 MSE train=0.4692 val=0.4928
# 173 MSE train=0.4700 val=0.4892
# 174 MSE train=0.4695 val=0.4902
# 175 MSE train=0.4687 val=0.4939
# 176 MSE train=0.4705 val=0.4875
# 177 MSE train=0.4744 val=0.4829
# 178 MSE train=0.4683 val=0.4949
# 179 MSE train=0.4690 val=0.5048
# 180 MSE train=0.4697 val=0.5082
# 181 MSE train=0.4681 val=0.4930
# 182 MSE train=0.4680 val=0.5005
# 183 MSE train=0.4676 val=0.4964
# 184 MSE train=0.4679 val=0.4916
# 185 MSE train=0.4680 val=0.5029
# 186 MSE train=0.4699 val=0.4853
# 187 MSE train=0.4788 val=0.4799
# 188 MSE train=0.4682 val=0.5058
# 189 MSE train=0.4668 val=0.4963
# 190 MSE train=0.4667 val=0.4938
# 191 MSE train=0.4693 val=0.4846
# 192 MSE train=0.4668 val=0.5003
# 193 MSE train=0.4666 val=0.4910
# 194 MSE train=0.4662 val=0.4961
# 195 MSE train=0.4705 val=0.5166
# 196 MSE train=0.4712 val=0.5187
# 197 MSE train=0.4694 val=0.5141
# 198 MSE train=0.4773 val=0.5343
# 199 MSE train=0.4692 val=0.5141
# 200 MSE train=0.4665 val=0.4863
# 201 MSE train=0.4712 val=0.4805
# 202 MSE train=0.4656 val=0.4883
# 203 MSE train=0.4680 val=0.4828
# 204 MSE train=0.4654 val=0.5020
# 205 MSE train=0.4675 val=0.5111
# 206 MSE train=0.4644 val=0.4909
# 207 MSE train=0.4662 val=0.4837
# 208 MSE train=0.4639 val=0.4938
# 209 MSE train=0.4653 val=0.4848
# 210 MSE train=0.4752 val=0.5338
# 211 MSE train=0.4677 val=0.5154
# 212 MSE train=0.4632 val=0.4942
# 213 MSE train=0.4638 val=0.5017
# 214 MSE train=0.4629 val=0.4954
# 215 MSE train=0.4632 val=0.5000
# 216 MSE train=0.4654 val=0.5102
# 217 MSE train=0.4658 val=0.4806
# 218 MSE train=0.4639 val=0.5055
# 219 MSE train=0.4622 val=0.4879
# 220 MSE train=0.4622 val=0.4866
# 221 MSE train=0.4670 val=0.5179
# 222 MSE train=0.4613 val=0.4942
# 223 MSE train=0.4619 val=0.5009
# 224 MSE train=0.4624 val=0.5038
# 225 MSE train=0.4623 val=0.5041
# 226 MSE train=0.4607 val=0.4864
# 227 MSE train=0.4608 val=0.4846
# 228 MSE train=0.4608 val=0.4838
# 229 MSE train=0.4608 val=0.4825
# 230 MSE train=0.4595 val=0.4878
# 231 MSE train=0.4592 val=0.4921
# 232 MSE train=0.4617 val=0.5071
# 233 MSE train=0.4594 val=0.4982
# 234 MSE train=0.4597 val=0.5009
# 235 MSE train=0.4586 val=0.4961
# 236 MSE train=0.4791 val=0.4711
# 237 MSE train=0.4611 val=0.4763
# 238 MSE train=0.4605 val=0.4765
# 239 MSE train=0.4572 val=0.4850
# 240 MSE train=0.4602 val=0.5084
# 241 MSE train=0.4569 val=0.4955
# 242 MSE train=0.4562 val=0.4908
# 243 MSE train=0.4565 val=0.4814
# 244 MSE train=0.4555 val=0.4891
# 245 MSE train=0.4563 val=0.4793
# 246 MSE train=0.4571 val=0.5027
# 247 MSE train=0.4547 val=0.4825
# 248 MSE train=0.4667 val=0.4684
# 249 MSE train=0.4576 val=0.4731
# 250 MSE train=0.4555 val=0.4756
# 251 MSE train=0.4577 val=0.4714
# 252 MSE train=0.4547 val=0.4749
# 253 MSE train=0.4524 val=0.4857
# 254 MSE train=0.4522 val=0.4886
# 255 MSE train=0.4517 val=0.4852
# 256 MSE train=0.4545 val=0.4713
# 257 MSE train=0.4510 val=0.4860
# 258 MSE train=0.4511 val=0.4772
# 259 MSE train=0.4529 val=0.4708
# 260 MSE train=0.4577 val=0.4653
# 261 MSE train=0.4522 val=0.4698
# 262 MSE train=0.4489 val=0.4833
# 263 MSE train=0.4484 val=0.4819
# 264 MSE train=0.4490 val=0.4913
# 265 MSE train=0.4481 val=0.4885
# 266 MSE train=0.4500 val=0.4676
# 267 MSE train=0.4472 val=0.4879
# 268 MSE train=0.4469 val=0.4723
# 269 MSE train=0.4475 val=0.4938
# 270 MSE train=0.4477 val=0.4964
# 271 MSE train=0.4541 val=0.5169
# 272 MSE train=0.4442 val=0.4764
# 273 MSE train=0.4437 val=0.4798
# 274 MSE train=0.4440 val=0.4869
# 275 MSE train=0.4437 val=0.4690
# 276 MSE train=0.4424 val=0.4821
# 277 MSE train=0.4416 val=0.4785
# 278 MSE train=0.4418 val=0.4849
# 279 MSE train=0.4407 val=0.4808
# 280 MSE train=0.4414 val=0.4882
# 281 MSE train=0.4425 val=0.4940
# 282 MSE train=0.4444 val=0.5018
# 283 MSE train=0.4383 val=0.4684
# 284 MSE train=0.4388 val=0.4623
# 285 MSE train=0.4368 val=0.4720
# 286 MSE train=0.4362 val=0.4708
# 287 MSE train=0.4355 val=0.4705
# 288 MSE train=0.4432 val=0.4508
# 289 MSE train=0.4346 val=0.4640
# 290 MSE train=0.4344 val=0.4788
# 291 MSE train=0.4333 val=0.4752
# 292 MSE train=0.4339 val=0.4565
# 293 MSE train=0.4319 val=0.4730
# 294 MSE train=0.4309 val=0.4684
# 295 MSE train=0.4304 val=0.4610
# 296 MSE train=0.4311 val=0.4796
# 297 MSE train=0.4292 val=0.4574
# 298 MSE train=0.4288 val=0.4552
# 299 MSE train=0.4272 val=0.4612
# 300 MSE train=0.4279 val=0.4762
# 301 MSE train=0.4287 val=0.4480
# 302 MSE train=0.4252 val=0.4684
# 303 MSE train=0.4240 val=0.4605
# 304 MSE train=0.4237 val=0.4686
# 305 MSE train=0.4231 val=0.4518
# 306 MSE train=0.4226 val=0.4708
# 307 MSE train=0.4221 val=0.4720
# 308 MSE train=0.4205 val=0.4669
# 309 MSE train=0.4193 val=0.4637
# 310 MSE train=0.4188 val=0.4656
# 311 MSE train=0.4172 val=0.4531
# 312 MSE train=0.4163 val=0.4524
# 313 MSE train=0.4164 val=0.4444
# 314 MSE train=0.4153 val=0.4444
# 315 MSE train=0.4142 val=0.4439
# 316 MSE train=0.4126 val=0.4484
# 317 MSE train=0.4131 val=0.4644
# 318 MSE train=0.4112 val=0.4416
# 319 MSE train=0.4097 val=0.4476
# 320 MSE train=0.4096 val=0.4585
# 321 MSE train=0.4080 val=0.4417
# 322 MSE train=0.4069 val=0.4493
# 323 MSE train=0.4058 val=0.4444
# 324 MSE train=0.4088 val=0.4263
# 325 MSE train=0.4053 val=0.4579
# 326 MSE train=0.4028 val=0.4448
# 327 MSE train=0.4030 val=0.4552
# 328 MSE train=0.4017 val=0.4529
# 329 MSE train=0.4017 val=0.4248
# 330 MSE train=0.3990 val=0.4288
# 331 MSE train=0.3972 val=0.4355
# 332 MSE train=0.3963 val=0.4410
# 333 MSE train=0.3952 val=0.4406
# 334 MSE train=0.3939 val=0.4372
# 335 MSE train=0.3944 val=0.4193
# 336 MSE train=0.3937 val=0.4496
# 337 MSE train=0.3905 val=0.4327
# 338 MSE train=0.3894 val=0.4238
# 339 MSE train=0.3888 val=0.4374
# 340 MSE train=0.3875 val=0.4360
# 341 MSE train=0.3858 val=0.4229
# 342 MSE train=0.3888 val=0.4522
# 343 MSE train=0.3886 val=0.4031
# 344 MSE train=0.3857 val=0.4046
# 345 MSE train=0.3850 val=0.4025
# 346 MSE train=0.3803 val=0.4130
# 347 MSE train=0.3845 val=0.3972
# 348 MSE train=0.3773 val=0.4152
# 349 MSE train=0.3799 val=0.4439
# 350 MSE train=0.3764 val=0.4318
# 351 MSE train=0.3807 val=0.3909
# 352 MSE train=0.3728 val=0.4221
# 353 MSE train=0.3712 val=0.4086
# 354 MSE train=0.3715 val=0.3971
# 355 MSE train=0.3695 val=0.4228
# 356 MSE train=0.3673 val=0.4054
# 357 MSE train=0.3672 val=0.4213
# 358 MSE train=0.3662 val=0.3932
# 359 MSE train=0.3635 val=0.4075
# 360 MSE train=0.3622 val=0.4034
# 361 MSE train=0.3640 val=0.4258
# 362 MSE train=0.3598 val=0.4042
# 363 MSE train=0.3588 val=0.3905
# 364 MSE train=0.3571 val=0.3993
# 365 MSE train=0.3584 val=0.4178
# 366 MSE train=0.3553 val=0.4068
# 367 MSE train=0.3531 val=0.3946
# 368 MSE train=0.3530 val=0.3792
# 369 MSE train=0.3505 val=0.3918
# 370 MSE train=0.3492 val=0.3875
# 371 MSE train=0.3500 val=0.4066
# 372 MSE train=0.3465 val=0.3841
# 373 MSE train=0.3455 val=0.3779
# 374 MSE train=0.3439 val=0.3850
# 375 MSE train=0.3425 val=0.3828
# 376 MSE train=0.3413 val=0.3842
# 377 MSE train=0.3435 val=0.4054
# 378 MSE train=0.3386 val=0.3793
# 379 MSE train=0.3396 val=0.3600
# 380 MSE train=0.3373 val=0.3615
# 381 MSE train=0.3352 val=0.3846
# 382 MSE train=0.3338 val=0.3821
# 383 MSE train=0.3324 val=0.3798
# 384 MSE train=0.3312 val=0.3610
# 385 MSE train=0.3294 val=0.3658
# 386 MSE train=0.3303 val=0.3502
# 387 MSE train=0.3272 val=0.3742
# 388 MSE train=0.3276 val=0.3480
# 389 MSE train=0.3242 val=0.3614
# 390 MSE train=0.3229 val=0.3630
# 391 MSE train=0.3216 val=0.3578
# 392 MSE train=0.3206 val=0.3662
# 393 MSE train=0.3195 val=0.3665
# 394 MSE train=0.3179 val=0.3607
# 395 MSE train=0.3185 val=0.3744
# 396 MSE train=0.3163 val=0.3666
# 397 MSE train=0.3139 val=0.3546
# 398 MSE train=0.3153 val=0.3328
# 399 MSE train=0.3114 val=0.3482
# 400 MSE train=0.3101 val=0.3467
# 401 MSE train=0.3096 val=0.3574
# 402 MSE train=0.3083 val=0.3556
# 403 MSE train=0.3068 val=0.3334
# 404 MSE train=0.3063 val=0.3278
# 405 MSE train=0.3037 val=0.3410
# 406 MSE train=0.3030 val=0.3484
# 407 MSE train=0.3014 val=0.3304
# 408 MSE train=0.3002 val=0.3283
# 409 MSE train=0.2996 val=0.3225
# 410 MSE train=0.2977 val=0.3263
# 411 MSE train=0.2975 val=0.3473
# 412 MSE train=0.2958 val=0.3423
# 413 MSE train=0.2943 val=0.3385
# 414 MSE train=0.2926 val=0.3321
# 415 MSE train=0.2927 val=0.3116
# 416 MSE train=0.2904 val=0.3167
# 417 MSE train=0.2896 val=0.3337
# 418 MSE train=0.2878 val=0.3160
# 419 MSE train=0.2892 val=0.3016
# 420 MSE train=0.2870 val=0.3034
# 421 MSE train=0.2866 val=0.3389
# 422 MSE train=0.2830 val=0.3104
# 423 MSE train=0.2822 val=0.3226
# 424 MSE train=0.2839 val=0.3386
# 425 MSE train=0.2800 val=0.3222
# 426 MSE train=0.2802 val=0.3305
# 427 MSE train=0.2784 val=0.3257
# 428 MSE train=0.2764 val=0.3179
# 429 MSE train=0.2761 val=0.3231
# 430 MSE train=0.2738 val=0.2977
# 431 MSE train=0.2723 val=0.3036
# 432 MSE train=0.2712 val=0.3050
# 433 MSE train=0.2701 val=0.3025
# 434 MSE train=0.2690 val=0.2956
# 435 MSE train=0.2678 val=0.2953
# 436 MSE train=0.2667 val=0.2978
# 437 MSE train=0.2674 val=0.3138
# 438 MSE train=0.2646 val=0.2965
# 439 MSE train=0.2634 val=0.2947
# 440 MSE train=0.2637 val=0.3070
# 441 MSE train=0.2613 val=0.2849
# 442 MSE train=0.2601 val=0.2888
# 443 MSE train=0.2594 val=0.2802
# 444 MSE train=0.2580 val=0.2827
# 445 MSE train=0.2570 val=0.2883
# 446 MSE train=0.2574 val=0.2997
# 447 MSE train=0.2553 val=0.2903
# 448 MSE train=0.2559 val=0.2637
# 449 MSE train=0.2528 val=0.2838
# 450 MSE train=0.2517 val=0.2728
# 451 MSE train=0.2517 val=0.2637
# 452 MSE train=0.2503 val=0.2862
# 453 MSE train=0.2486 val=0.2686
# 454 MSE train=0.2475 val=0.2699
# 455 MSE train=0.2465 val=0.2672
# 456 MSE train=0.2462 val=0.2798
# 457 MSE train=0.2472 val=0.2904
# 458 MSE train=0.2438 val=0.2590
# 459 MSE train=0.2437 val=0.2521
# 460 MSE train=0.2415 val=0.2609
# 461 MSE train=0.2416 val=0.2770
# 462 MSE train=0.2416 val=0.2454
# 463 MSE train=0.2390 val=0.2516
# 464 MSE train=0.2376 val=0.2555
# 465 MSE train=0.2370 val=0.2504
# 466 MSE train=0.2357 val=0.2616
# 467 MSE train=0.2351 val=0.2645
# 468 MSE train=0.2341 val=0.2469
# 469 MSE train=0.2374 val=0.2842
# 470 MSE train=0.2318 val=0.2544
# 471 MSE train=0.2308 val=0.2470
# 472 MSE train=0.2339 val=0.2288
# 473 MSE train=0.2307 val=0.2659
# 474 MSE train=0.2280 val=0.2485
# 475 MSE train=0.2275 val=0.2545
# 476 MSE train=0.2271 val=0.2341
# 477 MSE train=0.2253 val=0.2460
# 478 MSE train=0.2250 val=0.2331
# 479 MSE train=0.2235 val=0.2437
# 480 MSE train=0.2276 val=0.2182
# 481 MSE train=0.2283 val=0.2145
# 482 MSE train=0.2207 val=0.2363
# 483 MSE train=0.2265 val=0.2125
# 484 MSE train=0.2209 val=0.2202
# 485 MSE train=0.2182 val=0.2283
# 486 MSE train=0.2171 val=0.2318
# 487 MSE train=0.2178 val=0.2182
# 488 MSE train=0.2158 val=0.2380
# 489 MSE train=0.2146 val=0.2325
# 490 MSE train=0.2137 val=0.2254
# 491 MSE train=0.2128 val=0.2277
# 492 MSE train=0.2121 val=0.2204
# 493 MSE train=0.2128 val=0.2416
# 494 MSE train=0.2114 val=0.2116
# 495 MSE train=0.2103 val=0.2337
# 496 MSE train=0.2086 val=0.2222
# 497 MSE train=0.2085 val=0.2305
# 498 MSE train=0.2078 val=0.2081
# 499 MSE train=0.2061 val=0.2201
# 500 MSE train=0.2055 val=0.2110
# 501 MSE train=0.2057 val=0.2300
# 502 MSE train=0.2038 val=0.2088
# 503 MSE train=0.2029 val=0.2095
# 504 MSE train=0.2022 val=0.2173
# 505 MSE train=0.2018 val=0.2208
# 506 MSE train=0.2012 val=0.2004
# 507 MSE train=0.1996 val=0.2095
# 508 MSE train=0.2007 val=0.2261
# 509 MSE train=0.1991 val=0.2212
# 510 MSE train=0.1983 val=0.2197
# 511 MSE train=0.1973 val=0.1962
# 512 MSE train=0.1965 val=0.1948
# 513 MSE train=0.1949 val=0.2065
# 514 MSE train=0.1976 val=0.2279
# 515 MSE train=0.1938 val=0.2105
# 516 MSE train=0.1950 val=0.2218
# 517 MSE train=0.1921 val=0.2068
# 518 MSE train=0.1912 val=0.2048
# 519 MSE train=0.1906 val=0.2052
# 520 MSE train=0.1899 val=0.1898
# 521 MSE train=0.1906 val=0.1823
# 522 MSE train=0.1884 val=0.1867
# 523 MSE train=0.1872 val=0.1910
# 524 MSE train=0.1870 val=0.2007
# 525 MSE train=0.1867 val=0.2032
# 526 MSE train=0.1854 val=0.1974
# 527 MSE train=0.1843 val=0.1868
# 528 MSE train=0.1837 val=0.1935
# 529 MSE train=0.1832 val=0.1946
# 530 MSE train=0.1827 val=0.1958
# 531 MSE train=0.1814 val=0.1871
# 532 MSE train=0.1808 val=0.1887
# 533 MSE train=0.1801 val=0.1798
# 534 MSE train=0.1793 val=0.1848
# 535 MSE train=0.1796 val=0.1725
# 536 MSE train=0.1781 val=0.1763
# 537 MSE train=0.1777 val=0.1880
# 538 MSE train=0.1766 val=0.1759
# 539 MSE train=0.1769 val=0.1686
# 540 MSE train=0.1767 val=0.1922
# 541 MSE train=0.1746 val=0.1802
# 542 MSE train=0.1744 val=0.1846
# 543 MSE train=0.1752 val=0.1924
# 544 MSE train=0.1754 val=0.1951
# 545 MSE train=0.1719 val=0.1717
# 546 MSE train=0.1715 val=0.1793
# 547 MSE train=0.1712 val=0.1635
# 548 MSE train=0.1713 val=0.1845
# 549 MSE train=0.1695 val=0.1763
# 550 MSE train=0.1690 val=0.1766
# 551 MSE train=0.1680 val=0.1706
# 552 MSE train=0.1689 val=0.1567
# 553 MSE train=0.1675 val=0.1585
# 554 MSE train=0.1660 val=0.1678
# 555 MSE train=0.1655 val=0.1632
# 556 MSE train=0.1649 val=0.1692
# 557 MSE train=0.1653 val=0.1766
# 558 MSE train=0.1649 val=0.1530
# 559 MSE train=0.1636 val=0.1560
# 560 MSE train=0.1624 val=0.1592
# 561 MSE train=0.1623 val=0.1697
# 562 MSE train=0.1611 val=0.1587
# 563 MSE train=0.1605 val=0.1601
# 564 MSE train=0.1599 val=0.1599
# 565 MSE train=0.1594 val=0.1607
# 566 MSE train=0.1588 val=0.1538
# 567 MSE train=0.1581 val=0.1559
# 568 MSE train=0.1580 val=0.1611
# 569 MSE train=0.1575 val=0.1614
# 570 MSE train=0.1570 val=0.1610
# 571 MSE train=0.1560 val=0.1492
# 572 MSE train=0.1553 val=0.1498
# 573 MSE train=0.1550 val=0.1458
# 574 MSE train=0.1544 val=0.1458
# 575 MSE train=0.1538 val=0.1458
# 576 MSE train=0.1537 val=0.1580
# 577 MSE train=0.1526 val=0.1462
# 578 MSE train=0.1521 val=0.1453
# 579 MSE train=0.1521 val=0.1403
# 580 MSE train=0.1511 val=0.1516
# 581 MSE train=0.1509 val=0.1543
# 582 MSE train=0.1498 val=0.1449
# 583 MSE train=0.1494 val=0.1478
# 584 MSE train=0.1488 val=0.1467
# 585 MSE train=0.1483 val=0.1417
# 586 MSE train=0.1493 val=0.1564
# 587 MSE train=0.1472 val=0.1433
# 588 MSE train=0.1467 val=0.1406
# 589 MSE train=0.1462 val=0.1413
# 590 MSE train=0.1465 val=0.1490
# 591 MSE train=0.1474 val=0.1556
# 592 MSE train=0.1452 val=0.1460
# 593 MSE train=0.1465 val=0.1542
# 594 MSE train=0.1442 val=0.1449
# 595 MSE train=0.1433 val=0.1390
# 596 MSE train=0.1428 val=0.1350
# 597 MSE train=0.1424 val=0.1390
# 598 MSE train=0.1419 val=0.1372
# 599 MSE train=0.1415 val=0.1321
# 600 MSE train=0.1409 val=0.1340
# 601 MSE train=0.1407 val=0.1382
# 602 MSE train=0.1401 val=0.1358
# 603 MSE train=0.1398 val=0.1280
# 604 MSE train=0.1392 val=0.1285
# 605 MSE train=0.1387 val=0.1285
# 606 MSE train=0.1415 val=0.1180
# 607 MSE train=0.1386 val=0.1228
# 608 MSE train=0.1374 val=0.1277
# 609 MSE train=0.1369 val=0.1289
# 610 MSE train=0.1376 val=0.1201
# 611 MSE train=0.1361 val=0.1248
# 612 MSE train=0.1356 val=0.1272
# 613 MSE train=0.1385 val=0.1142
# 614 MSE train=0.1348 val=0.1287
# 615 MSE train=0.1344 val=0.1277
# 616 MSE train=0.1345 val=0.1188
# 617 MSE train=0.1339 val=0.1193
# 618 MSE train=0.1332 val=0.1255
# 619 MSE train=0.1328 val=0.1209
# 620 MSE train=0.1358 val=0.1429
# 621 MSE train=0.1321 val=0.1187
# 622 MSE train=0.1316 val=0.1231
# 623 MSE train=0.1312 val=0.1207
# 624 MSE train=0.1314 val=0.1280
# 625 MSE train=0.1304 val=0.1197
# 626 MSE train=0.1317 val=0.1109
# 627 MSE train=0.1297 val=0.1184
# 628 MSE train=0.1293 val=0.1200
# 629 MSE train=0.1289 val=0.1180
# 630 MSE train=0.1286 val=0.1200
# 631 MSE train=0.1282 val=0.1178
# 632 MSE train=0.1278 val=0.1168
# 633 MSE train=0.1293 val=0.1297
# 634 MSE train=0.1274 val=0.1207
# 635 MSE train=0.1267 val=0.1152
# 636 MSE train=0.1265 val=0.1179
# 637 MSE train=0.1278 val=0.1277
# 638 MSE train=0.1262 val=0.1203
# 639 MSE train=0.1255 val=0.1104
# 640 MSE train=0.1254 val=0.1081
# 641 MSE train=0.1252 val=0.1071
# 642 MSE train=0.1243 val=0.1125
# 643 MSE train=0.1242 val=0.1081
# 644 MSE train=0.1237 val=0.1131
# 645 MSE train=0.1233 val=0.1108
# 646 MSE train=0.1230 val=0.1111
# 647 MSE train=0.1228 val=0.1078
# 648 MSE train=0.1223 val=0.1098
# 649 MSE train=0.1225 val=0.1164
# 650 MSE train=0.1220 val=0.1145
# 651 MSE train=0.1214 val=0.1113
# 652 MSE train=0.1213 val=0.1047
# 653 MSE train=0.1209 val=0.1114
# 654 MSE train=0.1206 val=0.1113
# 655 MSE train=0.1202 val=0.1097
# 656 MSE train=0.1198 val=0.1059
# 657 MSE train=0.1200 val=0.1014
# 658 MSE train=0.1194 val=0.1095
# 659 MSE train=0.1189 val=0.1054
# 660 MSE train=0.1198 val=0.0984
# 661 MSE train=0.1194 val=0.0983
# 662 MSE train=0.1183 val=0.1013
# 663 MSE train=0.1186 val=0.1124
# 664 MSE train=0.1186 val=0.1135
# 665 MSE train=0.1175 val=0.1001
# 666 MSE train=0.1194 val=0.0939
# 667 MSE train=0.1168 val=0.1001
# 668 MSE train=0.1164 val=0.1015
# 669 MSE train=0.1162 val=0.1045
# 670 MSE train=0.1159 val=0.1033
# 671 MSE train=0.1156 val=0.1029
# 672 MSE train=0.1155 val=0.1045
# 673 MSE train=0.1153 val=0.0975
# 674 MSE train=0.1149 val=0.1028
# 675 MSE train=0.1146 val=0.1002
# 676 MSE train=0.1146 val=0.1039
# 677 MSE train=0.1151 val=0.0932
# 678 MSE train=0.1140 val=0.1024
# 679 MSE train=0.1144 val=0.1062
# 680 MSE train=0.1134 val=0.0999
# 681 MSE train=0.1137 val=0.0934
# 682 MSE train=0.1130 val=0.0951
# 683 MSE train=0.1127 val=0.0997
# 684 MSE train=0.1125 val=0.0943
# 685 MSE train=0.1122 val=0.0986
# 686 MSE train=0.1119 val=0.0960
# 687 MSE train=0.1117 val=0.0963
# 688 MSE train=0.1115 val=0.0970
# 689 MSE train=0.1119 val=0.0900
# 690 MSE train=0.1110 val=0.0941
# 691 MSE train=0.1109 val=0.0920
# 692 MSE train=0.1109 val=0.0908
# 693 MSE train=0.1109 val=0.0893
# 694 MSE train=0.1101 val=0.0951
# 695 MSE train=0.1104 val=0.0894
# 696 MSE train=0.1098 val=0.0911
# 697 MSE train=0.1099 val=0.0985
# 698 MSE train=0.1094 val=0.0913
# 699 MSE train=0.1097 val=0.0877
# 700 MSE train=0.1090 val=0.0903
# 701 MSE train=0.1106 val=0.1044
# 702 MSE train=0.1086 val=0.0947
# 703 MSE train=0.1086 val=0.0960
# 704 MSE train=0.1082 val=0.0941
# 705 MSE train=0.1080 val=0.0878
# 706 MSE train=0.1101 val=0.1045
# 707 MSE train=0.1076 val=0.0935
# 708 MSE train=0.1074 val=0.0870
# 709 MSE train=0.1070 val=0.0899
# 710 MSE train=0.1084 val=0.0826
# 711 MSE train=0.1067 val=0.0899
# 712 MSE train=0.1070 val=0.0844
# 713 MSE train=0.1067 val=0.0845
# 714 MSE train=0.1061 val=0.0877
# 715 MSE train=0.1059 val=0.0891
# 716 MSE train=0.1059 val=0.0855
# 717 MSE train=0.1058 val=0.0909
# 718 MSE train=0.1055 val=0.0856
# 719 MSE train=0.1061 val=0.0945
# 720 MSE train=0.1050 val=0.0873
# 721 MSE train=0.1048 val=0.0868
# 722 MSE train=0.1052 val=0.0919
# 723 MSE train=0.1052 val=0.0923
# 724 MSE train=0.1045 val=0.0896
# 725 MSE train=0.1042 val=0.0872
# 726 MSE train=0.1042 val=0.0897
# 727 MSE train=0.1045 val=0.0808
# 728 MSE train=0.1039 val=0.0892
# 729 MSE train=0.1037 val=0.0826
# 730 MSE train=0.1046 val=0.0945
# 731 MSE train=0.1033 val=0.0829
# 732 MSE train=0.1032 val=0.0822
# 733 MSE train=0.1030 val=0.0872
# 734 MSE train=0.1037 val=0.0919
# 735 MSE train=0.1033 val=0.0907
# 736 MSE train=0.1024 val=0.0827
# 737 MSE train=0.1023 val=0.0812
# 738 MSE train=0.1022 val=0.0810
# 739 MSE train=0.1019 val=0.0817
# 740 MSE train=0.1022 val=0.0877
# 741 MSE train=0.1016 val=0.0817
# 742 MSE train=0.1020 val=0.0782
# 743 MSE train=0.1014 val=0.0807
# 744 MSE train=0.1012 val=0.0839
# 745 MSE train=0.1012 val=0.0794
# 746 MSE train=0.1013 val=0.0865
# 747 MSE train=0.1007 val=0.0809
# 748 MSE train=0.1006 val=0.0816
# 749 MSE train=0.1014 val=0.0757
# 750 MSE train=0.1004 val=0.0833
# 751 MSE train=0.1007 val=0.0764
# 752 MSE train=0.1001 val=0.0792
# 753 MSE train=0.1002 val=0.0845
# 754 MSE train=0.0997 val=0.0801
# 755 MSE train=0.1018 val=0.0923
# 756 MSE train=0.0996 val=0.0775
# 757 MSE train=0.0997 val=0.0844
# 758 MSE train=0.0993 val=0.0779
# 759 MSE train=0.0991 val=0.0806
# 760 MSE train=0.0997 val=0.0746
# 761 MSE train=0.0993 val=0.0752
# 762 MSE train=0.1001 val=0.0729
# 763 MSE train=0.0989 val=0.0754
# 764 MSE train=0.0993 val=0.0737
# 765 MSE train=0.0985 val=0.0808
# 766 MSE train=0.0985 val=0.0816
# 767 MSE train=0.0985 val=0.0740
# 768 MSE train=0.0981 val=0.0793
# 769 MSE train=0.0980 val=0.0800
# 770 MSE train=0.0978 val=0.0757
# 771 MSE train=0.0993 val=0.0710
# 772 MSE train=0.0997 val=0.0704
# 773 MSE train=0.0975 val=0.0797
# 774 MSE train=0.0976 val=0.0735
# 775 MSE train=0.0971 val=0.0769
# 776 MSE train=0.0972 val=0.0793
# 777 MSE train=0.0978 val=0.0715
# 778 MSE train=0.0969 val=0.0786
# 779 MSE train=0.0968 val=0.0788
# 780 MSE train=0.0965 val=0.0757
# 781 MSE train=0.0971 val=0.0819
# 782 MSE train=0.0984 val=0.0872
# 783 MSE train=0.0962 val=0.0767
# 784 MSE train=0.0967 val=0.0717
# 785 MSE train=0.0961 val=0.0738
# 786 MSE train=0.0959 val=0.0749
# 787 MSE train=0.0963 val=0.0804
# 788 MSE train=0.0959 val=0.0783
# 789 MSE train=0.0958 val=0.0785
# 790 MSE train=0.0957 val=0.0784
# 791 MSE train=0.0960 val=0.0708
# 792 MSE train=0.0955 val=0.0722
# 793 MSE train=0.0953 val=0.0722
# 794 MSE train=0.0953 val=0.0717
# 795 MSE train=0.0949 val=0.0737
# 796 MSE train=0.0951 val=0.0712
# 797 MSE train=0.0951 val=0.0704
# 798 MSE train=0.0950 val=0.0773
# 799 MSE train=0.0946 val=0.0720
# 800 MSE train=0.0946 val=0.0711
# 801 MSE train=0.0952 val=0.0686
# 802 MSE train=0.0943 val=0.0718
# 803 MSE train=0.0947 val=0.0689
# 804 MSE train=0.0941 val=0.0714
# 805 MSE train=0.0947 val=0.0685
# 806 MSE train=0.0939 val=0.0737
# 807 MSE train=0.0941 val=0.0696
# 808 MSE train=0.0937 val=0.0720
# 809 MSE train=0.0944 val=0.0784
# 810 MSE train=0.0936 val=0.0729
# 811 MSE train=0.0935 val=0.0703
# 812 MSE train=0.0935 val=0.0699
# 813 MSE train=0.0933 val=0.0727
# 814 MSE train=0.0949 val=0.0812
# 815 MSE train=0.0944 val=0.0796
# 816 MSE train=0.0933 val=0.0751
# 817 MSE train=0.0934 val=0.0762
# 818 MSE train=0.0928 val=0.0718
# 819 MSE train=0.0928 val=0.0702
# 820 MSE train=0.0926 val=0.0712
# 821 MSE train=0.0930 val=0.0678
# 822 MSE train=0.0931 val=0.0758
# 823 MSE train=0.0939 val=0.0796
# 824 MSE train=0.0924 val=0.0722
# 825 MSE train=0.0923 val=0.0729
# 826 MSE train=0.0923 val=0.0688
# 827 MSE train=0.0924 val=0.0741
# 828 MSE train=0.0923 val=0.0676
# 829 MSE train=0.0921 val=0.0681
# 830 MSE train=0.0919 val=0.0717
# 831 MSE train=0.0924 val=0.0754
# 832 MSE train=0.0917 val=0.0691
# 833 MSE train=0.0917 val=0.0723
# 834 MSE train=0.0920 val=0.0743
# 835 MSE train=0.0934 val=0.0802
# 836 MSE train=0.0915 val=0.0681
# 837 MSE train=0.0917 val=0.0665
# 838 MSE train=0.0912 val=0.0691
# 839 MSE train=0.0913 val=0.0674
# 840 MSE train=0.0918 val=0.0749
# 841 MSE train=0.0913 val=0.0728
# 842 MSE train=0.0911 val=0.0719
# 843 MSE train=0.0909 val=0.0698
# 844 MSE train=0.0910 val=0.0719
# 845 MSE train=0.0908 val=0.0710
# 846 MSE train=0.0906 val=0.0683
# 847 MSE train=0.0905 val=0.0680
# 848 MSE train=0.0905 val=0.0680
# 849 MSE train=0.0904 val=0.0676
# 850 MSE train=0.0904 val=0.0674
# 851 MSE train=0.0903 val=0.0675
# 852 MSE train=0.0905 val=0.0655
# 853 MSE train=0.0902 val=0.0669
# 854 MSE train=0.0901 val=0.0688
# 855 MSE train=0.0900 val=0.0681
# 856 MSE train=0.0900 val=0.0691
# 857 MSE train=0.0899 val=0.0684
# 858 MSE train=0.0908 val=0.0748
# 859 MSE train=0.0899 val=0.0703
# 860 MSE train=0.0903 val=0.0729
# 861 MSE train=0.0896 val=0.0681
# 862 MSE train=0.0896 val=0.0688
# 863 MSE train=0.0897 val=0.0706
# 864 MSE train=0.0894 val=0.0672
# 865 MSE train=0.0904 val=0.0629
# 866 MSE train=0.0893 val=0.0666
# 867 MSE train=0.0892 val=0.0663
# 868 MSE train=0.0891 val=0.0671
# 869 MSE train=0.0891 val=0.0675
# 870 MSE train=0.0890 val=0.0669
# 871 MSE train=0.0899 val=0.0734
# 872 MSE train=0.0903 val=0.0618
# 873 MSE train=0.0889 val=0.0680
# 874 MSE train=0.0889 val=0.0680
# 875 MSE train=0.0889 val=0.0641
# 876 MSE train=0.0889 val=0.0639
# 877 MSE train=0.0887 val=0.0648
# 878 MSE train=0.0889 val=0.0632
# 879 MSE train=0.0886 val=0.0644
# 880 MSE train=0.0886 val=0.0689
# 881 MSE train=0.0886 val=0.0693
# 882 MSE train=0.0887 val=0.0697
# 883 MSE train=0.0882 val=0.0659
# 884 MSE train=0.0882 val=0.0669
# 885 MSE train=0.0882 val=0.0669
# 886 MSE train=0.0885 val=0.0627
# 887 MSE train=0.0882 val=0.0632
# 888 MSE train=0.0881 val=0.0675
# 889 MSE train=0.0882 val=0.0686
# 890 MSE train=0.0884 val=0.0621
# 891 MSE train=0.0880 val=0.0675
# 892 MSE train=0.0878 val=0.0664
# 893 MSE train=0.0883 val=0.0618
# 894 MSE train=0.0877 val=0.0674
# 895 MSE train=0.0880 val=0.0629
# 896 MSE train=0.0875 val=0.0657
# 897 MSE train=0.0875 val=0.0648
# 898 MSE train=0.0874 val=0.0652
# 899 MSE train=0.0874 val=0.0639
# 900 MSE train=0.0873 val=0.0636
# 901 MSE train=0.0874 val=0.0627
# 902 MSE train=0.0874 val=0.0673
# 903 MSE train=0.0872 val=0.0653
# 904 MSE train=0.0873 val=0.0624
# 905 MSE train=0.0870 val=0.0647
# 906 MSE train=0.0870 val=0.0652
# 907 MSE train=0.0870 val=0.0651
# 908 MSE train=0.0878 val=0.0604
# 909 MSE train=0.0871 val=0.0672
# 910 MSE train=0.0871 val=0.0615
# 911 MSE train=0.0867 val=0.0640
# 912 MSE train=0.0871 val=0.0677
# 913 MSE train=0.0874 val=0.0606
# 914 MSE train=0.0868 val=0.0620
# 915 MSE train=0.0865 val=0.0647
# 916 MSE train=0.0865 val=0.0640
# 917 MSE train=0.0868 val=0.0613
# 918 MSE train=0.0865 val=0.0627
# 919 MSE train=0.0864 val=0.0647
# 920 MSE train=0.0863 val=0.0632
# 921 MSE train=0.0864 val=0.0618
# 922 MSE train=0.0870 val=0.0690
# 923 MSE train=0.0877 val=0.0720
# 924 MSE train=0.0867 val=0.0604
# 925 MSE train=0.0862 val=0.0656
# 926 MSE train=0.0861 val=0.0618
# 927 MSE train=0.0860 val=0.0631
# 928 MSE train=0.0859 val=0.0635
# 929 MSE train=0.0860 val=0.0646
# 930 MSE train=0.0859 val=0.0644
# 931 MSE train=0.0861 val=0.0612
# 932 MSE train=0.0858 val=0.0636
# 933 MSE train=0.0859 val=0.0614
# 934 MSE train=0.0858 val=0.0647
# 935 MSE train=0.0856 val=0.0632
# 936 MSE train=0.0865 val=0.0689
# 937 MSE train=0.0856 val=0.0624
# 938 MSE train=0.0859 val=0.0604
# 939 MSE train=0.0856 val=0.0616
# 940 MSE train=0.0856 val=0.0614
# 941 MSE train=0.0854 val=0.0622
# 942 MSE train=0.0855 val=0.0648
# 943 MSE train=0.0854 val=0.0649
# 944 MSE train=0.0857 val=0.0667
# 945 MSE train=0.0856 val=0.0602
# 946 MSE train=0.0861 val=0.0589
# 947 MSE train=0.0857 val=0.0595
# 948 MSE train=0.0851 val=0.0617
# 949 MSE train=0.0852 val=0.0652
# 950 MSE train=0.0850 val=0.0621
# 951 MSE train=0.0849 val=0.0615
# 952 MSE train=0.0851 val=0.0652
# 953 MSE train=0.0848 val=0.0620
# 954 MSE train=0.0859 val=0.0689
# 955 MSE train=0.0849 val=0.0646
# 956 MSE train=0.0855 val=0.0589
# 957 MSE train=0.0854 val=0.0589
# 958 MSE train=0.0847 val=0.0606
# 959 MSE train=0.0846 val=0.0626
# 960 MSE train=0.0846 val=0.0627
# 961 MSE train=0.0846 val=0.0615
# 962 MSE train=0.0851 val=0.0590
# 963 MSE train=0.0845 val=0.0629
# 964 MSE train=0.0848 val=0.0656
# 965 MSE train=0.0844 val=0.0623
# 966 MSE train=0.0847 val=0.0652
# 967 MSE train=0.0844 val=0.0628
# 968 MSE train=0.0849 val=0.0665
# 969 MSE train=0.0851 val=0.0677
# 970 MSE train=0.0848 val=0.0589
# 971 MSE train=0.0842 val=0.0628
# 972 MSE train=0.0845 val=0.0648
# 973 MSE train=0.0842 val=0.0599
# 974 MSE train=0.0862 val=0.0708
# 975 MSE train=0.0840 val=0.0620
# 976 MSE train=0.0840 val=0.0624
# 977 MSE train=0.0849 val=0.0670
# 978 MSE train=0.0839 val=0.0602
# 979 MSE train=0.0838 val=0.0607
# 980 MSE train=0.0841 val=0.0641
# 981 MSE train=0.0838 val=0.0605
# 982 MSE train=0.0838 val=0.0630
# 983 MSE train=0.0847 val=0.0577
# 984 MSE train=0.0837 val=0.0606
# 985 MSE train=0.0839 val=0.0642
# 986 MSE train=0.0836 val=0.0601
# 987 MSE train=0.0836 val=0.0604
# 988 MSE train=0.0835 val=0.0602
# 989 MSE train=0.0843 val=0.0660
# 990 MSE train=0.0856 val=0.0705
# 991 MSE train=0.0841 val=0.0659
# 992 MSE train=0.0834 val=0.0605
# 993 MSE train=0.0833 val=0.0606
# 994 MSE train=0.0835 val=0.0626
# 995 MSE train=0.0834 val=0.0626
# 996 MSE train=0.0835 val=0.0585
# 997 MSE train=0.0832 val=0.0608
# 998 MSE train=0.0832 val=0.0596
# 999 MSE train=0.0833 val=0.0588

# %% [markdown]
# ... and plot the training metrics (which feature overfitting) ...

# %%
from plotting import plot_mse_train_vs_val

### plot_mse_train_vs_val(mse_train, mse_val)

# %% [markdown]
# ... and the predictions for the training set ...

# %%
plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train), fig_name="fig_02_19a.pdf")  ### plot_pred_2d(x_train, y_gt_train, y_p=dnn2_reg(wa, wb, x_train))
plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train), fig_name="fig_02_19b.pdf")  ### plot_pred_vs_gt(y_gt_train, y_p=dnn2_reg(wa, wb, x_train))

# %% [markdown]
# ... the predictions for the validation set ...

# %%
plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val), fig_name="fig_02_19c.pdf")  ### plot_pred_2d(x_val, y_gt_val, y_p=dnn2_reg(wa, wb, x_val))
plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val), fig_name="fig_02_19d.pdf")  ### plot_pred_vs_gt(y_gt_val, y_p=dnn2_reg(wa, wb, x_val))

# %% [markdown]
# ... and the predictions for the test set.

# %%
(x_test, y_gt_test) = load_data(filename="data_reg_2d_nonlinear_test.csv")

plot_pred_2d(x_test, y_gt_test, y_p=dnn2_reg(wa, wb, x_test), fig_name="fig_02_19e.pdf")  ### plot_pred_2d(x_test, y_gt_test, y_p=dnn2_reg(wa, wb, x_test))
plot_pred_vs_gt(y_gt_test, y_p=dnn2_reg(wa, wb, x_test), fig_name="fig_02_19f.pdf")  ### plot_pred_vs_gt(y_gt_test, y_p=dnn2_reg(wa, wb, x_test))
