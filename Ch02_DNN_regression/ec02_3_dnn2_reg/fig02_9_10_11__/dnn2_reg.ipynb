# %% [markdown]
# # Regressing 2D Data with a Two-Layer Neural Network
#
# This notebook provides you with a complete code example that
# loads the data in `data_reg_2d_linear.csv`, trains a two-layer dense neural network to fit them, and finally uses the trained network to predict the values of the data in `data_reg_2d_linear_test.csv`.

# %% [markdown]
# ## Loading and Plotting the Data

# %%
from loader import load_data

(x, y_gt) = load_data(filename="data_reg_2d_linear.csv")

print("x:", x)
print("y_gt:", y_gt)
# Out:
# x: [[-0.01264992 -0.85443355]
#  [ 0.76032383 -0.97434942]
#  [ 0.01950686  0.27497154]
#  [-1.58945469 -1.54899742]
#  [-0.4683091   0.04368673]
#  [-0.07725676  0.35296562]
#  [-0.88869315  0.9471676 ]
#  [-0.28959776 -0.32629691]
#  [-0.3686084   0.77991726]
#  [-0.01630287  0.69537186]
#  [ 1.04251786  0.30325747]
#  [-1.02762036  0.28614963]
#  [ 1.35221365  0.00522689]
#  [ 1.11043191  0.06395982]
#  [ 0.20114065 -0.72740412]
#  [-0.5236721   1.02450951]
#  [-0.74496852  0.76759749]
#  [-0.34330278  1.47764927]
#  [-1.48967134  0.66148164]
#  [ 0.91347373  0.20379262]
#  [-1.04925868 -0.70112109]
#  [ 1.47620376  0.38821102]
#  [ 0.16479918 -0.08658965]
#  [-0.88185459 -0.33227438]
#  [-0.08707602 -0.18477628]
#  [ 1.34159875  1.94937676]
#  [-0.32110135  1.54589904]
#  [ 2.40018166 -0.03238685]
#  [-1.00355408  0.07884853]
#  [ 0.48644429  0.64149119]
#  [ 0.49777571 -0.98064575]
#  [ 0.96754236  1.76567471]
#  [-1.05642191 -1.36633827]
#  [ 1.00046248  0.80779301]
#  [ 0.48090259  1.32363817]
#  [-0.93721223 -1.31488225]
#  [-0.7783187  -1.1272839 ]
#  [ 0.34408419 -0.59420601]
#  [ 0.14022603  0.38744433]
#  [ 1.35776922 -0.4143762 ]
#  [ 2.80911898  0.68255868]
#  [ 0.4589316   0.07317612]
#  [-1.81432287  0.14730497]
#  [ 0.83614238  0.69531097]
#  [ 0.11296394  0.25870933]
#  [-1.71934709  1.01517158]
#  [-1.71868797 -0.59817465]
#  [ 0.45265262 -0.45593674]
#  [ 0.63533505 -0.29305603]
#  [-0.11942826  2.06364796]
#  [ 0.79408066 -0.22186649]
#  [-0.10699554 -0.47041277]
#  [ 0.73952767  0.41419289]
#  [-0.59058245 -1.59234153]
#  [ 0.77327396 -1.0739063 ]
#  [ 0.78235185  0.50550473]
#  [-1.65406412  0.44774281]
#  [ 1.54045014  0.24329076]
#  [ 0.29312637 -0.58120338]
#  [ 1.30666726 -0.85124457]
#  [ 1.26200767  0.82934275]
#  [-1.67260291 -0.4229299 ]
#  [ 1.6559003   0.30206492]
#  [ 0.2162945   0.32574282]
#  [-1.52612859 -1.27944869]
#  [ 0.52189237 -0.68728934]
#  [-0.66306602  1.04537616]
#  [ 2.31646537 -0.71454372]
#  [-0.22226882 -1.797801  ]
#  [ 0.26051652  0.25109185]
#  [ 0.74700593 -1.63554144]
#  [ 0.70100306 -0.07968232]
#  [-0.03932948 -0.01464685]
#  [ 0.08308927 -0.03931517]
#  [ 0.62154512  0.33152256]
#  [ 0.48815081 -1.72709135]
#  [-0.90325557  1.53684554]
#  [-0.19668924 -1.39968601]
#  [ 1.03698104  0.40279586]
#  [ 0.28778897 -0.91074571]
#  [ 0.30439596 -0.6509071 ]
#  [-0.18928775  0.41564778]
#  [ 0.48325921 -0.61170165]
#  [-0.52167755 -0.96631475]
#  [ 0.6834997  -0.63102658]
#  [ 1.33345131 -0.44956364]
#  [-1.28697275 -0.07694561]
#  [-0.15552617  1.4958745 ]
#  [ 0.18305908  0.15829629]
#  [-0.26668814 -0.20220024]
#  [ 0.10410271 -1.15704215]
#  [-1.20081694 -2.001835  ]
#  [-1.7929256  -0.84189802]
#  [-0.65477546 -2.16013035]
#  [-0.85060906 -1.37363553]
#  [ 1.06019767 -0.39463539]
#  [-0.05963293  0.54051271]
#  [-1.55767705 -0.7502383 ]
#  [-0.97368135  0.25868212]
#  [ 0.04686402 -1.04956388]]
# y_gt: [[-0.84178364]
#  [-1.73467326]
#  [ 0.25546468]
#  [ 0.04045727]
#  [ 0.51199583]
#  [ 0.43022238]
#  [ 1.83586075]
#  [-0.03669916]
#  [ 1.14852566]
#  [ 0.71167473]
#  [-0.73926039]
#  [ 1.31377   ]
#  [-1.34698676]
#  [-1.04647209]
#  [-0.92854478]
#  [ 1.54818162]
#  [ 1.51256601]
#  [ 1.82095205]
#  [ 2.15115298]
#  [-0.70968111]
#  [ 0.34813758]
#  [-1.08799274]
#  [-0.25138883]
#  [ 0.54958021]
#  [-0.09770026]
#  [ 0.60777801]
#  [ 1.86700039]
#  [-2.4325685 ]
#  [ 1.08240261]
#  [ 0.1550469 ]
#  [-1.47842146]
#  [ 0.79813236]
#  [-0.30991635]
#  [-0.19266947]
#  [ 0.84273558]
#  [-0.37767002]
#  [-0.3489652 ]
#  [-0.9382902 ]
#  [ 0.2472183 ]
#  [-1.77214542]
#  [-2.1265603 ]
#  [-0.38575548]
#  [ 1.96162784]
#  [-0.14083141]
#  [ 0.14574539]
#  [ 2.73451867]
#  [ 1.12051331]
#  [-0.90858935]
#  [-0.92839108]
#  [ 2.18307622]
#  [-1.01594714]
#  [-0.36341723]
#  [-0.32533478]
#  [-1.00175908]
#  [-1.84718026]
#  [-0.27684712]
#  [ 2.10180693]
#  [-1.29715939]
#  [-0.87432975]
#  [-2.15791183]
#  [-0.43266492]
#  [ 1.24967301]
#  [-1.35383538]
#  [ 0.10944832]
#  [ 0.2466799 ]
#  [-1.20918171]
#  [ 1.70844217]
#  [-3.03100909]
#  [-1.57553217]
#  [-0.00942467]
#  [-2.38254737]
#  [-0.78068538]
#  [ 0.02468263]
#  [-0.12240443]
#  [-0.29002256]
#  [-2.21524216]
#  [ 2.44010111]
#  [-1.20299677]
#  [-0.63418518]
#  [-1.19853467]
#  [-0.95530306]
#  [ 0.60493553]
#  [-1.09496086]
#  [-0.44463719]
#  [-1.31452628]
#  [-1.78301495]
#  [ 1.21002714]
#  [ 1.65140067]
#  [-0.02476279]
#  [ 0.0644879 ]
#  [-1.26114486]
#  [-0.80101806]
#  [ 0.95102757]
#  [-1.50535489]
#  [-0.52302647]
#  [-1.45483305]
#  [ 0.60014564]
#  [ 0.80743875]
#  [ 1.23236347]
#  [-1.0964279 ]]

# %%
from plotting import plot_data_2d

plot_data_2d(x, y_gt, fig_name="fig_02_09.pdf")  ### plot_data_2d(x, y_gt)

# %% [markdown]
# ## Implementing a Dense Neural Network
#
# Implement the sigmoidal activation function ...

# %%
from numpy import exp

def sigmoid(x):
    """Sigmoid function."""
    return 1 / (1 + exp(-x))

# %% [markdown]
# ... implement a function to define the neural network ...

# %%
def dnn2_reg(wa, wb, x):
    """Two-layer dense neural network for classification."""
    return sigmoid(x @ wa) @ wb

# %% [markdown]
# ... define the number of neurons in the first layer ...

# %%
num_neurons = 3

# %% [markdown]
# ... randomly initialize its weights ...

# %%
from numpy.random import default_rng

rng = default_rng()
wa = rng.standard_normal(size=(2, num_neurons)) # Input weights layer 1.
wb = rng.standard_normal(size=(num_neurons, 1)) # Input weights layer 2.

# %% [markdown]
# ... obtain its predictions for the input data ...

# %%
y_p = dnn2_reg(wa, wb, x)

# %% [markdown]
# ... and plot its predictions.

# %%
from plotting import plot_pred_2d

plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x), fig_name="fig_02_10.pdf")  ### plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x))

# %% [markdown]
# ## Training with the Backpropagation Algorithm
#
# Implement the first derivative of the sigmoid function ...

# %%
def d_sigmoid(x):
    """Derivative of sigmoid function."""
    return sigmoid(x) * (1 - sigmoid(x))

# %% [markdown]
# ... implement the backpropagation algorithm ...

# %%
from numpy import reshape, sum, transpose

num_samples = len(x)
num_train_iterations = 10 ** 5
eta = .1 # Learning rate.

for i in range(num_train_iterations):
    selected = rng.integers(0, num_samples) # Select random sample.
    x_selected = reshape(x[selected], (1, -1))
    y_gt_selected = reshape(y_gt[selected], (1, -1))
    
    # Detailed neural network calculation.
    x_selected_a = x_selected # Input layer 1.
    p_a = x_selected_a @ wa # Activation potential layer 1.
    y_selected_a = sigmoid(p_a) # Output layer 1.

    x_selected_b = y_selected_a # Input layer 2.
    p_b = x_selected_b @ wb # Activation potential layer 2.
    y_selected_b = p_b # Output neuron layer 2 (output neuron).

    y_p_selected = y_selected_b
    
    # Update weights.
    error = y_p_selected - y_gt_selected
    
    delta_b = error * 1
    wb -= eta * delta_b * transpose(x_selected_b)

    delta_a = sum(wb * delta_b, axis=1) * d_sigmoid(p_a)
    wa -= eta * delta_a * transpose(x_selected_a)
    
    if i%100 == 0:
        print(f"{i} y_p={y_p_selected[0, 0]:.2f} error = {error[0, 0]:.2f}")
# Out:
# 0 y_p=0.35 error = -2.09
# 100 y_p=-0.37 error = 0.56
# 200 y_p=0.60 error = -0.01
# 300 y_p=-1.98 error = 0.18
# 400 y_p=1.77 error = -0.06
# 500 y_p=-1.00 error = -0.13
# 600 y_p=-0.46 error = -0.03
# 700 y_p=0.88 error = 0.04
# 800 y_p=-0.96 error = -0.18
# 900 y_p=0.81 error = 0.01
# 1000 y_p=0.30 error = 0.05
# 1100 y_p=1.97 error = 0.01
# 1200 y_p=-2.01 error = 0.15
# 1300 y_p=0.16 error = 0.01
# 1400 y_p=-0.95 error = -0.10
# 1500 y_p=-0.13 error = 0.01
# 1600 y_p=0.57 error = 0.06
# 1700 y_p=1.57 error = 0.02
# 1800 y_p=-0.76 error = -0.02
# 1900 y_p=-0.79 error = -0.08
# 2000 y_p=-0.39 error = -0.01
# 2100 y_p=-1.34 error = -0.08
# 2200 y_p=-0.03 error = -0.00
# 2300 y_p=2.19 error = -0.25
# 2400 y_p=0.86 error = 0.06
# 2500 y_p=1.64 error = 0.13
# 2600 y_p=-0.96 error = -0.06
# 2700 y_p=2.44 error = -0.29
# 2800 y_p=1.95 error = -0.02
# 2900 y_p=0.63 error = 0.08
# 3000 y_p=-1.48 error = -0.02
# 3100 y_p=-0.75 error = 0.05
# 3200 y_p=-1.22 error = -0.13
# 3300 y_p=-1.15 error = -0.06
# 3400 y_p=-0.77 error = -0.03
# 3500 y_p=-0.02 error = -0.01
# 3600 y_p=-1.95 error = 0.17
# 3700 y_p=-0.86 error = -0.06
# 3800 y_p=-0.69 error = -0.06
# 3900 y_p=-0.91 error = -0.07
# 4000 y_p=-1.54 error = -0.03
# 4100 y_p=-1.14 error = -0.04
# 4200 y_p=-1.84 error = 0.01
# 4300 y_p=-1.82 error = -0.05
# 4400 y_p=0.16 error = 0.01
# 4500 y_p=0.77 error = 0.06
# 4600 y_p=-2.03 error = 0.10
# 4700 y_p=-1.09 error = -0.07
# 4800 y_p=-1.77 error = -0.00
# 4900 y_p=-0.99 error = -0.04
# 5000 y_p=-0.34 error = -0.03
# 5100 y_p=-1.53 error = -0.07
# 5200 y_p=1.27 error = 0.04
# 5300 y_p=0.02 error = -0.02
# 5400 y_p=-0.99 error = -0.06
# 5500 y_p=-0.96 error = -0.04
# 5600 y_p=1.02 error = 0.07
# 5700 y_p=1.35 error = 0.10
# 5800 y_p=0.76 error = 0.05
# 5900 y_p=-0.01 error = 0.01
# 6000 y_p=0.01 error = -0.04
# 6100 y_p=-1.10 error = -0.01
# 6200 y_p=-1.09 error = -0.07
# 6300 y_p=-1.27 error = -0.06
# 6400 y_p=-1.39 error = -0.03
# 6500 y_p=0.35 error = 0.10
# 6600 y_p=1.83 error = -0.01
# 6700 y_p=1.22 error = 0.07
# 6800 y_p=1.37 error = 0.05
# 6900 y_p=-0.98 error = -0.04
# 7000 y_p=1.27 error = 0.02
# 7100 y_p=-1.23 error = -0.03
# 7200 y_p=-0.98 error = -0.07
# 7300 y_p=-0.91 error = -0.07
# 7400 y_p=-1.24 error = -0.04
# 7500 y_p=-0.16 error = -0.02
# 7600 y_p=0.63 error = 0.03
# 7700 y_p=-1.13 error = -0.04
# 7800 y_p=-1.57 error = -0.12
# 7900 y_p=1.23 error = 0.09
# 8000 y_p=-2.66 error = 0.37
# 8100 y_p=-1.33 error = -0.07
# 8200 y_p=1.61 error = 0.06
# 8300 y_p=-0.49 error = -0.04
# 8400 y_p=-0.08 error = 0.01
# 8500 y_p=0.34 error = 0.09
# 8600 y_p=-0.62 error = 0.01
# 8700 y_p=-1.51 error = -0.01
# 8800 y_p=1.38 error = 0.06
# 8900 y_p=2.12 error = -0.06
# 9000 y_p=1.34 error = 0.02
# 9100 y_p=-0.26 error = -0.01
# 9200 y_p=-0.95 error = -0.04
# 9300 y_p=1.61 error = 0.06
# 9400 y_p=-0.96 error = -0.03
# 9500 y_p=-1.27 error = -0.01
# 9600 y_p=-1.36 error = -0.00
# 9700 y_p=-1.36 error = -0.02
# 9800 y_p=-0.79 error = -0.08
# 9900 y_p=-1.75 error = 0.03
# 10000 y_p=2.11 error = -0.08
# 10100 y_p=-1.71 error = 0.03
# 10200 y_p=-1.02 error = -0.07
# 10300 y_p=1.85 error = 0.03
# 10400 y_p=0.76 error = -0.04
# 10500 y_p=-1.49 error = -0.03
# 10600 y_p=-0.78 error = -0.04
# 10700 y_p=0.58 error = 0.03
# 10800 y_p=0.48 error = 0.05
# 10900 y_p=-1.02 error = -0.02
# 11000 y_p=0.53 error = 0.02
# 11100 y_p=-0.47 error = -0.02
# 11200 y_p=1.15 error = 0.02
# 11300 y_p=1.57 error = 0.05
# 11400 y_p=-0.97 error = -0.01
# 11500 y_p=0.96 error = 0.01
# 11600 y_p=-1.13 error = -0.04
# 11700 y_p=1.75 error = 0.04
# 11800 y_p=-0.97 error = -0.06
# 11900 y_p=-1.36 error = -0.01
# 12000 y_p=1.25 error = 0.04
# 12100 y_p=-0.25 error = 0.00
# 12200 y_p=-0.43 error = -0.10
# 12300 y_p=-1.25 error = -0.16
# 12400 y_p=1.57 error = 0.02
# 12500 y_p=0.65 error = 0.05
# 12600 y_p=1.24 error = 0.03
# 12700 y_p=0.97 error = 0.02
# 12800 y_p=1.18 error = 0.04
# 12900 y_p=1.31 error = 0.06
# 13000 y_p=-2.74 error = 0.29
# 13100 y_p=-0.51 error = -0.07
# 13200 y_p=-1.01 error = -0.05
# 13300 y_p=-1.15 error = -0.05
# 13400 y_p=0.95 error = 0.00
# 13500 y_p=1.56 error = 0.01
# 13600 y_p=0.56 error = 0.05
# 13700 y_p=-0.03 error = 0.00
# 13800 y_p=0.32 error = 0.08
# 13900 y_p=-1.65 error = -0.07
# 14000 y_p=-1.78 error = -0.04
# 14100 y_p=-1.30 error = -0.00
# 14200 y_p=-0.29 error = -0.01
# 14300 y_p=1.11 error = 0.02
# 14400 y_p=-0.34 error = -0.05
# 14500 y_p=-1.22 error = -0.02
# 14600 y_p=0.02 error = -0.00
# 14700 y_p=2.12 error = -0.03
# 14800 y_p=0.38 error = 0.03
# 14900 y_p=0.64 error = 0.03
# 15000 y_p=-1.83 error = -0.06
# 15100 y_p=0.27 error = 0.02
# 15200 y_p=-0.13 error = 0.01
# 15300 y_p=-0.82 error = -0.02
# 15400 y_p=0.04 error = 0.02
# 15500 y_p=-1.48 error = 0.03
# 15600 y_p=1.97 error = 0.01
# 15700 y_p=-1.32 error = -0.02
# 15800 y_p=-0.81 error = -0.07
# 15900 y_p=-0.14 error = -0.02
# 16000 y_p=-1.49 error = -0.01
# 16100 y_p=-1.11 error = -0.02
# 16200 y_p=1.83 error = -0.03
# 16300 y_p=-1.49 error = -0.01
# 16400 y_p=-0.02 error = 0.02
# 16500 y_p=0.66 error = 0.06
# 16600 y_p=-0.52 error = 0.01
# 16700 y_p=-0.40 error = -0.02
# 16800 y_p=-0.03 error = -0.00
# 16900 y_p=-1.87 error = -0.03
# 17000 y_p=0.95 error = -0.00
# 17100 y_p=-0.30 error = -0.01
# 17200 y_p=-2.30 error = 0.13
# 17300 y_p=-1.41 error = -0.06
# 17400 y_p=-0.09 error = 0.01
# 17500 y_p=-1.16 error = -0.06
# 17600 y_p=-2.73 error = 0.30
# 17700 y_p=-1.23 error = -0.03
# 17800 y_p=1.26 error = 0.01
# 17900 y_p=-1.03 error = -0.03
# 18000 y_p=1.52 error = 0.01
# 18100 y_p=0.01 error = -0.01
# 18200 y_p=0.80 error = -0.00
# 18300 y_p=-1.76 error = 0.01
# 18400 y_p=-0.95 error = -0.04
# 18500 y_p=-1.24 error = -0.04
# 18600 y_p=1.27 error = 0.03
# 18700 y_p=1.93 error = -0.03
# 18800 y_p=-0.44 error = 0.00
# 18900 y_p=1.36 error = 0.04
# 19000 y_p=0.28 error = 0.03
# 19100 y_p=1.31 error = 0.08
# 19200 y_p=-0.97 error = -0.03
# 19300 y_p=0.80 error = 0.01
# 19400 y_p=1.58 error = 0.04
# 19500 y_p=0.42 error = 0.07
# 19600 y_p=-1.75 error = 0.03
# 19700 y_p=-0.47 error = -0.04
# 19800 y_p=2.40 error = -0.04
# 19900 y_p=1.76 error = 0.05
# 20000 y_p=-0.95 error = -0.02
# 20100 y_p=-1.38 error = -0.03
# 20200 y_p=-1.14 error = -0.05
# 20300 y_p=-1.01 error = -0.01
# 20400 y_p=-2.28 error = 0.10
# 20500 y_p=-1.59 error = -0.01
# 20600 y_p=-1.75 error = 0.02
# 20700 y_p=-1.27 error = -0.06
# 20800 y_p=-1.51 error = -0.05
# 20900 y_p=1.25 error = 0.04
# 21000 y_p=-2.13 error = 0.08
# 21100 y_p=0.10 error = 0.03
# 21200 y_p=-0.95 error = -0.02
# 21300 y_p=1.17 error = 0.02
# 21400 y_p=-1.31 error = -0.05
# 21500 y_p=2.17 error = -0.01
# 21600 y_p=-1.22 error = -0.02
# 21700 y_p=0.02 error = -0.01
# 21800 y_p=-1.10 error = -0.01
# 21900 y_p=0.66 error = 0.05
# 22000 y_p=1.60 error = 0.06
# 22100 y_p=-1.74 error = -0.01
# 22200 y_p=-0.97 error = -0.04
# 22300 y_p=-1.13 error = -0.04
# 22400 y_p=-2.36 error = 0.02
# 22500 y_p=-2.79 error = 0.24
# 22600 y_p=0.64 error = 0.04
# 22700 y_p=1.85 error = -0.02
# 22800 y_p=-1.44 error = -0.14
# 22900 y_p=0.17 error = 0.03
# 23000 y_p=-1.21 error = -0.01
# 23100 y_p=-1.40 error = -0.05
# 23200 y_p=0.80 error = 0.01
# 23300 y_p=-2.08 error = 0.08
# 23400 y_p=0.14 error = -0.00
# 23500 y_p=1.56 error = 0.01
# 23600 y_p=-1.74 error = -0.00
# 23700 y_p=-0.37 error = -0.02
# 23800 y_p=-0.14 error = 0.01
# 23900 y_p=-1.23 error = -0.03
# 24000 y_p=-0.13 error = 0.01
# 24100 y_p=-2.28 error = 0.11
# 24200 y_p=0.82 error = 0.01
# 24300 y_p=0.77 error = 0.06
# 24400 y_p=-0.17 error = -0.03
# 24500 y_p=1.84 error = 0.01
# 24600 y_p=0.58 error = 0.03
# 24700 y_p=-2.05 error = 0.08
# 24800 y_p=1.66 error = 0.01
# 24900 y_p=2.35 error = -0.09
# 25000 y_p=-1.10 error = -0.05
# 25100 y_p=1.85 error = -0.02
# 25200 y_p=-1.46 error = -0.01
# 25300 y_p=-0.80 error = -0.02
# 25400 y_p=2.10 error = -0.09
# 25500 y_p=1.92 error = -0.04
# 25600 y_p=1.25 error = 0.01
# 25700 y_p=0.03 error = -0.02
# 25800 y_p=1.13 error = 0.18
# 25900 y_p=0.53 error = 0.02
# 26000 y_p=-1.82 error = 0.03
# 26100 y_p=-0.13 error = 0.01
# 26200 y_p=1.87 error = 0.03
# 26300 y_p=0.63 error = 0.03
# 26400 y_p=-1.31 error = -0.01
# 26500 y_p=-1.31 error = -0.02
# 26600 y_p=-0.38 error = -0.02
# 26700 y_p=-0.39 error = -0.00
# 26800 y_p=-0.80 error = -0.00
# 26900 y_p=-0.30 error = -0.03
# 27000 y_p=0.66 error = 0.05
# 27100 y_p=-0.82 error = -0.02
# 27200 y_p=1.09 error = 0.14
# 27300 y_p=1.12 error = 0.04
# 27400 y_p=-2.27 error = 0.11
# 27500 y_p=-1.77 error = 0.02
# 27600 y_p=-0.90 error = -0.03
# 27700 y_p=0.09 error = 0.05
# 27800 y_p=-2.33 error = 0.10
# 27900 y_p=-0.51 error = 0.01
# 28000 y_p=-1.36 error = -0.01
# 28100 y_p=-0.94 error = -0.03
# 28200 y_p=-0.36 error = -0.03
# 28300 y_p=1.94 error = -0.02
# 28400 y_p=1.88 error = 0.01
# 28500 y_p=0.63 error = 0.03
# 28600 y_p=-0.46 error = -0.02
# 28700 y_p=0.45 error = 0.02
# 28800 y_p=-1.31 error = 0.00
# 28900 y_p=-0.30 error = -0.02
# 29000 y_p=-1.71 error = 0.03
# 29100 y_p=-2.34 error = 0.10
# 29200 y_p=0.29 error = 0.05
# 29300 y_p=0.26 error = 0.01
# 29400 y_p=-1.34 error = 0.02
# 29500 y_p=0.64 error = 0.04
# 29600 y_p=-1.00 error = -0.06
# 29700 y_p=0.63 error = 0.03
# 29800 y_p=1.85 error = 0.02
# 29900 y_p=1.34 error = 0.03
# 30000 y_p=-0.86 error = -0.02
# 30100 y_p=-1.50 error = -0.03
# 30200 y_p=-0.80 error = 0.00
# 30300 y_p=-1.38 error = -0.03
# 30400 y_p=-0.38 error = -0.01
# 30500 y_p=-0.04 error = -0.00
# 30600 y_p=1.23 error = 0.02
# 30700 y_p=1.71 error = -0.00
# 30800 y_p=-1.35 error = 0.01
# 30900 y_p=-0.33 error = -0.00
# 31000 y_p=-0.17 error = 0.02
# 31100 y_p=-2.34 error = 0.09
# 31200 y_p=0.03 error = 0.01
# 31300 y_p=-0.97 error = -0.06
# 31400 y_p=-1.75 error = -0.01
# 31500 y_p=0.26 error = 0.02
# 31600 y_p=-2.17 error = 0.05
# 31700 y_p=0.00 error = 0.01
# 31800 y_p=1.13 error = 0.01
# 31900 y_p=-1.49 error = -0.01
# 32000 y_p=-0.65 error = -0.02
# 32100 y_p=1.24 error = 0.01
# 32200 y_p=-0.31 error = 0.01
# 32300 y_p=-0.37 error = -0.01
# 32400 y_p=-2.37 error = 0.06
# 32500 y_p=0.88 error = 0.04
# 32600 y_p=0.09 error = -0.02
# 32700 y_p=-0.03 error = -0.00
# 32800 y_p=1.58 error = 0.06
# 32900 y_p=1.35 error = 0.04
# 33000 y_p=-2.35 error = 0.08
# 33100 y_p=-1.55 error = 0.03
# 33200 y_p=0.63 error = 0.02
# 33300 y_p=1.27 error = 0.04
# 33400 y_p=2.58 error = -0.15
# 33500 y_p=1.14 error = 0.05
# 33600 y_p=0.27 error = 0.02
# 33700 y_p=-0.39 error = -0.01
# 33800 y_p=-0.15 error = -0.01
# 33900 y_p=-0.03 error = -0.00
# 34000 y_p=-1.02 error = -0.02
# 34100 y_p=-0.35 error = -0.01
# 34200 y_p=-1.38 error = -0.06
# 34300 y_p=1.87 error = 0.05
# 34400 y_p=0.16 error = 0.01
# 34500 y_p=2.11 error = -0.08
# 34600 y_p=-0.73 error = -0.02
# 34700 y_p=-0.47 error = -0.03
# 34800 y_p=0.53 error = 0.02
# 34900 y_p=-0.38 error = -0.01
# 35000 y_p=-1.75 error = 0.02
# 35100 y_p=-1.15 error = -0.05
# 35200 y_p=-0.36 error = -0.00
# 35300 y_p=-1.11 error = -0.02
# 35400 y_p=-1.56 error = 0.02
# 35500 y_p=0.64 error = 0.04
# 35600 y_p=-1.03 error = -0.02
# 35700 y_p=-1.11 error = -0.03
# 35800 y_p=1.22 error = 0.08
# 35900 y_p=0.89 error = 0.05
# 36000 y_p=-0.46 error = -0.01
# 36100 y_p=-1.77 error = 0.01
# 36200 y_p=-1.55 error = 0.03
# 36300 y_p=-1.47 error = 0.03
# 36400 y_p=-2.39 error = 0.04
# 36500 y_p=-1.53 error = -0.05
# 36600 y_p=-0.37 error = -0.01
# 36700 y_p=-1.34 error = -0.03
# 36800 y_p=-1.37 error = -0.02
# 36900 y_p=0.54 error = 0.03
# 37000 y_p=1.97 error = 0.01
# 37100 y_p=-1.12 error = -0.02
# 37200 y_p=-2.80 error = 0.23
# 37300 y_p=0.65 error = 0.04
# 37400 y_p=0.63 error = 0.03
# 37500 y_p=-1.21 error = -0.00
# 37600 y_p=-1.76 error = -0.02
# 37700 y_p=2.60 error = -0.13
# 37800 y_p=-1.32 error = -0.01
# 37900 y_p=-1.82 error = 0.02
# 38000 y_p=-0.77 error = -0.03
# 38100 y_p=-0.91 error = -0.03
# 38200 y_p=0.35 error = -0.00
# 38300 y_p=0.27 error = 0.02
# 38400 y_p=-1.73 error = 0.00
# 38500 y_p=0.26 error = 0.01
# 38600 y_p=1.82 error = -0.04
# 38700 y_p=0.87 error = 0.06
# 38800 y_p=0.87 error = 0.03
# 38900 y_p=-1.35 error = -0.04
# 39000 y_p=0.82 error = 0.01
# 39100 y_p=-1.23 error = -0.03
# 39200 y_p=-1.51 error = -0.03
# 39300 y_p=-0.97 error = -0.03
# 39400 y_p=-1.76 error = 0.03
# 39500 y_p=0.28 error = 0.03
# 39600 y_p=-0.04 error = -0.01
# 39700 y_p=-2.05 error = 0.08
# 39800 y_p=-0.20 error = -0.01
# 39900 y_p=-0.33 error = 0.02
# 40000 y_p=1.73 error = 0.02
# 40100 y_p=-1.22 error = -0.01
# 40200 y_p=1.35 error = 0.03
# 40300 y_p=-0.37 error = -0.01
# 40400 y_p=-1.11 error = -0.02
# 40500 y_p=-1.22 error = -0.02
# 40600 y_p=-2.36 error = 0.02
# 40700 y_p=-0.65 error = -0.01
# 40800 y_p=-1.36 error = -0.01
# 40900 y_p=0.57 error = 0.03
# 41000 y_p=0.08 error = 0.01
# 41100 y_p=-0.48 error = -0.03
# 41200 y_p=-1.78 error = 0.00
# 41300 y_p=-1.05 error = -0.03
# 41400 y_p=1.95 error = -0.01
# 41500 y_p=1.23 error = 0.02
# 41600 y_p=-0.95 error = -0.02
# 41700 y_p=-2.31 error = 0.07
# 41800 y_p=-0.48 error = -0.04
# 41900 y_p=-0.04 error = 0.00
# 42000 y_p=1.10 error = 0.02
# 42100 y_p=1.33 error = 0.02
# 42200 y_p=0.25 error = 0.00
# 42300 y_p=-0.92 error = -0.01
# 42400 y_p=-1.85 error = -0.06
# 42500 y_p=-0.74 error = -0.03
# 42600 y_p=-0.37 error = 0.00
# 42700 y_p=-0.40 error = -0.02
# 42800 y_p=-2.10 error = 0.05
# 42900 y_p=-1.95 error = -0.11
# 43000 y_p=2.10 error = 0.00
# 43100 y_p=-0.97 error = -0.04
# 43200 y_p=-0.29 error = 0.00
# 43300 y_p=1.29 error = 0.04
# 43400 y_p=1.94 error = -0.02
# 43500 y_p=0.54 error = 0.02
# 43600 y_p=-0.40 error = -0.02
# 43700 y_p=-0.94 error = -0.02
# 43800 y_p=-0.66 error = -0.03
# 43900 y_p=-1.36 error = -0.01
# 44000 y_p=-2.14 error = -0.01
# 44100 y_p=1.20 error = 0.05
# 44200 y_p=-0.15 error = -0.01
# 44300 y_p=-0.76 error = -0.02
# 44400 y_p=-0.47 error = -0.03
# 44500 y_p=-0.53 error = -0.01
# 44600 y_p=1.64 error = -0.01
# 44700 y_p=1.85 error = -0.02
# 44800 y_p=-1.12 error = -0.03
# 44900 y_p=1.28 error = 0.03
# 45000 y_p=0.17 error = 0.01
# 45100 y_p=0.75 error = 0.04
# 45200 y_p=-0.39 error = -0.01
# 45300 y_p=1.87 error = 0.00
# 45400 y_p=-1.86 error = -0.02
# 45500 y_p=-0.96 error = -0.02
# 45600 y_p=1.70 error = 0.05
# 45700 y_p=0.82 error = 0.02
# 45800 y_p=0.04 error = -0.00
# 45900 y_p=-1.13 error = -0.03
# 46000 y_p=-1.21 error = -0.01
# 46100 y_p=2.16 error = -0.02
# 46200 y_p=-2.32 error = 0.06
# 46300 y_p=1.25 error = 0.04
# 46400 y_p=0.30 error = 0.06
# 46500 y_p=1.35 error = 0.04
# 46600 y_p=0.03 error = 0.00
# 46700 y_p=0.73 error = 0.02
# 46800 y_p=-0.45 error = -0.02
# 46900 y_p=-1.24 error = -0.03
# 47000 y_p=-0.79 error = 0.02
# 47100 y_p=1.33 error = 0.02
# 47200 y_p=-0.34 error = 0.01
# 47300 y_p=1.92 error = -0.04
# 47400 y_p=0.45 error = 0.02
# 47500 y_p=-0.29 error = -0.02
# 47600 y_p=-0.37 error = -0.01
# 47700 y_p=-1.14 error = -0.05
# 47800 y_p=-1.11 error = -0.03
# 47900 y_p=-0.02 error = 0.01
# 48000 y_p=0.62 error = 0.02
# 48100 y_p=-0.37 error = -0.02
# 48200 y_p=-2.10 error = 0.06
# 48300 y_p=0.27 error = 0.02
# 48400 y_p=0.63 error = 0.03
# 48500 y_p=0.16 error = 0.00
# 48600 y_p=-1.02 error = -0.02
# 48700 y_p=1.33 error = 0.02
# 48800 y_p=-2.31 error = 0.08
# 48900 y_p=-1.62 error = -0.05
# 49000 y_p=1.85 error = -0.02
# 49100 y_p=-1.37 error = -0.02
# 49200 y_p=1.53 error = 0.01
# 49300 y_p=-1.55 error = 0.03
# 49400 y_p=2.37 error = -0.07
# 49500 y_p=-1.11 error = -0.02
# 49600 y_p=-0.36 error = -0.01
# 49700 y_p=-1.21 error = -0.01
# 49800 y_p=0.19 error = 0.03
# 49900 y_p=-1.32 error = -0.01
# 50000 y_p=1.15 error = 0.03
# 50100 y_p=2.65 error = -0.08
# 50200 y_p=0.86 error = 0.02
# 50300 y_p=-0.17 error = -0.03
# 50400 y_p=-0.20 error = -0.01
# 50500 y_p=0.36 error = 0.01
# 50600 y_p=-0.81 error = -0.03
# 50700 y_p=-0.81 error = -0.03
# 50800 y_p=-0.29 error = 0.00
# 50900 y_p=-1.48 error = -0.00
# 51000 y_p=-0.76 error = 0.04
# 51100 y_p=-0.01 error = 0.00
# 51200 y_p=-1.07 error = -0.03
# 51300 y_p=1.97 error = 0.00
# 51400 y_p=-1.23 error = -0.02
# 51500 y_p=1.78 error = -0.04
# 51600 y_p=-1.76 error = 0.02
# 51700 y_p=-1.05 error = -0.03
# 51800 y_p=-0.47 error = -0.02
# 51900 y_p=-2.32 error = 0.07
# 52000 y_p=-1.35 error = -0.03
# 52100 y_p=-0.13 error = -0.01
# 52200 y_p=-1.13 error = -0.03
# 52300 y_p=2.09 error = -0.09
# 52400 y_p=1.26 error = 0.02
# 52500 y_p=-0.00 error = 0.01
# 52600 y_p=-2.34 error = 0.09
# 52700 y_p=1.92 error = -0.04
# 52800 y_p=-1.82 error = -0.04
# 52900 y_p=-0.39 error = -0.00
# 53000 y_p=-0.20 error = -0.01
# 53100 y_p=0.61 error = 0.01
# 53200 y_p=-0.65 error = -0.02
# 53300 y_p=0.44 error = 0.01
# 53400 y_p=0.26 error = 0.02
# 53500 y_p=-1.11 error = -0.01
# 53600 y_p=0.41 error = 0.06
# 53700 y_p=2.15 error = -0.04
# 53800 y_p=1.10 error = 0.01
# 53900 y_p=-0.76 error = -0.02
# 54000 y_p=-1.36 error = -0.01
# 54100 y_p=-0.29 error = -0.00
# 54200 y_p=-2.34 error = 0.09
# 54300 y_p=0.72 error = 0.01
# 54400 y_p=0.35 error = 0.01
# 54500 y_p=2.16 error = 0.01
# 54600 y_p=-0.87 error = -0.02
# 54700 y_p=0.89 error = 0.05
# 54800 y_p=-2.87 error = 0.17
# 54900 y_p=0.24 error = -0.01
# 55000 y_p=0.58 error = 0.03
# 55100 y_p=-2.11 error = 0.05
# 55200 y_p=0.23 error = -0.02
# 55300 y_p=-2.19 error = 0.02
# 55400 y_p=0.86 error = 0.02
# 55500 y_p=-0.45 error = -0.02
# 55600 y_p=1.33 error = 0.01
# 55700 y_p=-0.16 error = -0.02
# 55800 y_p=-1.36 error = -0.00
# 55900 y_p=-1.07 error = -0.02
# 56000 y_p=1.91 error = 0.04
# 56100 y_p=0.33 error = -0.02
# 56200 y_p=-0.80 error = -0.00
# 56300 y_p=0.13 error = 0.02
# 56400 y_p=-0.36 error = -0.03
# 56500 y_p=-0.74 error = -0.00
# 56600 y_p=0.08 error = 0.04
# 56700 y_p=-1.52 error = -0.02
# 56800 y_p=-1.21 error = -0.01
# 56900 y_p=-0.97 error = -0.02
# 57000 y_p=1.31 error = 0.06
# 57100 y_p=2.38 error = -0.06
# 57200 y_p=-0.72 error = -0.01
# 57300 y_p=-0.34 error = -0.01
# 57400 y_p=-0.76 error = -0.02
# 57500 y_p=0.16 error = 0.01
# 57600 y_p=-0.36 error = -0.05
# 57700 y_p=1.23 error = 0.02
# 57800 y_p=-1.07 error = -0.02
# 57900 y_p=-0.95 error = -0.01
# 58000 y_p=0.63 error = 0.03
# 58100 y_p=-1.13 error = -0.04
# 58200 y_p=-1.27 error = -0.01
# 58300 y_p=-1.84 error = 0.01
# 58400 y_p=1.69 error = 0.04
# 58500 y_p=1.14 error = 0.02
# 58600 y_p=0.85 error = 0.05
# 58700 y_p=-0.33 error = -0.00
# 58800 y_p=0.12 error = 0.01
# 58900 y_p=1.36 error = 0.05
# 59000 y_p=-0.71 error = -0.00
# 59100 y_p=-0.12 error = -0.00
# 59200 y_p=-0.95 error = -0.01
# 59300 y_p=-0.95 error = -0.02
# 59400 y_p=-0.04 error = -0.03
# 59500 y_p=-0.18 error = 0.01
# 59600 y_p=1.82 error = -0.01
# 59700 y_p=0.25 error = -0.00
# 59800 y_p=-0.34 error = -0.02
# 59900 y_p=-0.96 error = -0.03
# 60000 y_p=-1.49 error = -0.03
# 60100 y_p=-0.35 error = -0.02
# 60200 y_p=-1.27 error = -0.01
# 60300 y_p=1.26 error = 0.03
# 60400 y_p=-0.26 error = -0.00
# 60500 y_p=2.13 error = -0.02
# 60600 y_p=-0.90 error = -0.03
# 60700 y_p=-2.05 error = 0.07
# 60800 y_p=0.35 error = 0.00
# 60900 y_p=1.82 error = -0.00
# 61000 y_p=-2.41 error = 0.02
# 61100 y_p=-0.92 error = -0.01
# 61200 y_p=1.22 error = 0.01
# 61300 y_p=0.11 error = 0.01
# 61400 y_p=-0.26 error = -0.01
# 61500 y_p=0.04 error = 0.01
# 61600 y_p=1.13 error = 0.01
# 61700 y_p=0.27 error = 0.03
# 61800 y_p=-2.19 error = 0.02
# 61900 y_p=-1.36 error = -0.00
# 62000 y_p=1.15 error = 0.00
# 62100 y_p=-1.35 error = -0.03
# 62200 y_p=0.02 error = -0.01
# 62300 y_p=2.34 error = -0.10
# 62400 y_p=-0.31 error = -0.00
# 62500 y_p=-0.31 error = 0.00
# 62600 y_p=-1.11 error = -0.01
# 62700 y_p=-1.53 error = -0.05
# 62800 y_p=-1.09 error = -0.01
# 62900 y_p=2.06 error = -0.04
# 63000 y_p=-0.27 error = -0.01
# 63100 y_p=-0.02 error = -0.01
# 63200 y_p=1.84 error = -0.03
# 63300 y_p=-1.06 error = -0.01
# 63400 y_p=-0.63 error = 0.01
# 63500 y_p=-2.15 error = 0.06
# 63600 y_p=0.28 error = 0.02
# 63700 y_p=-0.38 error = 0.00
# 63800 y_p=2.20 error = 0.02
# 63900 y_p=-0.19 error = 0.00
# 64000 y_p=-0.94 error = -0.03
# 64100 y_p=-0.94 error = -0.01
# 64200 y_p=0.06 error = -0.00
# 64300 y_p=-0.29 error = 0.00
# 64400 y_p=-0.56 error = -0.04
# 64500 y_p=0.80 error = 0.00
# 64600 y_p=-0.82 error = -0.02
# 64700 y_p=-2.35 error = 0.09
# 64800 y_p=-0.19 error = 0.00
# 64900 y_p=-1.11 error = -0.01
# 65000 y_p=0.11 error = 0.00
# 65100 y_p=-1.12 error = -0.02
# 65200 y_p=2.07 error = -0.03
# 65300 y_p=0.66 error = 0.06
# 65400 y_p=1.15 error = 0.03
# 65500 y_p=-0.43 error = -0.05
# 65600 y_p=-0.28 error = -0.00
# 65700 y_p=-0.12 error = -0.00
# 65800 y_p=-1.23 error = -0.04
# 65900 y_p=-1.57 error = 0.00
# 66000 y_p=-0.77 error = -0.06
# 66100 y_p=-1.22 error = -0.02
# 66200 y_p=-1.82 error = 0.03
# 66300 y_p=-1.04 error = -0.02
# 66400 y_p=-1.12 error = -0.03
# 66500 y_p=-0.43 error = -0.00
# 66600 y_p=-0.72 error = -0.01
# 66700 y_p=-0.33 error = -0.00
# 66800 y_p=-0.97 error = -0.01
# 66900 y_p=1.18 error = 0.03
# 67000 y_p=-0.96 error = -0.09
# 67100 y_p=-0.55 error = -0.02
# 67200 y_p=1.88 error = 0.06
# 67300 y_p=0.27 error = 0.02
# 67400 y_p=-1.32 error = -0.00
# 67500 y_p=-0.26 error = -0.01
# 67600 y_p=-1.35 error = -0.06
# 67700 y_p=1.24 error = -0.01
# 67800 y_p=-0.66 error = -0.03
# 67900 y_p=1.22 error = 0.07
# 68000 y_p=-0.78 error = 0.02
# 68100 y_p=1.19 error = 0.04
# 68200 y_p=2.59 error = -0.15
# 68300 y_p=-1.79 error = -0.00
# 68400 y_p=-1.05 error = -0.04
# 68500 y_p=0.88 error = 0.04
# 68600 y_p=0.66 error = 0.05
# 68700 y_p=0.83 error = 0.03
# 68800 y_p=0.64 error = 0.03
# 68900 y_p=0.63 error = 0.02
# 69000 y_p=-1.83 error = -0.05
# 69100 y_p=0.87 error = 0.03
# 69200 y_p=-0.44 error = -0.01
# 69300 y_p=-0.80 error = 0.00
# 69400 y_p=-1.06 error = -0.02
# 69500 y_p=0.59 error = -0.02
# 69600 y_p=-0.01 error = -0.00
# 69700 y_p=-0.02 error = 0.00
# 69800 y_p=1.33 error = 0.01
# 69900 y_p=-1.37 error = -0.03
# 70000 y_p=-0.96 error = -0.02
# 70100 y_p=0.11 error = 0.00
# 70200 y_p=1.37 error = 0.12
# 70300 y_p=-1.75 error = 0.02
# 70400 y_p=-0.11 error = -0.01
# 70500 y_p=-0.13 error = -0.01
# 70600 y_p=-0.74 error = -0.03
# 70700 y_p=1.70 error = -0.01
# 70800 y_p=-0.26 error = 0.01
# 70900 y_p=-0.86 error = -0.02
# 71000 y_p=1.58 error = 0.04
# 71100 y_p=0.79 error = -0.00
# 71200 y_p=-1.74 error = -0.00
# 71300 y_p=2.60 error = -0.13
# 71400 y_p=-1.35 error = 0.01
# 71500 y_p=-1.82 error = 0.03
# 71600 y_p=0.82 error = 0.02
# 71700 y_p=-1.11 error = -0.02
# 71800 y_p=1.72 error = 0.01
# 71900 y_p=-1.46 error = -0.01
# 72000 y_p=0.07 error = 0.00
# 72100 y_p=2.10 error = -0.05
# 72200 y_p=-0.09 error = 0.00
# 72300 y_p=-2.16 error = 0.06
# 72400 y_p=-1.12 error = -0.02
# 72500 y_p=1.35 error = 0.03
# 72600 y_p=-1.23 error = -0.03
# 72700 y_p=1.80 error = -0.02
# 72800 y_p=0.85 error = 0.04
# 72900 y_p=-1.22 error = -0.01
# 73000 y_p=-0.35 error = -0.00
# 73100 y_p=2.67 error = -0.06
# 73200 y_p=0.63 error = 0.03
# 73300 y_p=-1.05 error = -0.01
# 73400 y_p=-1.32 error = -0.01
# 73500 y_p=0.60 error = -0.00
# 73600 y_p=0.56 error = 0.05
# 73700 y_p=0.24 error = -0.00
# 73800 y_p=-0.12 error = -0.00
# 73900 y_p=-0.00 error = 0.01
# 74000 y_p=-1.04 error = -0.02
# 74100 y_p=1.16 error = 0.01
# 74200 y_p=2.37 error = -0.07
# 74300 y_p=1.93 error = -0.03
# 74400 y_p=2.34 error = -0.10
# 74500 y_p=0.61 error = 0.06
# 74600 y_p=-0.76 error = -0.05
# 74700 y_p=-0.35 error = 0.02
# 74800 y_p=0.54 error = 0.03
# 74900 y_p=-1.05 error = -0.00
# 75000 y_p=-0.76 error = -0.05
# 75100 y_p=0.53 error = 0.02
# 75200 y_p=-0.92 error = -0.01
# 75300 y_p=-1.05 error = -0.01
# 75400 y_p=-1.03 error = -0.01
# 75500 y_p=-0.72 error = -0.01
# 75600 y_p=0.84 error = 0.03
# 75700 y_p=0.35 error = 0.00
# 75800 y_p=-1.36 error = -0.00
# 75900 y_p=-0.94 error = -0.01
# 76000 y_p=-0.52 error = -0.00
# 76100 y_p=1.74 error = 0.03
# 76200 y_p=0.26 error = 0.02
# 76300 y_p=-0.39 error = -0.00
# 76400 y_p=1.31 error = -0.00
# 76500 y_p=0.82 error = 0.01
# 76600 y_p=0.82 error = 0.02
# 76700 y_p=-0.45 error = -0.01
# 76800 y_p=-2.18 error = -0.06
# 76900 y_p=0.00 error = 0.01
# 77000 y_p=-0.37 error = -0.02
# 77100 y_p=-2.16 error = 0.05
# 77200 y_p=-0.86 error = -0.06
# 77300 y_p=0.53 error = 0.01
# 77400 y_p=-0.14 error = 0.00
# 77500 y_p=0.02 error = -0.02
# 77600 y_p=-1.25 error = -0.16
# 77700 y_p=1.15 error = 0.07
# 77800 y_p=2.71 error = -0.03
# 77900 y_p=0.45 error = 0.01
# 78000 y_p=1.86 error = 0.02
# 78100 y_p=1.16 error = 0.04
# 78200 y_p=2.14 error = -0.01
# 78300 y_p=0.44 error = 0.01
# 78400 y_p=-1.01 error = -0.00
# 78500 y_p=-1.10 error = -0.06
# 78600 y_p=-0.91 error = -0.03
# 78700 y_p=-0.89 error = -0.01
# 78800 y_p=-0.10 error = -0.01
# 78900 y_p=0.12 error = 0.01
# 79000 y_p=-2.87 error = 0.16
# 79100 y_p=1.85 error = 0.01
# 79200 y_p=-1.03 error = -0.01
# 79300 y_p=-0.96 error = -0.01
# 79400 y_p=1.12 error = 0.04
# 79500 y_p=2.24 error = 0.05
# 79600 y_p=-1.34 error = -0.03
# 79700 y_p=2.63 error = -0.11
# 79800 y_p=-0.87 error = -0.03
# 79900 y_p=0.82 error = 0.02
# 80000 y_p=-0.93 error = -0.02
# 80100 y_p=0.15 error = 0.01
# 80200 y_p=1.55 error = 0.00
# 80300 y_p=-0.91 error = -0.01
# 80400 y_p=-2.07 error = 0.05
# 80500 y_p=1.16 error = 0.01
# 80600 y_p=0.26 error = 0.01
# 80700 y_p=-0.35 error = -0.00
# 80800 y_p=-1.06 error = -0.04
# 80900 y_p=-0.53 error = -0.01
# 81000 y_p=-0.41 error = -0.03
# 81100 y_p=0.86 error = 0.05
# 81200 y_p=0.84 error = 0.05
# 81300 y_p=-0.72 error = -0.01
# 81400 y_p=0.16 error = 0.01
# 81500 y_p=0.26 error = 0.01
# 81600 y_p=0.35 error = 0.00
# 81700 y_p=-0.36 error = -0.01
# 81800 y_p=0.24 error = -0.01
# 81900 y_p=-0.95 error = -0.02
# 82000 y_p=1.54 error = -0.01
# 82100 y_p=-1.30 error = -0.09
# 82200 y_p=-0.43 error = 0.01
# 82300 y_p=-0.41 error = -0.02
# 82400 y_p=0.03 error = 0.00
# 82500 y_p=-1.47 error = -0.01
# 82600 y_p=-0.45 error = -0.00
# 82700 y_p=-1.22 error = -0.01
# 82800 y_p=1.31 error = 0.06
# 82900 y_p=-1.49 error = 0.01
# 83000 y_p=1.88 error = 0.01
# 83100 y_p=-1.51 error = -0.06
# 83200 y_p=-1.47 error = 0.00
# 83300 y_p=-0.34 error = -0.03
# 83400 y_p=0.08 error = 0.01
# 83500 y_p=1.82 error = -0.00
# 83600 y_p=-0.81 error = -0.01
# 83700 y_p=1.10 error = 0.02
# 83800 y_p=-0.22 error = -0.03
# 83900 y_p=-0.97 error = -0.02
# 84000 y_p=-0.76 error = -0.05
# 84100 y_p=0.83 error = 0.03
# 84200 y_p=-1.47 error = -0.02
# 84300 y_p=-0.72 error = -0.01
# 84400 y_p=-1.67 error = -0.10
# 84500 y_p=-1.33 error = -0.03
# 84600 y_p=-1.02 error = -0.00
# 84700 y_p=0.35 error = 0.00
# 84800 y_p=2.14 error = -0.02
# 84900 y_p=-0.02 error = 0.01
# 85000 y_p=0.11 error = -0.00
# 85100 y_p=-0.30 error = 0.01
# 85200 y_p=-0.89 error = -0.02
# 85300 y_p=2.19 error = 0.01
# 85400 y_p=-1.36 error = -0.01
# 85500 y_p=0.74 error = 0.03
# 85600 y_p=-0.98 error = -0.04
# 85700 y_p=-0.35 error = -0.03
# 85800 y_p=2.39 error = -0.05
# 85900 y_p=-0.27 error = -0.08
# 86000 y_p=-0.12 error = 0.00
# 86100 y_p=-1.22 error = -0.01
# 86200 y_p=-2.44 error = -0.01
# 86300 y_p=-0.20 error = -0.00
# 86400 y_p=-1.53 error = -0.02
# 86500 y_p=-0.36 error = 0.01
# 86600 y_p=-1.01 error = 0.00
# 86700 y_p=-2.37 error = 0.06
# 86800 y_p=-1.27 error = -0.01
# 86900 y_p=-1.05 error = -0.05
# 87000 y_p=-0.12 error = 0.00
# 87100 y_p=0.25 error = 0.00
# 87200 y_p=0.17 error = 0.02
# 87300 y_p=0.09 error = 0.02
# 87400 y_p=-1.79 error = -0.02
# 87500 y_p=2.18 error = 0.00
# 87600 y_p=-0.44 error = -0.01
# 87700 y_p=-1.24 error = -0.03
# 87800 y_p=1.33 error = 0.02
# 87900 y_p=1.93 error = -0.03
# 88000 y_p=2.15 error = 0.00
# 88100 y_p=-1.21 error = -0.01
# 88200 y_p=-1.51 error = -0.03
# 88300 y_p=-0.81 error = -0.01
# 88400 y_p=-0.27 error = 0.02
# 88500 y_p=-1.48 error = -0.01
# 88600 y_p=1.83 error = -0.01
# 88700 y_p=-0.38 error = -0.02
# 88800 y_p=-0.38 error = -0.03
# 88900 y_p=-1.07 error = -0.02
# 89000 y_p=-0.34 error = -0.01
# 89100 y_p=-2.17 error = 0.05
# 89200 y_p=-0.13 error = -0.00
# 89300 y_p=0.83 error = 0.02
# 89400 y_p=1.51 error = -0.01
# 89500 y_p=0.44 error = 0.01
# 89600 y_p=-0.40 error = 0.03
# 89700 y_p=-1.03 error = -0.01
# 89800 y_p=0.93 error = 0.13
# 89900 y_p=-0.28 error = -0.01
# 90000 y_p=0.84 error = 0.04
# 90100 y_p=-0.98 error = -0.03
# 90200 y_p=-0.96 error = -0.03
# 90300 y_p=-0.75 error = -0.04
# 90400 y_p=-0.47 error = -0.03
# 90500 y_p=-2.88 error = 0.15
# 90600 y_p=-1.13 error = -0.03
# 90700 y_p=-0.95 error = -0.02
# 90800 y_p=-1.76 error = 0.01
# 90900 y_p=-1.68 error = -0.10
# 91000 y_p=0.83 error = 0.03
# 91100 y_p=-0.44 error = -0.00
# 91200 y_p=0.02 error = -0.02
# 91300 y_p=0.75 error = -0.05
# 91400 y_p=-0.20 error = -0.01
# 91500 y_p=1.57 error = 0.02
# 91600 y_p=0.01 error = -0.03
# 91700 y_p=-1.35 error = -0.01
# 91800 y_p=-2.35 error = 0.04
# 91900 y_p=0.25 error = 0.01
# 92000 y_p=-2.13 error = 0.03
# 92100 y_p=2.05 error = 0.08
# 92200 y_p=-1.29 error = 0.01
# 92300 y_p=-1.82 error = 0.02
# 92400 y_p=0.87 error = 0.06
# 92500 y_p=-1.03 error = -0.01
# 92600 y_p=-0.14 error = -0.02
# 92700 y_p=-2.15 error = 0.06
# 92800 y_p=-1.03 error = -0.02
# 92900 y_p=-2.33 error = 0.10
# 93000 y_p=-1.49 error = -0.01
# 93100 y_p=0.06 error = -0.00
# 93200 y_p=1.16 error = 0.04
# 93300 y_p=1.52 error = 0.01
# 93400 y_p=1.10 error = 0.02
# 93500 y_p=-0.53 error = -0.00
# 93600 y_p=-0.33 error = -0.00
# 93700 y_p=-1.47 error = 0.00
# 93800 y_p=-1.80 error = -0.02
# 93900 y_p=1.90 error = 0.03
# 94000 y_p=1.21 error = -0.00
# 94100 y_p=-1.06 error = -0.01
# 94200 y_p=-1.01 error = -0.05
# 94300 y_p=-0.26 error = -0.01
# 94400 y_p=1.22 error = 0.01
# 94500 y_p=-0.32 error = 0.00
# 94600 y_p=0.61 error = 0.01
# 94700 y_p=-0.96 error = -0.03
# 94800 y_p=0.12 error = 0.01
# 94900 y_p=-0.66 error = -0.03
# 95000 y_p=2.68 error = -0.05
# 95100 y_p=1.15 error = 0.03
# 95200 y_p=-0.76 error = -0.02
# 95300 y_p=-1.85 error = 0.00
# 95400 y_p=-0.03 error = 0.01
# 95500 y_p=0.26 error = 0.01
# 95600 y_p=0.72 error = 0.01
# 95700 y_p=1.57 error = 0.02
# 95800 y_p=-0.01 error = 0.01
# 95900 y_p=-0.40 error = -0.02
# 96000 y_p=-1.12 error = -0.03
# 96100 y_p=0.81 error = 0.00
# 96200 y_p=-0.33 error = -0.02
# 96300 y_p=2.42 error = -0.02
# 96400 y_p=-1.77 error = -0.03
# 96500 y_p=1.83 error = 0.01
# 96600 y_p=1.16 error = 0.04
# 96700 y_p=-0.66 error = -0.02
# 96800 y_p=-1.23 error = -0.02
# 96900 y_p=-0.75 error = 0.06
# 97000 y_p=-0.44 error = 0.01
# 97100 y_p=1.25 error = 0.02
# 97200 y_p=0.62 error = 0.02
# 97300 y_p=1.10 error = 0.02
# 97400 y_p=-0.12 error = -0.00
# 97500 y_p=0.63 error = 0.03
# 97600 y_p=0.44 error = 0.01
# 97700 y_p=0.26 error = 0.00
# 97800 y_p=-1.83 error = 0.02
# 97900 y_p=1.21 error = 0.00
# 98000 y_p=-1.91 error = -0.13
# 98100 y_p=1.88 error = 0.05
# 98200 y_p=-1.20 error = -0.00
# 98300 y_p=-0.95 error = -0.01
# 98400 y_p=-1.03 error = -0.03
# 98500 y_p=0.35 error = -0.00
# 98600 y_p=1.32 error = 0.00
# 98700 y_p=-0.42 error = 0.01
# 98800 y_p=-0.25 error = 0.00
# 98900 y_p=-1.32 error = -0.01
# 99000 y_p=-0.98 error = -0.03
# 99100 y_p=1.83 error = -0.01
# 99200 y_p=1.28 error = 0.03
# 99300 y_p=-1.02 error = -0.01
# 99400 y_p=2.05 error = -0.05
# 99500 y_p=0.16 error = 0.01
# 99600 y_p=-0.97 error = -0.04
# 99700 y_p=-0.88 error = -0.01
# 99800 y_p=0.26 error = 0.01
# 99900 y_p=-2.94 error = 0.09

# %% [markdown]
# ... and plot its predictions.

# %%
plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x), fig_name="fig_02_11.pdf")  ### plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x))

# %% [markdown]
# ## Testing the Performance of the Trained Neural Network
#
# Check how the trained neuron works on the test data.

# %%
### (x_test, y_gt_test) = load_data(filename="data_reg_2d_linear_test.csv")

### plot_pred_2d(x_test, y_gt_test, y_p=dnn2_reg(wa, wb, x_test))
