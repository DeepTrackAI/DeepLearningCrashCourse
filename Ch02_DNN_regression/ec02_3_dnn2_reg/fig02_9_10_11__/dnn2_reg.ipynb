# %% [markdown]
# # Regressing 2D Data with a Two-Layer Neural Network
#
# This notebook provides you with a complete code example that
# loads the data in `data_reg_2d_linear.csv`, trains a two-layer dense neural network to fit them, and finally uses the trained network to predict the values of the data in `data_reg_2d_linear_test.csv`.

# %% [markdown]
# ## Loading and Plotting the Data

# %%
from loader import load_data

(x, y_gt) = load_data(filename="data_reg_2d_linear.csv")

print("x:", x)
print("y_gt:", y_gt)
# Out:
# x: [[-0.01264992 -0.85443355]
#  [ 0.76032383 -0.97434942]
#  [ 0.01950686  0.27497154]
#  [-1.58945469 -1.54899742]
#  [-0.4683091   0.04368673]
#  [-0.07725676  0.35296562]
#  [-0.88869315  0.9471676 ]
#  [-0.28959776 -0.32629691]
#  [-0.3686084   0.77991726]
#  [-0.01630287  0.69537186]
#  [ 1.04251786  0.30325747]
#  [-1.02762036  0.28614963]
#  [ 1.35221365  0.00522689]
#  [ 1.11043191  0.06395982]
#  [ 0.20114065 -0.72740412]
#  [-0.5236721   1.02450951]
#  [-0.74496852  0.76759749]
#  [-0.34330278  1.47764927]
#  [-1.48967134  0.66148164]
#  [ 0.91347373  0.20379262]
#  [-1.04925868 -0.70112109]
#  [ 1.47620376  0.38821102]
#  [ 0.16479918 -0.08658965]
#  [-0.88185459 -0.33227438]
#  [-0.08707602 -0.18477628]
#  [ 1.34159875  1.94937676]
#  [-0.32110135  1.54589904]
#  [ 2.40018166 -0.03238685]
#  [-1.00355408  0.07884853]
#  [ 0.48644429  0.64149119]
#  [ 0.49777571 -0.98064575]
#  [ 0.96754236  1.76567471]
#  [-1.05642191 -1.36633827]
#  [ 1.00046248  0.80779301]
#  [ 0.48090259  1.32363817]
#  [-0.93721223 -1.31488225]
#  [-0.7783187  -1.1272839 ]
#  [ 0.34408419 -0.59420601]
#  [ 0.14022603  0.38744433]
#  [ 1.35776922 -0.4143762 ]
#  [ 2.80911898  0.68255868]
#  [ 0.4589316   0.07317612]
#  [-1.81432287  0.14730497]
#  [ 0.83614238  0.69531097]
#  [ 0.11296394  0.25870933]
#  [-1.71934709  1.01517158]
#  [-1.71868797 -0.59817465]
#  [ 0.45265262 -0.45593674]
#  [ 0.63533505 -0.29305603]
#  [-0.11942826  2.06364796]
#  [ 0.79408066 -0.22186649]
#  [-0.10699554 -0.47041277]
#  [ 0.73952767  0.41419289]
#  [-0.59058245 -1.59234153]
#  [ 0.77327396 -1.0739063 ]
#  [ 0.78235185  0.50550473]
#  [-1.65406412  0.44774281]
#  [ 1.54045014  0.24329076]
#  [ 0.29312637 -0.58120338]
#  [ 1.30666726 -0.85124457]
#  [ 1.26200767  0.82934275]
#  [-1.67260291 -0.4229299 ]
#  [ 1.6559003   0.30206492]
#  [ 0.2162945   0.32574282]
#  [-1.52612859 -1.27944869]
#  [ 0.52189237 -0.68728934]
#  [-0.66306602  1.04537616]
#  [ 2.31646537 -0.71454372]
#  [-0.22226882 -1.797801  ]
#  [ 0.26051652  0.25109185]
#  [ 0.74700593 -1.63554144]
#  [ 0.70100306 -0.07968232]
#  [-0.03932948 -0.01464685]
#  [ 0.08308927 -0.03931517]
#  [ 0.62154512  0.33152256]
#  [ 0.48815081 -1.72709135]
#  [-0.90325557  1.53684554]
#  [-0.19668924 -1.39968601]
#  [ 1.03698104  0.40279586]
#  [ 0.28778897 -0.91074571]
#  [ 0.30439596 -0.6509071 ]
#  [-0.18928775  0.41564778]
#  [ 0.48325921 -0.61170165]
#  [-0.52167755 -0.96631475]
#  [ 0.6834997  -0.63102658]
#  [ 1.33345131 -0.44956364]
#  [-1.28697275 -0.07694561]
#  [-0.15552617  1.4958745 ]
#  [ 0.18305908  0.15829629]
#  [-0.26668814 -0.20220024]
#  [ 0.10410271 -1.15704215]
#  [-1.20081694 -2.001835  ]
#  [-1.7929256  -0.84189802]
#  [-0.65477546 -2.16013035]
#  [-0.85060906 -1.37363553]
#  [ 1.06019767 -0.39463539]
#  [-0.05963293  0.54051271]
#  [-1.55767705 -0.7502383 ]
#  [-0.97368135  0.25868212]
#  [ 0.04686402 -1.04956388]]
# y_gt: [[-0.84178364]
#  [-1.73467326]
#  [ 0.25546468]
#  [ 0.04045727]
#  [ 0.51199583]
#  [ 0.43022238]
#  [ 1.83586075]
#  [-0.03669916]
#  [ 1.14852566]
#  [ 0.71167473]
#  [-0.73926039]
#  [ 1.31377   ]
#  [-1.34698676]
#  [-1.04647209]
#  [-0.92854478]
#  [ 1.54818162]
#  [ 1.51256601]
#  [ 1.82095205]
#  [ 2.15115298]
#  [-0.70968111]
#  [ 0.34813758]
#  [-1.08799274]
#  [-0.25138883]
#  [ 0.54958021]
#  [-0.09770026]
#  [ 0.60777801]
#  [ 1.86700039]
#  [-2.4325685 ]
#  [ 1.08240261]
#  [ 0.1550469 ]
#  [-1.47842146]
#  [ 0.79813236]
#  [-0.30991635]
#  [-0.19266947]
#  [ 0.84273558]
#  [-0.37767002]
#  [-0.3489652 ]
#  [-0.9382902 ]
#  [ 0.2472183 ]
#  [-1.77214542]
#  [-2.1265603 ]
#  [-0.38575548]
#  [ 1.96162784]
#  [-0.14083141]
#  [ 0.14574539]
#  [ 2.73451867]
#  [ 1.12051331]
#  [-0.90858935]
#  [-0.92839108]
#  [ 2.18307622]
#  [-1.01594714]
#  [-0.36341723]
#  [-0.32533478]
#  [-1.00175908]
#  [-1.84718026]
#  [-0.27684712]
#  [ 2.10180693]
#  [-1.29715939]
#  [-0.87432975]
#  [-2.15791183]
#  [-0.43266492]
#  [ 1.24967301]
#  [-1.35383538]
#  [ 0.10944832]
#  [ 0.2466799 ]
#  [-1.20918171]
#  [ 1.70844217]
#  [-3.03100909]
#  [-1.57553217]
#  [-0.00942467]
#  [-2.38254737]
#  [-0.78068538]
#  [ 0.02468263]
#  [-0.12240443]
#  [-0.29002256]
#  [-2.21524216]
#  [ 2.44010111]
#  [-1.20299677]
#  [-0.63418518]
#  [-1.19853467]
#  [-0.95530306]
#  [ 0.60493553]
#  [-1.09496086]
#  [-0.44463719]
#  [-1.31452628]
#  [-1.78301495]
#  [ 1.21002714]
#  [ 1.65140067]
#  [-0.02476279]
#  [ 0.0644879 ]
#  [-1.26114486]
#  [-0.80101806]
#  [ 0.95102757]
#  [-1.50535489]
#  [-0.52302647]
#  [-1.45483305]
#  [ 0.60014564]
#  [ 0.80743875]
#  [ 1.23236347]
#  [-1.0964279 ]]

# %%
from plotting import plot_data_2d

plot_data_2d(x, y_gt, fig_name="fig_02_09.pdf")  ### plot_data_2d(x, y_gt)

# %% [markdown]
# ## Implementing a Dense Neural Network
#
# Implement the sigmoidal activation function ...

# %%
from numpy import exp

def sigmoid(x):
    """Sigmoid function."""
    return 1 / (1 + exp(-x))

# %% [markdown]
# ... implement a function to define the neural network ...

# %%
def dnn2_reg(wa, wb, x):
    """Two-layer dense neural network for classification."""
    return sigmoid(x @ wa) @ wb

# %% [markdown]
# ... define the number of neurons in the first layer ...

# %%
num_neurons = 3

# %% [markdown]
# ... randomly initialize its weights ...

# %%
from numpy.random import default_rng

rng = default_rng()
wa = rng.standard_normal(size=(2, num_neurons)) # Input weights layer 1.
wb = rng.standard_normal(size=(num_neurons, 1)) # Input weights layer 2.

# %% [markdown]
# ... obtain its predictions for the input data ...

# %%
y_p = dnn2_reg(wa, wb, x)

# %% [markdown]
# ... and plot its predictions.

# %%
from plotting import plot_pred_2d

plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x), fig_name="fig_02_10.pdf")  ### plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x))

# %% [markdown]
# ## Training with the Backpropagation Algorithm
#
# Implement the first derivative of the sigmoid function ...

# %%
def d_sigmoid(x):
    """Derivative of sigmoid function."""
    return sigmoid(x) * (1 - sigmoid(x))

# %% [markdown]
# ... implement the backpropagation algorithm ...

# %%
from numpy import reshape, sum, transpose

num_samples = len(x)
num_train_iterations = 10 ** 5
eta = .1 # Learning rate.

for i in range(num_train_iterations):
    selected = rng.integers(0, num_samples) # Select random sample.
    x_selected = reshape(x[selected], (1, -1))
    y_gt_selected = reshape(y_gt[selected], (1, -1))
    
    # Detailed neural network calculation.
    x_selected_a = x_selected # Input layer 1.
    p_a = x_selected_a @ wa # Activation potential layer 1.
    y_selected_a = sigmoid(p_a) # Output layer 1.

    x_selected_b = y_selected_a # Input layer 2.
    p_b = x_selected_b @ wb # Activation potential layer 2.
    y_selected_b = p_b # Output neuron layer 2 (output neuron).

    y_p_selected = y_selected_b
    
    # Update weights.
    error = y_p_selected - y_gt_selected
    
    delta_b = error * 1
    wb -= eta * delta_b * transpose(x_selected_b)

    delta_a = sum(wb * delta_b, axis=1) * d_sigmoid(p_a)
    wa -= eta * delta_a * transpose(x_selected_a)
    
    if i%100 == 0:
        print(f"{i} y_p={y_p_selected[0, 0]:.2f} error = {error[0, 0]:.2f}")
# Out:
# 0 y_p=-0.29 error = 1.19
# 100 y_p=1.43 error = -0.41
# 200 y_p=-0.82 error = -0.08
# 300 y_p=1.48 error = 0.25
# 400 y_p=-1.70 error = 0.04
# 500 y_p=-0.79 error = -0.08
# 600 y_p=-1.37 error = -0.07
# 700 y_p=-1.16 error = -0.07
# 800 y_p=2.06 error = -0.38
# 900 y_p=-0.59 error = -0.07
# 1000 y_p=-2.10 error = 0.33
# 1100 y_p=-0.27 error = 0.04
# 1200 y_p=0.33 error = 0.08
# 1300 y_p=-1.79 error = -0.01
# 1400 y_p=0.02 error = 0.03
# 1500 y_p=-1.32 error = -0.06
# 1600 y_p=-1.27 error = -0.07
# 1700 y_p=2.27 error = -0.17
# 1800 y_p=2.30 error = -0.43
# 1900 y_p=-1.01 error = -0.14
# 2000 y_p=1.76 error = 0.05
# 2100 y_p=0.83 error = 0.12
# 2200 y_p=-1.54 error = -0.07
# 2300 y_p=1.62 error = 0.08
# 2400 y_p=-1.16 error = -0.06
# 2500 y_p=0.29 error = 0.04
# 2600 y_p=-0.10 error = -0.01
# 2700 y_p=-1.03 error = -0.09
# 2800 y_p=0.62 error = 0.11
# 2900 y_p=-1.76 error = 0.02
# 3000 y_p=-1.35 error = -0.05
# 3100 y_p=-0.76 error = -0.02
# 3200 y_p=-0.81 error = -0.10
# 3300 y_p=-0.23 error = -0.04
# 3400 y_p=-0.97 error = -0.06
# 3500 y_p=-0.78 error = 0.02
# 3600 y_p=-1.29 error = -0.09
# 3700 y_p=1.57 error = 0.02
# 3800 y_p=0.15 error = 0.01
# 3900 y_p=1.14 error = 0.02
# 4000 y_p=-1.40 error = -0.05
# 4100 y_p=-1.31 error = -0.01
# 4200 y_p=-0.75 error = -0.04
# 4300 y_p=-1.38 error = -0.12
# 4400 y_p=0.25 error = 0.01
# 4500 y_p=-1.46 error = 0.05
# 4600 y_p=0.28 error = 0.03
# 4700 y_p=-0.24 error = 0.01
# 4800 y_p=-1.01 error = -0.07
# 4900 y_p=-0.40 error = -0.03
# 5000 y_p=0.69 error = 0.08
# 5100 y_p=-1.48 error = -0.03
# 5200 y_p=0.69 error = 0.08
# 5300 y_p=-1.27 error = -0.07
# 5400 y_p=1.30 error = 0.05
# 5500 y_p=0.16 error = 0.01
# 5600 y_p=-0.99 error = -0.04
# 5700 y_p=0.07 error = 0.00
# 5800 y_p=-1.85 error = -0.07
# 5900 y_p=-1.23 error = -0.03
# 6000 y_p=-0.45 error = -0.07
# 6100 y_p=-1.13 error = -0.03
# 6200 y_p=0.06 error = -0.00
# 6300 y_p=2.42 error = -0.02
# 6400 y_p=1.83 error = 0.01
# 6500 y_p=-0.31 error = -0.02
# 6600 y_p=-1.26 error = -0.05
# 6700 y_p=-2.70 error = 0.33
# 6800 y_p=-0.84 error = -0.10
# 6900 y_p=0.12 error = 0.01
# 7000 y_p=1.21 error = 0.09
# 7100 y_p=-1.33 error = -0.03
# 7200 y_p=-0.38 error = -0.00
# 7300 y_p=1.88 error = 0.01
# 7400 y_p=-0.45 error = -0.02
# 7500 y_p=1.25 error = 0.04
# 7600 y_p=-0.01 error = -0.00
# 7700 y_p=-1.91 error = -0.06
# 7800 y_p=-0.39 error = -0.02
# 7900 y_p=0.18 error = 0.02
# 8000 y_p=-0.39 error = -0.01
# 8100 y_p=-1.08 error = -0.03
# 8200 y_p=-0.02 error = -0.01
# 8300 y_p=-0.09 error = 0.01
# 8400 y_p=0.86 error = 0.02
# 8500 y_p=-1.72 error = 0.01
# 8600 y_p=-0.14 error = -0.02
# 8700 y_p=-2.37 error = 0.01
# 8800 y_p=-1.78 error = -0.05
# 8900 y_p=0.61 error = 0.00
# 9000 y_p=0.09 error = 0.02
# 9100 y_p=1.55 error = 0.03
# 9200 y_p=-1.38 error = -0.02
# 9300 y_p=0.86 error = 0.02
# 9400 y_p=-0.00 error = 0.02
# 9500 y_p=-1.38 error = -0.03
# 9600 y_p=-1.45 error = 0.00
# 9700 y_p=-1.04 error = -0.04
# 9800 y_p=-2.08 error = 0.08
# 9900 y_p=-1.14 error = -0.04
# 10000 y_p=-0.94 error = -0.06
# 10100 y_p=-0.28 error = -0.01
# 10200 y_p=0.59 error = 0.04
# 10300 y_p=-0.99 error = -0.07
# 10400 y_p=-2.25 error = 0.14
# 10500 y_p=1.85 error = -0.02
# 10600 y_p=2.05 error = -0.05
# 10700 y_p=0.85 error = 0.04
# 10800 y_p=-2.43 error = -0.00
# 10900 y_p=1.72 error = 0.07
# 11000 y_p=0.10 error = 0.06
# 11100 y_p=-0.87 error = -0.03
# 11200 y_p=0.89 error = 0.05
# 11300 y_p=-0.47 error = -0.04
# 11400 y_p=0.18 error = 0.03
# 11500 y_p=-0.83 error = -0.05
# 11600 y_p=-0.25 error = -0.00
# 11700 y_p=-1.30 error = -0.00
# 11800 y_p=0.65 error = 0.05
# 11900 y_p=-1.05 error = -0.04
# 12000 y_p=0.88 error = 0.04
# 12100 y_p=-2.16 error = -0.00
# 12200 y_p=0.66 error = 0.05
# 12300 y_p=-1.03 error = -0.03
# 12400 y_p=-0.26 error = 0.02
# 12500 y_p=1.36 error = 0.11
# 12600 y_p=-2.14 error = 0.07
# 12700 y_p=-1.44 error = -0.09
# 12800 y_p=-0.69 error = -0.05
# 12900 y_p=-0.41 error = -0.06
# 13000 y_p=-0.43 error = -0.00
# 13100 y_p=-0.00 error = 0.01
# 13200 y_p=2.07 error = -0.03
# 13300 y_p=-1.37 error = -0.08
# 13400 y_p=2.15 error = -0.03
# 13500 y_p=0.01 error = 0.01
# 13600 y_p=-0.05 error = -0.01
# 13700 y_p=0.08 error = 0.02
# 13800 y_p=2.10 error = -0.08
# 13900 y_p=-2.09 error = 0.03
# 14000 y_p=2.13 error = 0.03
# 14100 y_p=-0.25 error = 0.00
# 14200 y_p=-0.37 error = 0.01
# 14300 y_p=0.28 error = 0.02
# 14400 y_p=-0.32 error = -0.01
# 14500 y_p=-1.76 error = -0.02
# 14600 y_p=-2.05 error = 0.08
# 14700 y_p=0.37 error = 0.02
# 14800 y_p=-1.78 error = -0.05
# 14900 y_p=2.52 error = -0.22
# 15000 y_p=1.26 error = 0.01
# 15100 y_p=-1.90 error = -0.06
# 15200 y_p=-0.08 error = 0.02
# 15300 y_p=-0.38 error = -0.00
# 15400 y_p=-2.28 error = 0.10
# 15500 y_p=-0.20 error = -0.01
# 15600 y_p=0.39 error = 0.05
# 15700 y_p=-0.86 error = -0.12
# 15800 y_p=-0.67 error = -0.04
# 15900 y_p=-0.33 error = -0.01
# 16000 y_p=-0.34 error = -0.03
# 16100 y_p=0.16 error = 0.01
# 16200 y_p=1.64 error = -0.02
# 16300 y_p=0.27 error = 0.01
# 16400 y_p=-0.39 error = -0.02
# 16500 y_p=0.80 error = -0.01
# 16600 y_p=0.11 error = -0.05
# 16700 y_p=-2.11 error = 0.05
# 16800 y_p=1.20 error = 0.08
# 16900 y_p=-0.78 error = -0.04
# 17000 y_p=-1.37 error = -0.03
# 17100 y_p=-0.42 error = -0.04
# 17200 y_p=-0.53 error = -0.01
# 17300 y_p=-1.40 error = -0.11
# 17400 y_p=2.35 error = -0.09
# 17500 y_p=1.14 error = 0.05
# 17600 y_p=0.17 error = 0.01
# 17700 y_p=-1.27 error = -0.01
# 17800 y_p=-1.22 error = -0.02
# 17900 y_p=-0.44 error = -0.01
# 18000 y_p=-1.04 error = -0.04
# 18100 y_p=-1.12 error = -0.03
# 18200 y_p=-0.36 error = -0.01
# 18300 y_p=0.27 error = 0.01
# 18400 y_p=-2.06 error = 0.07
# 18500 y_p=-1.25 error = -0.04
# 18600 y_p=-0.93 error = -0.02
# 18700 y_p=-1.37 error = -0.01
# 18800 y_p=-1.08 error = -0.08
# 18900 y_p=2.12 error = -0.06
# 19000 y_p=0.73 error = 0.02
# 19100 y_p=-1.54 error = -0.04
# 19200 y_p=-1.48 error = -0.02
# 19300 y_p=-0.75 error = -0.02
# 19400 y_p=1.18 error = 0.03
# 19500 y_p=0.66 error = 0.05
# 19600 y_p=-2.79 error = 0.24
# 19700 y_p=1.23 error = 0.02
# 19800 y_p=-0.91 error = -0.03
# 19900 y_p=-1.81 error = -0.04
# 20000 y_p=-2.11 error = 0.05
# 20100 y_p=-0.45 error = -0.01
# 20200 y_p=-0.04 error = -0.01
# 20300 y_p=-0.25 error = -0.00
# 20400 y_p=0.17 error = 0.01
# 20500 y_p=0.81 error = 0.01
# 20600 y_p=1.59 error = 0.07
# 20700 y_p=-0.04 error = -0.01
# 20800 y_p=-1.56 error = -0.06
# 20900 y_p=-0.52 error = -0.00
# 21000 y_p=-1.53 error = -0.07
# 21100 y_p=-0.98 error = -0.03
# 21200 y_p=1.82 error = -0.01
# 21300 y_p=0.85 error = 0.04
# 21400 y_p=-1.58 error = -0.00
# 21500 y_p=-1.76 error = 0.01
# 21600 y_p=-0.86 error = -0.12
# 21700 y_p=0.13 error = 0.02
# 21800 y_p=-0.39 error = -0.01
# 21900 y_p=0.14 error = 0.03
# 22000 y_p=-0.13 error = 0.01
# 22100 y_p=0.12 error = 0.08
# 22200 y_p=-1.48 error = 0.02
# 22300 y_p=-1.37 error = -0.01
# 22400 y_p=-1.49 error = -0.04
# 22500 y_p=0.63 error = 0.02
# 22600 y_p=0.55 error = -0.00
# 22700 y_p=-1.60 error = -0.03
# 22800 y_p=2.00 error = 0.04
# 22900 y_p=2.33 error = -0.11
# 23000 y_p=0.82 error = 0.02
# 23100 y_p=-0.02 error = 0.01
# 23200 y_p=-2.27 error = 0.11
# 23300 y_p=0.05 error = 0.01
# 23400 y_p=-1.80 error = -0.02
# 23500 y_p=0.58 error = 0.07
# 23600 y_p=-0.77 error = -0.04
# 23700 y_p=-1.46 error = -0.01
# 23800 y_p=-1.40 error = -0.08
# 23900 y_p=-0.20 error = -0.06
# 24000 y_p=-0.48 error = -0.03
# 24100 y_p=0.79 error = 0.08
# 24200 y_p=-1.23 error = -0.03
# 24300 y_p=0.16 error = 0.01
# 24400 y_p=0.17 error = 0.01
# 24500 y_p=-0.76 error = -0.02
# 24600 y_p=-0.35 error = 0.00
# 24700 y_p=0.64 error = 0.04
# 24800 y_p=1.69 error = 0.04
# 24900 y_p=-0.76 error = -0.02
# 25000 y_p=-2.09 error = 0.06
# 25100 y_p=0.54 error = 0.03
# 25200 y_p=1.10 error = 0.01
# 25300 y_p=0.56 error = 0.01
# 25400 y_p=1.27 error = 0.02
# 25500 y_p=2.04 error = -0.06
# 25600 y_p=-0.28 error = 0.03
# 25700 y_p=2.33 error = -0.11
# 25800 y_p=1.65 error = 0.00
# 25900 y_p=-1.07 error = -0.05
# 26000 y_p=0.35 error = 0.01
# 26100 y_p=-0.97 error = -0.04
# 26200 y_p=1.13 error = 0.01
# 26300 y_p=0.07 error = 0.01
# 26400 y_p=2.43 error = -0.01
# 26500 y_p=-0.13 error = -0.00
# 26600 y_p=-0.91 error = -0.03
# 26700 y_p=-0.34 error = -0.03
# 26800 y_p=-0.79 error = -0.05
# 26900 y_p=-2.05 error = 0.08
# 27000 y_p=-0.27 error = 0.01
# 27100 y_p=-1.84 error = -0.06
# 27200 y_p=1.07 error = 0.12
# 27300 y_p=0.48 error = 0.05
# 27400 y_p=1.96 error = -0.00
# 27500 y_p=1.33 error = 0.08
# 27600 y_p=-0.44 error = -0.01
# 27700 y_p=-2.15 error = 0.06
# 27800 y_p=-0.64 error = -0.01
# 27900 y_p=0.98 error = 0.03
# 28000 y_p=1.83 error = 0.01
# 28100 y_p=-1.76 error = 0.02
# 28200 y_p=0.62 error = 0.02
# 28300 y_p=0.03 error = 0.00
# 28400 y_p=-1.23 error = -0.03
# 28500 y_p=-1.22 error = -0.02
# 28600 y_p=-0.63 error = 0.00
# 28700 y_p=-2.30 error = 0.13
# 28800 y_p=-0.34 error = -0.01
# 28900 y_p=0.11 error = 0.00
# 29000 y_p=0.36 error = 0.02
# 29100 y_p=-2.05 error = 0.08
# 29200 y_p=-1.31 error = -0.01
# 29300 y_p=-0.40 error = -0.02
# 29400 y_p=-0.46 error = -0.02
# 29500 y_p=0.13 error = 0.09
# 29600 y_p=-0.96 error = -0.05
# 29700 y_p=-1.25 error = -0.05
# 29800 y_p=-0.85 error = -0.04
# 29900 y_p=0.87 error = 0.02
# 30000 y_p=-1.37 error = -0.06
# 30100 y_p=-0.82 error = -0.02
# 30200 y_p=1.67 error = 0.02
# 30300 y_p=0.28 error = 0.02
# 30400 y_p=-1.37 error = -0.05
# 30500 y_p=-2.18 error = 0.03
# 30600 y_p=-0.10 error = -0.00
# 30700 y_p=0.18 error = 0.02
# 30800 y_p=2.11 error = 0.00
# 30900 y_p=1.27 error = 0.06
# 31000 y_p=1.74 error = 0.04
# 31100 y_p=-0.13 error = 0.01
# 31200 y_p=-0.95 error = -0.02
# 31300 y_p=0.56 error = 0.04
# 31400 y_p=2.08 error = -0.02
# 31500 y_p=-0.26 error = -0.01
# 31600 y_p=-0.29 error = -0.00
# 31700 y_p=-0.37 error = -0.00
# 31800 y_p=-0.95 error = -0.04
# 31900 y_p=1.55 error = 0.00
# 32000 y_p=-1.30 error = -0.04
# 32100 y_p=-0.28 error = 0.03
# 32200 y_p=-1.08 error = 0.00
# 32300 y_p=1.73 error = 0.02
# 32400 y_p=0.03 error = -0.01
# 32500 y_p=0.35 error = -0.00
# 32600 y_p=-0.55 error = -0.03
# 32700 y_p=-0.14 error = 0.00
# 32800 y_p=0.05 error = 0.01
# 32900 y_p=-1.13 error = -0.04
# 33000 y_p=0.35 error = 0.00
# 33100 y_p=-0.48 error = -0.05
# 33200 y_p=-1.42 error = -0.07
# 33300 y_p=-1.29 error = 0.00
# 33400 y_p=0.81 error = -0.03
# 33500 y_p=-0.80 error = -0.02
# 33600 y_p=-1.08 error = -0.03
# 33700 y_p=-0.42 error = 0.02
# 33800 y_p=0.64 error = 0.04
# 33900 y_p=-1.34 error = 0.02
# 34000 y_p=-0.29 error = -0.01
# 34100 y_p=1.90 error = 0.07
# 34200 y_p=-2.98 error = 0.05
# 34300 y_p=-1.24 error = -0.03
# 34400 y_p=0.62 error = 0.01
# 34500 y_p=-1.83 error = 0.02
# 34600 y_p=-1.24 error = -0.03
# 34700 y_p=1.65 error = -0.00
# 34800 y_p=1.32 error = 0.09
# 34900 y_p=0.30 error = 0.04
# 35000 y_p=0.54 error = 0.03
# 35100 y_p=-0.34 error = -0.02
# 35200 y_p=2.11 error = -0.05
# 35300 y_p=-1.77 error = 0.01
# 35400 y_p=-0.96 error = -0.02
# 35500 y_p=-1.08 error = -0.03
# 35600 y_p=0.81 error = 0.01
# 35700 y_p=-0.28 error = -0.00
# 35800 y_p=-1.08 error = -0.06
# 35900 y_p=-0.12 error = 0.00
# 36000 y_p=0.81 error = 0.01
# 36100 y_p=1.35 error = 0.04
# 36200 y_p=1.26 error = 0.01
# 36300 y_p=-1.34 error = -0.03
# 36400 y_p=-1.32 error = -0.01
# 36500 y_p=0.06 error = -0.00
# 36600 y_p=-1.22 error = -0.02
# 36700 y_p=-1.74 error = -0.01
# 36800 y_p=-1.76 error = 0.01
# 36900 y_p=-0.38 error = -0.06
# 37000 y_p=-1.28 error = -0.02
# 37100 y_p=-0.26 error = 0.05
# 37200 y_p=-0.26 error = -0.01
# 37300 y_p=0.90 error = 0.05
# 37400 y_p=2.13 error = -0.02
# 37500 y_p=1.13 error = 0.01
# 37600 y_p=-0.96 error = -0.03
# 37700 y_p=0.69 error = 0.08
# 37800 y_p=2.06 error = -0.04
# 37900 y_p=0.65 error = 0.05
# 38000 y_p=0.87 error = 0.03
# 38100 y_p=2.40 error = -0.04
# 38200 y_p=0.97 error = 0.02
# 38300 y_p=-0.40 error = -0.04
# 38400 y_p=0.15 error = -0.01
# 38500 y_p=-0.12 error = 0.01
# 38600 y_p=-0.04 error = -0.00
# 38700 y_p=-2.80 error = 0.23
# 38800 y_p=-1.71 error = 0.03
# 38900 y_p=-2.16 error = 0.06
# 39000 y_p=0.02 error = -0.00
# 39100 y_p=-0.43 error = 0.00
# 39200 y_p=1.60 error = 0.05
# 39300 y_p=0.85 error = 0.00
# 39400 y_p=-1.38 error = -0.02
# 39500 y_p=-0.34 error = -0.03
# 39600 y_p=-1.51 error = -0.01
# 39700 y_p=1.10 error = 0.02
# 39800 y_p=-1.22 error = -0.01
# 39900 y_p=0.60 error = 0.05
# 40000 y_p=-1.84 error = 0.01
# 40100 y_p=-1.31 error = -0.02
# 40200 y_p=0.62 error = 0.01
# 40300 y_p=1.18 error = 0.10
# 40400 y_p=-0.89 error = -0.11
# 40500 y_p=-0.15 error = -0.01
# 40600 y_p=-1.74 error = -0.01
# 40700 y_p=-0.67 error = -0.03
# 40800 y_p=-2.13 error = 0.03
# 40900 y_p=-1.21 error = -0.00
# 41000 y_p=-1.22 error = -0.01
# 41100 y_p=-0.98 error = -0.04
# 41200 y_p=-1.75 error = 0.03
# 41300 y_p=1.58 error = 0.04
# 41400 y_p=-0.98 error = -0.05
# 41500 y_p=-0.35 error = -0.00
# 41600 y_p=-0.04 error = -0.01
# 41700 y_p=1.70 error = -0.01
# 41800 y_p=-1.48 error = -0.00
# 41900 y_p=-0.27 error = -0.07
# 42000 y_p=-1.32 error = -0.01
# 42100 y_p=-0.04 error = -0.00
# 42200 y_p=1.58 error = 0.04
# 42300 y_p=-2.30 error = 0.08
# 42400 y_p=-0.95 error = -0.02
# 42500 y_p=-1.21 error = -0.01
# 42600 y_p=-0.46 error = -0.01
# 42700 y_p=-0.26 error = -0.00
# 42800 y_p=1.70 error = 0.05
# 42900 y_p=0.45 error = 0.02
# 43000 y_p=0.52 error = 0.01
# 43100 y_p=-1.34 error = -0.03
# 43200 y_p=0.26 error = 0.01
# 43300 y_p=-0.01 error = 0.00
# 43400 y_p=0.63 error = 0.03
# 43500 y_p=0.27 error = 0.01
# 43600 y_p=0.02 error = -0.00
# 43700 y_p=-0.90 error = -0.03
# 43800 y_p=-0.32 error = -0.01
# 43900 y_p=2.11 error = -0.07
# 44000 y_p=-0.87 error = -0.02
# 44100 y_p=-1.04 error = -0.02
# 44200 y_p=-0.87 error = -0.03
# 44300 y_p=1.24 error = 0.03
# 44400 y_p=-0.37 error = -0.01
# 44500 y_p=-2.35 error = 0.04
# 44600 y_p=0.11 error = -0.00
# 44700 y_p=0.45 error = 0.02
# 44800 y_p=-1.03 error = -0.01
# 44900 y_p=0.09 error = -0.02
# 45000 y_p=-0.89 error = -0.01
# 45100 y_p=0.06 error = 0.02
# 45200 y_p=0.60 error = -0.00
# 45300 y_p=1.27 error = 0.04
# 45400 y_p=-0.02 error = 0.01
# 45500 y_p=1.11 error = -0.01
# 45600 y_p=-0.79 error = -0.05
# 45700 y_p=0.28 error = 0.03
# 45800 y_p=-0.96 error = -0.01
# 45900 y_p=-1.26 error = -0.06
# 46000 y_p=1.09 error = 0.01
# 46100 y_p=0.57 error = 0.02
# 46200 y_p=-0.73 error = 0.07
# 46300 y_p=-2.05 error = 0.08
# 46400 y_p=-1.30 error = -0.00
# 46500 y_p=-0.13 error = -0.01
# 46600 y_p=-0.39 error = -0.01
# 46700 y_p=-0.04 error = -0.00
# 46800 y_p=-1.08 error = -0.03
# 46900 y_p=-1.46 error = -0.01
# 47000 y_p=0.27 error = 0.01
# 47100 y_p=1.35 error = 0.04
# 47200 y_p=0.83 error = 0.03
# 47300 y_p=1.84 error = -0.03
# 47400 y_p=-1.80 error = -0.01
# 47500 y_p=-1.01 error = -0.06
# 47600 y_p=0.11 error = 0.07
# 47700 y_p=2.36 error = -0.08
# 47800 y_p=-1.21 error = -0.01
# 47900 y_p=-2.12 error = 0.04
# 48000 y_p=0.23 error = -0.01
# 48100 y_p=0.03 error = 0.00
# 48200 y_p=-2.10 error = 0.06
# 48300 y_p=1.93 error = 0.07
# 48400 y_p=-1.32 error = -0.05
# 48500 y_p=1.90 error = 0.03
# 48600 y_p=-0.01 error = -0.00
# 48700 y_p=-0.03 error = 0.00
# 48800 y_p=-1.32 error = -0.00
# 48900 y_p=-2.35 error = 0.08
# 49000 y_p=0.87 error = 0.07
# 49100 y_p=1.81 error = -0.01
# 49200 y_p=0.26 error = 0.02
# 49300 y_p=0.00 error = 0.01
# 49400 y_p=-1.35 error = -0.03
# 49500 y_p=-1.27 error = -0.00
# 49600 y_p=1.24 error = 0.03
# 49700 y_p=-0.32 error = -0.03
# 49800 y_p=2.35 error = -0.09
# 49900 y_p=-1.32 error = -0.01
# 50000 y_p=-1.71 error = 0.02
# 50100 y_p=1.63 error = -0.02
# 50200 y_p=-2.84 error = 0.20
# 50300 y_p=1.36 error = 0.05
# 50400 y_p=-1.38 error = -0.03
# 50500 y_p=-0.37 error = -0.02
# 50600 y_p=-2.11 error = 0.05
# 50700 y_p=0.62 error = 0.02
# 50800 y_p=1.88 error = 0.05
# 50900 y_p=-1.27 error = -0.01
# 51000 y_p=1.62 error = 0.07
# 51100 y_p=-1.09 error = -0.05
# 51200 y_p=0.14 error = -0.00
# 51300 y_p=0.81 error = -0.00
# 51400 y_p=-1.00 error = -0.00
# 51500 y_p=-1.30 error = -0.04
# 51600 y_p=-1.12 error = -0.02
# 51700 y_p=-0.82 error = -0.04
# 51800 y_p=-0.39 error = 0.00
# 51900 y_p=-0.38 error = -0.02
# 52000 y_p=-0.04 error = -0.00
# 52100 y_p=-1.04 error = -0.04
# 52200 y_p=1.27 error = 0.04
# 52300 y_p=0.89 error = 0.05
# 52400 y_p=-1.47 error = 0.04
# 52500 y_p=-0.99 error = -0.03
# 52600 y_p=-1.21 error = -0.01
# 52700 y_p=2.63 error = -0.11
# 52800 y_p=-0.42 error = -0.03
# 52900 y_p=0.07 error = 0.00
# 53000 y_p=-1.73 error = 0.00
# 53100 y_p=-1.30 error = -0.01
# 53200 y_p=-1.60 error = -0.03
# 53300 y_p=2.34 error = -0.10
# 53400 y_p=-2.13 error = 0.08
# 53500 y_p=-1.82 error = 0.02
# 53600 y_p=-0.44 error = -0.01
# 53700 y_p=-1.08 error = -0.03
# 53800 y_p=1.64 error = -0.01
# 53900 y_p=-0.25 error = -0.00
# 54000 y_p=1.12 error = 0.00
# 54100 y_p=0.25 error = 0.00
# 54200 y_p=-0.35 error = 0.01
# 54300 y_p=-1.57 error = 0.01
# 54400 y_p=-0.36 error = -0.03
# 54500 y_p=0.53 error = 0.02
# 54600 y_p=-0.29 error = -0.02
# 54700 y_p=-1.73 error = 0.01
# 54800 y_p=-0.10 error = -0.00
# 54900 y_p=2.37 error = -0.07
# 55000 y_p=1.89 error = 0.05
# 55100 y_p=0.12 error = 0.01
# 55200 y_p=1.90 error = 0.06
# 55300 y_p=-2.94 error = 0.09
# 55400 y_p=1.16 error = 0.07
# 55500 y_p=-0.39 error = -0.01
# 55600 y_p=-0.38 error = -0.02
# 55700 y_p=-0.12 error = 0.00
# 55800 y_p=-1.81 error = 0.04
# 55900 y_p=0.39 error = 0.04
# 56000 y_p=-0.50 error = 0.02
# 56100 y_p=-0.52 error = 0.00
# 56200 y_p=-1.49 error = -0.01
# 56300 y_p=-0.03 error = -0.02
# 56400 y_p=-0.40 error = -0.05
# 56500 y_p=-1.00 error = -0.00
# 56600 y_p=-0.50 error = 0.02
# 56700 y_p=-0.86 error = -0.02
# 56800 y_p=2.12 error = -0.03
# 56900 y_p=-1.20 error = 0.00
# 57000 y_p=1.26 error = 0.03
# 57100 y_p=-1.21 error = -0.01
# 57200 y_p=-1.23 error = -0.04
# 57300 y_p=-0.40 error = -0.01
# 57400 y_p=-1.39 error = -0.04
# 57500 y_p=-2.33 error = 0.06
# 57600 y_p=-2.29 error = 0.10
# 57700 y_p=-2.36 error = 0.02
# 57800 y_p=0.15 error = 0.01
# 57900 y_p=-0.14 error = -0.00
# 58000 y_p=1.26 error = 0.05
# 58100 y_p=1.09 error = 0.01
# 58200 y_p=0.25 error = 0.01
# 58300 y_p=2.07 error = -0.04
# 58400 y_p=-1.75 error = -0.01
# 58500 y_p=-1.22 error = -0.01
# 58600 y_p=-1.00 error = 0.00
# 58700 y_p=-0.18 error = 0.01
# 58800 y_p=1.18 error = 0.03
# 58900 y_p=-1.30 error = -0.03
# 59000 y_p=-0.30 error = 0.01
# 59100 y_p=-1.00 error = -0.00
# 59200 y_p=-1.22 error = -0.01
# 59300 y_p=-1.78 error = 0.00
# 59400 y_p=-0.03 error = -0.00
# 59500 y_p=-0.33 error = 0.02
# 59600 y_p=0.16 error = 0.01
# 59700 y_p=-1.48 error = -0.00
# 59800 y_p=0.63 error = 0.02
# 59900 y_p=0.16 error = 0.00
# 60000 y_p=0.82 error = 0.02
# 60100 y_p=-0.31 error = -0.02
# 60200 y_p=-0.96 error = -0.03
# 60300 y_p=2.10 error = -0.05
# 60400 y_p=-0.44 error = 0.00
# 60500 y_p=-1.46 error = 0.04
# 60600 y_p=0.03 error = -0.01
# 60700 y_p=-1.20 error = -0.00
# 60800 y_p=-0.13 error = 0.01
# 60900 y_p=0.81 error = 0.02
# 61000 y_p=-1.13 error = -0.03
# 61100 y_p=-0.28 error = -0.00
# 61200 y_p=-1.78 error = 0.01
# 61300 y_p=0.05 error = 0.01
# 61400 y_p=0.83 error = 0.04
# 61500 y_p=-0.95 error = -0.02
# 61600 y_p=-0.96 error = -0.03
# 61700 y_p=0.99 error = 0.04
# 61800 y_p=0.11 error = 0.00
# 61900 y_p=-1.35 error = -0.00
# 62000 y_p=-1.56 error = 0.02
# 62100 y_p=-2.30 error = 0.08
# 62200 y_p=-0.39 error = -0.00
# 62300 y_p=-0.97 error = -0.02
# 62400 y_p=1.32 error = 0.09
# 62500 y_p=-0.13 error = -0.01
# 62600 y_p=0.16 error = 0.00
# 62700 y_p=-0.26 error = -0.00
# 62800 y_p=-0.29 error = -0.02
# 62900 y_p=0.15 error = -0.00
# 63000 y_p=1.51 error = -0.01
# 63100 y_p=-0.04 error = -0.02
# 63200 y_p=-1.08 error = -0.06
# 63300 y_p=2.63 error = -0.11
# 63400 y_p=-1.81 error = -0.04
# 63500 y_p=1.11 error = 0.02
# 63600 y_p=-1.21 error = -0.01
# 63700 y_p=-0.89 error = -0.05
# 63800 y_p=-1.48 error = -0.00
# 63900 y_p=-1.53 error = -0.05
# 64000 y_p=1.25 error = 0.04
# 64100 y_p=0.26 error = 0.01
# 64200 y_p=1.25 error = 0.02
# 64300 y_p=0.90 error = 0.06
# 64400 y_p=-2.36 error = 0.08
# 64500 y_p=1.66 error = 0.01
# 64600 y_p=-0.12 error = 0.00
# 64700 y_p=-1.83 error = 0.02
# 64800 y_p=-0.79 error = -0.05
# 64900 y_p=-0.26 error = 0.05
# 65000 y_p=-1.29 error = -0.03
# 65100 y_p=-1.39 error = -0.04
# 65200 y_p=1.84 error = -0.02
# 65300 y_p=1.81 error = -0.02
# 65400 y_p=1.09 error = 0.01
# 65500 y_p=-0.80 error = -0.02
# 65600 y_p=0.61 error = 0.01
# 65700 y_p=0.83 error = 0.02
# 65800 y_p=0.87 error = 0.02
# 65900 y_p=0.24 error = -0.00
# 66000 y_p=0.26 error = 0.01
# 66100 y_p=-0.45 error = -0.00
# 66200 y_p=-2.84 error = 0.19
# 66300 y_p=-0.48 error = -0.04
# 66400 y_p=1.89 error = 0.06
# 66500 y_p=-0.04 error = -0.02
# 66600 y_p=0.27 error = 0.03
# 66700 y_p=-2.32 error = 0.06
# 66800 y_p=0.61 error = 0.01
# 66900 y_p=0.07 error = 0.00
# 67000 y_p=-1.35 error = 0.01
# 67100 y_p=1.17 error = 0.02
# 67200 y_p=0.65 error = 0.05
# 67300 y_p=1.16 error = 0.01
# 67400 y_p=2.35 error = -0.09
# 67500 y_p=-0.85 error = -0.00
# 67600 y_p=-1.50 error = -0.04
# 67700 y_p=0.88 error = 0.07
# 67800 y_p=-1.08 error = -0.04
# 67900 y_p=-0.72 error = -0.01
# 68000 y_p=-0.38 error = 0.00
# 68100 y_p=-0.96 error = -0.03
# 68200 y_p=2.08 error = -0.02
# 68300 y_p=-0.94 error = -0.01
# 68400 y_p=0.55 error = 0.00
# 68500 y_p=-1.35 error = -0.00
# 68600 y_p=0.67 error = 0.06
# 68700 y_p=-0.45 error = -0.02
# 68800 y_p=-0.44 error = -0.01
# 68900 y_p=-0.02 error = 0.00
# 69000 y_p=-0.75 error = -0.01
# 69100 y_p=-1.11 error = -0.01
# 69200 y_p=2.07 error = -0.04
# 69300 y_p=-0.97 error = -0.03
# 69400 y_p=-2.10 error = 0.06
# 69500 y_p=-2.34 error = 0.09
# 69600 y_p=0.12 error = -0.03
# 69700 y_p=0.15 error = 0.00
# 69800 y_p=-1.26 error = -0.00
# 69900 y_p=-0.20 error = -0.06
# 70000 y_p=-0.13 error = -0.01
# 70100 y_p=0.26 error = 0.01
# 70200 y_p=-0.30 error = -0.01
# 70300 y_p=-2.32 error = 0.06
# 70400 y_p=1.22 error = 0.01
# 70500 y_p=-0.12 error = 0.00
# 70600 y_p=-1.29 error = -0.02
# 70700 y_p=-1.48 error = -0.00
# 70800 y_p=0.13 error = 0.02
# 70900 y_p=1.36 error = 0.04
# 71000 y_p=-1.77 error = -0.00
# 71100 y_p=1.17 error = 0.02
# 71200 y_p=-0.96 error = -0.02
# 71300 y_p=-0.89 error = -0.02
# 71400 y_p=-0.14 error = -0.02
# 71500 y_p=0.22 error = -0.03
# 71600 y_p=0.84 error = 0.03
# 71700 y_p=-0.13 error = 0.01
# 71800 y_p=0.88 error = 0.07
# 71900 y_p=-0.96 error = -0.03
# 72000 y_p=-2.12 error = 0.04
# 72100 y_p=1.22 error = 0.01
# 72200 y_p=1.53 error = 0.01
# 72300 y_p=-0.97 error = -0.01
# 72400 y_p=-2.84 error = 0.20
# 72500 y_p=-0.32 error = 0.01
# 72600 y_p=-1.48 error = -0.00
# 72700 y_p=-1.12 error = -0.02
# 72800 y_p=-1.24 error = -0.03
# 72900 y_p=2.06 error = -0.05
# 73000 y_p=-1.14 error = -0.05
# 73100 y_p=-0.34 error = 0.01
# 73200 y_p=0.57 error = 0.02
# 73300 y_p=0.06 error = -0.00
# 73400 y_p=-2.08 error = 0.04
# 73500 y_p=-0.84 error = -0.03
# 73600 y_p=-1.21 error = -0.01
# 73700 y_p=2.11 error = 0.01
# 73800 y_p=-0.19 error = 0.00
# 73900 y_p=-1.50 error = -0.02
# 74000 y_p=2.65 error = -0.09
# 74100 y_p=-1.52 error = -0.05
# 74200 y_p=-0.97 error = -0.04
# 74300 y_p=-0.45 error = -0.01
# 74400 y_p=-0.10 error = -0.00
# 74500 y_p=-0.89 error = -0.01
# 74600 y_p=-1.34 error = 0.00
# 74700 y_p=-0.03 error = -0.00
# 74800 y_p=-0.55 error = -0.03
# 74900 y_p=-0.47 error = -0.02
# 75000 y_p=0.16 error = 0.01
# 75100 y_p=-1.79 error = -0.01
# 75200 y_p=-0.30 error = 0.03
# 75300 y_p=-2.83 error = 0.20
# 75400 y_p=0.06 error = 0.02
# 75500 y_p=1.94 error = -0.02
# 75600 y_p=-1.74 error = -0.00
# 75700 y_p=-0.97 error = -0.01
# 75800 y_p=0.36 error = 0.02
# 75900 y_p=0.16 error = 0.01
# 76000 y_p=0.23 error = -0.01
# 76100 y_p=1.82 error = -0.01
# 76200 y_p=-0.47 error = -0.02
# 76300 y_p=1.12 error = 0.03
# 76400 y_p=-0.95 error = -0.01
# 76500 y_p=-0.95 error = -0.02
# 76600 y_p=0.02 error = -0.02
# 76700 y_p=-1.37 error = -0.06
# 76800 y_p=-1.38 error = -0.03
# 76900 y_p=-0.03 error = 0.01
# 77000 y_p=-0.03 error = 0.01
# 77100 y_p=-0.75 error = -0.01
# 77200 y_p=-0.96 error = -0.05
# 77300 y_p=0.03 error = 0.01
# 77400 y_p=-0.38 error = -0.02
# 77500 y_p=-0.14 error = -0.00
# 77600 y_p=0.06 error = 0.02
# 77700 y_p=-0.71 error = -0.08
# 77800 y_p=-0.88 error = -0.01
# 77900 y_p=-0.83 error = -0.02
# 78000 y_p=1.25 error = 0.00
# 78100 y_p=-0.80 error = 0.00
# 78200 y_p=-1.50 error = 0.00
# 78300 y_p=-0.29 error = 0.00
# 78400 y_p=0.37 error = 0.02
# 78500 y_p=1.89 error = 0.07
# 78600 y_p=-0.71 error = -0.00
# 78700 y_p=-1.07 error = 0.01
# 78800 y_p=0.57 error = 0.02
# 78900 y_p=-1.05 error = -0.00
# 79000 y_p=-0.02 error = 0.00
# 79100 y_p=-1.10 error = -0.01
# 79200 y_p=2.65 error = -0.09
# 79300 y_p=-2.14 error = 0.02
# 79400 y_p=-0.26 error = 0.05
# 79500 y_p=-0.75 error = -0.02
# 79600 y_p=-1.12 error = -0.02
# 79700 y_p=2.64 error = -0.09
# 79800 y_p=-1.31 error = -0.11
# 79900 y_p=0.86 error = 0.02
# 80000 y_p=-2.10 error = 0.05
# 80100 y_p=-0.35 error = -0.06
# 80200 y_p=-2.17 error = 0.05
# 80300 y_p=0.36 error = 0.01
# 80400 y_p=-2.19 error = 0.03
# 80500 y_p=-0.97 error = -0.03
# 80600 y_p=-0.03 error = -0.00
# 80700 y_p=-0.93 error = -0.02
# 80800 y_p=-1.04 error = -0.02
# 80900 y_p=2.36 error = -0.08
# 81000 y_p=0.08 error = 0.02
# 81100 y_p=0.45 error = 0.02
# 81200 y_p=1.92 error = 0.08
# 81300 y_p=0.73 error = 0.01
# 81400 y_p=-0.02 error = 0.00
# 81500 y_p=-1.78 error = -0.01
# 81600 y_p=-0.26 error = -0.01
# 81700 y_p=0.61 error = 0.01
# 81800 y_p=2.72 error = -0.01
# 81900 y_p=-0.85 error = -0.00
# 82000 y_p=2.70 error = -0.03
# 82100 y_p=1.21 error = 0.06
# 82200 y_p=-2.16 error = 0.06
# 82300 y_p=-1.20 error = 0.00
# 82400 y_p=-0.63 error = 0.00
# 82500 y_p=-1.46 error = -0.01
# 82600 y_p=-0.72 error = -0.01
# 82700 y_p=0.11 error = 0.00
# 82800 y_p=1.10 error = 0.02
# 82900 y_p=1.82 error = -0.01
# 83000 y_p=0.12 error = 0.01
# 83100 y_p=-0.16 error = -0.02
# 83200 y_p=1.31 error = 0.06
# 83300 y_p=-0.43 error = -0.00
# 83400 y_p=0.52 error = 0.01
# 83500 y_p=0.16 error = 0.01
# 83600 y_p=-1.22 error = -0.01
# 83700 y_p=-0.02 error = -0.01
# 83800 y_p=-1.84 error = 0.01
# 83900 y_p=0.17 error = 0.02
# 84000 y_p=-2.35 error = 0.09
# 84100 y_p=-0.26 error = -0.00
# 84200 y_p=-0.10 error = -0.01
# 84300 y_p=-1.21 error = -0.00
# 84400 y_p=-0.37 error = -0.01
# 84500 y_p=-0.13 error = 0.01
# 84600 y_p=1.16 error = 0.01
# 84700 y_p=0.11 error = 0.00
# 84800 y_p=0.16 error = 0.00
# 84900 y_p=2.12 error = -0.03
# 85000 y_p=-1.30 error = -0.04
# 85100 y_p=0.64 error = 0.04
# 85200 y_p=-0.51 error = 0.01
# 85300 y_p=-1.48 error = 0.00
# 85400 y_p=0.38 error = 0.04
# 85500 y_p=0.13 error = 0.02
# 85600 y_p=-1.35 error = 0.00
# 85700 y_p=1.27 error = 0.03
# 85800 y_p=1.53 error = 0.01
# 85900 y_p=-0.93 error = -0.02
# 86000 y_p=-1.04 error = -0.02
# 86100 y_p=-1.31 error = 0.00
# 86200 y_p=-0.30 error = -0.03
# 86300 y_p=-0.27 error = 0.00
# 86400 y_p=0.86 error = 0.05
# 86500 y_p=-1.13 error = -0.04
# 86600 y_p=-2.31 error = 0.07
# 86700 y_p=-2.19 error = 0.02
# 86800 y_p=0.01 error = -0.03
# 86900 y_p=-2.38 error = 0.05
# 87000 y_p=-0.01 error = -0.00
# 87100 y_p=-0.36 error = -0.00
# 87200 y_p=-0.12 error = 0.00
# 87300 y_p=0.73 error = 0.02
# 87400 y_p=0.54 error = 0.03
# 87500 y_p=-0.78 error = -0.00
# 87600 y_p=-0.10 error = -0.00
# 87700 y_p=0.53 error = 0.02
# 87800 y_p=1.83 error = -0.01
# 87900 y_p=-1.21 error = -0.01
# 88000 y_p=0.96 error = 0.01
# 88100 y_p=1.08 error = 0.00
# 88200 y_p=-1.22 error = -0.02
# 88300 y_p=-0.48 error = -0.05
# 88400 y_p=0.66 error = 0.06
# 88500 y_p=0.26 error = 0.00
# 88600 y_p=-0.90 error = -0.03
# 88700 y_p=-1.10 error = -0.01
# 88800 y_p=-0.18 error = 0.01
# 88900 y_p=-0.86 error = -0.02
# 89000 y_p=0.36 error = 0.01
# 89100 y_p=1.81 error = -0.01
# 89200 y_p=1.94 error = -0.02
# 89300 y_p=-0.97 error = -0.04
# 89400 y_p=0.62 error = 0.02
# 89500 y_p=-2.35 error = 0.03
# 89600 y_p=0.12 error = 0.01
# 89700 y_p=-1.11 error = -0.01
# 89800 y_p=0.35 error = 0.00
# 89900 y_p=-1.79 error = -0.00
# 90000 y_p=0.53 error = 0.01
# 90100 y_p=-1.32 error = -0.01
# 90200 y_p=2.06 error = -0.04
# 90300 y_p=-0.33 error = -0.01
# 90400 y_p=1.90 error = 0.03
# 90500 y_p=-0.89 error = -0.02
# 90600 y_p=-1.04 error = -0.03
# 90700 y_p=-1.21 error = -0.01
# 90800 y_p=0.22 error = -0.02
# 90900 y_p=2.10 error = -0.09
# 91000 y_p=-0.00 error = 0.00
# 91100 y_p=2.64 error = -0.10
# 91200 y_p=-2.32 error = 0.06
# 91300 y_p=1.56 error = 0.02
# 91400 y_p=-1.57 error = 0.00
# 91500 y_p=0.09 error = 0.05
# 91600 y_p=0.82 error = 0.02
# 91700 y_p=1.18 error = 0.03
# 91800 y_p=2.65 error = -0.08
# 91900 y_p=1.11 error = 0.03
# 92000 y_p=-0.01 error = 0.00
# 92100 y_p=0.81 error = 0.02
# 92200 y_p=0.36 error = 0.01
# 92300 y_p=1.10 error = 0.02
# 92400 y_p=1.55 error = 0.04
# 92500 y_p=-1.28 error = -0.02
# 92600 y_p=-1.28 error = -0.02
# 92700 y_p=1.85 error = -0.02
# 92800 y_p=-0.12 error = 0.01
# 92900 y_p=-0.64 error = -0.01
# 93000 y_p=-0.36 error = 0.01
# 93100 y_p=2.05 error = -0.05
# 93200 y_p=0.11 error = 0.01
# 93300 y_p=0.84 error = 0.03
# 93400 y_p=-0.95 error = -0.03
# 93500 y_p=0.61 error = 0.01
# 93600 y_p=0.85 error = 0.01
# 93700 y_p=0.62 error = 0.01
# 93800 y_p=-2.06 error = 0.06
# 93900 y_p=-0.39 error = -0.03
# 94000 y_p=-0.97 error = -0.04
# 94100 y_p=-2.33 error = 0.05
# 94200 y_p=-0.90 error = -0.02
# 94300 y_p=-1.33 error = -0.02
# 94400 y_p=-0.39 error = -0.01
# 94500 y_p=-2.16 error = 0.06
# 94600 y_p=-1.81 error = -0.04
# 94700 y_p=-0.79 error = -0.01
# 94800 y_p=2.15 error = -0.04
# 94900 y_p=1.58 error = 0.03
# 95000 y_p=-0.68 error = -0.04
# 95100 y_p=1.55 error = 0.04
# 95200 y_p=0.07 error = 0.01
# 95300 y_p=-0.93 error = -0.02
# 95400 y_p=-1.29 error = -0.03
# 95500 y_p=-0.84 error = -0.04
# 95600 y_p=1.83 error = -0.04
# 95700 y_p=-2.19 error = 0.02
# 95800 y_p=-2.34 error = 0.10
# 95900 y_p=0.06 error = 0.00
# 96000 y_p=-0.18 error = 0.01
# 96100 y_p=-1.02 error = -0.02
# 96200 y_p=1.54 error = 0.03
# 96300 y_p=0.82 error = 0.01
# 96400 y_p=-2.17 error = 0.05
# 96500 y_p=-0.34 error = 0.02
# 96600 y_p=0.80 error = -0.00
# 96700 y_p=1.65 error = -0.00
# 96800 y_p=1.24 error = 0.00
# 96900 y_p=-0.84 error = 0.00
# 97000 y_p=-0.25 error = -0.00
# 97100 y_p=0.15 error = -0.00
# 97200 y_p=0.83 error = 0.03
# 97300 y_p=-0.77 error = -0.03
# 97400 y_p=0.03 error = 0.00
# 97500 y_p=0.14 error = -0.01
# 97600 y_p=-0.33 error = -0.00
# 97700 y_p=-0.39 error = -0.01
# 97800 y_p=-1.10 error = -0.01
# 97900 y_p=0.45 error = 0.02
# 98000 y_p=1.55 error = 0.03
# 98100 y_p=1.94 error = -0.02
# 98200 y_p=-1.12 error = -0.03
# 98300 y_p=-0.45 error = -0.07
# 98400 y_p=1.84 error = 0.01
# 98500 y_p=-0.95 error = -0.02
# 98600 y_p=0.85 error = 0.01
# 98700 y_p=1.74 error = 0.04
# 98800 y_p=-0.86 error = -0.02
# 98900 y_p=-2.35 error = 0.04
# 99000 y_p=1.12 error = 0.04
# 99100 y_p=0.16 error = 0.01
# 99200 y_p=-0.73 error = 0.01
# 99300 y_p=1.29 error = 0.04
# 99400 y_p=0.26 error = 0.01
# 99500 y_p=1.12 error = 0.03
# 99600 y_p=-0.86 error = -0.02
# 99700 y_p=-0.32 error = -0.01
# 99800 y_p=1.01 error = 0.06
# 99900 y_p=0.02 error = -0.00

# %% [markdown]
# ... and plot its predictions.

# %%
plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x), fig_name="fig_02_11.pdf")  ### plot_pred_2d(x, y_gt, y_p=dnn2_reg(wa, wb, x))

# %% [markdown]
# ## Testing the Performance of the Trained Neural Network
#
# Check how the trained neuron works on the test data.

# %%
### (x_test, y_gt_test) = load_data(filename="data_reg_2d_linear_test.csv")

### plot_pred_2d(x_test, y_gt_test, y_p=dnn2_reg(wa, wb, x_test))
