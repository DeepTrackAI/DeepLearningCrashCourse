# %%
import numpy as np
import pygame
import gameboardClass
import matplotlib.pyplot as plt

#Define parameters of the board

# Game parameters: 
# - 'N_row' and 'N_col' (integers) define the size of the game board.
# - 'tile_size' (2 or 4) determines whether the small tile set (2) or the large tile set (4) should be used.
# - 'max_tile_count' (integer) sets the maximum number of tiles to be placed in one game.
# - 'stochastic_prob' (float between 0 and 1) determines the probability of taking a random tile. 
#   When stochastic_prob=0, tiles are taken according to a predefined sequence. 
#   When stochastic_prob=1, all tiles are random. For values 0<stochastic_prob<1, there is a mixture of deterministic and random tiles.

# Training parameters:
# - 'alpha' is the learning rate in Q-learning or for the stochastic gradient descent in deep Q-networks.
# - 'epsilon' is the probability to choose a random action in the epsilon-greedy policy.
# - 'episode_count' is the number of episodes a training session lasts.

# Additional training parameters for deep Q-networks:
# - 'epsilon_scale' is the scale of the episode number where epsilon_N changes from unity to epsilon.
# - 'replay_buffer_size' is the size of the experience replay buffer.
# - 'batch_size' is the number of samples taken from the experience replay buffer for each update.
# - 'sync_target_episode_count' is the number of episodes between synchronizations of the target network.
N_row=4
N_col=4
tile_size=2
max_tile_count=50
stochastic_prob=0

alpha=0.2
epsilon=0
episode_count=1000
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class HumanPlayer:
    def init_board(self,gameboard):
        self.episode=0
        self.reward_tots=[0]
        self.gameboard=gameboard

    def get_state(self):
        pass

    def next_turn(self,pygame):
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                raise SystemExit("Game terminated")
            if event.type==pygame.KEYDOWN:
                if event.key == pygame.K_ESCAPE:
                    self.reward_tots=[0]
                    self.gameboard.fn_restart()
                if not self.gameboard.gameover:
                    if event.key == pygame.K_UP:
                        self.gameboard.fn_move(self.gameboard.tile_x,(self.gameboard.tile_orientation+1)%len(self.gameboard.tiles[self.gameboard.cur_tile_type]))
                    if event.key == pygame.K_LEFT:
                        self.gameboard.fn_move(self.gameboard.tile_x-1,self.gameboard.tile_orientation)
                    if event.key == pygame.K_RIGHT:
                        self.gameboard.fn_move(self.gameboard.tile_x+1,self.gameboard.tile_orientation)
                    if (event.key == pygame.K_DOWN) or (event.key == pygame.K_SPACE):
                        self.reward_tots[self.episode]+=self.gameboard.fn_drop()


#play the game, use arrow keys to play
player=HumanPlayer()  
gameboard=gameboardClass.TGameBoard(N_row,N_col,tile_size,max_tile_count,player,stochastic_prob)

# %%
def Evaluate(gameboard,agent,agent_evaluate=None,strategy_file='',evaluate_agent=True):
    if agent_evaluate is None:
        evaluate_agent=False

    if evaluate_agent:
        agent_evaluate.epsilon=0
        agent_evaluate.init_board(gameboard)
        agent_evaluate.load_strategy(strategy_file)

    if isinstance(gameboard.agent,HumanPlayer):
        # Define some colors for painting
        COLOR_BLACK = (0, 0, 0)
        COLOR_GREY = (128, 128, 128)
        COLOR_WHITE = (255, 255, 255)
        COLOR_RED =  (255, 0, 0)

        # Initialize the game engine
        pygame.init()
        screen=pygame.display.set_mode((200+gameboard.N_col*20,150+gameboard.N_row*20))
        clock=pygame.time.Clock()
        pygame.key.set_repeat(300,100)
        pygame.display.set_caption('Turn-based tetris')
        font=pygame.font.SysFont('Calibri',25,True)
        fontLarge=pygame.font.SysFont('Calibri',50,True)
        framerate=0;

        # Loop until the window is closed
        while True:
            if isinstance(gameboard.agent,HumanPlayer):
                gameboard.agent.next_turn(pygame)
            else:
                pygame.event.pump()
                for event in pygame.event.get():
                    if event.type==pygame.KEYDOWN:
                        if event.key==pygame.K_SPACE:
                            if framerate > 0:
                                framerate=0
                            else:
                                framerate=10
                        if (event.key==pygame.K_LEFT) and (framerate>1):
                            framerate-=1
                        if event.key==pygame.K_RIGHT:
                            framerate+=1
                gameboard.agent.next_turn()

            if evaluate_agent:
                agent_evaluate.get_state()
                agent_evaluate.set_action()

            if pygame.display.get_active():
                # Paint game board
                screen.fill(COLOR_WHITE)

                for i in range(gameboard.N_row):
                    for j in range(gameboard.N_col):
                        pygame.draw.rect(screen,COLOR_GREY,[100+20*j,80+20*(gameboard.N_row-i),20,20],1)
                        if gameboard.board[i][j] > 0:
                            pygame.draw.rect(screen,COLOR_BLACK,[101+20*j,81+20*(gameboard.N_row-i),18,18])

                if gameboard.cur_tile_type is not None:
                    curTile=gameboard.tiles[gameboard.cur_tile_type][gameboard.tile_orientation]
                    for xLoop in range(len(curTile)):
                        for yLoop in range(curTile[xLoop][0],curTile[xLoop][1]):
                            pygame.draw.rect(screen,COLOR_RED,[101+20*((xLoop+gameboard.tile_x)%gameboard.N_col),81+20*(gameboard.N_row-(yLoop+gameboard.tile_y)),18,18])

                screen.blit(font.render("Reward: "+str(agent.reward_tots[agent.episode]),True,COLOR_BLACK),[0,0])
                screen.blit(font.render("Tile "+str(gameboard.tile_count)+"/"+str(gameboard.max_tile_count),True,COLOR_BLACK),[0,20])
                if framerate>0:
                    screen.blit(font.render("FPS: "+str(framerate),True,COLOR_BLACK),[320,0])
                screen.blit(font.render("Reward: "+str(agent.reward_tots[agent.episode]),True,COLOR_BLACK),[0,0])
                if gameboard.gameover:
                    screen.blit(fontLarge.render("Game Over", True,COLOR_RED), [80, 200])
                    screen.blit(font.render("Press ESC to try again", True,COLOR_RED), [85, 265])

                pygame.display.flip()
                clock.tick(framerate)

Evaluate(gameboard,player)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Game terminated
# c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\IPython\core\interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#Define standard Q learning agent

def convertToBinary(s,state_size=18):
    binary = np.array([int(i) for i in bin(s)[2:]])
    binary = np.pad(binary, (state_size - len(binary), 0), 'constant')
    return binary

class QLAgent:
    def __init__(self,alpha,epsilon,episode_count):
        # Initialize training parameters
        self.alpha=alpha
        self.epsilon=epsilon
        self.episode=0
        self.episode_count=episode_count

    def init_board(self,gameboard):
        
        #Set up and initialize the states, actions and Q-table and storage for the rewards
        self.gameboard=gameboard
        self.nr_of_rows = gameboard.N_row
        self.nr_of_cols = gameboard.N_col
        self.len_of_tiles = len(bin(len(gameboard.tiles)-1)[2:])
        self.board = gameboard.board
        self.tiles = gameboard.tiles
        self.tile_sequence = gameboard.tile_sequence
        self.reward_tots = np.array([0]*self.episode_count)
        
        self.nr_of_rotations=4
        self.nr_of_moves = self.nr_of_cols-1
        self.state_size = gameboard.N_col*gameboard.N_row+self.len_of_tiles
        self.nr_of_states = 2**self.state_size
        self.action_size = self.nr_of_moves*self.nr_of_rotations
        
        self.Q_table = np.zeros((self.nr_of_states,self.action_size))
        self.Q_target = self.Q_table

    def load_strategy(self, strategy_file):
        self.Q_table = np.loadtxt(strategy_file)
        self.Q_target = self.Q_table

    def get_state(self):
        #Convert board to binary list
        board = np.copy(self.gameboard.board.reshape(self.nr_of_cols*self.nr_of_rows,)).astype(int)
        board[board==-1] = 0
        #Convert tile to binary list
        tile = np.copy(self.gameboard.cur_tile_type)
        tile = convertToBinary(tile,self.len_of_tiles)   
        #Add binary lists
        state = np.append(tile,board)    
        #Convert binary list to int
        state = int("".join(str(i) for i in state),2)
        self.state = state
        
    def set_action(self):
        # Select action using epsilon-greedy policy
        if np.random.rand() < self.epsilon:
            action = np.random.randint(self.nr_of_moves*self.nr_of_rotations)            
        else:
            action = np.argmax(self.Q_table[self.state,:]) 
        #Extract rotation and movement from action parameter 
        tile_orientation = action % self.nr_of_rotations
        tile_x = int(action/self.nr_of_rotations)
        self.legalAction = self.gameboard.fn_move(tile_x,tile_orientation)
        self.action = action
        
    def train(self,old_state,reward):
        # Update the Q table using state and action stored as attributes in self and using function arguments for the old state and the reward
        if self.legalAction == 0:
            self.Q_table[old_state,self.action] += self.alpha*(reward+np.max(self.Q_table[self.state,:])-self.Q_table[old_state,self.action])
        else:
            self.Q_table[old_state,self.action] += -50 #penalty for illegal move

    def next_turn(self):
        if self.gameboard.gameover:
            self.episode+=1
            if self.episode%100==0:
                self.Q_target = self.Q_table
                print('episode '+str(self.episode)+'/'+str(self.episode_count)+' (reward: ',str(np.sum(self.reward_tots[range(self.episode-100,self.episode)])),')')
            if self.episode>=self.episode_count:
                np.savetxt('Q_table.txt',self.Q_table)
                raise SystemExit("Training finished")
            else:
                self.gameboard.fn_restart()
        else:
            # Select and execute action (move the tile to the desired column and orientation)
            self.set_action()
            old_state=np.copy(self.state)
            # Drop the tile on the game board
            reward=self.gameboard.fn_drop()   
            self.reward_tots[self.episode]+=reward
            # Read the new state
            self.get_state()
            # Update the Q-table using the old state and the reward
            self.train(old_state,reward)

# %% [markdown]
# Standard Q-learning to play Tetris

# %%
agent=QLAgent(alpha,epsilon,episode_count)
gameboard=gameboardClass.TGameBoard(N_row,N_col,tile_size,max_tile_count,agent,stochastic_prob)

while True:
    gameboard.agent.next_turn()
# Out:
# episode 100/1000 (reward:  -8906 )
# episode 200/1000 (reward:  -7313 )
# episode 300/1000 (reward:  -6154 )
# episode 400/1000 (reward:  -5479 )
# episode 500/1000 (reward:  -3031 )
# episode 600/1000 (reward:  6400 )
# episode 700/1000 (reward:  6400 )
# episode 800/1000 (reward:  6400 )
# episode 900/1000 (reward:  6400 )
# episode 1000/1000 (reward:  6400 )
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Training finished

# %%
gameboard=gameboardClass.TGameBoard(N_row,N_col,tile_size,max_tile_count,player,stochastic_prob)
plt.plot(agent.reward_tots)
plt.ylabel('Reward')
plt.xlabel('Episode')
Evaluate(gameboard,player,agent,strategy_file='Q_table.txt')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Game terminated

# %% [markdown]
# We consider the more challenging scenario of a random sequence of tiles. Here, we expect standard Q learning to not converge to an (even close to) optimal solution in finite time.

# %%
stochastic_prob=1
epsilon=0.001
episode_count=200000

agent=QLAgent(alpha,epsilon,episode_count)
gameboard=gameboardClass.TGameBoard(N_row,N_col,tile_size,max_tile_count,agent,stochastic_prob)

while True:
    gameboard.agent.next_turn()
# Out:
# episode 100/200000 (reward:  -9940 )
# episode 200/200000 (reward:  -9890 )
# episode 300/200000 (reward:  -9888 )
# episode 400/200000 (reward:  -9867 )
# episode 500/200000 (reward:  -9873 )
# episode 600/200000 (reward:  -9853 )
# episode 700/200000 (reward:  -9852 )
# episode 800/200000 (reward:  -9820 )
# episode 900/200000 (reward:  -9860 )
# episode 1000/200000 (reward:  -9835 )
# episode 1100/200000 (reward:  -9784 )
# episode 1200/200000 (reward:  -9850 )
# episode 1300/200000 (reward:  -9868 )
# episode 1400/200000 (reward:  -9844 )
# episode 1500/200000 (reward:  -9841 )
# episode 1600/200000 (reward:  -9766 )
# episode 1700/200000 (reward:  -9789 )
# episode 1800/200000 (reward:  -9863 )
# episode 1900/200000 (reward:  -9730 )
# episode 2000/200000 (reward:  -9725 )
# episode 2100/200000 (reward:  -9750 )
# episode 2200/200000 (reward:  -9743 )
# episode 2300/200000 (reward:  -9740 )
# episode 2400/200000 (reward:  -9749 )
# episode 2500/200000 (reward:  -9771 )
# episode 2600/200000 (reward:  -9676 )
# episode 2700/200000 (reward:  -9707 )
# episode 2800/200000 (reward:  -9703 )
# episode 2900/200000 (reward:  -9660 )
# episode 3000/200000 (reward:  -9787 )
# episode 3100/200000 (reward:  -9742 )
# episode 3200/200000 (reward:  -9729 )
# episode 3300/200000 (reward:  -9728 )
# episode 3400/200000 (reward:  -9762 )
# episode 3500/200000 (reward:  -9687 )
# episode 3600/200000 (reward:  -9652 )
# episode 3700/200000 (reward:  -9672 )
# episode 3800/200000 (reward:  -9769 )
# episode 3900/200000 (reward:  -9731 )
# episode 4000/200000 (reward:  -9775 )
# episode 4100/200000 (reward:  -9756 )
# episode 4200/200000 (reward:  -9726 )
# episode 4300/200000 (reward:  -9626 )
# episode 4400/200000 (reward:  -9721 )
# episode 4500/200000 (reward:  -9541 )
# episode 4600/200000 (reward:  -9744 )
# episode 4700/200000 (reward:  -9577 )
# episode 4800/200000 (reward:  -9713 )
# episode 4900/200000 (reward:  -9628 )
# episode 5000/200000 (reward:  -9652 )
# episode 5100/200000 (reward:  -9633 )
# episode 5200/200000 (reward:  -9645 )
# episode 5300/200000 (reward:  -9672 )
# episode 5400/200000 (reward:  -9639 )
# episode 5500/200000 (reward:  -9756 )
# episode 5600/200000 (reward:  -9717 )
# episode 5700/200000 (reward:  -9671 )
# episode 5800/200000 (reward:  -9681 )
# episode 5900/200000 (reward:  -9720 )
# episode 6000/200000 (reward:  -9616 )
# episode 6100/200000 (reward:  -9602 )
# episode 6200/200000 (reward:  -9643 )
# episode 6300/200000 (reward:  -9652 )
# episode 6400/200000 (reward:  -9582 )
# episode 6500/200000 (reward:  -9596 )
# episode 6600/200000 (reward:  -9637 )
# episode 6700/200000 (reward:  -9663 )
# episode 6800/200000 (reward:  -9609 )
# episode 6900/200000 (reward:  -9537 )
# episode 7000/200000 (reward:  -9601 )
# episode 7100/200000 (reward:  -9618 )
# episode 7200/200000 (reward:  -9508 )
# episode 7300/200000 (reward:  -9547 )
# episode 7400/200000 (reward:  -9567 )
# episode 7500/200000 (reward:  -9586 )
# episode 7600/200000 (reward:  -9620 )
# episode 7700/200000 (reward:  -9557 )
# episode 7800/200000 (reward:  -9499 )
# episode 7900/200000 (reward:  -9562 )
# episode 8000/200000 (reward:  -9487 )
# episode 8100/200000 (reward:  -9611 )
# episode 8200/200000 (reward:  -9555 )
# episode 8300/200000 (reward:  -9579 )
# episode 8400/200000 (reward:  -9521 )
# episode 8500/200000 (reward:  -9525 )
# episode 8600/200000 (reward:  -9532 )
# episode 8700/200000 (reward:  -9586 )
# episode 8800/200000 (reward:  -9429 )
# episode 8900/200000 (reward:  -9626 )
# episode 9000/200000 (reward:  -9525 )
# episode 9100/200000 (reward:  -9453 )
# episode 9200/200000 (reward:  -9514 )
# episode 9300/200000 (reward:  -9528 )
# episode 9400/200000 (reward:  -9547 )
# episode 9500/200000 (reward:  -9495 )
# episode 9600/200000 (reward:  -9563 )
# episode 9700/200000 (reward:  -9518 )
# episode 9800/200000 (reward:  -9502 )
# episode 9900/200000 (reward:  -9645 )
# episode 10000/200000 (reward:  -9529 )
# episode 10100/200000 (reward:  -9551 )
# episode 10200/200000 (reward:  -9501 )
# episode 10300/200000 (reward:  -9272 )
# episode 10400/200000 (reward:  -9495 )
# episode 10500/200000 (reward:  -9496 )
# episode 10600/200000 (reward:  -9255 )
# episode 10700/200000 (reward:  -9556 )
# episode 10800/200000 (reward:  -9621 )
# episode 10900/200000 (reward:  -9505 )
# episode 11000/200000 (reward:  -9515 )
# episode 11100/200000 (reward:  -9482 )
# episode 11200/200000 (reward:  -9479 )
# episode 11300/200000 (reward:  -9520 )
# episode 11400/200000 (reward:  -9480 )
# episode 11500/200000 (reward:  -9393 )
# episode 11600/200000 (reward:  -9439 )
# episode 11700/200000 (reward:  -9396 )
# episode 11800/200000 (reward:  -9493 )
# episode 11900/200000 (reward:  -9285 )
# episode 12000/200000 (reward:  -9438 )
# episode 12100/200000 (reward:  -9313 )
# episode 12200/200000 (reward:  -9546 )
# episode 12300/200000 (reward:  -9452 )
# episode 12400/200000 (reward:  -9409 )
# episode 12500/200000 (reward:  -9379 )
# episode 12600/200000 (reward:  -9525 )
# episode 12700/200000 (reward:  -9407 )
# episode 12800/200000 (reward:  -9335 )
# episode 12900/200000 (reward:  -9432 )
# episode 13000/200000 (reward:  -9491 )
# episode 13100/200000 (reward:  -9625 )
# episode 13200/200000 (reward:  -9472 )
# episode 13300/200000 (reward:  -9398 )
# episode 13400/200000 (reward:  -9322 )
# episode 13500/200000 (reward:  -9421 )
# episode 13600/200000 (reward:  -9325 )
# episode 13700/200000 (reward:  -9439 )
# episode 13800/200000 (reward:  -9297 )
# episode 13900/200000 (reward:  -9391 )
# episode 14000/200000 (reward:  -9540 )
# episode 14100/200000 (reward:  -9377 )
# episode 14200/200000 (reward:  -9402 )
# episode 14300/200000 (reward:  -9290 )
# episode 14400/200000 (reward:  -9419 )
# episode 14500/200000 (reward:  -9406 )
# episode 14600/200000 (reward:  -9337 )
# episode 14700/200000 (reward:  -9335 )
# episode 14800/200000 (reward:  -9348 )
# episode 14900/200000 (reward:  -9377 )
# episode 15000/200000 (reward:  -9407 )
# episode 15100/200000 (reward:  -9471 )
# episode 15200/200000 (reward:  -9321 )
# episode 15300/200000 (reward:  -9393 )
# episode 15400/200000 (reward:  -9341 )
# episode 15500/200000 (reward:  -9320 )
# episode 15600/200000 (reward:  -9303 )
# episode 15700/200000 (reward:  -9329 )
# episode 15800/200000 (reward:  -9363 )
# episode 15900/200000 (reward:  -9413 )
# episode 16000/200000 (reward:  -9293 )
# episode 16100/200000 (reward:  -9302 )
# episode 16200/200000 (reward:  -9392 )
# episode 16300/200000 (reward:  -9328 )
# episode 16400/200000 (reward:  -9395 )
# episode 16500/200000 (reward:  -9412 )
# episode 16600/200000 (reward:  -9152 )
# episode 16700/200000 (reward:  -9273 )
# episode 16800/200000 (reward:  -9119 )
# episode 16900/200000 (reward:  -9207 )
# episode 17000/200000 (reward:  -9402 )
# episode 17100/200000 (reward:  -9418 )
# episode 17200/200000 (reward:  -9400 )
# episode 17300/200000 (reward:  -9311 )
# episode 17400/200000 (reward:  -9305 )
# episode 17500/200000 (reward:  -9187 )
# episode 17600/200000 (reward:  -9333 )
# episode 17700/200000 (reward:  -9369 )
# episode 17800/200000 (reward:  -9283 )
# episode 17900/200000 (reward:  -9267 )
# episode 18000/200000 (reward:  -9260 )
# episode 18100/200000 (reward:  -9299 )
# episode 18200/200000 (reward:  -9337 )
# episode 18300/200000 (reward:  -9216 )
# episode 18400/200000 (reward:  -9268 )
# episode 18500/200000 (reward:  -9236 )
# episode 18600/200000 (reward:  -9234 )
# episode 18700/200000 (reward:  -9324 )
# episode 18800/200000 (reward:  -9275 )
# episode 18900/200000 (reward:  -9248 )
# episode 19000/200000 (reward:  -9265 )
# episode 19100/200000 (reward:  -9277 )
# episode 19200/200000 (reward:  -9302 )
# episode 19300/200000 (reward:  -9320 )
# episode 19400/200000 (reward:  -9280 )
# episode 19500/200000 (reward:  -9103 )
# episode 19600/200000 (reward:  -9210 )
# episode 19700/200000 (reward:  -9207 )
# episode 19800/200000 (reward:  -9124 )
# episode 19900/200000 (reward:  -9069 )
# episode 20000/200000 (reward:  -9222 )
# episode 20100/200000 (reward:  -9283 )
# episode 20200/200000 (reward:  -9379 )
# episode 20300/200000 (reward:  -9297 )
# episode 20400/200000 (reward:  -9433 )
# episode 20500/200000 (reward:  -9456 )
# episode 20600/200000 (reward:  -9026 )
# episode 20700/200000 (reward:  -9158 )
# episode 20800/200000 (reward:  -9036 )
# episode 20900/200000 (reward:  -9405 )
# episode 21000/200000 (reward:  -9284 )
# episode 21100/200000 (reward:  -9259 )
# episode 21200/200000 (reward:  -9280 )
# episode 21300/200000 (reward:  -9318 )
# episode 21400/200000 (reward:  -9330 )
# episode 21500/200000 (reward:  -9352 )
# episode 21600/200000 (reward:  -9104 )
# episode 21700/200000 (reward:  -9355 )
# episode 21800/200000 (reward:  -9254 )
# episode 21900/200000 (reward:  -9262 )
# episode 22000/200000 (reward:  -9128 )
# episode 22100/200000 (reward:  -9269 )
# episode 22200/200000 (reward:  -9259 )
# episode 22300/200000 (reward:  -9136 )
# episode 22400/200000 (reward:  -9153 )
# episode 22500/200000 (reward:  -9262 )
# episode 22600/200000 (reward:  -9229 )
# episode 22700/200000 (reward:  -9281 )
# episode 22800/200000 (reward:  -9262 )
# episode 22900/200000 (reward:  -9181 )
# episode 23000/200000 (reward:  -9230 )
# episode 23100/200000 (reward:  -9145 )
# episode 23200/200000 (reward:  -9342 )
# episode 23300/200000 (reward:  -9317 )
# episode 23400/200000 (reward:  -9284 )
# episode 23500/200000 (reward:  -9183 )
# episode 23600/200000 (reward:  -9083 )
# episode 23700/200000 (reward:  -9207 )
# episode 23800/200000 (reward:  -9194 )
# episode 23900/200000 (reward:  -9326 )
# episode 24000/200000 (reward:  -9253 )
# episode 24100/200000 (reward:  -9264 )
# episode 24200/200000 (reward:  -9223 )
# episode 24300/200000 (reward:  -9197 )
# episode 24400/200000 (reward:  -9264 )
# episode 24500/200000 (reward:  -9220 )
# episode 24600/200000 (reward:  -9140 )
# episode 24700/200000 (reward:  -9074 )
# episode 24800/200000 (reward:  -9294 )
# episode 24900/200000 (reward:  -9104 )
# episode 25000/200000 (reward:  -9245 )
# episode 25100/200000 (reward:  -8852 )
# episode 25200/200000 (reward:  -9182 )
# episode 25300/200000 (reward:  -9213 )
# episode 25400/200000 (reward:  -9343 )
# episode 25500/200000 (reward:  -9283 )
# episode 25600/200000 (reward:  -9308 )
# episode 25700/200000 (reward:  -9252 )
# episode 25800/200000 (reward:  -9297 )
# episode 25900/200000 (reward:  -9254 )
# episode 26000/200000 (reward:  -9313 )
# episode 26100/200000 (reward:  -9299 )
# episode 26200/200000 (reward:  -9232 )
# episode 26300/200000 (reward:  -9166 )
# episode 26400/200000 (reward:  -9145 )
# episode 26500/200000 (reward:  -9229 )
# episode 26600/200000 (reward:  -9239 )
# episode 26700/200000 (reward:  -9243 )
# episode 26800/200000 (reward:  -9197 )
# episode 26900/200000 (reward:  -9336 )
# episode 27000/200000 (reward:  -9103 )
# episode 27100/200000 (reward:  -9324 )
# episode 27200/200000 (reward:  -9236 )
# episode 27300/200000 (reward:  -9228 )
# episode 27400/200000 (reward:  -9125 )
# episode 27500/200000 (reward:  -9090 )
# episode 27600/200000 (reward:  -9173 )
# episode 27700/200000 (reward:  -9328 )
# episode 27800/200000 (reward:  -9265 )
# episode 27900/200000 (reward:  -9170 )
# episode 28000/200000 (reward:  -9211 )
# episode 28100/200000 (reward:  -9145 )
# episode 28200/200000 (reward:  -9103 )
# episode 28300/200000 (reward:  -9066 )
# episode 28400/200000 (reward:  -9295 )
# episode 28500/200000 (reward:  -9213 )
# episode 28600/200000 (reward:  -9085 )
# episode 28700/200000 (reward:  -9248 )
# episode 28800/200000 (reward:  -9290 )
# episode 28900/200000 (reward:  -9416 )
# episode 29000/200000 (reward:  -9105 )
# episode 29100/200000 (reward:  -9213 )
# episode 29200/200000 (reward:  -9177 )
# episode 29300/200000 (reward:  -8905 )
# episode 29400/200000 (reward:  -9136 )
# episode 29500/200000 (reward:  -9051 )
# episode 29600/200000 (reward:  -9159 )
# episode 29700/200000 (reward:  -9198 )
# episode 29800/200000 (reward:  -9218 )
# episode 29900/200000 (reward:  -9288 )
# episode 30000/200000 (reward:  -9320 )
# episode 30100/200000 (reward:  -9124 )
# episode 30200/200000 (reward:  -9116 )
# episode 30300/200000 (reward:  -9092 )
# episode 30400/200000 (reward:  -9121 )
# episode 30500/200000 (reward:  -9234 )
# episode 30600/200000 (reward:  -9303 )
# episode 30700/200000 (reward:  -9245 )
# episode 30800/200000 (reward:  -9234 )
# episode 30900/200000 (reward:  -9197 )
# episode 31000/200000 (reward:  -8882 )
# episode 31100/200000 (reward:  -9080 )
# episode 31200/200000 (reward:  -8986 )
# episode 31300/200000 (reward:  -9073 )
# episode 31400/200000 (reward:  -9091 )
# episode 31500/200000 (reward:  -9004 )
# episode 31600/200000 (reward:  -9047 )
# episode 31700/200000 (reward:  -9024 )
# episode 31800/200000 (reward:  -9221 )
# episode 31900/200000 (reward:  -9026 )
# episode 32000/200000 (reward:  -9053 )
# episode 32100/200000 (reward:  -9230 )
# episode 32200/200000 (reward:  -9177 )
# episode 32300/200000 (reward:  -8581 )
# episode 32400/200000 (reward:  -8970 )
# episode 32500/200000 (reward:  -9161 )
# episode 32600/200000 (reward:  -9080 )
# episode 32700/200000 (reward:  -9083 )
# episode 32800/200000 (reward:  -9204 )
# episode 32900/200000 (reward:  -9046 )
# episode 33000/200000 (reward:  -9085 )
# episode 33100/200000 (reward:  -9012 )
# episode 33200/200000 (reward:  -9183 )
# episode 33300/200000 (reward:  -8990 )
# episode 33400/200000 (reward:  -9171 )
# episode 33500/200000 (reward:  -8939 )
# episode 33600/200000 (reward:  -9226 )
# episode 33700/200000 (reward:  -8991 )
# episode 33800/200000 (reward:  -9101 )
# episode 33900/200000 (reward:  -9017 )
# episode 34000/200000 (reward:  -8929 )
# episode 34100/200000 (reward:  -9006 )
# episode 34200/200000 (reward:  -8734 )
# episode 34300/200000 (reward:  -8903 )
# episode 34400/200000 (reward:  -8884 )
# episode 34500/200000 (reward:  -8810 )
# episode 34600/200000 (reward:  -8877 )
# episode 34700/200000 (reward:  -8775 )
# episode 34800/200000 (reward:  -8779 )
# episode 34900/200000 (reward:  -9019 )
# episode 35000/200000 (reward:  -8832 )
# episode 35100/200000 (reward:  -8744 )
# episode 35200/200000 (reward:  -8894 )
# episode 35300/200000 (reward:  -8644 )
# episode 35400/200000 (reward:  -8852 )
# episode 35500/200000 (reward:  -8381 )
# episode 35600/200000 (reward:  -9033 )
# episode 35700/200000 (reward:  -8908 )
# episode 35800/200000 (reward:  -8620 )
# episode 35900/200000 (reward:  -8759 )
# episode 36000/200000 (reward:  -8962 )
# episode 36100/200000 (reward:  -8901 )
# episode 36200/200000 (reward:  -8973 )
# episode 36300/200000 (reward:  -8505 )
# episode 36400/200000 (reward:  -8366 )
# episode 36500/200000 (reward:  -8785 )
# episode 36600/200000 (reward:  -8767 )
# episode 36700/200000 (reward:  -8839 )
# episode 36800/200000 (reward:  -8703 )
# episode 36900/200000 (reward:  -8493 )
# episode 37000/200000 (reward:  -8080 )
# episode 37100/200000 (reward:  -8538 )
# episode 37200/200000 (reward:  -8898 )
# episode 37300/200000 (reward:  -8154 )
# episode 37400/200000 (reward:  -8244 )
# episode 37500/200000 (reward:  -8670 )
# episode 37600/200000 (reward:  -8760 )
# episode 37700/200000 (reward:  -8557 )
# episode 37800/200000 (reward:  -8501 )
# episode 37900/200000 (reward:  -8754 )
# episode 38000/200000 (reward:  -8492 )
# episode 38100/200000 (reward:  -8717 )
# episode 38200/200000 (reward:  -8475 )
# episode 38300/200000 (reward:  -8529 )
# episode 38400/200000 (reward:  -8669 )
# episode 38500/200000 (reward:  -8610 )
# episode 38600/200000 (reward:  -8171 )
# episode 38700/200000 (reward:  -8243 )
# episode 38800/200000 (reward:  -8399 )
# episode 38900/200000 (reward:  -8189 )
# episode 39000/200000 (reward:  -8740 )
# episode 39100/200000 (reward:  -7990 )
# episode 39200/200000 (reward:  -8265 )
# episode 39300/200000 (reward:  -8070 )
# episode 39400/200000 (reward:  -8205 )
# episode 39500/200000 (reward:  -8631 )
# episode 39600/200000 (reward:  -8532 )
# episode 39700/200000 (reward:  -8805 )
# episode 39800/200000 (reward:  -8383 )
# episode 39900/200000 (reward:  -8452 )
# episode 40000/200000 (reward:  -8464 )
# episode 40100/200000 (reward:  -8227 )
# episode 40200/200000 (reward:  -8233 )
# episode 40300/200000 (reward:  -8443 )
# episode 40400/200000 (reward:  -8273 )
# episode 40500/200000 (reward:  -8838 )
# episode 40600/200000 (reward:  -8479 )
# episode 40700/200000 (reward:  -8193 )
# episode 40800/200000 (reward:  -7919 )
# episode 40900/200000 (reward:  -8074 )
# episode 41000/200000 (reward:  -7851 )
# episode 41100/200000 (reward:  -7966 )
# episode 41200/200000 (reward:  -7969 )
# episode 41300/200000 (reward:  -7804 )
# episode 41400/200000 (reward:  -8122 )
# episode 41500/200000 (reward:  -7422 )
# episode 41600/200000 (reward:  -7925 )
# episode 41700/200000 (reward:  -8330 )
# episode 41800/200000 (reward:  -8022 )
# episode 41900/200000 (reward:  -8226 )
# episode 42000/200000 (reward:  -7891 )
# episode 42100/200000 (reward:  -7974 )
# episode 42200/200000 (reward:  -7803 )
# episode 42300/200000 (reward:  -8216 )
# episode 42400/200000 (reward:  -7861 )
# episode 42500/200000 (reward:  -7863 )
# episode 42600/200000 (reward:  -7616 )
# episode 42700/200000 (reward:  -7835 )
# episode 42800/200000 (reward:  -8084 )
# episode 42900/200000 (reward:  -8214 )
# episode 43000/200000 (reward:  -8432 )
# episode 43100/200000 (reward:  -7081 )
# episode 43200/200000 (reward:  -8087 )
# episode 43300/200000 (reward:  -6704 )
# episode 43400/200000 (reward:  -6272 )
# episode 43500/200000 (reward:  -6706 )
# episode 43600/200000 (reward:  -6975 )
# episode 43700/200000 (reward:  -7375 )
# episode 43800/200000 (reward:  -7224 )
# episode 43900/200000 (reward:  -6587 )
# episode 44000/200000 (reward:  -6403 )
# episode 44100/200000 (reward:  -6682 )
# episode 44200/200000 (reward:  -6078 )
# episode 44300/200000 (reward:  -6657 )
# episode 44400/200000 (reward:  -5532 )
# episode 44500/200000 (reward:  -6332 )
# episode 44600/200000 (reward:  -6915 )
# episode 44700/200000 (reward:  -7439 )
# episode 44800/200000 (reward:  -6222 )
# episode 44900/200000 (reward:  -6745 )
# episode 45000/200000 (reward:  -6677 )
# episode 45100/200000 (reward:  -6640 )
# episode 45200/200000 (reward:  -6055 )
# episode 45300/200000 (reward:  -6584 )
# episode 45400/200000 (reward:  -6610 )
# episode 45500/200000 (reward:  -6904 )
# episode 45600/200000 (reward:  -7437 )
# episode 45700/200000 (reward:  -6883 )
# episode 45800/200000 (reward:  -6604 )
# episode 45900/200000 (reward:  -7275 )
# episode 46000/200000 (reward:  -7350 )
# episode 46100/200000 (reward:  -6358 )
# episode 46200/200000 (reward:  -6613 )
# episode 46300/200000 (reward:  -6461 )
# episode 46400/200000 (reward:  -6569 )
# episode 46500/200000 (reward:  -6937 )
# episode 46600/200000 (reward:  -6770 )
# episode 46700/200000 (reward:  -7368 )
# episode 46800/200000 (reward:  -6992 )
# episode 46900/200000 (reward:  -7006 )
# episode 47000/200000 (reward:  -6549 )
# episode 47100/200000 (reward:  -6399 )
# episode 47200/200000 (reward:  -6098 )
# episode 47300/200000 (reward:  -6735 )
# episode 47400/200000 (reward:  -6648 )
# episode 47500/200000 (reward:  -6626 )
# episode 47600/200000 (reward:  -6138 )
# episode 47700/200000 (reward:  -5628 )
# episode 47800/200000 (reward:  -5481 )
# episode 47900/200000 (reward:  -6744 )
# episode 48000/200000 (reward:  -6646 )
# episode 48100/200000 (reward:  -4526 )
# episode 48200/200000 (reward:  -5405 )
# episode 48300/200000 (reward:  -5969 )
# episode 48400/200000 (reward:  -6820 )
# episode 48500/200000 (reward:  -5635 )
# episode 48600/200000 (reward:  -6677 )
# episode 48700/200000 (reward:  -5896 )
# episode 48800/200000 (reward:  -6867 )
# episode 48900/200000 (reward:  -6093 )
# episode 49000/200000 (reward:  -5841 )
# episode 49100/200000 (reward:  -6552 )
# episode 49200/200000 (reward:  -6547 )
# episode 49300/200000 (reward:  -5906 )
# episode 49400/200000 (reward:  -5928 )
# episode 49500/200000 (reward:  -6413 )
# episode 49600/200000 (reward:  -6350 )
# episode 49700/200000 (reward:  -6816 )
# episode 49800/200000 (reward:  -5948 )
# episode 49900/200000 (reward:  -5311 )
# episode 50000/200000 (reward:  -6060 )
# episode 50100/200000 (reward:  -6401 )
# episode 50200/200000 (reward:  -6503 )
# episode 50300/200000 (reward:  -6277 )
# episode 50400/200000 (reward:  -6946 )
# episode 50500/200000 (reward:  -5303 )
# episode 50600/200000 (reward:  -5802 )
# episode 50700/200000 (reward:  -7161 )
# episode 50800/200000 (reward:  -6093 )
# episode 50900/200000 (reward:  -7459 )
# episode 51000/200000 (reward:  -6116 )
# episode 51100/200000 (reward:  -6580 )
# episode 51200/200000 (reward:  -5916 )
# episode 51300/200000 (reward:  -6398 )
# episode 51400/200000 (reward:  -6187 )
# episode 51500/200000 (reward:  -6677 )
# episode 51600/200000 (reward:  -6830 )
# episode 51700/200000 (reward:  -6898 )
# episode 51800/200000 (reward:  -7095 )
# episode 51900/200000 (reward:  -7425 )
# episode 52000/200000 (reward:  -7272 )
# episode 52100/200000 (reward:  -6665 )
# episode 52200/200000 (reward:  -7748 )
# episode 52300/200000 (reward:  -7029 )
# episode 52400/200000 (reward:  -7740 )
# episode 52500/200000 (reward:  -7259 )
# episode 52600/200000 (reward:  -6254 )
# episode 52700/200000 (reward:  -5983 )
# episode 52800/200000 (reward:  -6991 )
# episode 52900/200000 (reward:  -6724 )
# episode 53000/200000 (reward:  -6848 )
# episode 53100/200000 (reward:  -6807 )
# episode 53200/200000 (reward:  -7286 )
# episode 53300/200000 (reward:  -7063 )
# episode 53400/200000 (reward:  -7351 )
# episode 53500/200000 (reward:  -7350 )
# episode 53600/200000 (reward:  -7866 )
# episode 53700/200000 (reward:  -6413 )
# episode 53800/200000 (reward:  -7441 )
# episode 53900/200000 (reward:  -6979 )
# episode 54000/200000 (reward:  -6982 )
# episode 54100/200000 (reward:  -7730 )
# episode 54200/200000 (reward:  -7394 )
# episode 54300/200000 (reward:  -7520 )
# episode 54400/200000 (reward:  -7873 )
# episode 54500/200000 (reward:  -7781 )
# episode 54600/200000 (reward:  -6863 )
# episode 54700/200000 (reward:  -7614 )
# episode 54800/200000 (reward:  -7076 )
# episode 54900/200000 (reward:  -6841 )
# episode 55000/200000 (reward:  -6216 )
# episode 55100/200000 (reward:  -6944 )
# episode 55200/200000 (reward:  -7039 )
# episode 55300/200000 (reward:  -5708 )
# episode 55400/200000 (reward:  -6517 )
# episode 55500/200000 (reward:  -6074 )
# episode 55600/200000 (reward:  -7321 )
# episode 55700/200000 (reward:  -6567 )
# episode 55800/200000 (reward:  -6798 )
# episode 55900/200000 (reward:  -6501 )
# episode 56000/200000 (reward:  -6899 )
# episode 56100/200000 (reward:  -6767 )
# episode 56200/200000 (reward:  -7477 )
# episode 56300/200000 (reward:  -6827 )
# episode 56400/200000 (reward:  -7171 )
# episode 56500/200000 (reward:  -6436 )
# episode 56600/200000 (reward:  -7364 )
# episode 56700/200000 (reward:  -7272 )
# episode 56800/200000 (reward:  -6845 )
# episode 56900/200000 (reward:  -6752 )
# episode 57000/200000 (reward:  -7864 )
# episode 57100/200000 (reward:  -7480 )
# episode 57200/200000 (reward:  -7098 )
# episode 57300/200000 (reward:  -7510 )
# episode 57400/200000 (reward:  -6873 )
# episode 57500/200000 (reward:  -7039 )
# episode 57600/200000 (reward:  -8228 )
# episode 57700/200000 (reward:  -7396 )
# episode 57800/200000 (reward:  -6924 )
# episode 57900/200000 (reward:  -5019 )
# episode 58000/200000 (reward:  -5628 )
# episode 58100/200000 (reward:  -7117 )
# episode 58200/200000 (reward:  -6422 )
# episode 58300/200000 (reward:  -5520 )
# episode 58400/200000 (reward:  -6031 )
# episode 58500/200000 (reward:  -6457 )
# episode 58600/200000 (reward:  -6427 )
# episode 58700/200000 (reward:  -6429 )
# episode 58800/200000 (reward:  -6381 )
# episode 58900/200000 (reward:  -5655 )
# episode 59000/200000 (reward:  -6067 )
# episode 59100/200000 (reward:  -5465 )
# episode 59200/200000 (reward:  -6217 )
# episode 59300/200000 (reward:  -6272 )
# episode 59400/200000 (reward:  -5334 )
# episode 59500/200000 (reward:  -6330 )
# episode 59600/200000 (reward:  -5638 )
# episode 59700/200000 (reward:  -6757 )
# episode 59800/200000 (reward:  -5863 )
# episode 59900/200000 (reward:  -5670 )
# episode 60000/200000 (reward:  -6135 )
# episode 60100/200000 (reward:  -5793 )
# episode 60200/200000 (reward:  -5842 )
# episode 60300/200000 (reward:  -5888 )
# episode 60400/200000 (reward:  -5940 )
# episode 60500/200000 (reward:  -6216 )
# episode 60600/200000 (reward:  -5092 )
# episode 60700/200000 (reward:  -5411 )
# episode 60800/200000 (reward:  -5484 )
# episode 60900/200000 (reward:  -5995 )
# episode 61000/200000 (reward:  -6238 )
# episode 61100/200000 (reward:  -3247 )
# episode 61200/200000 (reward:  -6152 )
# episode 61300/200000 (reward:  -5537 )
# episode 61400/200000 (reward:  -5522 )
# episode 61500/200000 (reward:  -5448 )
# episode 61600/200000 (reward:  -4678 )
# episode 61700/200000 (reward:  -5170 )
# episode 61800/200000 (reward:  -6916 )
# episode 61900/200000 (reward:  -5429 )
# episode 62000/200000 (reward:  -5111 )
# episode 62100/200000 (reward:  -5305 )
# episode 62200/200000 (reward:  -4913 )
# episode 62300/200000 (reward:  -5565 )
# episode 62400/200000 (reward:  -5354 )
# episode 62500/200000 (reward:  -5207 )
# episode 62600/200000 (reward:  -4630 )
# episode 62700/200000 (reward:  -5286 )
# episode 62800/200000 (reward:  -4695 )
# episode 62900/200000 (reward:  -5050 )
# episode 63000/200000 (reward:  -4831 )
# episode 63100/200000 (reward:  -6094 )
# episode 63200/200000 (reward:  -6288 )
# episode 63300/200000 (reward:  -5139 )
# episode 63400/200000 (reward:  -5344 )
# episode 63500/200000 (reward:  -5539 )
# episode 63600/200000 (reward:  -5277 )
# episode 63700/200000 (reward:  -5199 )
# episode 63800/200000 (reward:  -5995 )
# episode 63900/200000 (reward:  -6017 )
# episode 64000/200000 (reward:  -6578 )
# episode 64100/200000 (reward:  -5667 )
# episode 64200/200000 (reward:  -5187 )
# episode 64300/200000 (reward:  -4182 )
# episode 64400/200000 (reward:  -5285 )
# episode 64500/200000 (reward:  -5380 )
# episode 64600/200000 (reward:  -5392 )
# episode 64700/200000 (reward:  -4369 )
# episode 64800/200000 (reward:  -5731 )
# episode 64900/200000 (reward:  -6113 )
# episode 65000/200000 (reward:  -3539 )
# episode 65100/200000 (reward:  -5516 )
# episode 65200/200000 (reward:  -5546 )
# episode 65300/200000 (reward:  -5836 )
# episode 65400/200000 (reward:  -6070 )
# episode 65500/200000 (reward:  -5345 )
# episode 65600/200000 (reward:  -4591 )
# episode 65700/200000 (reward:  -5812 )
# episode 65800/200000 (reward:  -4028 )
# episode 65900/200000 (reward:  -5449 )
# episode 66000/200000 (reward:  -5282 )
# episode 66100/200000 (reward:  -5292 )
# episode 66200/200000 (reward:  -5108 )
# episode 66300/200000 (reward:  -5025 )
# episode 66400/200000 (reward:  -4864 )
# episode 66500/200000 (reward:  -4897 )
# episode 66600/200000 (reward:  -5557 )
# episode 66700/200000 (reward:  -6176 )
# episode 66800/200000 (reward:  -5909 )
# episode 66900/200000 (reward:  -3172 )
# episode 67000/200000 (reward:  -6180 )
# episode 67100/200000 (reward:  -5159 )
# episode 67200/200000 (reward:  -4886 )
# episode 67300/200000 (reward:  -5433 )
# episode 67400/200000 (reward:  -4597 )
# episode 67500/200000 (reward:  -4799 )
# episode 67600/200000 (reward:  -3118 )
# episode 67700/200000 (reward:  -5694 )
# episode 67800/200000 (reward:  -5859 )
# episode 67900/200000 (reward:  -4742 )
# episode 68000/200000 (reward:  -5561 )
# episode 68100/200000 (reward:  -3683 )
# episode 68200/200000 (reward:  -4632 )
# episode 68300/200000 (reward:  -4639 )
# episode 68400/200000 (reward:  -5258 )
# episode 68500/200000 (reward:  -4899 )
# episode 68600/200000 (reward:  -5162 )
# episode 68700/200000 (reward:  -3332 )
# episode 68800/200000 (reward:  -4969 )
# episode 68900/200000 (reward:  -4692 )
# episode 69000/200000 (reward:  -3274 )
# episode 69100/200000 (reward:  -4663 )
# episode 69200/200000 (reward:  -5188 )
# episode 69300/200000 (reward:  -4018 )
# episode 69400/200000 (reward:  -3578 )
# episode 69500/200000 (reward:  -4034 )
# episode 69600/200000 (reward:  -4101 )
# episode 69700/200000 (reward:  -4522 )
# episode 69800/200000 (reward:  -3826 )
# episode 69900/200000 (reward:  -4773 )
# episode 70000/200000 (reward:  -6108 )
# episode 70100/200000 (reward:  -5389 )
# episode 70200/200000 (reward:  -3852 )
# episode 70300/200000 (reward:  -4176 )
# episode 70400/200000 (reward:  -4428 )
# episode 70500/200000 (reward:  -2510 )
# episode 70600/200000 (reward:  -3729 )
# episode 70700/200000 (reward:  -4453 )
# episode 70800/200000 (reward:  -4676 )
# episode 70900/200000 (reward:  -3809 )
# episode 71000/200000 (reward:  -4669 )
# episode 71100/200000 (reward:  -4328 )
# episode 71200/200000 (reward:  -3344 )
# episode 71300/200000 (reward:  -4783 )
# episode 71400/200000 (reward:  -2330 )
# episode 71500/200000 (reward:  -2638 )
# episode 71600/200000 (reward:  -3346 )
# episode 71700/200000 (reward:  -2020 )
# episode 71800/200000 (reward:  -4475 )
# episode 71900/200000 (reward:  -1317 )
# episode 72000/200000 (reward:  -1947 )
# episode 72100/200000 (reward:  -3890 )
# episode 72200/200000 (reward:  -3805 )
# episode 72300/200000 (reward:  -3352 )
# episode 72400/200000 (reward:  -4423 )
# episode 72500/200000 (reward:  -3473 )
# episode 72600/200000 (reward:  -3361 )
# episode 72700/200000 (reward:  -2754 )
# episode 72800/200000 (reward:  -2876 )
# episode 72900/200000 (reward:  -3589 )
# episode 73000/200000 (reward:  -3695 )
# episode 73100/200000 (reward:  -3176 )
# episode 73200/200000 (reward:  -3660 )
# episode 73300/200000 (reward:  -2200 )
# episode 73400/200000 (reward:  -4008 )
# episode 73500/200000 (reward:  -3744 )
# episode 73600/200000 (reward:  -3976 )
# episode 73700/200000 (reward:  -2891 )
# episode 73800/200000 (reward:  -2054 )
# episode 73900/200000 (reward:  -3087 )
# episode 74000/200000 (reward:  -3062 )
# episode 74100/200000 (reward:  -4059 )
# episode 74200/200000 (reward:  -4494 )
# episode 74300/200000 (reward:  -3811 )
# episode 74400/200000 (reward:  -3449 )
# episode 74500/200000 (reward:  -3060 )
# episode 74600/200000 (reward:  -3702 )
# episode 74700/200000 (reward:  -3075 )
# episode 74800/200000 (reward:  -3556 )
# episode 74900/200000 (reward:  -2622 )
# episode 75000/200000 (reward:  -2561 )
# episode 75100/200000 (reward:  -3582 )
# episode 75200/200000 (reward:  -2965 )
# episode 75300/200000 (reward:  -3219 )
# episode 75400/200000 (reward:  -2803 )
# episode 75500/200000 (reward:  -1958 )
# episode 75600/200000 (reward:  -3822 )
# episode 75700/200000 (reward:  -4258 )
# episode 75800/200000 (reward:  -2532 )
# episode 75900/200000 (reward:  -3923 )
# episode 76000/200000 (reward:  -1542 )
# episode 76100/200000 (reward:  -4046 )
# episode 76200/200000 (reward:  -4428 )
# episode 76300/200000 (reward:  -2482 )
# episode 76400/200000 (reward:  -3504 )
# episode 76500/200000 (reward:  -3798 )
# episode 76600/200000 (reward:  -2920 )
# episode 76700/200000 (reward:  -4565 )
# episode 76800/200000 (reward:  -3048 )
# episode 76900/200000 (reward:  -3557 )
# episode 77000/200000 (reward:  -2972 )
# episode 77100/200000 (reward:  -3638 )
# episode 77200/200000 (reward:  -3193 )
# episode 77300/200000 (reward:  -4282 )
# episode 77400/200000 (reward:  -2547 )
# episode 77500/200000 (reward:  -3781 )
# episode 77600/200000 (reward:  -2524 )
# episode 77700/200000 (reward:  -3163 )
# episode 77800/200000 (reward:  -3340 )
# episode 77900/200000 (reward:  -3990 )
# episode 78000/200000 (reward:  -3859 )
# episode 78100/200000 (reward:  -2524 )
# episode 78200/200000 (reward:  -1433 )
# episode 78300/200000 (reward:  -2403 )
# episode 78400/200000 (reward:  -3285 )
# episode 78500/200000 (reward:  -2693 )
# episode 78600/200000 (reward:  -3331 )
# episode 78700/200000 (reward:  -3748 )
# episode 78800/200000 (reward:  -3246 )
# episode 78900/200000 (reward:  -3699 )
# episode 79000/200000 (reward:  -4401 )
# episode 79100/200000 (reward:  -2931 )
# episode 79200/200000 (reward:  -3534 )
# episode 79300/200000 (reward:  -3227 )
# episode 79400/200000 (reward:  -2871 )
# episode 79500/200000 (reward:  -2728 )
# episode 79600/200000 (reward:  -3398 )
# episode 79700/200000 (reward:  -3182 )
# episode 79800/200000 (reward:  -2362 )
# episode 79900/200000 (reward:  -2450 )
# episode 80000/200000 (reward:  -4294 )
# episode 80100/200000 (reward:  -1692 )
# episode 80200/200000 (reward:  -1994 )
# episode 80300/200000 (reward:  -1848 )
# episode 80400/200000 (reward:  -2752 )
# episode 80500/200000 (reward:  -4205 )
# episode 80600/200000 (reward:  -2149 )
# episode 80700/200000 (reward:  -3090 )
# episode 80800/200000 (reward:  -2388 )
# episode 80900/200000 (reward:  -2659 )
# episode 81000/200000 (reward:  -3104 )
# episode 81100/200000 (reward:  -3792 )
# episode 81200/200000 (reward:  -3140 )
# episode 81300/200000 (reward:  -2474 )
# episode 81400/200000 (reward:  -3522 )
# episode 81500/200000 (reward:  -3449 )
# episode 81600/200000 (reward:  -2327 )
# episode 81700/200000 (reward:  -3351 )
# episode 81800/200000 (reward:  -3792 )
# episode 81900/200000 (reward:  -1398 )
# episode 82000/200000 (reward:  -3746 )
# episode 82100/200000 (reward:  -3128 )
# episode 82200/200000 (reward:  -2390 )
# episode 82300/200000 (reward:  -1509 )
# episode 82400/200000 (reward:  -1803 )
# episode 82500/200000 (reward:  -3018 )
# episode 82600/200000 (reward:  -2216 )
# episode 82700/200000 (reward:  -2017 )
# episode 82800/200000 (reward:  -3208 )
# episode 82900/200000 (reward:  -2551 )
# episode 83000/200000 (reward:  -2926 )
# episode 83100/200000 (reward:  -3489 )
# episode 83200/200000 (reward:  -1504 )
# episode 83300/200000 (reward:  -3067 )
# episode 83400/200000 (reward:  -2939 )
# episode 83500/200000 (reward:  -3470 )
# episode 83600/200000 (reward:  -3379 )
# episode 83700/200000 (reward:  -3804 )
# episode 83800/200000 (reward:  -3414 )
# episode 83900/200000 (reward:  -2855 )
# episode 84000/200000 (reward:  -2469 )
# episode 84100/200000 (reward:  -1011 )
# episode 84200/200000 (reward:  -2910 )
# episode 84300/200000 (reward:  -906 )
# episode 84400/200000 (reward:  -1890 )
# episode 84500/200000 (reward:  -2789 )
# episode 84600/200000 (reward:  -2404 )
# episode 84700/200000 (reward:  -1329 )
# episode 84800/200000 (reward:  -3288 )
# episode 84900/200000 (reward:  -2723 )
# episode 85000/200000 (reward:  -2708 )
# episode 85100/200000 (reward:  -2598 )
# episode 85200/200000 (reward:  -1638 )
# episode 85300/200000 (reward:  -2702 )
# episode 85400/200000 (reward:  -1837 )
# episode 85500/200000 (reward:  -1911 )
# episode 85600/200000 (reward:  -2392 )
# episode 85700/200000 (reward:  -1784 )
# episode 85800/200000 (reward:  -2953 )
# episode 85900/200000 (reward:  -2957 )
# episode 86000/200000 (reward:  -2549 )
# episode 86100/200000 (reward:  -2788 )
# episode 86200/200000 (reward:  -4006 )
# episode 86300/200000 (reward:  -2094 )
# episode 86400/200000 (reward:  -3808 )
# episode 86500/200000 (reward:  -3200 )
# episode 86600/200000 (reward:  -4650 )
# episode 86700/200000 (reward:  -3582 )
# episode 86800/200000 (reward:  -3581 )
# episode 86900/200000 (reward:  -1935 )
# episode 87000/200000 (reward:  -3347 )
# episode 87100/200000 (reward:  -2560 )
# episode 87200/200000 (reward:  -3514 )
# episode 87300/200000 (reward:  -2823 )
# episode 87400/200000 (reward:  -2949 )
# episode 87500/200000 (reward:  -3296 )
# episode 87600/200000 (reward:  -1659 )
# episode 87700/200000 (reward:  -2713 )
# episode 87800/200000 (reward:  -3635 )
# episode 87900/200000 (reward:  -3021 )
# episode 88000/200000 (reward:  -2402 )
# episode 88100/200000 (reward:  -2673 )
# episode 88200/200000 (reward:  -2183 )
# episode 88300/200000 (reward:  -3038 )
# episode 88400/200000 (reward:  -2344 )
# episode 88500/200000 (reward:  -3818 )
# episode 88600/200000 (reward:  -3025 )
# episode 88700/200000 (reward:  -1109 )
# episode 88800/200000 (reward:  -1413 )
# episode 88900/200000 (reward:  -3019 )
# episode 89000/200000 (reward:  -2600 )
# episode 89100/200000 (reward:  -1882 )
# episode 89200/200000 (reward:  -1513 )
# episode 89300/200000 (reward:  -1956 )
# episode 89400/200000 (reward:  -2064 )
# episode 89500/200000 (reward:  -2636 )
# episode 89600/200000 (reward:  -1905 )
# episode 89700/200000 (reward:  -1842 )
# episode 89800/200000 (reward:  -1712 )
# episode 89900/200000 (reward:  -3838 )
# episode 90000/200000 (reward:  -2119 )
# episode 90100/200000 (reward:  -3687 )
# episode 90200/200000 (reward:  -1298 )
# episode 90300/200000 (reward:  -630 )
# episode 90400/200000 (reward:  -2252 )
# episode 90500/200000 (reward:  -2994 )
# episode 90600/200000 (reward:  -1686 )
# episode 90700/200000 (reward:  -999 )
# episode 90800/200000 (reward:  -2998 )
# episode 90900/200000 (reward:  -2283 )
# episode 91000/200000 (reward:  -1714 )
# episode 91100/200000 (reward:  -2228 )
# episode 91200/200000 (reward:  -1294 )
# episode 91300/200000 (reward:  -2287 )
# episode 91400/200000 (reward:  -1808 )
# episode 91500/200000 (reward:  -2346 )
# episode 91600/200000 (reward:  -3659 )
# episode 91700/200000 (reward:  -1699 )
# episode 91800/200000 (reward:  -3058 )
# episode 91900/200000 (reward:  -2070 )
# episode 92000/200000 (reward:  -2469 )
# episode 92100/200000 (reward:  -1324 )
# episode 92200/200000 (reward:  -2310 )
# episode 92300/200000 (reward:  -1966 )
# episode 92400/200000 (reward:  -3555 )
# episode 92500/200000 (reward:  -1484 )
# episode 92600/200000 (reward:  -2327 )
# episode 92700/200000 (reward:  -399 )
# episode 92800/200000 (reward:  -2853 )
# episode 92900/200000 (reward:  -2506 )
# episode 93000/200000 (reward:  -2127 )
# episode 93100/200000 (reward:  -2792 )
# episode 93200/200000 (reward:  -1084 )
# episode 93300/200000 (reward:  -2163 )
# episode 93400/200000 (reward:  -3110 )
# episode 93500/200000 (reward:  -2791 )
# episode 93600/200000 (reward:  -2039 )
# episode 93700/200000 (reward:  -2253 )
# episode 93800/200000 (reward:  -1736 )
# episode 93900/200000 (reward:  -2433 )
# episode 94000/200000 (reward:  -2319 )
# episode 94100/200000 (reward:  -1342 )
# episode 94200/200000 (reward:  -2265 )
# episode 94300/200000 (reward:  -1484 )
# episode 94400/200000 (reward:  -1152 )
# episode 94500/200000 (reward:  -1698 )
# episode 94600/200000 (reward:  -3081 )
# episode 94700/200000 (reward:  -2285 )
# episode 94800/200000 (reward:  -1243 )
# episode 94900/200000 (reward:  -1571 )
# episode 95000/200000 (reward:  -2474 )
# episode 95100/200000 (reward:  -1514 )
# episode 95200/200000 (reward:  -1024 )
# episode 95300/200000 (reward:  -1053 )
# episode 95400/200000 (reward:  -2250 )
# episode 95500/200000 (reward:  -927 )
# episode 95600/200000 (reward:  -2589 )
# episode 95700/200000 (reward:  -2380 )
# episode 95800/200000 (reward:  -347 )
# episode 95900/200000 (reward:  -1670 )
# episode 96000/200000 (reward:  -1277 )
# episode 96100/200000 (reward:  -3122 )
# episode 96200/200000 (reward:  -2260 )
# episode 96300/200000 (reward:  -3216 )
# episode 96400/200000 (reward:  -3040 )
# episode 96500/200000 (reward:  -681 )
# episode 96600/200000 (reward:  -1805 )
# episode 96700/200000 (reward:  -1787 )
# episode 96800/200000 (reward:  -1158 )
# episode 96900/200000 (reward:  -2729 )
# episode 97000/200000 (reward:  -1261 )
# episode 97100/200000 (reward:  -2342 )
# episode 97200/200000 (reward:  -2058 )
# episode 97300/200000 (reward:  -1467 )
# episode 97400/200000 (reward:  -2256 )
# episode 97500/200000 (reward:  -1272 )
# episode 97600/200000 (reward:  -702 )
# episode 97700/200000 (reward:  -1797 )
# episode 97800/200000 (reward:  -1663 )
# episode 97900/200000 (reward:  -2406 )
# episode 98000/200000 (reward:  -2251 )
# episode 98100/200000 (reward:  -2883 )
# episode 98200/200000 (reward:  -3023 )
# episode 98300/200000 (reward:  -2813 )
# episode 98400/200000 (reward:  -2550 )
# episode 98500/200000 (reward:  -1972 )
# episode 98600/200000 (reward:  -3041 )
# episode 98700/200000 (reward:  -2303 )
# episode 98800/200000 (reward:  -1952 )
# episode 98900/200000 (reward:  -2510 )
# episode 99000/200000 (reward:  -3857 )
# episode 99100/200000 (reward:  -2291 )
# episode 99200/200000 (reward:  -66 )
# episode 99300/200000 (reward:  -1810 )
# episode 99400/200000 (reward:  -2307 )
# episode 99500/200000 (reward:  -2465 )
# episode 99600/200000 (reward:  -1922 )
# episode 99700/200000 (reward:  -2338 )
# episode 99800/200000 (reward:  -2246 )
# episode 99900/200000 (reward:  -1160 )
# episode 100000/200000 (reward:  -3289 )
# episode 100100/200000 (reward:  -2573 )
# episode 100200/200000 (reward:  -2623 )
# episode 100300/200000 (reward:  -2266 )
# episode 100400/200000 (reward:  -3470 )
# episode 100500/200000 (reward:  -1623 )
# episode 100600/200000 (reward:  -3973 )
# episode 100700/200000 (reward:  -3105 )
# episode 100800/200000 (reward:  -2390 )
# episode 100900/200000 (reward:  -3536 )
# episode 101000/200000 (reward:  -1699 )
# episode 101100/200000 (reward:  -3683 )
# episode 101200/200000 (reward:  -2507 )
# episode 101300/200000 (reward:  -3329 )
# episode 101400/200000 (reward:  -4000 )
# episode 101500/200000 (reward:  -3984 )
# episode 101600/200000 (reward:  -3764 )
# episode 101700/200000 (reward:  -3588 )
# episode 101800/200000 (reward:  -3822 )
# episode 101900/200000 (reward:  -4699 )
# episode 102000/200000 (reward:  -3231 )
# episode 102100/200000 (reward:  -2662 )
# episode 102200/200000 (reward:  -2854 )
# episode 102300/200000 (reward:  -3847 )
# episode 102400/200000 (reward:  -3334 )
# episode 102500/200000 (reward:  -3478 )
# episode 102600/200000 (reward:  -3862 )
# episode 102700/200000 (reward:  -3596 )
# episode 102800/200000 (reward:  -2789 )
# episode 102900/200000 (reward:  -3092 )
# episode 103000/200000 (reward:  -1814 )
# episode 103100/200000 (reward:  -2996 )
# episode 103200/200000 (reward:  -3441 )
# episode 103300/200000 (reward:  -2850 )
# episode 103400/200000 (reward:  -1939 )
# episode 103500/200000 (reward:  -3425 )
# episode 103600/200000 (reward:  -1835 )
# episode 103700/200000 (reward:  -2072 )
# episode 103800/200000 (reward:  -2011 )
# episode 103900/200000 (reward:  -1896 )
# episode 104000/200000 (reward:  -2377 )
# episode 104100/200000 (reward:  -2491 )
# episode 104200/200000 (reward:  -2068 )
# episode 104300/200000 (reward:  -3557 )
# episode 104400/200000 (reward:  -2550 )
# episode 104500/200000 (reward:  -782 )
# episode 104600/200000 (reward:  -3178 )
# episode 104700/200000 (reward:  -1766 )
# episode 104800/200000 (reward:  -1450 )
# episode 104900/200000 (reward:  -1521 )
# episode 105000/200000 (reward:  -2923 )
# episode 105100/200000 (reward:  -2280 )
# episode 105200/200000 (reward:  -2790 )
# episode 105300/200000 (reward:  -2285 )
# episode 105400/200000 (reward:  -1476 )
# episode 105500/200000 (reward:  -1235 )
# episode 105600/200000 (reward:  -2909 )
# episode 105700/200000 (reward:  -3001 )
# episode 105800/200000 (reward:  -2199 )
# episode 105900/200000 (reward:  -1819 )
# episode 106000/200000 (reward:  -2128 )
# episode 106100/200000 (reward:  -2793 )
# episode 106200/200000 (reward:  -3029 )
# episode 106300/200000 (reward:  -3271 )
# episode 106400/200000 (reward:  -1727 )
# episode 106500/200000 (reward:  -2245 )
# episode 106600/200000 (reward:  -2932 )
# episode 106700/200000 (reward:  -2637 )
# episode 106800/200000 (reward:  -3018 )
# episode 106900/200000 (reward:  -759 )
# episode 107000/200000 (reward:  -3482 )
# episode 107100/200000 (reward:  -2382 )
# episode 107200/200000 (reward:  -1877 )
# episode 107300/200000 (reward:  -3105 )
# episode 107400/200000 (reward:  -2260 )
# episode 107500/200000 (reward:  -2436 )
# episode 107600/200000 (reward:  -2536 )
# episode 107700/200000 (reward:  -2298 )
# episode 107800/200000 (reward:  -2484 )
# episode 107900/200000 (reward:  -3518 )
# episode 108000/200000 (reward:  -781 )
# episode 108100/200000 (reward:  -3211 )
# episode 108200/200000 (reward:  -2576 )
# episode 108300/200000 (reward:  -2198 )
# episode 108400/200000 (reward:  -2619 )
# episode 108500/200000 (reward:  -2882 )
# episode 108600/200000 (reward:  -3634 )
# episode 108700/200000 (reward:  -2927 )
# episode 108800/200000 (reward:  -2098 )
# episode 108900/200000 (reward:  -3892 )
# episode 109000/200000 (reward:  -2378 )
# episode 109100/200000 (reward:  -4299 )
# episode 109200/200000 (reward:  -4777 )
# episode 109300/200000 (reward:  -3922 )
# episode 109400/200000 (reward:  -4030 )
# episode 109500/200000 (reward:  -3221 )
# episode 109600/200000 (reward:  -3698 )
# episode 109700/200000 (reward:  -2825 )
# episode 109800/200000 (reward:  -3689 )
# episode 109900/200000 (reward:  -2561 )
# episode 110000/200000 (reward:  -2763 )
# episode 110100/200000 (reward:  -2226 )
# episode 110200/200000 (reward:  -3862 )
# episode 110300/200000 (reward:  -3276 )
# episode 110400/200000 (reward:  -2123 )
# episode 110500/200000 (reward:  -604 )
# episode 110600/200000 (reward:  -2932 )
# episode 110700/200000 (reward:  -3451 )
# episode 110800/200000 (reward:  -3187 )
# episode 110900/200000 (reward:  -1943 )
# episode 111000/200000 (reward:  -377 )
# episode 111100/200000 (reward:  -882 )
# episode 111200/200000 (reward:  -2030 )
# episode 111300/200000 (reward:  -1746 )
# episode 111400/200000 (reward:  -1701 )
# episode 111500/200000 (reward:  -2967 )
# episode 111600/200000 (reward:  -2280 )
# episode 111700/200000 (reward:  -2010 )
# episode 111800/200000 (reward:  -3684 )
# episode 111900/200000 (reward:  -1383 )
# episode 112000/200000 (reward:  -1294 )
# episode 112100/200000 (reward:  -1227 )
# episode 112200/200000 (reward:  -1104 )
# episode 112300/200000 (reward:  -1793 )
# episode 112400/200000 (reward:  -3411 )
# episode 112500/200000 (reward:  -3015 )
# episode 112600/200000 (reward:  -3282 )
# episode 112700/200000 (reward:  -217 )
# episode 112800/200000 (reward:  -1211 )
# episode 112900/200000 (reward:  -124 )
# episode 113000/200000 (reward:  -1097 )
# episode 113100/200000 (reward:  -1330 )
# episode 113200/200000 (reward:  87 )
# episode 113300/200000 (reward:  -1309 )
# episode 113400/200000 (reward:  -2340 )
# episode 113500/200000 (reward:  -556 )
# episode 113600/200000 (reward:  -219 )
# episode 113700/200000 (reward:  890 )
# episode 113800/200000 (reward:  -638 )
# episode 113900/200000 (reward:  -2198 )
# episode 114000/200000 (reward:  -1481 )
# episode 114100/200000 (reward:  -1411 )
# episode 114200/200000 (reward:  -488 )
# episode 114300/200000 (reward:  -1160 )
# episode 114400/200000 (reward:  -1058 )
# episode 114500/200000 (reward:  -1651 )
# episode 114600/200000 (reward:  -1101 )
# episode 114700/200000 (reward:  -1098 )
# episode 114800/200000 (reward:  -1645 )
# episode 114900/200000 (reward:  -1598 )
# episode 115000/200000 (reward:  -1843 )
# episode 115100/200000 (reward:  -1783 )
# episode 115200/200000 (reward:  -1246 )
# episode 115300/200000 (reward:  -1732 )
# episode 115400/200000 (reward:  -1092 )
# episode 115500/200000 (reward:  -1932 )
# episode 115600/200000 (reward:  -1461 )
# episode 115700/200000 (reward:  -2992 )
# episode 115800/200000 (reward:  -2217 )
# episode 115900/200000 (reward:  -1477 )
# episode 116000/200000 (reward:  -1177 )
# episode 116100/200000 (reward:  -1526 )
# episode 116200/200000 (reward:  -1359 )
# episode 116300/200000 (reward:  -1401 )
# episode 116400/200000 (reward:  -1091 )
# episode 116500/200000 (reward:  -3088 )
# episode 116600/200000 (reward:  -1314 )
# episode 116700/200000 (reward:  -3104 )
# episode 116800/200000 (reward:  -2743 )
# episode 116900/200000 (reward:  -2314 )
# episode 117000/200000 (reward:  276 )
# episode 117100/200000 (reward:  -1529 )
# episode 117200/200000 (reward:  -2505 )
# episode 117300/200000 (reward:  -1533 )
# episode 117400/200000 (reward:  -2518 )
# episode 117500/200000 (reward:  -2682 )
# episode 117600/200000 (reward:  -1900 )
# episode 117700/200000 (reward:  -2230 )
# episode 117800/200000 (reward:  -3431 )
# episode 117900/200000 (reward:  -2540 )
# episode 118000/200000 (reward:  -1333 )
# episode 118100/200000 (reward:  -1164 )
# episode 118200/200000 (reward:  -1256 )
# episode 118300/200000 (reward:  -2566 )
# episode 118400/200000 (reward:  -1215 )
# episode 118500/200000 (reward:  -1702 )
# episode 118600/200000 (reward:  -1127 )
# episode 118700/200000 (reward:  -2949 )
# episode 118800/200000 (reward:  -2689 )
# episode 118900/200000 (reward:  -3216 )
# episode 119000/200000 (reward:  -2548 )
# episode 119100/200000 (reward:  -1767 )
# episode 119200/200000 (reward:  -2043 )
# episode 119300/200000 (reward:  -761 )
# episode 119400/200000 (reward:  -1928 )
# episode 119500/200000 (reward:  -2844 )
# episode 119600/200000 (reward:  -2047 )
# episode 119700/200000 (reward:  -1487 )
# episode 119800/200000 (reward:  -2188 )
# episode 119900/200000 (reward:  -2611 )
# episode 120000/200000 (reward:  -2986 )
# episode 120100/200000 (reward:  -2375 )
# episode 120200/200000 (reward:  -3620 )
# episode 120300/200000 (reward:  -2690 )
# episode 120400/200000 (reward:  -2056 )
# episode 120500/200000 (reward:  -2586 )
# episode 120600/200000 (reward:  -2069 )
# episode 120700/200000 (reward:  -1552 )
# episode 120800/200000 (reward:  -2156 )
# episode 120900/200000 (reward:  -908 )
# episode 121000/200000 (reward:  -2296 )
# episode 121100/200000 (reward:  -1598 )
# episode 121200/200000 (reward:  -1962 )
# episode 121300/200000 (reward:  -1834 )
# episode 121400/200000 (reward:  -2281 )
# episode 121500/200000 (reward:  -3277 )
# episode 121600/200000 (reward:  -2376 )
# episode 121700/200000 (reward:  -1527 )
# episode 121800/200000 (reward:  -2115 )
# episode 121900/200000 (reward:  -2201 )
# episode 122000/200000 (reward:  -1602 )
# episode 122100/200000 (reward:  -651 )
# episode 122200/200000 (reward:  -471 )
# episode 122300/200000 (reward:  -2093 )
# episode 122400/200000 (reward:  -1335 )
# episode 122500/200000 (reward:  -1116 )
# episode 122600/200000 (reward:  -1484 )
# episode 122700/200000 (reward:  -1816 )
# episode 122800/200000 (reward:  -878 )
# ...
# episode 159100/200000 (reward:  -1010 )
# episode 159200/200000 (reward:  -786 )
# episode 159300/200000 (reward:  -308 )
# episode 159400/200000 (reward:  -1623 )
# episode 159500/200000 (reward:  -807 )
# episode 159600/200000 (reward:  -220 )
# episode 159700/200000 (reward:  -1212 )
# episode 159800/200000 (reward:  -872 )
# episode 159900/200000 (reward:  -93 )
# episode 160000/200000 (reward:  -707 )
# episode 160100/200000 (reward:  -993 )
# episode 160200/200000 (reward:  -504 )
# episode 160300/200000 (reward:  89 )
# episode 160400/200000 (reward:  -935 )
# episode 160500/200000 (reward:  -1347 )
# episode 160600/200000 (reward:  -213 )
# episode 160700/200000 (reward:  -523 )
# episode 160800/200000 (reward:  -504 )
# episode 160900/200000 (reward:  -164 )
# episode 161000/200000 (reward:  -895 )
# episode 161100/200000 (reward:  -488 )
# episode 161200/200000 (reward:  -1588 )
# episode 161300/200000 (reward:  -760 )
# episode 161400/200000 (reward:  -568 )
# episode 161500/200000 (reward:  532 )
# episode 161600/200000 (reward:  -1817 )
# episode 161700/200000 (reward:  1145 )
# episode 161800/200000 (reward:  754 )
# episode 161900/200000 (reward:  -390 )
# episode 162000/200000 (reward:  -914 )
# episode 162100/200000 (reward:  611 )
# episode 162200/200000 (reward:  -748 )
# episode 162300/200000 (reward:  547 )
# episode 162400/200000 (reward:  -132 )
# episode 162500/200000 (reward:  -496 )
# episode 162600/200000 (reward:  -737 )
# episode 162700/200000 (reward:  1380 )
# episode 162800/200000 (reward:  -28 )
# episode 162900/200000 (reward:  -81 )
# episode 163000/200000 (reward:  -150 )
# episode 163100/200000 (reward:  37 )
# episode 163200/200000 (reward:  -1055 )
# episode 163300/200000 (reward:  391 )
# episode 163400/200000 (reward:  -983 )
# episode 163500/200000 (reward:  -595 )
# episode 163600/200000 (reward:  -1012 )
# episode 163700/200000 (reward:  463 )
# episode 163800/200000 (reward:  -1564 )
# episode 163900/200000 (reward:  -411 )
# episode 164000/200000 (reward:  -859 )
# episode 164100/200000 (reward:  1289 )
# episode 164200/200000 (reward:  477 )
# episode 164300/200000 (reward:  -642 )
# episode 164400/200000 (reward:  -578 )
# episode 164500/200000 (reward:  743 )
# episode 164600/200000 (reward:  -530 )
# episode 164700/200000 (reward:  1407 )
# episode 164800/200000 (reward:  -203 )
# episode 164900/200000 (reward:  376 )
# episode 165000/200000 (reward:  -779 )
# episode 165100/200000 (reward:  836 )
# episode 165200/200000 (reward:  563 )
# episode 165300/200000 (reward:  414 )
# episode 165400/200000 (reward:  -690 )
# episode 165500/200000 (reward:  -465 )
# episode 165600/200000 (reward:  1421 )
# episode 165700/200000 (reward:  -609 )
# episode 165800/200000 (reward:  1612 )
# episode 165900/200000 (reward:  211 )
# episode 166000/200000 (reward:  520 )
# episode 166100/200000 (reward:  1577 )
# episode 166200/200000 (reward:  -581 )
# episode 166300/200000 (reward:  -139 )
# episode 166400/200000 (reward:  -98 )
# episode 166500/200000 (reward:  902 )
# episode 166600/200000 (reward:  272 )
# episode 166700/200000 (reward:  296 )
# episode 166800/200000 (reward:  -1070 )
# episode 166900/200000 (reward:  318 )
# episode 167000/200000 (reward:  -1070 )
# episode 167100/200000 (reward:  455 )
# episode 167200/200000 (reward:  -1179 )
# episode 167300/200000 (reward:  216 )
# episode 167400/200000 (reward:  -723 )
# episode 167500/200000 (reward:  -482 )
# episode 167600/200000 (reward:  1541 )
# episode 167700/200000 (reward:  -431 )
# episode 167800/200000 (reward:  -192 )
# episode 167900/200000 (reward:  -298 )
# episode 168000/200000 (reward:  1316 )
# episode 168100/200000 (reward:  -466 )
# episode 168200/200000 (reward:  -870 )
# episode 168300/200000 (reward:  -292 )
# episode 168400/200000 (reward:  -649 )
# episode 168500/200000 (reward:  -557 )
# episode 168600/200000 (reward:  -1215 )
# episode 168700/200000 (reward:  848 )
# episode 168800/200000 (reward:  -766 )
# episode 168900/200000 (reward:  -985 )
# episode 169000/200000 (reward:  -347 )
# episode 169100/200000 (reward:  -1671 )
# episode 169200/200000 (reward:  -1161 )
# episode 169300/200000 (reward:  436 )
# episode 169400/200000 (reward:  -1303 )
# episode 169500/200000 (reward:  -1065 )
# episode 169600/200000 (reward:  866 )
# episode 169700/200000 (reward:  511 )
# episode 169800/200000 (reward:  -467 )
# episode 169900/200000 (reward:  -863 )
# episode 170000/200000 (reward:  -743 )
# episode 170100/200000 (reward:  -716 )
# episode 170200/200000 (reward:  -1241 )
# episode 170300/200000 (reward:  -297 )
# episode 170400/200000 (reward:  -1669 )
# episode 170500/200000 (reward:  -915 )
# episode 170600/200000 (reward:  -1287 )
# episode 170700/200000 (reward:  205 )
# episode 170800/200000 (reward:  -436 )
# episode 170900/200000 (reward:  119 )
# episode 171000/200000 (reward:  1385 )
# episode 171100/200000 (reward:  1003 )
# episode 171200/200000 (reward:  -1461 )
# episode 171300/200000 (reward:  178 )
# episode 171400/200000 (reward:  2113 )
# episode 171500/200000 (reward:  523 )
# episode 171600/200000 (reward:  -1051 )
# episode 171700/200000 (reward:  -654 )
# episode 171800/200000 (reward:  -477 )
# episode 171900/200000 (reward:  -741 )
# episode 172000/200000 (reward:  330 )
# episode 172100/200000 (reward:  -1291 )
# episode 172200/200000 (reward:  -521 )
# episode 172300/200000 (reward:  -925 )
# episode 172400/200000 (reward:  -4 )
# episode 172500/200000 (reward:  -507 )
# episode 172600/200000 (reward:  -286 )
# episode 172700/200000 (reward:  719 )
# episode 172800/200000 (reward:  235 )
# episode 172900/200000 (reward:  -1083 )
# episode 173000/200000 (reward:  -641 )
# episode 173100/200000 (reward:  -1190 )
# episode 173200/200000 (reward:  -830 )
# episode 173300/200000 (reward:  -117 )
# episode 173400/200000 (reward:  395 )
# episode 173500/200000 (reward:  344 )
# episode 173600/200000 (reward:  -475 )
# episode 173700/200000 (reward:  393 )
# episode 173800/200000 (reward:  416 )
# episode 173900/200000 (reward:  1326 )
# episode 174000/200000 (reward:  427 )
# episode 174100/200000 (reward:  -1482 )
# episode 174200/200000 (reward:  -194 )
# episode 174300/200000 (reward:  77 )
# episode 174400/200000 (reward:  -618 )
# episode 174500/200000 (reward:  -1051 )
# episode 174600/200000 (reward:  436 )
# episode 174700/200000 (reward:  356 )
# episode 174800/200000 (reward:  -1058 )
# episode 174900/200000 (reward:  1144 )
# episode 175000/200000 (reward:  -142 )
# episode 175100/200000 (reward:  -338 )
# episode 175200/200000 (reward:  428 )
# episode 175300/200000 (reward:  -7 )
# episode 175400/200000 (reward:  923 )
# episode 175500/200000 (reward:  1185 )
# episode 175600/200000 (reward:  686 )
# episode 175700/200000 (reward:  -264 )
# episode 175800/200000 (reward:  -984 )
# episode 175900/200000 (reward:  -106 )
# episode 176000/200000 (reward:  174 )
# episode 176100/200000 (reward:  991 )
# episode 176200/200000 (reward:  451 )
# episode 176300/200000 (reward:  -832 )
# episode 176400/200000 (reward:  727 )
# episode 176500/200000 (reward:  480 )
# episode 176600/200000 (reward:  1502 )
# episode 176700/200000 (reward:  1310 )
# episode 176800/200000 (reward:  -363 )
# episode 176900/200000 (reward:  889 )
# episode 177000/200000 (reward:  -425 )
# episode 177100/200000 (reward:  -315 )
# episode 177200/200000 (reward:  474 )
# episode 177300/200000 (reward:  -588 )
# episode 177400/200000 (reward:  1228 )
# episode 177500/200000 (reward:  136 )
# episode 177600/200000 (reward:  457 )
# episode 177700/200000 (reward:  630 )
# episode 177800/200000 (reward:  260 )
# episode 177900/200000 (reward:  -48 )
# episode 178000/200000 (reward:  2469 )
# episode 178100/200000 (reward:  -1173 )
# episode 178200/200000 (reward:  2132 )
# episode 178300/200000 (reward:  2235 )
# episode 178400/200000 (reward:  113 )
# episode 178500/200000 (reward:  875 )
# episode 178600/200000 (reward:  1038 )
# episode 178700/200000 (reward:  972 )
# episode 178800/200000 (reward:  -40 )
# episode 178900/200000 (reward:  154 )
# episode 179000/200000 (reward:  963 )
# episode 179100/200000 (reward:  726 )
# episode 179200/200000 (reward:  2661 )
# episode 179300/200000 (reward:  168 )
# episode 179400/200000 (reward:  2142 )
# episode 179500/200000 (reward:  763 )
# episode 179600/200000 (reward:  1029 )
# episode 179700/200000 (reward:  231 )
# episode 179800/200000 (reward:  930 )
# episode 179900/200000 (reward:  247 )
# episode 180000/200000 (reward:  426 )
# episode 180100/200000 (reward:  931 )
# episode 180200/200000 (reward:  -397 )
# episode 180300/200000 (reward:  -481 )
# episode 180400/200000 (reward:  1530 )
# episode 180500/200000 (reward:  327 )
# episode 180600/200000 (reward:  261 )
# episode 180700/200000 (reward:  -525 )
# episode 180800/200000 (reward:  1994 )
# episode 180900/200000 (reward:  2163 )
# episode 181000/200000 (reward:  1017 )
# episode 181100/200000 (reward:  115 )
# episode 181200/200000 (reward:  70 )
# episode 181300/200000 (reward:  698 )
# episode 181400/200000 (reward:  592 )
# episode 181500/200000 (reward:  311 )
# episode 181600/200000 (reward:  841 )
# episode 181700/200000 (reward:  275 )
# episode 181800/200000 (reward:  450 )
# episode 181900/200000 (reward:  1278 )
# episode 182000/200000 (reward:  3200 )
# episode 182100/200000 (reward:  740 )
# episode 182200/200000 (reward:  999 )
# episode 182300/200000 (reward:  -605 )
# episode 182400/200000 (reward:  216 )
# episode 182500/200000 (reward:  1163 )
# episode 182600/200000 (reward:  866 )
# episode 182700/200000 (reward:  982 )
# episode 182800/200000 (reward:  1364 )
# episode 182900/200000 (reward:  558 )
# episode 183000/200000 (reward:  810 )
# episode 183100/200000 (reward:  174 )
# episode 183200/200000 (reward:  541 )
# episode 183300/200000 (reward:  1030 )
# episode 183400/200000 (reward:  1177 )
# episode 183500/200000 (reward:  975 )
# episode 183600/200000 (reward:  -329 )
# episode 183700/200000 (reward:  518 )
# episode 183800/200000 (reward:  1996 )
# episode 183900/200000 (reward:  23 )
# episode 184000/200000 (reward:  655 )
# episode 184100/200000 (reward:  2273 )
# episode 184200/200000 (reward:  1984 )
# episode 184300/200000 (reward:  771 )
# episode 184400/200000 (reward:  941 )
# episode 184500/200000 (reward:  1214 )
# episode 184600/200000 (reward:  1423 )
# episode 184700/200000 (reward:  544 )
# episode 184800/200000 (reward:  1634 )
# episode 184900/200000 (reward:  1442 )
# episode 185000/200000 (reward:  824 )
# episode 185100/200000 (reward:  176 )
# episode 185200/200000 (reward:  1597 )
# episode 185300/200000 (reward:  338 )
# episode 185400/200000 (reward:  1989 )
# episode 185500/200000 (reward:  591 )
# episode 185600/200000 (reward:  420 )
# episode 185700/200000 (reward:  447 )
# episode 185800/200000 (reward:  256 )
# episode 185900/200000 (reward:  -9 )
# episode 186000/200000 (reward:  736 )
# episode 186100/200000 (reward:  964 )
# episode 186200/200000 (reward:  2346 )
# episode 186300/200000 (reward:  986 )
# episode 186400/200000 (reward:  619 )
# episode 186500/200000 (reward:  2540 )
# episode 186600/200000 (reward:  -192 )
# episode 186700/200000 (reward:  1612 )
# episode 186800/200000 (reward:  1710 )
# episode 186900/200000 (reward:  -282 )
# episode 187000/200000 (reward:  1600 )
# episode 187100/200000 (reward:  1410 )
# episode 187200/200000 (reward:  814 )
# episode 187300/200000 (reward:  1999 )
# episode 187400/200000 (reward:  1098 )
# episode 187500/200000 (reward:  961 )
# episode 187600/200000 (reward:  1550 )
# episode 187700/200000 (reward:  2520 )
# episode 187800/200000 (reward:  1066 )
# episode 187900/200000 (reward:  2111 )
# episode 188000/200000 (reward:  3113 )
# episode 188100/200000 (reward:  1957 )
# episode 188200/200000 (reward:  1093 )
# episode 188300/200000 (reward:  430 )
# episode 188400/200000 (reward:  806 )
# episode 188500/200000 (reward:  1339 )
# episode 188600/200000 (reward:  1026 )
# episode 188700/200000 (reward:  2000 )
# episode 188800/200000 (reward:  1740 )
# episode 188900/200000 (reward:  1717 )
# episode 189000/200000 (reward:  2339 )
# episode 189100/200000 (reward:  1343 )
# episode 189200/200000 (reward:  493 )
# episode 189300/200000 (reward:  2165 )
# episode 189400/200000 (reward:  987 )
# episode 189500/200000 (reward:  2774 )
# episode 189600/200000 (reward:  477 )
# episode 189700/200000 (reward:  1148 )
# episode 189800/200000 (reward:  1455 )
# episode 189900/200000 (reward:  1833 )
# episode 190000/200000 (reward:  1050 )
# episode 190100/200000 (reward:  1106 )
# episode 190200/200000 (reward:  2361 )
# episode 190300/200000 (reward:  669 )
# episode 190400/200000 (reward:  330 )
# episode 190500/200000 (reward:  2268 )
# episode 190600/200000 (reward:  1620 )
# episode 190700/200000 (reward:  1889 )
# episode 190800/200000 (reward:  1327 )
# episode 190900/200000 (reward:  1378 )
# episode 191000/200000 (reward:  1171 )
# episode 191100/200000 (reward:  2075 )
# episode 191200/200000 (reward:  2456 )
# episode 191300/200000 (reward:  2767 )
# episode 191400/200000 (reward:  2042 )
# episode 191500/200000 (reward:  499 )
# episode 191600/200000 (reward:  2627 )
# episode 191700/200000 (reward:  2905 )
# episode 191800/200000 (reward:  1580 )
# episode 191900/200000 (reward:  1332 )
# episode 192000/200000 (reward:  1960 )
# episode 192100/200000 (reward:  1625 )
# episode 192200/200000 (reward:  1450 )
# episode 192300/200000 (reward:  2038 )
# episode 192400/200000 (reward:  1264 )
# episode 192500/200000 (reward:  1529 )
# episode 192600/200000 (reward:  1144 )
# episode 192700/200000 (reward:  1940 )
# episode 192800/200000 (reward:  1027 )
# episode 192900/200000 (reward:  688 )
# episode 193000/200000 (reward:  2408 )
# episode 193100/200000 (reward:  2014 )
# episode 193200/200000 (reward:  840 )
# episode 193300/200000 (reward:  1705 )
# episode 193400/200000 (reward:  2314 )
# episode 193500/200000 (reward:  1202 )
# episode 193600/200000 (reward:  3442 )
# episode 193700/200000 (reward:  2030 )
# episode 193800/200000 (reward:  2669 )
# episode 193900/200000 (reward:  869 )
# episode 194000/200000 (reward:  1562 )
# episode 194100/200000 (reward:  1812 )
# episode 194200/200000 (reward:  2057 )
# episode 194300/200000 (reward:  2187 )
# episode 194400/200000 (reward:  1641 )
# episode 194500/200000 (reward:  1741 )
# episode 194600/200000 (reward:  668 )
# episode 194700/200000 (reward:  1663 )
# episode 194800/200000 (reward:  840 )
# episode 194900/200000 (reward:  2168 )
# episode 195000/200000 (reward:  982 )
# episode 195100/200000 (reward:  2083 )
# episode 195200/200000 (reward:  1615 )
# episode 195300/200000 (reward:  2100 )
# episode 195400/200000 (reward:  2500 )
# episode 195500/200000 (reward:  2294 )
# episode 195600/200000 (reward:  1997 )
# episode 195700/200000 (reward:  826 )
# episode 195800/200000 (reward:  1669 )
# episode 195900/200000 (reward:  1527 )
# episode 196000/200000 (reward:  1871 )
# episode 196100/200000 (reward:  3912 )
# episode 196200/200000 (reward:  453 )
# episode 196300/200000 (reward:  2164 )
# episode 196400/200000 (reward:  914 )
# episode 196500/200000 (reward:  2294 )
# episode 196600/200000 (reward:  2570 )
# episode 196700/200000 (reward:  2650 )
# episode 196800/200000 (reward:  2031 )
# episode 196900/200000 (reward:  1445 )
# episode 197000/200000 (reward:  1892 )
# episode 197100/200000 (reward:  676 )
# episode 197200/200000 (reward:  2415 )
# episode 197300/200000 (reward:  2549 )
# episode 197400/200000 (reward:  786 )
# episode 197500/200000 (reward:  1572 )
# episode 197600/200000 (reward:  2266 )
# episode 197700/200000 (reward:  690 )
# episode 197800/200000 (reward:  1772 )
# episode 197900/200000 (reward:  2680 )
# episode 198000/200000 (reward:  2158 )
# episode 198100/200000 (reward:  2097 )
# episode 198200/200000 (reward:  535 )
# episode 198300/200000 (reward:  1640 )
# episode 198400/200000 (reward:  2592 )
# episode 198500/200000 (reward:  738 )
# episode 198600/200000 (reward:  1347 )
# episode 198700/200000 (reward:  1600 )
# episode 198800/200000 (reward:  2198 )
# episode 198900/200000 (reward:  588 )
# episode 199000/200000 (reward:  1066 )
# episode 199100/200000 (reward:  1876 )
# episode 199200/200000 (reward:  1512 )
# episode 199300/200000 (reward:  622 )
# episode 199400/200000 (reward:  1544 )
# episode 199500/200000 (reward:  3175 )
# episode 199600/200000 (reward:  1227 )
# episode 199700/200000 (reward:  2686 )
# episode 199800/200000 (reward:  944 )
# episode 199900/200000 (reward:  1619 )
# episode 200000/200000 (reward:  2657 )
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Training finished

# %%
gameboard=gameboardClass.TGameBoard(N_row,N_col,tile_size,max_tile_count,player,stochastic_prob)
plt.plot(agent.reward_tots)
running_mean=np.zeros(len(agent.reward_tots))
for i in range(len(agent.reward_tots)):
    running_mean[i]=np.mean(agent.reward_tots[max(0,i-500):i])
plt.plot(running_mean)
plt.ylabel('Reward')
plt.xlabel('Episode')
Evaluate(gameboard,player,agent,strategy_file='Q_table.txt')
# Out:
# c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Game terminated

# %% [markdown]
# Possibly, we can also let the user play the game again in these more difficult conditions.

# %%
Evaluate(gameboard,player)

# %%
import sys
sys.path.append('./deeplay')
import deeplay as dl
import torch
import random

    
class Quadruplet:
    def __init__(self, state, action, reward, new_state, terminal):
        self.state = state
        self.action = action
        self.new_state = new_state
        self.reward = reward
        self.terminal = terminal

class DQLAgent(dl.Application):
    # Agent for learning to play tetris using deep Q-learning
    def __init__(self,q_net,target_net, alpha, epsilon, epsilon_scale, replay_buffer_size, batch_size, sync_target_episode_count, episode_count,**kwargs):
        # Initialize training parameters
        self.alpha = alpha
        self.epsilon = epsilon
        self.epsilon_scale = epsilon_scale
        self.replay_buffer_size = replay_buffer_size
        self.batch_size = batch_size
        self.sync_target_episode_count = sync_target_episode_count

        self.q_net = q_net
        self.target_net = target_net
        self.episode = 0
        self.episode_count = episode_count
        self.max_reward=0
        super().__init__(**kwargs)

    def init_board(self, gameboard):

        # Initialize board variables
        self.gameboard = gameboard
        self.nr_of_actions=gameboard.N_col*4
        self.len_of_tiles = len(bin(len(gameboard.tiles)-1)[2:])
        self.state_size = gameboard.N_col*gameboard.N_row+self.len_of_tiles

        # Initialize networks and storage
        self.reward_tots = np.zeros(self.episode_count)
        self.exp_buffer = []

    def load_strategy(self, strategy_file):
        #Load model weights
        model_state_dict = torch.load(strategy_file)
        self.q_net.load_state_dict(model_state_dict)
        self.target_net.load_state_dict(model_state_dict)

    def get_state(self):
        #Convert board to binary list
        board = np.copy(self.gameboard.board.reshape(16,)).astype(int)
        board[board==-1] = 0
        #Convert tile to binary list
        tile = np.copy(self.gameboard.cur_tile_type)
        tile = convertToBinary(tile,self.len_of_tiles)   
        #Combine binary lists and save as state
        state = np.append(tile,board)    
        self.state = torch.tensor(state, dtype=torch.float32)

    def set_action(self):
        r = random.random()
        with torch.no_grad():
            self.output = self.q_net(self.state.view(1, self.state_size)).detach().numpy()[0]
            if np.random.rand() < self.epsilon:
                action = np.random.randint(self.nr_of_actions)            
            else:
                action = np.argmax(self.output)
            #Extract rotation and movement from action parameter 
            rotation = action % 4
            position = int(action/4)  
            self.legalAction = self.gameboard.fn_move(position,rotation)
            self.action = action
 

    def training_step(self, batch):
        # Store states in a list
        states = []
        next_states = []
        for quadruple in batch:
            states.append(quadruple.state)
            next_states.append(quadruple.new_state)
        # Initialize targets and target mask
        targets = torch.zeros(self.batch_size, self.nr_of_actions)
        targets_mask = torch.zeros(self.batch_size, self.nr_of_actions)
        # Evaluate next state with target network
        with torch.no_grad():
            q_hat = self.target_net(torch.stack(next_states, dim=0))
        # Computes targets
        for idx, quadruple in enumerate(batch):
            if quadruple.terminal:
                y = quadruple.reward
            else:
                y = quadruple.reward + np.nanmax(q_hat[idx,:])
            targets[idx, quadruple.action] = y
            targets_mask[idx, quadruple.action] = 1
        # Evaluate old states, apply mask and update weights
        self.optimizer.zero_grad()
        outputs = self.q_net(torch.stack(states, dim=0)) * targets_mask
        loss = self.loss(outputs, targets)
        loss.backward()
        self.optimizer.step()

    def next_turn(self):
        if self.gameboard.gameover:
            self.episode += 1
            self.epsilon = max(0.001, 1 - self.episode / self.epsilon_scale)
            if self.episode % 100 == 0:
                current_reward = np.sum(self.reward_tots[range(self.episode - 100, self.episode)])
                print('episode ' + str(self.episode) + ' / ' + str(self.episode_count) + ' (reward: ', str(current_reward))
                if current_reward > self.max_reward:
                    self.max_reward = current_reward
                    torch.save(self.q_net.state_dict(), 'q_net.pth')
            if self.episode >= self.episode_count:
                raise SystemExit("Training finished")
            else:
                if (len(self.exp_buffer) >= self.replay_buffer_size) and (self.episode % self.sync_target_episode_count == 0):
                    self.target_net.load_state_dict(self.q_net.state_dict())
                self.gameboard.fn_restart()
        else:
            # Select and execute action (move the tile to the desired column and orientation)
            self.set_action()
            old_state = self.state
            # Drop the tile on the game board
            reward = self.gameboard.fn_drop()
            self.reward_tots[self.episode] += reward

            # Read the new state
            self.get_state()
            terminal = self.gameboard.gameover
            quadruplet = Quadruplet(old_state, self.action, reward, self.state, terminal)
            self.exp_buffer.append(quadruplet)
            if len(self.exp_buffer) >= self.replay_buffer_size:
                batch = random.sample(self.exp_buffer, self.batch_size)
                self.training_step(batch)
            if len(self.exp_buffer) >= self.replay_buffer_size + 1:
                self.exp_buffer.pop(0)

# %%
alpha=0.001
episode_count=10000

epsilon_scale=5000
replay_buffer_size=10000
batch_size=64
sync_target_episode_count=100

hidden_units=[128,128]

q_net=dl.MultiLayerPerceptron(gameboard.N_row * gameboard.N_col + 2,hidden_units, gameboard.N_col*4)
q_net.blocks[:-1].activation = torch.nn.ReLU()
q_net=q_net.build()
print(q_net)
target_net=dl.MultiLayerPerceptron(gameboard.N_row * gameboard.N_col + 2,hidden_units,gameboard.N_col*4)
target_net.blocks[:-1].activation = torch.nn.ReLU() #GELU stabilizes training, ReLU works ok as well
target_net=target_net.build()

agent=DQLAgent(q_net,target_net,alpha,epsilon,epsilon_scale,replay_buffer_size,batch_size,sync_target_episode_count,episode_count,loss=torch.nn.MSELoss(),optimizer=torch.optim.Adam(q_net.parameters(),lr=alpha))
gameboard=gameboardClass.TGameBoard(N_row,N_col,tile_size,max_tile_count,agent,stochastic_prob)

while True:
    gameboard.agent.next_turn()
# Out:
# MultiLayerPerceptron(
#   (blocks): LayerList(
#     (0): LayerActivationNormalizationDropout(
#       (layer): Linear(in_features=18, out_features=128, bias=True)
#       (activation): ReLU()
#       (normalization): Identity()
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (1): LayerActivationNormalizationDropout(
#       (layer): Linear(in_features=128, out_features=128, bias=True)
#       (activation): ReLU()
#       (normalization): Identity()
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (2): LayerActivationNormalizationDropout(
#       (layer): Linear(in_features=128, out_features=16, bias=True)
#       (activation): Identity()
#       (normalization): Identity()
#       (dropout): Dropout(p=0, inplace=False)
#     )
#   )
# )
# episode 100 / 10000 (reward:  -9986.0
# episode 200 / 10000 (reward:  -9974.0
# episode 300 / 10000 (reward:  -9973.0
# episode 400 / 10000 (reward:  -9976.0
# episode 500 / 10000 (reward:  -9988.0
# episode 600 / 10000 (reward:  -9974.0
# episode 700 / 10000 (reward:  -9966.0
# episode 800 / 10000 (reward:  -9972.0
# episode 900 / 10000 (reward:  -9980.0
# episode 1000 / 10000 (reward:  -9981.0
# episode 1100 / 10000 (reward:  -9985.0
# episode 1200 / 10000 (reward:  -9975.0
# episode 1300 / 10000 (reward:  -9969.0
# episode 1400 / 10000 (reward:  -9991.0
# episode 1500 / 10000 (reward:  -9993.0
# episode 1600 / 10000 (reward:  -9970.0
# episode 1700 / 10000 (reward:  -9972.0
# episode 1800 / 10000 (reward:  -9990.0
# episode 1900 / 10000 (reward:  -9983.0
# episode 2000 / 10000 (reward:  -9987.0
# episode 2100 / 10000 (reward:  -9957.0
# episode 2200 / 10000 (reward:  -9990.0
# episode 2300 / 10000 (reward:  -9995.0
# episode 2400 / 10000 (reward:  -9986.0
# episode 2500 / 10000 (reward:  -9983.0
# episode 2600 / 10000 (reward:  -9985.0
# episode 2700 / 10000 (reward:  -9986.0
# episode 2800 / 10000 (reward:  -9994.0
# episode 2900 / 10000 (reward:  -9957.0
# episode 3000 / 10000 (reward:  -9862.0
# episode 3100 / 10000 (reward:  -9807.0
# episode 3200 / 10000 (reward:  -9850.0
# episode 3300 / 10000 (reward:  -9784.0
# episode 3400 / 10000 (reward:  -9762.0
# episode 3500 / 10000 (reward:  -9606.0
# episode 3600 / 10000 (reward:  -9638.0
# episode 3700 / 10000 (reward:  -9529.0
# episode 3800 / 10000 (reward:  -9659.0
# episode 3900 / 10000 (reward:  -9704.0
# episode 4000 / 10000 (reward:  -9622.0
# episode 4100 / 10000 (reward:  -9586.0
# episode 4200 / 10000 (reward:  -9474.0
# episode 4300 / 10000 (reward:  -9508.0
# episode 4400 / 10000 (reward:  -9309.0
# episode 4500 / 10000 (reward:  -8912.0
# episode 4600 / 10000 (reward:  -8690.0
# episode 4700 / 10000 (reward:  -8520.0
# episode 4800 / 10000 (reward:  -8424.0
# episode 4900 / 10000 (reward:  -7391.0
# episode 5000 / 10000 (reward:  -6676.0
# episode 5100 / 10000 (reward:  -5381.0
# episode 5200 / 10000 (reward:  -5094.0
# episode 5300 / 10000 (reward:  -2759.0
# episode 5400 / 10000 (reward:  -2807.0
# episode 5500 / 10000 (reward:  -3420.0
# episode 5600 / 10000 (reward:  -866.0
# episode 5700 / 10000 (reward:  -1007.0
# episode 5800 / 10000 (reward:  -9.0
# episode 5900 / 10000 (reward:  -736.0
# episode 6000 / 10000 (reward:  3026.0
# episode 6100 / 10000 (reward:  2484.0
# episode 6200 / 10000 (reward:  2973.0
# episode 6300 / 10000 (reward:  537.0
# episode 6400 / 10000 (reward:  3513.0
# episode 6500 / 10000 (reward:  2510.0
# episode 6600 / 10000 (reward:  2039.0
# episode 6700 / 10000 (reward:  1162.0
# episode 6800 / 10000 (reward:  2177.0
# episode 6900 / 10000 (reward:  3990.0
# episode 7000 / 10000 (reward:  3323.0
# episode 7100 / 10000 (reward:  4769.0
# episode 7200 / 10000 (reward:  4037.0
# episode 7300 / 10000 (reward:  4132.0
# episode 7400 / 10000 (reward:  5776.0
# episode 7500 / 10000 (reward:  3175.0
# episode 7600 / 10000 (reward:  4678.0
# episode 7700 / 10000 (reward:  3598.0
# episode 7800 / 10000 (reward:  3165.0
# episode 7900 / 10000 (reward:  4917.0
# episode 8000 / 10000 (reward:  3789.0
# episode 8100 / 10000 (reward:  3498.0
# episode 8200 / 10000 (reward:  3799.0
# episode 8300 / 10000 (reward:  4136.0
# episode 8400 / 10000 (reward:  4570.0
# episode 8500 / 10000 (reward:  3030.0
# episode 8600 / 10000 (reward:  3745.0
# episode 8700 / 10000 (reward:  1919.0
# episode 8800 / 10000 (reward:  4186.0
# episode 8900 / 10000 (reward:  4164.0
# episode 9000 / 10000 (reward:  2708.0
# episode 9100 / 10000 (reward:  2821.0
# episode 9200 / 10000 (reward:  4101.0
# episode 9300 / 10000 (reward:  3523.0
# episode 9400 / 10000 (reward:  3873.0
# episode 9500 / 10000 (reward:  3266.0
# episode 9600 / 10000 (reward:  3740.0
# episode 9700 / 10000 (reward:  4449.0
# episode 9800 / 10000 (reward:  3746.0
# episode 9900 / 10000 (reward:  4281.0
# episode 10000 / 10000 (reward:  2963.0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Training finished
# c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\IPython\core\interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
gameboard=gameboardClass.TGameBoard(N_row,N_col,tile_size,max_tile_count,player,stochastic_prob)
plt.plot(agent.reward_tots)
running_mean=np.zeros(len(agent.reward_tots))
for i in range(len(agent.reward_tots)):
    running_mean[i]=np.mean(agent.reward_tots[max(0,i-500):i])
plt.plot(running_mean)
plt.ylabel('Reward')
plt.xlabel('Episode')
Evaluate(gameboard,player,agent,strategy_file='q_net.pth')
# Out:
# c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Game terminated
