# %% [markdown]
# In this guide, we delve into an engaging and intriguing application of recurrent sequence-to-sequence models by training a basic chatbot using film scripts from the Cornell Movie-Dialogs Corpus.
#
# Conversational models are currently a trending subject in the field of AI research. Chatbots are commonly used in various scenarios such as customer service platforms and online help desks. These bots typically utilize retrieval-based models that provide pre-set responses to specific types of questions. While these models might be adequate for highly specific domains like a company's IT helpdesk, they lack the robustness required for broader applications. However, the recent surge in deep learning, spearheaded recently by ChatGPT, has led to the development of potent multi-domain generative conversational models. In this guide, we will create one such model using the tools we have learnt so far.
#
# To begin, download the dialog dataset:
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html (should be replaced with direct data source for DLCC)
#
# and put in a ``data/`` directory under the current directory.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import csv
import re
import os
import unicodedata
from io import open
import json
import deeplay as dl

# Check for CUDA availability for PyTorch
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# Mount Google Drive if using Google Colab
#from google.colab import drive
#drive.mount('/content/gdrive')
#os.chdir("/content/gdrive/My Drive")

# %% [markdown]
# ## Data Loading and Preprocessing
#
# This step involves reorganizing our data file and loading the data into formats that are manageable.
#
# The [Cornell Movie-Dialogs Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html) is a comprehensive dataset of dialogues from movie characters:
#
# - It contains 220,579 conversational exchanges between 10,292 pairs of movie characters.
# - It features 9,035 characters from 617 movies.
# - It has a total of 304,713 utterances.
#
# This dataset is vast and varied, with a wide range of language formality, time periods, sentiment, etc. We anticipate that this diversity will make our model capable of handling a variety of inputs and queries.
#
# Initially, we will examine some lines from our data file to understand the original format.

# %%
# Set the corpus name
corpus_name = "movie-corpus"

# Function to print first 'n' lines from a file
def print_lines(file, n=10):
    with open(file, 'r', encoding='utf-8') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line.strip())

print_lines(os.path.join(corpus_name, "utterances.jsonl"))
# Out:
# {"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}
# {"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}
# {"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L925", "conversation_id": "L924", "text": "Let's go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}
# {"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L872", "conversation_id": "L870", "text": "Okay -- you're gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}
# {"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}
# {"id": "L870", "conversation_id": "L870", "text": "I'm kidding.  You know how sometimes you just become this \"persona\"?  And you don't know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\"", "tag": "''", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n't", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}

# %% [markdown]
# ### Generate Formatted Data File
#
# For ease of use, we will generate a well-structured data file where each line comprises a tab-separated pair of a *query sentence* and a *response sentence*.
#
# The functions below aid in parsing the raw `utterances.jsonl` data file.
#
# - `loadLinesAndConversations` breaks down each line of the file into a dictionary of lines with fields: `lineID`, `characterID`, and text, and then groups these into conversations with fields: `conversationID`, `movieID`, and lines.
# - `extractSentencePairs` pulls out pairs of sentences from the conversations.

# %%
# Load lines and conversations
def load_data(file_name):
    lines, conversations = {}, {}
    with open(file_name, 'r', encoding='iso-8859-1') as file:
        for line in file:
            data = json.loads(line)
            lines[data["id"]] = {"lineID": data["id"], "characterID": data["speaker"], "text": data["text"]}
            conv_id = data["conversation_id"]
            if conv_id not in conversations:
                conversations[conv_id] = {
                    "conversationID": conv_id,
                    "movieID": data["meta"]["movie_id"],
                    "lines": [lines[data["id"]]]
                }
            else:
                conversations[conv_id]["lines"].append(lines[data["id"]])
    return lines, conversations

# Extract sentence pairs from conversations
def extract_pairs(conversations):
    return [[input_line["text"].strip(), target_line["text"].strip()]
            for conversation in conversations.values()
            for input_line, target_line in zip(conversation["lines"], conversation["lines"][1:])
            if input_line["text"].strip() and target_line["text"].strip()]
    
# Processing and writing to file
def process_and_write(corpus_name):
    # Define path to new file
    datafile = os.path.join(corpus_name, "formatted_movie_lines.txt")
    delimiter = '\t'  # Tab character, no need to unescape

    # Load lines and conversations
    print("\nProcessing corpus into lines and conversations...")
    lines, conversations = load_data(os.path.join(corpus_name, "utterances.jsonl"))

    # Write new csv file
    print("\nWriting newly formatted file...")
    with open(datafile, 'w', encoding='utf-8') as outputfile:
        writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
        for pair in extract_pairs(conversations):
            writer.writerow(pair)

    # Print a sample of lines (assuming a function printLines exists)
    print("\nSample lines from file:")
    # If printLines is not defined, we can simply print the first few lines from the file
    with open(datafile, 'r', encoding='utf-8') as file:
        for _ in range(5):  # Print first 5 lines as a sample
            print(file.readline().strip())
    return datafile

datafile=process_and_write(corpus_name)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# They do not!	They do to!
# I hope so.	She okay?
# Let's go.	Wow
# Okay -- you're gonna need to learn how to lie.	No
# No	"I'm kidding.  You know how sometimes you just become this ""persona""?  And you don't know how to quit?"

# %% [markdown]
# ### Data Loading and Trimming
#
# The next step involves creating a vocabulary and loading query/response sentence pairs into memory.
#
# Keep in mind that we are working with sequences of **words**, which do not inherently map to a discrete numerical space. Therefore, we need to create such a mapping by associating each unique word we encounter in our dataset with an index value.
#
# To achieve this, we define a `Vocabulary` class, which maintains a mapping from words to indexes, a reverse mapping from indexes to words, a count of each word, and a total word count. The class offers methods for adding a word to the vocabulary (`add_word`), adding all words in a sentence (`add_sentence`), and trimming infrequently seen words (`trim`). We will discuss trimming in more detail later.

# %%
# Default word tokens
PAD_TOKEN = 0  # Used for padding short sentences
SOS_TOKEN = 1  # Start-of-sentence token
EOS_TOKEN = 2  # End-of-sentence token

class Vocabulary:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word_to_index = {"PAD":PAD_TOKEN,"SOS":SOS_TOKEN, "EOS":EOS_TOKEN}
        self.word_to_count = {}
        self.index_to_word = {PAD_TOKEN: "PAD", SOS_TOKEN: "SOS", EOS_TOKEN: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def add_sentence(self, sentence):
        for word in sentence.split():
            self.add_word(word)

    def add_word(self, word):
        if word not in self.word_to_index:
            self.word_to_index[word] = self.num_words
            self.word_to_count[word] = 1
            self.index_to_word[self.num_words] = word
            self.num_words += 1
        else:
            self.word_to_count[word] += 1

    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = [word for word, count in self.word_to_count.items() if count >= min_count]

        # Save the counts for the kept words
        keep_word_counts = {word: self.word_to_count[word] for word in keep_words}

        # Reinitialize dictionaries
        self.word_to_index, self.word_to_count, self.index_to_word = {"PAD":PAD_TOKEN,"SOS":SOS_TOKEN, "EOS":EOS_TOKEN}, {}, {PAD_TOKEN: "PAD", SOS_TOKEN: "SOS", EOS_TOKEN: "EOS"}
        self.num_words = 3  # Reset to count default tokens

        for word in keep_words:
            self.word_to_index[word] = self.num_words
            self.word_to_count[word] = keep_word_counts[word]
            self.index_to_word[self.num_words] = word
            self.num_words += 1

        # Provide a report on the trimming process
        print(f'keep_words {len(keep_words)} / {len(self.index_to_word) - 3} = '
              f'{len(keep_words) / (len(self.index_to_word) - 3):.4f}')

# Helper function to add multiple sentences to a Vocabulary instance
def add_sentences_to_vocabulary(vocab, sentences):
    for sentence in sentences:
        vocab.add_sentence(sentence)

# %% [markdown]
# We can now compile our vocabulary and query/response sentence pairs. However, before we can utilize this data, we need to carry out some preprocessing steps.
#
# Initially, we need to transform the Unicode strings into ASCII using `unicodeToAscii`. Subsequently, we should convert all characters to lowercase and remove all non-letter characters, excluding basic punctuation (`normalize_string`). Lastly, to facilitate training convergence, we will exclude sentences exceeding the `MAX_LENGTH` threshold.

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII
def normalize_string(s):
    """
    Normalize the string: Convert to ASCII, make lowercase, strip leading/trailing whitespace,
    separate punctuation with spaces, and remove non-letter characters. 
    """  
    s = unicodedata.normalize('NFD', s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", re.sub(r"[^a-zA-Z.!?]+", r" ", s))
    s = re.sub(r"\s+", r" ", s).strip()
    
    return s

def load_prepare_data(corpus_name, datafile):
    """
    Load and prepare data: Open the datafile, split into lines, normalize,
    filter by length, create a vocabulary, and add each sentence to it.
    """
    with open(datafile, encoding='utf-8') as file:
        lines = [line.split('\t') for line in file.read().strip().split('\n')]
    pairs = [[normalize_string(s) for s in pair] for pair in lines]
    pairs = [pair for pair in pairs if all(len(s.split()) < MAX_LENGTH for s in pair)]
    voc = Vocabulary(corpus_name)
    for pair in pairs:
        for s in pair:
            voc.add_sentence(s)
    return voc, pairs

# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = load_prepare_data(corpus_name, datafile)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# pairs:
# ['they do not !', 'they do to !']
# ['i hope so .', 'she okay ?']
# ['let s go .', 'wow']
# ['like my fear of wearing pastels ?', 'the real you .']
# ['the real you .', 'what good stuff ?']
# ['what crap ?', 'do you listen to this crap ?']
# ['you always been this selfish ?', 'but']
# ['but', 'then that s all you had to say .']
# ['then that s all you had to say .', 'well no . . .']
# ['tons', 'have fun tonight ?']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1) Trim words used under ``MIN_COUNT`` threshold using the ``voc.trim``
#    function.
#
# 2) Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trim_rare_words(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word_to_index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word_to_index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trim_rare_words(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7832 / 7832 = 1.0000
# Trimmed from 64259 pairs to 53074, 0.8259 of total

# %% [markdown]
# ### Data Preparation for Models
#
# Despite our extensive efforts to curate and process our data into a convenient vocabulary object and list of sentence pairs, our models will ultimately require numerical torch tensors as inputs.
#
#  To accommodate sentences of different sizes in the same batch, we will create our batched input tensor of shape (max_length, batch_size), where sentences shorter than the max_length are zero padded after an EOS_token.
#
# If we simply convert our English sentences to tensors by converting words to their indexes and zero-pad, our tensor would have shape (batch_size, max_length) and indexing the first dimension would return a full sequence across all time-steps. However, we need to be able to index our batch along time, and across all sequences in the batch. Therefore, we transpose our input batch shape to (max_length, batch_size), so that indexing across the first dimension returns a time step across all sentences in the batch.
#
# The output function palso returns a binary mask tensor and a maximum target sentence length. The binary mask tensor has the same shape as the output target tensor, but every element that is a PAD_token is 0 and all others are 1.
#
# `batch_to_train_data` simply takes a bunch of pairs and returns the input and target tensors using the aforementioned functions.

# %%
import itertools
import torch
import random

# Assuming PAD_token and EOS_token are defined with their respective integral values

def indexes_from_sentence(vocabulary, sentence):
    """
    Convert sentence to a list of indexes, appending the EOS token at the end.
    """
    return [vocabulary.word_to_index[word] for word in sentence.split(' ')] + [EOS_TOKEN]

def binary_matrix(l, value=PAD_TOKEN):
    """
    Create a binary matrix representing the padding of sentences.
    """
    return [[0 if token == value else 1 for token in seq] for seq in l]

def batch_to_train_data(vocabulary, pair_batch):
    """
    Prepare the batch for training: sort by input length, create tensors for input/target variables.
    """
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = zip(*pair_batch)
    input_indexes = [indexes_from_sentence(vocabulary, sentence) for sentence in input_batch]
    input_lengths = torch.tensor([len(indexes) for indexes in input_indexes])
    input_padded = torch.LongTensor(list(itertools.zip_longest(*input_indexes, fillvalue=PAD_TOKEN)))

    output_indexes = [indexes_from_sentence(vocabulary, sentence) for sentence in output_batch]
    output_padded = torch.LongTensor(list(itertools.zip_longest(*output_indexes, fillvalue=PAD_TOKEN)))
    output_mask = torch.BoolTensor(binary_matrix(output_padded))
    max_target_len = max(len(indexes) for indexes in output_indexes)

    return input_padded, input_lengths, output_padded, output_mask, max_target_len

# Example for validation
small_batch_size = 5
batches = batch_to_train_data(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  24,    8,   24,    8, 1255],
#         [ 495,  203, 4291,   53, 7267],
#         [3199,    5,   11,   11,   11],
#         [ 468, 7014,    2,    2,    2],
#         [ 105,   11,    0,    0,    0],
#         [  24,    2,    0,    0,    0],
#         [ 466,    0,    0,    0,    0],
#         [  11,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 6, 4, 4, 4])
# target_variable: tensor([[  67,    8,   27,    8,   76],
#         [  16,  203, 3313,  263,   90],
#         [  64, 7010,  300,   81,   81],
#         [ 595,   26,   14,   11,   14],
#         [1380,   77,    2,    2,    2],
#         [  11,  592,    0,    0,    0],
#         [   2,  331,    0,    0,    0],
#         [   0, 7014,    0,    0,    0],
#         [   0,   11,    0,    0,    0],
#         [   0,    2,    0,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True, False, False, False],
#         [ True,  True, False, False, False],
#         [False,  True, False, False, False],
#         [False,  True, False, False, False],
#         [False,  True, False, False, False]])
# max_target_len: 10

# %% [markdown]
# ## Training Procedure Definition
#
# ### Loss with Masking
#
# Given that we're working with batches of padded sequences, we can't compute loss using all tensor elements. We establish `mask_nll_loss` to compute our loss based on the decoder's output tensor, the target tensor, and a binary mask tensor that indicates the padding of the target tensor. This loss function computes the average negative log likelihood of the elements that align with a *1* in the mask tensor.

# %%
def mask_nll_loss(inp, target, mask, device):
    """
    Calculate the negative log likelihood loss with a mask over the lengths of target sequences.
    """
    n_total = mask.sum()
    cross_entropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = cross_entropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, n_total.item()

# %% [markdown]
# ### Single Training Iteration Procedure
#
# The `train` function encapsulates the process for a single training iteration (a single batch of inputs).
#
# We employ two strategies to aid convergence:
#
# -  **Teacher forcing**: At a probability determined by `teacher_forcing_ratio`, we use the current target word as the decoder’s next input instead of the decoder’s current guess. This helps in efficient training but can cause instability during inference. Hence, the `teacher_forcing_ratio` must be set carefully.
#
# -  **Gradient clipping**: This technique counters the "exploding gradient" problem by capping gradients to a maximum value, preventing them from growing exponentially and causing overflow or overshooting steep cost function cliffs.
#
# **Procedure:**
#
#    1) Pass the entire input batch through the encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Pass the input batch sequence through the decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
# Note: PyTorch’s RNN modules (`RNN`, `LSTM`, `GRU`) can be used like any other non-recurrent layers by passing them the entire input sequence. We use the `GRU` layer like this in the `encoder`. However, you can also run these modules one time-step at a time, as we do for the `decoder` model.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_TOKEN for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# ### Training Iterations
#
# Now we can integrate the complete training procedure with the data. The `train_iters` function executes `n_iterations` of training using the provided models, optimizers, data, etc. Most of the complex work is handled by the `train` function.
#
# It's important to note that when we save our model, we store a tarball that includes the encoder and decoder `state_dicts` (parameters), the optimizers' `state_dicts`, the loss, the iteration, etc. Saving the model in this way provides maximum flexibility with the checkpoint. After loading a checkpoint, we can either use the model parameters to run inference or continue training from where we left off.

# %%
def train_iters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding,
                encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every,
                clip, corpus_name):
    """
    Run training for a set number of iterations.
    """
    # Load batches for each iteration
    training_batches = [batch_to_train_data(voc, [random.choice(pairs) for _ in range(batch_size)])
                        for _ in range(n_iteration)]

    print('Initializing ...')
    start_iteration = 1
    print_loss_total = 0  # Reset every print_every

    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss_total += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print(f"Iteration: {iteration}; Percent complete: {iteration / n_iteration * 100:.1f}%; Average loss: {print_loss_avg:.4f}")
            print_loss_total = 0

        # Save checkpoint
        if iteration % save_every == 0:
            directory = os.path.join(save_dir, model_name, corpus_name, f'{encoder_n_layers}-{decoder_n_layers}_{hidden_features}')
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, f'{iteration}_checkpoint.tar'))

# %% [markdown]
# ## Evaluation
#
# After training the model, we want to interact with the bot. We need to define how the model decodes the encoded input.
#
# ### Greedy Decoding
#
# Greedy decoding is used during training when we're not using teacher forcing. At each time step, we choose the word from `decoder_output` with the highest softmax value. This method is optimal at a single time-step level.
#
# We define a `GreedySearchDecoder` class to perform greedy decoding. The input sentence is evaluated as follows:
#
# **Computation Steps:**
#
#    1) Pass input through the encoder model.
#    2) Prepare the encoder's final hidden layer to be the first hidden input to the decoder.
#    3) Initialize the decoder's first input as SOS_token.
#    4) Initialize tensors to append decoded words to.
#    5) Iteratively decode one word token at a time:
#        a) Pass through the decoder.
#        b) Obtain the most likely word token and its softmax score.
#        c) Record the token and score.
#        d) Prepare the current token to be the next decoder input.
#    6) Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        """
        Greedy decoding module initialization.
        """
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        """
        Forward propagation of the input to produce a sequence of tokens.
        """
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)

        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]

        # Initialize decoder input with SOS_token
        decoder_input = torch.tensor([[SOS_TOKEN]], device=device, dtype=torch.long)

        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros(0, dtype=torch.long, device=device)
        all_scores = torch.zeros(0, device=device)

        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)

            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)

            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)

            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)

        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# ### Text Evaluation
#
# With our decoding method defined, we can create functions to evaluate a string input sentence. The `evaluate` function handles the input sentence, it formats the sentence as an input batch of word indexes with *batch_size==1*. This is done by converting the sentence words to their corresponding indexes and transposing the dimensions to prepare the tensor for our models. A `lengths` tensor is also created which contains the length of our input sentence. The decoded response sentence tensor is obtained using our `GreedySearchDecoder` object (`searcher`). Finally, the response’s indexes are converted to words and the list of decoded words is returned.
#
# `evaluate_input` serves as the user interface for our chatbot. It prompts an input text field where we can enter our query sentence. After entering our input sentence and pressing *Enter*, our text is normalized like our training data, and is fed to the `evaluate` function to obtain a decoded output sentence. This process is looped for continuous interaction with our bot until we enter either “q” or “quit”.
#
# If a sentence is entered that contains a word not in the vocabulary, an error message is printed and the user is prompted to enter another sentence.

# %%
def evaluate(searcher, voc, sentence, max_length=MAX_LENGTH):
    """
    Evaluate a sentence using the encoder, decoder, and searcher provided.
    """
    # Prepare the input sentence as a batch of word indexes
    indexes_batch = [indexes_from_sentence(voc, sentence)]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1).to(device)
    lengths = lengths.to("cpu")  # Lengths need to be on CPU for pack_padded_sequence

    # Decode the sentence with the searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    decoded_words = [voc.index_to_word[token.item()] for token in tokens]

    return decoded_words

def evaluate_input(encoder, decoder, searcher, voc):
    """
    Interactively evaluate input from the user.
    """
    while True:
        try:
            input_sentence = input('> ')
            if input_sentence in ('q', 'quit'):
                break
            print (input_sentence)
            input_sentence = normalize_string(input_sentence)
            output_words = evaluate(searcher, voc, input_sentence)
            output_words = [word for word in output_words if word not in ('EOS', 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ## Models Overview
#
# ### Seq2Seq Model
#
# Our chatbot uses a sequence-to-sequence (seq2seq) model, which takes a variable-length sequence as input and returns a variable-length sequence as output. This is achieved by using two separate recurrent neural nets (RNNs): an **encoder** and a **decoder**. The encoder encodes the input sequence into a fixed-length context vector, which theoretically contains semantic information about the input sentence. The decoder takes an input word and the context vector, and returns a guess for the next word in the sequence and a hidden state for the next iteration.
#
# ### Encoder
#
# The encoder RNN iterates through the input sentence one token at a time, outputting an "output" vector and a "hidden state" vector at each time step. The hidden state vector is passed to the next time step, while the output vector is recorded. The encoder uses a multi-layered Gated Recurrent Unit (GRU) and a bidirectional variant of the GRU. An `embedding` layer is used to encode our word indices in an arbitrarily sized feature space.
#
# ### Decoder
#
# The decoder RNN generates the response sentence in a token-by-token fashion. It uses the encoder’s context vectors, and internal hidden states to generate the next word in the sequence. To avoid information loss, especially when dealing with long input sequences, an "attention mechanism" is typically used that allows the decoder to pay attention to certain parts of the input sequence, rather than using the entire fixed context at every step. However, in this tutorial, we only consider the use of standard RNNs, which will limit the performance of our model.

# %%
# Set configuration parameters for the model
model_name = 'cb_model'
hidden_features = 500
in_features=hidden_features
encoder_n_layers = 2
decoder_n_layers = 2
rnn_type = 'GRU'
dropout = 0.1
batch_size = 64

# Set training and optimization parameters
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

embedding = nn.Embedding(voc.num_words, hidden_features)
# Initialize the EncoderRNN
encoder =dl.EncoderRNN(
    in_features=in_features, 
    hidden_features=hidden_features,
    num_layers=encoder_n_layers, 
    embedding=embedding,
    rnn_type=rnn_type, 
    dropout=dropout
).to(device)


encoder.build()
print(encoder)

decoder =dl.DecoderRNN(
    in_features=in_features, 
    hidden_features=hidden_features,
    out_features=voc.num_words,
    num_layers=decoder_n_layers, 
    embedding=embedding,
    rnn_type=rnn_type, 
    dropout=dropout
).to(device)


encoder.build()
print(decoder)
# Out:
# EncoderRNN(
#   (blocks): LayerList(
#     (0): GRU(500, 500, num_layers=2, dropout=0.1)
#   )
#   (rnn): GRU(500, 500, num_layers=2, dropout=0.1)
#   (embedding): Embedding(7835, 500)
# )
# DecoderRNN(
#   (blocks): LayerList(
#     (0): GRU(500, 500, num_layers=2, dropout=0.1)
#   )
#   (rnn): GRU(500, 500, num_layers=2, dropout=0.1)
#   (embedding): Embedding(7835, 500)
#   (embedding_dropout): Dropout(p=0.1, inplace=False)
#   (out): Linear(in_features=500, out_features=7835, bias=True)
# )

# %% [markdown]
# ## Define and train model
#
# Now, we're ready to run our model!
#
# Whether we're training or testing the chatbot model, we need to initialize the encoder and decoder models. In the next block, we configure the parameters, and construct and initialize the models. You're encouraged to experiment with different model configurations to enhance performance.

# %%
# Initialize word embeddings and encoder & decoder models
# Set models to training mode
encoder.train()
decoder.train()

# Initialize optimizers for the encoder and decoder
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

# Move optimizer states to GPU if necessary
if torch.cuda.is_available():
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

# Begin the training process
train_iters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name)
# Out:
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9828
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8544
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.7097
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.5482
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.3108
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.9890
# Iteration: 7; Percent complete: 0.2%; Average loss: 7.6131
# Iteration: 8; Percent complete: 0.2%; Average loss: 7.0363
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.5861
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.5028
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.2936
# Iteration: 12; Percent complete: 0.3%; Average loss: 6.0369
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.8092
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.4931
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.1215
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.3872
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.2979
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.0792
# Iteration: 19; Percent complete: 0.5%; Average loss: 5.1494
# Iteration: 20; Percent complete: 0.5%; Average loss: 4.9287
# Iteration: 21; Percent complete: 0.5%; Average loss: 5.1301
# Iteration: 22; Percent complete: 0.5%; Average loss: 4.8403
# Iteration: 23; Percent complete: 0.6%; Average loss: 5.0435
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.7565
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.9039
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.8459
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.7667
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.7920
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.8018
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.8646
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.7719
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.8745
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.7808
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.7812
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.7843
# Iteration: 36; Percent complete: 0.9%; Average loss: 5.0301
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.8084
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.8156
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.6134
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.8124
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.8815
# Iteration: 42; Percent complete: 1.1%; Average loss: 4.7130
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.5875
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.4790
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.8840
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.6796
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.8463
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.7740
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.5904
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.9179
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.5800
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.6262
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.5496
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.6303
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.7886
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.8601
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.6060
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.7280
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.6271
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.8939
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.7104
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.9935
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.5842
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.7353
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.5096
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.8348
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.5467
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.6556
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.6016
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.6413
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.6222
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.6204
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.6286
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.3451
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.6297
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.7078
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.5863
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.4846
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.5617
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.2561
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.4238
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.4372
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.5041
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.5157
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.6086
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.5418
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.6136
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.4285
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.4244
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.2734
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.6316
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.4186
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.5408
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.6825
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.3012
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.5199
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.4332
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.3654
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.4309
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.3793
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.4622
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.3775
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.4846
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.5029
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.0698
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.3653
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.4638
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.5222
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.2968
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.3566
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.5088
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.2959
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.4859
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.3121
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.4872
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.6039
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.2757
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.4811
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.6881
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.3497
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.3186
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.3844
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.3458
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.5160
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.5528
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.1954
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.1697
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.4390
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.2090
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.2948
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.0303
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.1160
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.3684
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.2269
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.4275
# Iteration: 136; Percent complete: 3.4%; Average loss: 3.9848
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.2373
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.3839
# Iteration: 139; Percent complete: 3.5%; Average loss: 4.1218
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.2840
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.3144
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.1891
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.2173
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.0072
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.0473
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.2424
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.1647
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.3034
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.0014
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.1578
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.0153
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.1835
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.3271
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.0899
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.1625
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.1112
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.1095
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.1393
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.2757
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.2966
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.1348
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.1706
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.2010
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.0549
# Iteration: 165; Percent complete: 4.1%; Average loss: 3.9411
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.0545
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.1151
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.1136
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.1239
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.0996
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.1031
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.1147
# Iteration: 173; Percent complete: 4.3%; Average loss: 4.1055
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.4140
# Iteration: 175; Percent complete: 4.4%; Average loss: 3.9216
# Iteration: 176; Percent complete: 4.4%; Average loss: 3.8513
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.3559
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.2135
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.0671
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.1892
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.0432
# Iteration: 182; Percent complete: 4.5%; Average loss: 3.9163
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.2411
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.2306
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.0902
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.1294
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.1413
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.1136
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.1215
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.2027
# Iteration: 191; Percent complete: 4.8%; Average loss: 4.0191
# Iteration: 192; Percent complete: 4.8%; Average loss: 3.8820
# Iteration: 193; Percent complete: 4.8%; Average loss: 3.9941
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.1492
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.2259
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.2533
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.1285
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.1023
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.3118
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.0249
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.4364
# Iteration: 202; Percent complete: 5.1%; Average loss: 3.8321
# Iteration: 203; Percent complete: 5.1%; Average loss: 4.1227
# Iteration: 204; Percent complete: 5.1%; Average loss: 4.2443
# Iteration: 205; Percent complete: 5.1%; Average loss: 4.0268
# Iteration: 206; Percent complete: 5.1%; Average loss: 3.9454
# Iteration: 207; Percent complete: 5.2%; Average loss: 3.8562
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.2614
# Iteration: 209; Percent complete: 5.2%; Average loss: 3.8805
# Iteration: 210; Percent complete: 5.2%; Average loss: 3.9736
# Iteration: 211; Percent complete: 5.3%; Average loss: 4.4195
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.3091
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.0596
# Iteration: 214; Percent complete: 5.3%; Average loss: 4.1506
# Iteration: 215; Percent complete: 5.4%; Average loss: 4.1378
# Iteration: 216; Percent complete: 5.4%; Average loss: 3.9643
# Iteration: 217; Percent complete: 5.4%; Average loss: 4.0229
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.1084
# Iteration: 219; Percent complete: 5.5%; Average loss: 4.0242
# Iteration: 220; Percent complete: 5.5%; Average loss: 3.9011
# Iteration: 221; Percent complete: 5.5%; Average loss: 4.2687
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.0828
# Iteration: 223; Percent complete: 5.6%; Average loss: 3.8788
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.1678
# Iteration: 225; Percent complete: 5.6%; Average loss: 3.9628
# Iteration: 226; Percent complete: 5.7%; Average loss: 4.0808
# Iteration: 227; Percent complete: 5.7%; Average loss: 4.0065
# Iteration: 228; Percent complete: 5.7%; Average loss: 3.7385
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.0101
# Iteration: 230; Percent complete: 5.8%; Average loss: 3.7908
# Iteration: 231; Percent complete: 5.8%; Average loss: 3.9814
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.0363
# Iteration: 233; Percent complete: 5.8%; Average loss: 3.9703
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.1956
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.2020
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.1155
# Iteration: 237; Percent complete: 5.9%; Average loss: 4.0779
# Iteration: 238; Percent complete: 5.9%; Average loss: 3.9388
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.3101
# Iteration: 240; Percent complete: 6.0%; Average loss: 4.3247
# Iteration: 241; Percent complete: 6.0%; Average loss: 3.7862
# Iteration: 242; Percent complete: 6.0%; Average loss: 4.0586
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.0584
# Iteration: 244; Percent complete: 6.1%; Average loss: 4.4293
# Iteration: 245; Percent complete: 6.1%; Average loss: 4.1070
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.6732
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.0070
# Iteration: 248; Percent complete: 6.2%; Average loss: 3.8121
# Iteration: 249; Percent complete: 6.2%; Average loss: 4.1101
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.0919
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.9871
# Iteration: 252; Percent complete: 6.3%; Average loss: 4.1176
# Iteration: 253; Percent complete: 6.3%; Average loss: 3.8283
# Iteration: 254; Percent complete: 6.3%; Average loss: 4.0880
# Iteration: 255; Percent complete: 6.4%; Average loss: 3.7521
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.8818
# Iteration: 257; Percent complete: 6.4%; Average loss: 4.1423
# Iteration: 258; Percent complete: 6.5%; Average loss: 3.9955
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.8570
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.0373
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.8460
# Iteration: 262; Percent complete: 6.6%; Average loss: 4.0897
# Iteration: 263; Percent complete: 6.6%; Average loss: 3.9775
# Iteration: 264; Percent complete: 6.6%; Average loss: 3.9529
# Iteration: 265; Percent complete: 6.6%; Average loss: 4.0515
# Iteration: 266; Percent complete: 6.7%; Average loss: 4.0571
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.8963
# Iteration: 268; Percent complete: 6.7%; Average loss: 3.8981
# Iteration: 269; Percent complete: 6.7%; Average loss: 3.9570
# Iteration: 270; Percent complete: 6.8%; Average loss: 3.9046
# Iteration: 271; Percent complete: 6.8%; Average loss: 4.0925
# Iteration: 272; Percent complete: 6.8%; Average loss: 4.1194
# Iteration: 273; Percent complete: 6.8%; Average loss: 4.1911
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.9694
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.9329
# Iteration: 276; Percent complete: 6.9%; Average loss: 3.8702
# Iteration: 277; Percent complete: 6.9%; Average loss: 3.9518
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.8164
# Iteration: 279; Percent complete: 7.0%; Average loss: 3.9309
# Iteration: 280; Percent complete: 7.0%; Average loss: 4.1009
# Iteration: 281; Percent complete: 7.0%; Average loss: 3.9451
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.8041
# Iteration: 283; Percent complete: 7.1%; Average loss: 3.9734
# Iteration: 284; Percent complete: 7.1%; Average loss: 4.0626
# Iteration: 285; Percent complete: 7.1%; Average loss: 4.0513
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.9133
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.7595
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.7651
# Iteration: 289; Percent complete: 7.2%; Average loss: 4.0100
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.1795
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.9076
# Iteration: 292; Percent complete: 7.3%; Average loss: 3.8644
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.0234
# Iteration: 294; Percent complete: 7.3%; Average loss: 3.7549
# Iteration: 295; Percent complete: 7.4%; Average loss: 3.7516
# Iteration: 296; Percent complete: 7.4%; Average loss: 4.1887
# Iteration: 297; Percent complete: 7.4%; Average loss: 3.8602
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.9807
# Iteration: 299; Percent complete: 7.5%; Average loss: 3.7769
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.9665
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.7953
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.6828
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.7417
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.9152
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.7580
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.6502
# Iteration: 307; Percent complete: 7.7%; Average loss: 3.7831
# Iteration: 308; Percent complete: 7.7%; Average loss: 3.9406
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.8905
# Iteration: 310; Percent complete: 7.8%; Average loss: 4.0581
# Iteration: 311; Percent complete: 7.8%; Average loss: 3.9336
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.7561
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.9579
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.0852
# Iteration: 315; Percent complete: 7.9%; Average loss: 3.9204
# Iteration: 316; Percent complete: 7.9%; Average loss: 4.0064
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.6197
# Iteration: 318; Percent complete: 8.0%; Average loss: 4.0129
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.9912
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.6932
# Iteration: 321; Percent complete: 8.0%; Average loss: 3.8245
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.7914
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.6902
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.8445
# Iteration: 325; Percent complete: 8.1%; Average loss: 3.7620
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.7694
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.9450
# Iteration: 328; Percent complete: 8.2%; Average loss: 4.0840
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.7045
# Iteration: 330; Percent complete: 8.2%; Average loss: 4.0598
# Iteration: 331; Percent complete: 8.3%; Average loss: 3.6178
# Iteration: 332; Percent complete: 8.3%; Average loss: 4.0476
# Iteration: 333; Percent complete: 8.3%; Average loss: 4.1139
# Iteration: 334; Percent complete: 8.3%; Average loss: 3.7242
# Iteration: 335; Percent complete: 8.4%; Average loss: 3.5191
# Iteration: 336; Percent complete: 8.4%; Average loss: 3.7250
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.9808
# Iteration: 338; Percent complete: 8.5%; Average loss: 3.7185
# Iteration: 339; Percent complete: 8.5%; Average loss: 3.7236
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.8134
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.9703
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.7198
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.8159
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.7432
# Iteration: 345; Percent complete: 8.6%; Average loss: 3.9435
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.8654
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.8214
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.9319
# Iteration: 349; Percent complete: 8.7%; Average loss: 4.0361
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.6394
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.6508
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.6164
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.7878
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.6200
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.9430
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.6175
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.5691
# Iteration: 358; Percent complete: 8.9%; Average loss: 4.2077
# Iteration: 359; Percent complete: 9.0%; Average loss: 3.8326
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.9698
# Iteration: 361; Percent complete: 9.0%; Average loss: 3.7381
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.7923
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.7874
# Iteration: 364; Percent complete: 9.1%; Average loss: 3.5028
# Iteration: 365; Percent complete: 9.1%; Average loss: 3.7159
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.6365
# Iteration: 367; Percent complete: 9.2%; Average loss: 4.0229
# Iteration: 368; Percent complete: 9.2%; Average loss: 4.0004
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.6708
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.8091
# Iteration: 371; Percent complete: 9.3%; Average loss: 4.1366
# Iteration: 372; Percent complete: 9.3%; Average loss: 3.8583
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.6931
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.7413
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.8994
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.9243
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.7808
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.6800
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.8718
# Iteration: 380; Percent complete: 9.5%; Average loss: 3.7154
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.0233
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.8898
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.4947
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.8163
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.6226
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.9308
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.7312
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.7609
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.7333
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.6833
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.6416
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.6408
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.8587
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.7140
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.7636
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.9847
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.7690
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.9290
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.9237
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.5801
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.7404
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.8451
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.7899
# Iteration: 404; Percent complete: 10.1%; Average loss: 3.9208
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.8112
# Iteration: 406; Percent complete: 10.2%; Average loss: 4.0740
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.9135
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.8268
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.6114
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.7809
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.6214
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.8653
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.6919
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.5550
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.8856
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.8246
# Iteration: 417; Percent complete: 10.4%; Average loss: 3.5682
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.7580
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.6686
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.7134
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.7867
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.8194
# Iteration: 423; Percent complete: 10.6%; Average loss: 3.5651
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.7720
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.7712
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.6662
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.7882
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.6117
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.7739
# Iteration: 430; Percent complete: 10.8%; Average loss: 4.0443
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.7731
# Iteration: 432; Percent complete: 10.8%; Average loss: 3.9497
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.6532
# Iteration: 434; Percent complete: 10.8%; Average loss: 4.0127
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.7572
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.7210
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.8065
# Iteration: 438; Percent complete: 10.9%; Average loss: 3.9355
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.8271
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.6279
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.9016
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.7933
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.6882
# Iteration: 444; Percent complete: 11.1%; Average loss: 4.0156
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.5291
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.9600
# Iteration: 447; Percent complete: 11.2%; Average loss: 4.0019
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.9519
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.6735
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.8266
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.5410
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.7216
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.6169
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.7035
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.6810
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.7629
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.7404
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.3678
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.7714
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.8486
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.8925
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.8354
# Iteration: 463; Percent complete: 11.6%; Average loss: 3.8895
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.6708
# Iteration: 465; Percent complete: 11.6%; Average loss: 3.8067
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.5964
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.6360
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.4724
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.9207
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.6825
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.8840
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.7568
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.7807
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.8767
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.5173
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.7955
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.5074
# Iteration: 478; Percent complete: 11.9%; Average loss: 4.0728
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.8980
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.6468
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.6636
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.8057
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.7546
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.3282
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.9466
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.8236
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.4127
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.6458
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.4860
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.9490
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.7639
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.8580
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.8123
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.8355
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.6817
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.8497
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.7975
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.8764
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.6253
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.8525
# Iteration: 501; Percent complete: 12.5%; Average loss: 4.0367
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.6641
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.7249
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.8200
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.9447
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.8030
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.5666
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.6575
# Iteration: 509; Percent complete: 12.7%; Average loss: 3.5959
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.7422
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.8545
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.7104
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.5469
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.6221
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.4583
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.6315
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.5906
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.6268
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.7818
# Iteration: 520; Percent complete: 13.0%; Average loss: 4.1925
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.5794
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.7588
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.8834
# Iteration: 524; Percent complete: 13.1%; Average loss: 3.5615
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.7374
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.3619
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.7874
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.6225
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.4058
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.3832
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.6176
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.6800
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.9347
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.6155
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.6810
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.7719
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.7078
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.7272
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.7507
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.8172
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.5371
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.5061
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.7474
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.7291
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.6926
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.6627
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.5736
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.7109
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.5578
# Iteration: 550; Percent complete: 13.8%; Average loss: 3.6550
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.6465
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.7557
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.7563
# Iteration: 554; Percent complete: 13.9%; Average loss: 3.5221
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.7195
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.5956
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.5638
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.8181
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.7316
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.5495
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.5766
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.7136
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.2904
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.9532
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.6285
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.6520
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.6815
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.6117
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.8424
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.9078
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.8346
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.6605
# Iteration: 573; Percent complete: 14.3%; Average loss: 4.0321
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.7646
# Iteration: 575; Percent complete: 14.4%; Average loss: 4.0246
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.5765
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.8197
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.7142
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.6279
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.5058
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.7139
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.8860
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.2962
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.7176
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.4902
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.7922
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.4609
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.6067
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.8247
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.9205
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.7912
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.7816
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.5180
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.6366
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.5861
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.6871
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.4307
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.4984
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.8435
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.5335
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.5829
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.6778
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.8674
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.5684
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.7929
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.5474
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.7159
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.3529
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.6062
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.7204
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.7213
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.4646
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.5516
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.6047
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.6876
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.6811
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.6523
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.9689
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.4878
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.5895
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.7732
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.6510
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.7669
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.6176
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.6589
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.5712
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.4313
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.6026
# Iteration: 629; Percent complete: 15.7%; Average loss: 3.2950
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.5131
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.5495
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.8605
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.6321
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.9019
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.7988
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.4753
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.3216
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.6406
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.5583
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.6901
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.5936
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.4720
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.7047
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.7342
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.5601
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.7119
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.6728
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.5308
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.5926
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.5939
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.5578
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.4506
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.7447
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.4486
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.7445
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.5194
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.7320
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.6242
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.3260
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.6393
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.7781
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.4413
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.5745
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.4964
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.4700
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.4965
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.6601
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.4980
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.6464
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.4027
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.8476
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.7761
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.5887
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.4457
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.5061
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.5962
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.6875
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.5761
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.7261
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.5512
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.5212
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.3118
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.5580
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.7782
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.4728
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.8450
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.5828
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.6197
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.7874
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.6218
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.7104
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.7057
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.2835
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.6144
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.7604
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.6836
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.8554
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.5440
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.4010
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.7464
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.6317
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.8309
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.4773
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.7861
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.4903
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.6472
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.4504
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.4771
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.6772
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.6210
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.5115
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.6054
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.5912
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.6463
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.5250
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.8411
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.5443
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.7504
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.3384
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.4563
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.3977
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.6434
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.6325
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.6836
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.7617
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.5690
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.7069
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.9965
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.6930
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.7126
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.4244
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.4404
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.2768
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.6890
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.5798
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.4926
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.6392
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.2829
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.4345
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.2610
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.4948
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.7431
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.5006
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.4622
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.7737
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.4912
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.5126
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.4620
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.4919
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.5399
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.4033
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.5377
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.3993
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.4711
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.4886
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.3263
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.7668
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.8425
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.5434
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.5199
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.5287
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.4305
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.2979
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.6535
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.7821
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.4268
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.5540
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.3503
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.8588
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.3691
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.7513
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.5533
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.7314
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.6676
# Iteration: 775; Percent complete: 19.4%; Average loss: 3.3587
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.5643
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.6780
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.3285
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.6963
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.3206
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.5265
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 2.7320
# Iteration: 3749; Percent complete: 93.7%; Average loss: 2.8582
# Iteration: 3750; Percent complete: 93.8%; Average loss: 2.4495
# Iteration: 3751; Percent complete: 93.8%; Average loss: 2.7691
# Iteration: 3752; Percent complete: 93.8%; Average loss: 2.5668
# Iteration: 3753; Percent complete: 93.8%; Average loss: 2.6499
# Iteration: 3754; Percent complete: 93.8%; Average loss: 2.8310
# Iteration: 3755; Percent complete: 93.9%; Average loss: 2.4903
# Iteration: 3756; Percent complete: 93.9%; Average loss: 2.7576
# Iteration: 3757; Percent complete: 93.9%; Average loss: 2.8613
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.5979
# Iteration: 3759; Percent complete: 94.0%; Average loss: 2.6131
# Iteration: 3760; Percent complete: 94.0%; Average loss: 3.0861
# Iteration: 3761; Percent complete: 94.0%; Average loss: 2.7031
# Iteration: 3762; Percent complete: 94.0%; Average loss: 2.6201
# Iteration: 3763; Percent complete: 94.1%; Average loss: 2.9783
# Iteration: 3764; Percent complete: 94.1%; Average loss: 2.8381
# Iteration: 3765; Percent complete: 94.1%; Average loss: 2.7077
# Iteration: 3766; Percent complete: 94.2%; Average loss: 2.6095
# Iteration: 3767; Percent complete: 94.2%; Average loss: 2.7826
# Iteration: 3768; Percent complete: 94.2%; Average loss: 2.5945
# Iteration: 3769; Percent complete: 94.2%; Average loss: 2.5389
# Iteration: 3770; Percent complete: 94.2%; Average loss: 2.8364
# Iteration: 3771; Percent complete: 94.3%; Average loss: 2.9195
# Iteration: 3772; Percent complete: 94.3%; Average loss: 2.6872
# Iteration: 3773; Percent complete: 94.3%; Average loss: 2.6074
# Iteration: 3774; Percent complete: 94.3%; Average loss: 2.7660
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.5643
# Iteration: 3776; Percent complete: 94.4%; Average loss: 2.6479
# Iteration: 3777; Percent complete: 94.4%; Average loss: 2.6911
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.5933
# Iteration: 3779; Percent complete: 94.5%; Average loss: 2.5328
# Iteration: 3780; Percent complete: 94.5%; Average loss: 2.6350
# Iteration: 3781; Percent complete: 94.5%; Average loss: 2.7939
# Iteration: 3782; Percent complete: 94.5%; Average loss: 2.8050
# Iteration: 3783; Percent complete: 94.6%; Average loss: 2.8085
# Iteration: 3784; Percent complete: 94.6%; Average loss: 2.4064
# Iteration: 3785; Percent complete: 94.6%; Average loss: 2.7582
# Iteration: 3786; Percent complete: 94.7%; Average loss: 2.7884
# Iteration: 3787; Percent complete: 94.7%; Average loss: 2.5055
# Iteration: 3788; Percent complete: 94.7%; Average loss: 2.7323
# Iteration: 3789; Percent complete: 94.7%; Average loss: 2.7000
# Iteration: 3790; Percent complete: 94.8%; Average loss: 2.6263
# Iteration: 3791; Percent complete: 94.8%; Average loss: 2.6176
# Iteration: 3792; Percent complete: 94.8%; Average loss: 2.5831
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.7576
# Iteration: 3794; Percent complete: 94.8%; Average loss: 2.4369
# Iteration: 3795; Percent complete: 94.9%; Average loss: 2.5556
# Iteration: 3796; Percent complete: 94.9%; Average loss: 2.9071
# Iteration: 3797; Percent complete: 94.9%; Average loss: 2.7948
# Iteration: 3798; Percent complete: 95.0%; Average loss: 2.9065
# Iteration: 3799; Percent complete: 95.0%; Average loss: 2.6730
# Iteration: 3800; Percent complete: 95.0%; Average loss: 2.6933
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.9294
# Iteration: 3802; Percent complete: 95.0%; Average loss: 2.8083
# Iteration: 3803; Percent complete: 95.1%; Average loss: 2.5698
# Iteration: 3804; Percent complete: 95.1%; Average loss: 2.5158
# Iteration: 3805; Percent complete: 95.1%; Average loss: 3.0017
# Iteration: 3806; Percent complete: 95.2%; Average loss: 2.6610
# Iteration: 3807; Percent complete: 95.2%; Average loss: 2.6910
# Iteration: 3808; Percent complete: 95.2%; Average loss: 2.9083
# Iteration: 3809; Percent complete: 95.2%; Average loss: 2.8224
# Iteration: 3810; Percent complete: 95.2%; Average loss: 2.5356
# Iteration: 3811; Percent complete: 95.3%; Average loss: 2.8567
# Iteration: 3812; Percent complete: 95.3%; Average loss: 2.7025
# Iteration: 3813; Percent complete: 95.3%; Average loss: 2.4261
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.7545
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.6515
# Iteration: 3816; Percent complete: 95.4%; Average loss: 2.4733
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.7331
# Iteration: 3818; Percent complete: 95.5%; Average loss: 2.7690
# Iteration: 3819; Percent complete: 95.5%; Average loss: 2.6779
# Iteration: 3820; Percent complete: 95.5%; Average loss: 2.7538
# Iteration: 3821; Percent complete: 95.5%; Average loss: 2.6028
# Iteration: 3822; Percent complete: 95.5%; Average loss: 2.7777
# Iteration: 3823; Percent complete: 95.6%; Average loss: 2.4600
# Iteration: 3824; Percent complete: 95.6%; Average loss: 2.6292
# Iteration: 3825; Percent complete: 95.6%; Average loss: 3.0282
# Iteration: 3826; Percent complete: 95.7%; Average loss: 2.7878
# Iteration: 3827; Percent complete: 95.7%; Average loss: 2.7557
# Iteration: 3828; Percent complete: 95.7%; Average loss: 2.5431
# Iteration: 3829; Percent complete: 95.7%; Average loss: 2.8154
# Iteration: 3830; Percent complete: 95.8%; Average loss: 2.6839
# Iteration: 3831; Percent complete: 95.8%; Average loss: 2.7921
# Iteration: 3832; Percent complete: 95.8%; Average loss: 2.5201
# Iteration: 3833; Percent complete: 95.8%; Average loss: 2.6451
# Iteration: 3834; Percent complete: 95.9%; Average loss: 2.6419
# Iteration: 3835; Percent complete: 95.9%; Average loss: 2.8697
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.6299
# Iteration: 3837; Percent complete: 95.9%; Average loss: 2.5939
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.8523
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.6204
# Iteration: 3840; Percent complete: 96.0%; Average loss: 2.5877
# Iteration: 3841; Percent complete: 96.0%; Average loss: 2.5673
# Iteration: 3842; Percent complete: 96.0%; Average loss: 2.7902
# Iteration: 3843; Percent complete: 96.1%; Average loss: 2.5048
# Iteration: 3844; Percent complete: 96.1%; Average loss: 2.7759
# Iteration: 3845; Percent complete: 96.1%; Average loss: 2.7774
# Iteration: 3846; Percent complete: 96.2%; Average loss: 2.7680
# Iteration: 3847; Percent complete: 96.2%; Average loss: 2.7026
# Iteration: 3848; Percent complete: 96.2%; Average loss: 2.5690
# Iteration: 3849; Percent complete: 96.2%; Average loss: 2.8420
# Iteration: 3850; Percent complete: 96.2%; Average loss: 2.6313
# Iteration: 3851; Percent complete: 96.3%; Average loss: 2.7186
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.6803
# Iteration: 3853; Percent complete: 96.3%; Average loss: 2.6201
# Iteration: 3854; Percent complete: 96.4%; Average loss: 2.6152
# Iteration: 3855; Percent complete: 96.4%; Average loss: 2.7597
# Iteration: 3856; Percent complete: 96.4%; Average loss: 2.5782
# Iteration: 3857; Percent complete: 96.4%; Average loss: 2.8573
# Iteration: 3858; Percent complete: 96.5%; Average loss: 2.7363
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.5883
# Iteration: 3860; Percent complete: 96.5%; Average loss: 2.7673
# Iteration: 3861; Percent complete: 96.5%; Average loss: 2.8205
# Iteration: 3862; Percent complete: 96.5%; Average loss: 2.6984
# Iteration: 3863; Percent complete: 96.6%; Average loss: 2.8291
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.6422
# Iteration: 3865; Percent complete: 96.6%; Average loss: 2.8232
# Iteration: 3866; Percent complete: 96.7%; Average loss: 2.5784
# Iteration: 3867; Percent complete: 96.7%; Average loss: 2.7304
# Iteration: 3868; Percent complete: 96.7%; Average loss: 2.5236
# Iteration: 3869; Percent complete: 96.7%; Average loss: 2.8446
# Iteration: 3870; Percent complete: 96.8%; Average loss: 2.9277
# Iteration: 3871; Percent complete: 96.8%; Average loss: 2.6702
# Iteration: 3872; Percent complete: 96.8%; Average loss: 2.6658
# Iteration: 3873; Percent complete: 96.8%; Average loss: 2.5692
# Iteration: 3874; Percent complete: 96.9%; Average loss: 2.7648
# Iteration: 3875; Percent complete: 96.9%; Average loss: 2.3270
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.6234
# Iteration: 3877; Percent complete: 96.9%; Average loss: 2.8349
# Iteration: 3878; Percent complete: 97.0%; Average loss: 2.7078
# Iteration: 3879; Percent complete: 97.0%; Average loss: 2.6183
# Iteration: 3880; Percent complete: 97.0%; Average loss: 2.5212
# Iteration: 3881; Percent complete: 97.0%; Average loss: 2.7909
# Iteration: 3882; Percent complete: 97.0%; Average loss: 2.7544
# Iteration: 3883; Percent complete: 97.1%; Average loss: 2.7694
# Iteration: 3884; Percent complete: 97.1%; Average loss: 2.6611
# Iteration: 3885; Percent complete: 97.1%; Average loss: 2.4844
# Iteration: 3886; Percent complete: 97.2%; Average loss: 2.7184
# Iteration: 3887; Percent complete: 97.2%; Average loss: 2.7544
# Iteration: 3888; Percent complete: 97.2%; Average loss: 2.6119
# Iteration: 3889; Percent complete: 97.2%; Average loss: 2.8318
# Iteration: 3890; Percent complete: 97.2%; Average loss: 2.9592
# Iteration: 3891; Percent complete: 97.3%; Average loss: 2.7041
# Iteration: 3892; Percent complete: 97.3%; Average loss: 2.7342
# Iteration: 3893; Percent complete: 97.3%; Average loss: 2.7314
# Iteration: 3894; Percent complete: 97.4%; Average loss: 2.5844
# Iteration: 3895; Percent complete: 97.4%; Average loss: 2.7745
# Iteration: 3896; Percent complete: 97.4%; Average loss: 2.4716
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.8454
# Iteration: 3898; Percent complete: 97.5%; Average loss: 2.5989
# Iteration: 3899; Percent complete: 97.5%; Average loss: 2.4907
# Iteration: 3900; Percent complete: 97.5%; Average loss: 2.6292
# Iteration: 3901; Percent complete: 97.5%; Average loss: 2.7204
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.7269
# Iteration: 3903; Percent complete: 97.6%; Average loss: 2.8160
# Iteration: 3904; Percent complete: 97.6%; Average loss: 2.6991
# Iteration: 3905; Percent complete: 97.6%; Average loss: 2.5300
# Iteration: 3906; Percent complete: 97.7%; Average loss: 2.7723
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.6560
# Iteration: 3908; Percent complete: 97.7%; Average loss: 2.6704
# Iteration: 3909; Percent complete: 97.7%; Average loss: 2.6971
# Iteration: 3910; Percent complete: 97.8%; Average loss: 2.6589
# Iteration: 3911; Percent complete: 97.8%; Average loss: 2.7653
# Iteration: 3912; Percent complete: 97.8%; Average loss: 2.5487
# Iteration: 3913; Percent complete: 97.8%; Average loss: 2.7486
# Iteration: 3914; Percent complete: 97.9%; Average loss: 2.6515
# Iteration: 3915; Percent complete: 97.9%; Average loss: 2.5095
# Iteration: 3916; Percent complete: 97.9%; Average loss: 2.8051
# Iteration: 3917; Percent complete: 97.9%; Average loss: 2.8555
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.8150
# Iteration: 3919; Percent complete: 98.0%; Average loss: 2.7121
# Iteration: 3920; Percent complete: 98.0%; Average loss: 2.8412
# Iteration: 3921; Percent complete: 98.0%; Average loss: 2.7119
# Iteration: 3922; Percent complete: 98.0%; Average loss: 2.6807
# Iteration: 3923; Percent complete: 98.1%; Average loss: 2.5680
# Iteration: 3924; Percent complete: 98.1%; Average loss: 2.7980
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.7287
# Iteration: 3926; Percent complete: 98.2%; Average loss: 2.7895
# Iteration: 3927; Percent complete: 98.2%; Average loss: 2.6541
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.5854
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.7705
# Iteration: 3930; Percent complete: 98.2%; Average loss: 2.6686
# Iteration: 3931; Percent complete: 98.3%; Average loss: 2.5701
# Iteration: 3932; Percent complete: 98.3%; Average loss: 2.5202
# Iteration: 3933; Percent complete: 98.3%; Average loss: 2.9162
# Iteration: 3934; Percent complete: 98.4%; Average loss: 2.3578
# Iteration: 3935; Percent complete: 98.4%; Average loss: 2.7700
# Iteration: 3936; Percent complete: 98.4%; Average loss: 2.7434
# Iteration: 3937; Percent complete: 98.4%; Average loss: 2.7590
# Iteration: 3938; Percent complete: 98.5%; Average loss: 2.6301
# Iteration: 3939; Percent complete: 98.5%; Average loss: 2.4172
# Iteration: 3940; Percent complete: 98.5%; Average loss: 2.8720
# Iteration: 3941; Percent complete: 98.5%; Average loss: 2.6493
# Iteration: 3942; Percent complete: 98.6%; Average loss: 2.6218
# Iteration: 3943; Percent complete: 98.6%; Average loss: 2.5270
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.8197
# Iteration: 3945; Percent complete: 98.6%; Average loss: 2.7405
# Iteration: 3946; Percent complete: 98.7%; Average loss: 2.7740
# Iteration: 3947; Percent complete: 98.7%; Average loss: 2.5851
# Iteration: 3948; Percent complete: 98.7%; Average loss: 2.8951
# Iteration: 3949; Percent complete: 98.7%; Average loss: 2.7033
# Iteration: 3950; Percent complete: 98.8%; Average loss: 2.6423
# Iteration: 3951; Percent complete: 98.8%; Average loss: 2.6792
# Iteration: 3952; Percent complete: 98.8%; Average loss: 2.5665
# Iteration: 3953; Percent complete: 98.8%; Average loss: 2.7032
# Iteration: 3954; Percent complete: 98.9%; Average loss: 2.5359
# Iteration: 3955; Percent complete: 98.9%; Average loss: 2.5355
# Iteration: 3956; Percent complete: 98.9%; Average loss: 2.5682
# Iteration: 3957; Percent complete: 98.9%; Average loss: 2.5367
# Iteration: 3958; Percent complete: 99.0%; Average loss: 2.7376
# Iteration: 3959; Percent complete: 99.0%; Average loss: 2.6666
# Iteration: 3960; Percent complete: 99.0%; Average loss: 2.6436
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.5932
# Iteration: 3962; Percent complete: 99.1%; Average loss: 2.6989
# Iteration: 3963; Percent complete: 99.1%; Average loss: 2.4960
# Iteration: 3964; Percent complete: 99.1%; Average loss: 2.6070
# Iteration: 3965; Percent complete: 99.1%; Average loss: 2.5983
# Iteration: 3966; Percent complete: 99.2%; Average loss: 2.5954
# Iteration: 3967; Percent complete: 99.2%; Average loss: 2.9377
# Iteration: 3968; Percent complete: 99.2%; Average loss: 2.7139
# Iteration: 3969; Percent complete: 99.2%; Average loss: 2.8650
# Iteration: 3970; Percent complete: 99.2%; Average loss: 2.5412
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.7355
# Iteration: 3972; Percent complete: 99.3%; Average loss: 2.7657
# Iteration: 3973; Percent complete: 99.3%; Average loss: 2.7178
# Iteration: 3974; Percent complete: 99.4%; Average loss: 2.6452
# Iteration: 3975; Percent complete: 99.4%; Average loss: 2.7680
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.5574
# Iteration: 3977; Percent complete: 99.4%; Average loss: 2.5721
# Iteration: 3978; Percent complete: 99.5%; Average loss: 2.5493
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.6967
# Iteration: 3980; Percent complete: 99.5%; Average loss: 2.5671
# Iteration: 3981; Percent complete: 99.5%; Average loss: 2.6239
# Iteration: 3982; Percent complete: 99.6%; Average loss: 2.6240
# Iteration: 3983; Percent complete: 99.6%; Average loss: 2.7786
# Iteration: 3984; Percent complete: 99.6%; Average loss: 3.0018
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.5411
# Iteration: 3986; Percent complete: 99.7%; Average loss: 2.5925
# Iteration: 3987; Percent complete: 99.7%; Average loss: 2.6162
# Iteration: 3988; Percent complete: 99.7%; Average loss: 2.6012
# Iteration: 3989; Percent complete: 99.7%; Average loss: 2.6390
# Iteration: 3990; Percent complete: 99.8%; Average loss: 2.6554
# Iteration: 3991; Percent complete: 99.8%; Average loss: 2.9166
# Iteration: 3992; Percent complete: 99.8%; Average loss: 2.6608
# Iteration: 3993; Percent complete: 99.8%; Average loss: 2.7085
# Iteration: 3994; Percent complete: 99.9%; Average loss: 2.5471
# Iteration: 3995; Percent complete: 99.9%; Average loss: 2.7661
# Iteration: 3996; Percent complete: 99.9%; Average loss: 2.7808
# Iteration: 3997; Percent complete: 99.9%; Average loss: 2.4779
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.5445
# Iteration: 3999; Percent complete: 100.0%; Average loss: 2.6533
# Iteration: 4000; Percent complete: 100.0%; Average loss: 2.4128

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluate_input(encoder, decoder, searcher, voc)
# Out:
# hello
# Bot: hello ? ! ! ! !
# how are you?
# Bot: you re right . in there ?
# I sure am
# Bot: you re a cop . s holding .
# how did you know?
# Bot: i didn t know . s dead .
# alright
# Bot: i m sorry . in the car ?
# what?
# Bot: you know what i mean . ?
# she's in the car?
# Bot: i m going to take a while . ?
# goodbye
# Bot: i m sorry . in the car ?

# %% [markdown]
# Let's review the changes made to incorporate conversation history into your chatbot model training and evaluation:
# ### Changes for Training with Conversation History
#
# create_history_pairs Function: This function creates training pairs that include the history of the conversation. For each exchange in the pairs, it appends a certain number of previous exchanges (up to MAX_HISTORY) separated by the <EOS> token. These pairs are then used for training.
#
# Batch Preparation (batch_to_train_data): The function for preparing a batch of training data remains largely the same. The only difference is that it now handles input sequences that include conversation history.
#
# Training Function (train):
#     The core training logic remains unchanged.
#     The function receives input sequences that now contain conversation history.
#     The forward pass through the encoder and the decoding steps are performed as usual, without any specific changes needed to accommodate the conversation history.
#
# Data Preparation for Training:
#     The history_pairs are generated using the create_history_pairs function.
#     These pairs are then used throughout the training process.
#
# ### Changes for Evaluation with Conversation History
#
# evaluate Function:
#     The conversation history is now considered when evaluating a new input.
#     The history is concatenated with the current input sentence, separated by spaces.
#     The concatenated string is then processed and fed into the model for generating a response.
#
# evaluate_input Function:
#     Manages interactive evaluation with the user.
#     Maintains a conversation_history list, appending each user input and the model's response to it.
#     Passes the accumulated conversation history to the evaluate function for each new input.
#
# ### Training and Evaluation Process
#
# The model is trained with input sequences that include conversation history, allowing it to learn the context of the conversation.
# During evaluation, the model uses the accumulated conversation history to generate more context-aware responses.
#
# ### General Setup
#
# Model, optimizer, and training configurations are set according to your specifications.
# The training process (train_iters) follows the standard approach but uses the modified input pairs with conversation history.
#
# ### Important Notes
#
# The effectiveness of including conversation history in the model depends on the depth of context the model can understand and how well it can handle longer input sequences.
# Fine-tuning and experimenting with the MAX_HISTORY parameter and the MAX_LENGTH of sequences may be necessary to achieve optimal performance.

# %%
MAX_LENGTH = 10  # Maximum length of a single sentence, adjust as necessary
MAX_HISTORY = 5  # Number of previous exchanges to include in the history

def create_history_pairs(pairs, max_history=MAX_HISTORY):
    history_pairs = []
    for i in range(len(pairs)):
        dialogue_history = ' EOS '.join([pairs[j][0] for j in range(max(0, i-max_history), i)])
        history_pairs.append([dialogue_history, pairs[i][1]])
    return history_pairs

def zero_padding(l, fillvalue=0):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binary_matrix(l, value=0):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == value:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

def output_var(l, voc):
    indexes_batch = [indexes_from_sentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    pad_list = zero_padding(indexes_batch)
    mask = binary_matrix(pad_list)
    mask = torch.BoolTensor(mask)
    pad_var = torch.LongTensor(pad_list)
    return pad_var, mask, max_target_len

def indexes_from_sentence(voc, sentence):
    #return [voc.word_to_index[word] for word in sentence.split(' ')] + [EOS_TOKEN]
    return [voc.word_to_index[word] for word in sentence.split()] + [EOS_TOKEN] 

def batch_to_train_data(voc, pair_batch):
    pair_batch.sort(key=lambda p: len(p[0].split()), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = input_var(input_batch, voc)
    output, mask, max_target_len = output_var(output_batch, voc)
    return inp, lengths, output, mask, max_target_len

# Input_var function needs to calculate the correct lengths for packed sequences
def input_var(l, voc):
    indexes_batch = [indexes_from_sentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    pad_list = zero_padding(indexes_batch)
    pad_var = torch.LongTensor(pad_list)
    return pad_var, lengths
# Prepare the data with history
history_pairs = create_history_pairs(pairs)

# Modify the training function to handle the dialogue history in the input sequences
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_TOKEN for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

def train_iters(model_name, voc, history_pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding,
                encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every,
                clip, corpus_name):
    """
    Run training for a set number of iterations.
    """
    # Load batches for each iteration
    training_batches = [batch_to_train_data(voc, [random.choice(history_pairs) for _ in range(batch_size)])
                        for _ in range(n_iteration)]

    print('Initializing ...')
    start_iteration = 1
    print_loss_total = 0  # Reset every print_every

    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss_total += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print(f"Iteration: {iteration}; Percent complete: {iteration / n_iteration * 100:.1f}%; Average loss: {print_loss_avg:.4f}")
            print_loss_total = 0

        # Save checkpoint
        if iteration % save_every == 0:
            directory = os.path.join(save_dir, model_name, corpus_name, f'{encoder_n_layers}-{decoder_n_layers}_{hidden_features}')
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, f'{iteration}_checkpoint.tar'))

def evaluate(searcher, voc, conversation_history, max_length=MAX_LENGTH):
    """
    Evaluate a conversation history using the encoder, decoder, and searcher provided.
    """
    # Join the conversation history into a single input and normalize
    input_sentence = ' '.join(conversation_history)
    input_sentence = normalize_string(input_sentence)

    # Prepare the input sentence as a batch of word indexes
    indexes_batch = [indexes_from_sentence(voc, input_sentence)]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1).to(device)
    lengths = lengths.to("cpu")  # Lengths need to be on CPU for pack_padded_sequence

    # Decode the sentence with the searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    decoded_words = [voc.index_to_word[token.item()] for token in tokens]

    return decoded_words


def evaluate_input(searcher, voc):
    """
    Interactively evaluate input from the user, considering the entire conversation history.
    """
    conversation_history = []
    while True:
        try:
            input_sentence = input('> ')
            if input_sentence in ('q', 'quit'):
                break

            # Normalize and add the user's input to the conversation history
            input_sentence = normalize_string(input_sentence)
            conversation_history.append(input_sentence)

            # Evaluate the conversation history
            output_words = evaluate(searcher, voc, conversation_history)
            output_words = [word for word in output_words if word not in ('EOS', 'PAD')]
            print('Bot:', ' '.join(output_words))

            # Add the bot's response to the conversation history
            conversation_history.extend(output_words)
            conversation_history=conversation_history[-MAX_HISTORY*MAX_LENGTH:]
            
        except KeyError:
            print("Error: Encountered unknown word.")

# Set configuration parameters for the model
model_name = 'cb_model'
hidden_features = 2000
in_features=hidden_features
encoder_n_layers = 4
decoder_n_layers = 4
dropout = 0.1
batch_size = 64

# Set training and optimization parameters
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 16000
print_every = 1
save_every = 8000

# Initialize word embeddings and encoder & decoder models
embedding = nn.Embedding(voc.num_words, hidden_features)
# Initialize the EncoderRNN
encoder =dl.EncoderRNN(
    in_features=in_features, 
    hidden_features=hidden_features,
    num_layers=encoder_n_layers, 
    embedding=embedding,
    rnn_type=rnn_type, 
    dropout=dropout
).to(device)

decoder =dl.DecoderRNN(
    in_features=in_features, 
    hidden_features=hidden_features,
    out_features=voc.num_words,
    num_layers=decoder_n_layers, 
    embedding=embedding,
    rnn_type=rnn_type, 
    dropout=dropout
).to(device)

encoder.build()
decoder.build()
# Set models to training mode
encoder.train()
decoder.train()

# Initialize optimizers for the encoder and decoder
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

# Move optimizer states to GPU if necessary
if torch.cuda.is_available():
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

# %%
# Begin the training process
train_iters(model_name, voc, history_pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name)
# Out:
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9714
# Iteration: 2; Percent complete: 0.0%; Average loss: 8.5552
# Iteration: 3; Percent complete: 0.0%; Average loss: 8.3447
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ccx55\OneDrive\Documents\GitHub\deeplay\NLPRNN_non_DL.ipynb Cell 33 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> # Begin the training process
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> train_iters(model_name, voc, history_pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
#       <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a>            embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
#       <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a>            print_every, save_every, clip, corpus_name)
#
# c:\Users\ccx55\OneDrive\Documents\GitHub\deeplay\NLPRNN_non_DL.ipynb Cell 33 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=148'>149</a> input_variable, lengths, target_variable, mask, max_target_len = training_batch
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=150'>151</a> # Run a training iteration with batch
# --> <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=151'>152</a> loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=152'>153</a>              decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=153'>154</a> print_loss_total += loss
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=155'>156</a> # Print progress
#
# c:\Users\ccx55\OneDrive\Documents\GitHub\deeplay\NLPRNN_non_DL.ipynb Cell 33 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=116'>117</a>         n_totals += nTotal
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=118'>119</a> # Perform backpropagation
# --> <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=119'>120</a> loss.backward()
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=121'>122</a> # Clip gradients: gradients are modified in place
#     <a href='vscode-notebook-cell:/c%3A/Users/ccx55/OneDrive/Documents/GitHub/deeplay/NLPRNN_non_DL.ipynb#X44sZmlsZQ%3D%3D?line=122'>123</a> _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
#
# File c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File c:\Users\ccx55\Anaconda3\envs\DLCC\Lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
def evaluate(searcher, voc, conversation_history, max_length=MAX_LENGTH):
    """
    Evaluate a conversation history using the encoder, decoder, and searcher provided.
    """
    # Join the conversation history into a single input and normalize
    input_sentence = ' '.join(conversation_history)
    input_sentence = normalize_string(input_sentence)
    input_sentence=input_sentence.replace("eos","EOS")
    
    # Prepare the input sentence as a batch of word indexes
    indexes_batch = [indexes_from_sentence(voc, input_sentence)]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1).to(device)
    lengths = lengths.to("cpu")  # Lengths need to be on CPU for pack_padded_sequence

    # Decode the sentence with the searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    decoded_words = [voc.index_to_word[token.item()] for token in tokens]

    return decoded_words

def evaluate_input(searcher, voc):
    """
    Interactively evaluate input from the user, considering the entire conversation history.
    """
    conversation_history = []
    while True:
        try:
            input_sentence = input('> ')
            if input_sentence in ('q', 'quit'):
                break

            # Normalize and add the user's input to the conversation history
            print(input_sentence)
            input_sentence = normalize_string(input_sentence)
            conversation_history.append(input_sentence)
            conversation_history.append("EOS")


            # Evaluate the conversation history
            output_words = evaluate(searcher, voc, conversation_history)
            print('Bot:', ' '.join([word for word in output_words if word not in ('EOS', 'PAD')]))

            # Add the bot's response to the conversation history
            conversation_history.extend(output_words)
            conversation_history=conversation_history[-MAX_HISTORY*MAX_LENGTH:]
            

        except KeyError:
            print("Error: Encountered unknown word.")

# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluate_input(searcher, voc)
# Out:
# hello
# Bot: . . . . . . . . . .
# alright
# Bot: . . . . . . . . . .
# what?
# Bot: . . . . . . . . . .
