# %% [markdown]
# In this guide, we delve into an engaging and intriguing application of recurrent sequence-to-sequence models by training a basic chatbot using film scripts from the Cornell Movie-Dialogs Corpus.
#
# Conversational models are currently a trending subject in the field of AI research. Chatbots are commonly used in various scenarios such as customer service platforms and online help desks. These bots typically utilize retrieval-based models that provide pre-set responses to specific types of questions. While these models might be adequate for highly specific domains like a company's IT helpdesk, they lack the robustness required for broader applications. However, the recent surge in deep learning, spearheaded recently by ChatGPT, has led to the development of potent multi-domain generative conversational models. In this guide, we will create one such model using the tools we have learnt so far.
#
# To begin, download the dialog dataset:
#
# https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html (should be replaced with direct data source for DLCC)
#
# and put in a ``data/`` directory under the current directory.

# %% [markdown]
# https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import csv
import re
import os
import unicodedata
from io import open
import json

# Check for CUDA availability for PyTorch
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# Mount Google Drive if using Google Colab
#from google.colab import drive
#drive.mount('/content/gdrive')
#os.chdir("/content/gdrive/My Drive")

# %% [markdown]
# ## Data Loading and Preprocessing
#
# This step involves reorganizing our data file and loading the data into formats that are manageable.
#
# The [Cornell Movie-Dialogs Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html) is a comprehensive dataset of dialogues from movie characters:
#
# - It contains 220,579 conversational exchanges between 10,292 pairs of movie characters.
# - It features 9,035 characters from 617 movies.
# - It has a total of 304,713 utterances.
#
# This dataset is vast and varied, with a wide range of language formality, time periods, sentiment, etc. We anticipate that this diversity will make our model capable of handling a variety of inputs and queries.
#
# Initially, we will examine some lines from our data file to understand the original format.

# %%
# Set the corpus name
corpus_name = "movie-corpus"

# Function to print first 'n' lines from a file
def print_lines(file, n=10):
    with open(file, 'r', encoding='utf-8') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line.strip())

print_lines(os.path.join(corpus_name, "utterances.jsonl"))
# Out:
# {"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}
# {"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}
# {"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L925", "conversation_id": "L924", "text": "Let's go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}
# {"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L872", "conversation_id": "L870", "text": "Okay -- you're gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}
# {"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}
# {"id": "L870", "conversation_id": "L870", "text": "I'm kidding.  You know how sometimes you just become this \"persona\"?  And you don't know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\"", "tag": "''", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n't", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}
# {"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}

# %% [markdown]
# ### Generate Formatted Data File
#
# For ease of use, we will generate a well-structured data file where each line comprises a tab-separated pair of a *query sentence* and a *response sentence*.
#
# The functions below aid in parsing the raw `utterances.jsonl` data file.
#
# - `loadLinesAndConversations` breaks down each line of the file into a dictionary of lines with fields: `lineID`, `characterID`, and text, and then groups these into conversations with fields: `conversationID`, `movieID`, and lines.
# - `extractSentencePairs` pulls out pairs of sentences from the conversations.

# %%
# Load lines and conversations
def load_data(file_name):
    lines, conversations = {}, {}
    with open(file_name, 'r', encoding='iso-8859-1') as file:
        for line in file:
            data = json.loads(line)
            lines[data["id"]] = {"lineID": data["id"], "characterID": data["speaker"], "text": data["text"]}
            conv_id = data["conversation_id"]
            if conv_id not in conversations:
                conversations[conv_id] = {
                    "conversationID": conv_id,
                    "movieID": data["meta"]["movie_id"],
                    "lines": [lines[data["id"]]]
                }
            else:
                conversations[conv_id]["lines"].append(lines[data["id"]])
    return lines, conversations

# Extract sentence pairs from conversations
def extract_pairs(conversations):
    return [[input_line["text"].strip(), target_line["text"].strip()]
            for conversation in conversations.values()
            for input_line, target_line in zip(conversation["lines"], conversation["lines"][1:])
            if input_line["text"].strip() and target_line["text"].strip()]
    
# Processing and writing to file
def process_and_write(corpus_name):
    # Define path to new file
    datafile = os.path.join(corpus_name, "formatted_movie_lines.txt")
    delimiter = '\t'  # Tab character, no need to unescape

    # Load lines and conversations
    print("\nProcessing corpus into lines and conversations...")
    lines, conversations = load_data(os.path.join(corpus_name, "utterances.jsonl"))

    # Write new csv file
    print("\nWriting newly formatted file...")
    with open(datafile, 'w', encoding='utf-8') as outputfile:
        writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
        for pair in extract_pairs(conversations):
            writer.writerow(pair)

    # Print a sample of lines (assuming a function printLines exists)
    print("\nSample lines from file:")
    # If printLines is not defined, we can simply print the first few lines from the file
    with open(datafile, 'r', encoding='utf-8') as file:
        for _ in range(5):  # Print first 5 lines as a sample
            print(file.readline().strip())
    return datafile

datafile=process_and_write(corpus_name)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# They do not!	They do to!
# I hope so.	She okay?
# Let's go.	Wow
# Okay -- you're gonna need to learn how to lie.	No
# No	"I'm kidding.  You know how sometimes you just become this ""persona""?  And you don't know how to quit?"

# %% [markdown]
# ### Data Loading and Trimming
#
# The next step involves creating a vocabulary and loading query/response sentence pairs into memory.
#
# Keep in mind that we are working with sequences of **words**, which do not inherently map to a discrete numerical space. Therefore, we need to create such a mapping by associating each unique word we encounter in our dataset with an index value.
#
# To achieve this, we define a `Vocabulary` class, which maintains a mapping from words to indexes, a reverse mapping from indexes to words, a count of each word, and a total word count. The class offers methods for adding a word to the vocabulary (`add_word`), adding all words in a sentence (`add_sentence`), and trimming infrequently seen words (`trim`). We will discuss trimming in more detail later.

# %%
# Default word tokens
PAD_TOKEN = 0  # Used for padding short sentences
SOS_TOKEN = 1  # Start-of-sentence token
EOS_TOKEN = 2  # End-of-sentence token

class Vocabulary:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word_to_index = {"PAD":PAD_TOKEN,"SOS":SOS_TOKEN, "EOS":EOS_TOKEN}
        self.word_to_count = {}
        self.index_to_word = {PAD_TOKEN: "PAD", SOS_TOKEN: "SOS", EOS_TOKEN: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def add_sentence(self, sentence):
        for word in sentence.split():
            self.add_word(word)

    def add_word(self, word):
        if word not in self.word_to_index:
            self.word_to_index[word] = self.num_words
            self.word_to_count[word] = 1
            self.index_to_word[self.num_words] = word
            self.num_words += 1
        else:
            self.word_to_count[word] += 1

    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = [word for word, count in self.word_to_count.items() if count >= min_count]

        # Save the counts for the kept words
        keep_word_counts = {word: self.word_to_count[word] for word in keep_words}

        # Reinitialize dictionaries
        self.word_to_index, self.word_to_count, self.index_to_word = {"PAD":PAD_TOKEN,"SOS":SOS_TOKEN, "EOS":EOS_TOKEN}, {}, {PAD_TOKEN: "PAD", SOS_TOKEN: "SOS", EOS_TOKEN: "EOS"}
        self.num_words = 3  # Reset to count default tokens

        for word in keep_words:
            self.word_to_index[word] = self.num_words
            self.word_to_count[word] = keep_word_counts[word]
            self.index_to_word[self.num_words] = word
            self.num_words += 1

        # Provide a report on the trimming process
        print(f'keep_words {len(keep_words)} / {len(self.index_to_word) - 3} = '
              f'{len(keep_words) / (len(self.index_to_word) - 3):.4f}')

# Helper function to add multiple sentences to a Vocabulary instance
def add_sentences_to_vocabulary(vocab, sentences):
    for sentence in sentences:
        vocab.add_sentence(sentence)

# %% [markdown]
# We can now compile our vocabulary and query/response sentence pairs. However, before we can utilize this data, we need to carry out some preprocessing steps.
#
# Initially, we need to transform the Unicode strings into ASCII using `unicodeToAscii`. Subsequently, we should convert all characters to lowercase and remove all non-letter characters, excluding basic punctuation (`normalize_string`). Lastly, to facilitate training convergence, we will exclude sentences exceeding the `MAX_LENGTH` threshold.

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII
def normalize_string(s):
    """
    Normalize the string: Convert to ASCII, make lowercase, strip leading/trailing whitespace,
    separate punctuation with spaces, and remove non-letter characters. 
    """  
    s = unicodedata.normalize('NFD', s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", re.sub(r"[^a-zA-Z.!?]+", r" ", s))
    s = re.sub(r"\s+", r" ", s).strip()
    
    return s

def load_prepare_data(corpus_name, datafile):
    """
    Load and prepare data: Open the datafile, split into lines, normalize,
    filter by length, create a vocabulary, and add each sentence to it.
    """
    with open(datafile, encoding='utf-8') as file:
        lines = [line.split('\t') for line in file.read().strip().split('\n')]
    pairs = [[normalize_string(s) for s in pair] for pair in lines]
    pairs = [pair for pair in pairs if all(len(s.split()) < MAX_LENGTH for s in pair)]
    voc = Vocabulary(corpus_name)
    for pair in pairs:
        for s in pair:
            voc.add_sentence(s)
    return voc, pairs

# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = load_prepare_data(corpus_name, datafile)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# pairs:
# ['they do not !', 'they do to !']
# ['i hope so .', 'she okay ?']
# ['let s go .', 'wow']
# ['like my fear of wearing pastels ?', 'the real you .']
# ['the real you .', 'what good stuff ?']
# ['what crap ?', 'do you listen to this crap ?']
# ['you always been this selfish ?', 'but']
# ['but', 'then that s all you had to say .']
# ['then that s all you had to say .', 'well no . . .']
# ['tons', 'have fun tonight ?']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1) Trim words used under ``MIN_COUNT`` threshold using the ``voc.trim``
#    function.
#
# 2) Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trim_rare_words(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word_to_index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word_to_index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trim_rare_words(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7832 / 7832 = 1.0000
# Trimmed from 64259 pairs to 53074, 0.8259 of total

# %% [markdown]
# ### Data Preparation for Models
#
# Despite our extensive efforts to curate and process our data into a convenient vocabulary object and list of sentence pairs, our models will ultimately require numerical torch tensors as inputs.
#
#  To accommodate sentences of different sizes in the same batch, we will create our batched input tensor of shape (max_length, batch_size), where sentences shorter than the max_length are zero padded after an EOS_token.
#
# If we simply convert our English sentences to tensors by converting words to their indexes and zero-pad, our tensor would have shape (batch_size, max_length) and indexing the first dimension would return a full sequence across all time-steps. However, we need to be able to index our batch along time, and across all sequences in the batch. Therefore, we transpose our input batch shape to (max_length, batch_size), so that indexing across the first dimension returns a time step across all sentences in the batch.
#
# The output function palso returns a binary mask tensor and a maximum target sentence length. The binary mask tensor has the same shape as the output target tensor, but every element that is a PAD_token is 0 and all others are 1.
#
# `batch_to_train_data` simply takes a bunch of pairs and returns the input and target tensors using the aforementioned functions.

# %%
import itertools
import torch
import random

# Assuming PAD_token and EOS_token are defined with their respective integral values

def indexes_from_sentence(vocabulary, sentence):
    """
    Convert sentence to a list of indexes, appending the EOS token at the end.
    """
    return [vocabulary.word_to_index[word] for word in sentence.split(' ')] + [EOS_TOKEN]

def binary_matrix(l, value=PAD_TOKEN):
    """
    Create a binary matrix representing the padding of sentences.
    """
    return [[0 if token == value else 1 for token in seq] for seq in l]

def batch_to_train_data(vocabulary, pair_batch):
    """
    Prepare the batch for training: sort by input length, create tensors for input/target variables.
    """
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = zip(*pair_batch)
    input_indexes = [indexes_from_sentence(vocabulary, sentence) for sentence in input_batch]
    input_lengths = torch.tensor([len(indexes) for indexes in input_indexes])
    input_padded = torch.LongTensor(list(itertools.zip_longest(*input_indexes, fillvalue=PAD_TOKEN)))

    output_indexes = [indexes_from_sentence(vocabulary, sentence) for sentence in output_batch]
    output_padded = torch.LongTensor(list(itertools.zip_longest(*output_indexes, fillvalue=PAD_TOKEN)))
    output_mask = torch.BoolTensor(binary_matrix(output_padded))
    max_target_len = max(len(indexes) for indexes in output_indexes)

    return input_padded, input_lengths, output_padded, output_mask, max_target_len

# Example for validation
small_batch_size = 5
batches = batch_to_train_data(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  26, 6058,   26, 1682,  276],
#         [  60,  105,    9,   11,   11],
#         [ 871,  139,   27,    2,    2],
#         [   7, 1212, 1851,    0,    0],
#         [ 577,   11,   28,    0,    0],
#         [ 382, 1582,   14,    0,    0],
#         [1263,   11,    2,    0,    0],
#         [  11,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 8, 7, 3, 3])
# target_variable: tensor([[ 145,  174,    8,   81,   80],
#         [  11,   14,    9,   16, 1551],
#         [   2,  223,   81, 1386,   16],
#         [   0,   14, 1851,   11, 7730],
#         [   0,    2,   28,    2,   14],
#         [   0,    0,   11,    0,    2],
#         [   0,    0,    2,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False, False,  True, False,  True],
#         [False, False,  True, False, False]])
# max_target_len: 7

# %% [markdown]
# ## Training Procedure Definition
#
# ### Loss with Masking
#
# Given that we're working with batches of padded sequences, we can't compute loss using all tensor elements. We establish `mask_nll_loss` to compute our loss based on the decoder's output tensor, the target tensor, and a binary mask tensor that indicates the padding of the target tensor. This loss function computes the average negative log likelihood of the elements that align with a *1* in the mask tensor.

# %%
def mask_nll_loss(inp, target, mask, device):
    """
    Calculate the negative log likelihood loss with a mask over the lengths of target sequences.
    """
    n_total = mask.sum()
    cross_entropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = cross_entropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, n_total.item()

# %% [markdown]
# ### Single Training Iteration Procedure
#
# The `train` function encapsulates the process for a single training iteration (a single batch of inputs).
#
# We employ two strategies to aid convergence:
#
# -  **Teacher forcing**: At a probability determined by `teacher_forcing_ratio`, we use the current target word as the decoder’s next input instead of the decoder’s current guess. This helps in efficient training but can cause instability during inference. Hence, the `teacher_forcing_ratio` must be set carefully.
#
# -  **Gradient clipping**: This technique counters the "exploding gradient" problem by capping gradients to a maximum value, preventing them from growing exponentially and causing overflow or overshooting steep cost function cliffs.
#
# **Procedure:**
#
#    1) Pass the entire input batch through the encoder.
#    2) Initialize decoder inputs as SOS_token, and hidden state as the encoder's final hidden state.
#    3) Pass the input batch sequence through the decoder one time step at a time.
#    4) If teacher forcing: set next decoder input as the current target; else: set next decoder input as current decoder output.
#    5) Calculate and accumulate loss.
#    6) Perform backpropagation.
#    7) Clip gradients.
#    8) Update encoder and decoder model parameters.
#
# Note: PyTorch’s RNN modules (`RNN`, `LSTM`, `GRU`) can be used like any other non-recurrent layers by passing them the entire input sequence. We use the `GRU` layer like this in the `encoder`. However, you can also run these modules one time-step at a time, as we do for the `decoder` model.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_TOKEN for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden,encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden,encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# ### Training Iterations
#
# Now we can integrate the complete training procedure with the data. The `train_iters` function executes `n_iterations` of training using the provided models, optimizers, data, etc. Most of the complex work is handled by the `train` function.
#
# It's important to note that when we save our model, we store a tarball that includes the encoder and decoder `state_dicts` (parameters), the optimizers' `state_dicts`, the loss, the iteration, etc. Saving the model in this way provides maximum flexibility with the checkpoint. After loading a checkpoint, we can either use the model parameters to run inference or continue training from where we left off.

# %%
def train_iters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding,
                encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every,
                clip, corpus_name):
    """
    Run training for a set number of iterations.
    """
    # Load batches for each iteration
    training_batches = [batch_to_train_data(voc, [random.choice(pairs) for _ in range(batch_size)])
                        for _ in range(n_iteration)]

    print('Initializing ...')
    start_iteration = 1
    print_loss_total = 0  # Reset every print_every

    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss_total += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print(f"Iteration: {iteration}; Percent complete: {iteration / n_iteration * 100:.1f}%; Average loss: {print_loss_avg:.4f}")
            print_loss_total = 0

        # Save checkpoint
        if iteration % save_every == 0:
            directory = os.path.join(save_dir, model_name, corpus_name, f'{encoder_n_layers}-{decoder_n_layers}_{hidden_features}')
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, f'{iteration}_checkpoint.tar'))

# %% [markdown]
# ## Evaluation
#
# After training the model, we want to interact with the bot. We need to define how the model decodes the encoded input.
#
# ### Greedy Decoding
#
# Greedy decoding is used during training when we're not using teacher forcing. At each time step, we choose the word from `decoder_output` with the highest softmax value. This method is optimal at a single time-step level.
#
# We define a `GreedySearchDecoder` class to perform greedy decoding. The input sentence is evaluated as follows:
#
# **Computation Steps:**
#
#    1) Pass input through the encoder model.
#    2) Prepare the encoder's final hidden layer to be the first hidden input to the decoder.
#    3) Initialize the decoder's first input as SOS_token.
#    4) Initialize tensors to append decoded words to.
#    5) Iteratively decode one word token at a time:
#        a) Pass through the decoder.
#        b) Obtain the most likely word token and its softmax score.
#        c) Record the token and score.
#        d) Prepare the current token to be the next decoder input.
#    6) Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        """
        Greedy decoding module initialization.
        """
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        """
        Forward propagation of the input to produce a sequence of tokens.
        """
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)

        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]

        # Initialize decoder input with SOS_token
        decoder_input = torch.tensor([[SOS_TOKEN]], device=device, dtype=torch.long)

        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros(0, dtype=torch.long, device=device)
        all_scores = torch.zeros(0, device=device)

        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)

            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)

            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)

            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)

        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# ### Text Evaluation
#
# With our decoding method defined, we can create functions to evaluate a string input sentence. The `evaluate` function handles the input sentence, it formats the sentence as an input batch of word indexes with *batch_size==1*. This is done by converting the sentence words to their corresponding indexes and transposing the dimensions to prepare the tensor for our models. A `lengths` tensor is also created which contains the length of our input sentence. The decoded response sentence tensor is obtained using our `GreedySearchDecoder` object (`searcher`). Finally, the response’s indexes are converted to words and the list of decoded words is returned.
#
# `evaluate_input` serves as the user interface for our chatbot. It prompts an input text field where we can enter our query sentence. After entering our input sentence and pressing *Enter*, our text is normalized like our training data, and is fed to the `evaluate` function to obtain a decoded output sentence. This process is looped for continuous interaction with our bot until we enter either “q” or “quit”.
#
# If a sentence is entered that contains a word not in the vocabulary, an error message is printed and the user is prompted to enter another sentence.

# %%
def evaluate(searcher, voc, sentence, max_length=MAX_LENGTH):
    """
    Evaluate a sentence using the encoder, decoder, and searcher provided.
    """
    # Prepare the input sentence as a batch of word indexes
    indexes_batch = [indexes_from_sentence(voc, sentence)]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1).to(device)
    lengths = lengths.to("cpu")  # Lengths need to be on CPU for pack_padded_sequence

    # Decode the sentence with the searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    decoded_words = [voc.index_to_word[token.item()] for token in tokens]

    return decoded_words

def evaluate_input(encoder, decoder, searcher, voc):
    """
    Interactively evaluate input from the user.
    """
    while True:
        try:
            input_sentence = input('> ')
            if input_sentence in ('q', 'quit'):
                break
            print (input_sentence)
            input_sentence = normalize_string(input_sentence)
            output_words = evaluate(searcher, voc, input_sentence)
            output_words = [word for word in output_words if word not in ('EOS', 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# ## Models Overview
#
# ### Seq2Seq Model
#
# Our chatbot uses a sequence-to-sequence (seq2seq) model, which takes a variable-length sequence as input and returns a variable-length sequence as output. This is achieved by using two separate recurrent neural nets (RNNs): an **encoder** and a **decoder**. The encoder encodes the input sequence into a fixed-length context vector, which theoretically contains semantic information about the input sentence. The decoder takes an input word and the context vector, and returns a guess for the next word in the sequence and a hidden state for the next iteration.
#
# ### Encoder
#
# The encoder RNN iterates through the input sentence one token at a time, outputting an "output" vector and a "hidden state" vector at each time step. The hidden state vector is passed to the next time step, while the output vector is recorded. The encoder uses a multi-layered Gated Recurrent Unit (GRU) and a bidirectional variant of the GRU. An `embedding` layer is used to encode our word indices in an arbitrarily sized feature space.
#
# ### Decoder
#
# The decoder RNN generates the response sentence in a token-by-token fashion. It uses the encoder’s context vectors, and internal hidden states to generate the next word in the sequence. To avoid information loss, especially when dealing with long input sequences, an "attention mechanism" is typically used that allows the decoder to pay attention to certain parts of the input sequence, rather than using the entire fixed context at every step. However, in this tutorial, we only consider the use of standard RNNs, which will limit the performance of our model.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0.0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size parameters are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden
    

# Attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)
    
class DecoderRNN(nn.Module):
    def __init__(self, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        # Initialize the parent class
        super(DecoderRNN,self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.rnn = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, input_step, last_hidden):
        """
        Forward pass for the decoder for a single step.
        Parameters
        ----------
        - input_step: The input at the current timestep
        - last_hidden: The hidden state from the previous timestep
        """
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)

        # Forward through unidirectional RNN
        rnn_output, hidden = self.rnn(embedded, last_hidden)

        # Squeeze the output to remove extra dimension
        rnn_output = rnn_output.squeeze(0)

        # Predict next word using the RNN output
        output = self.out(rnn_output)
        output = F.softmax(output, dim=1)

        return output, hidden


class AttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(AttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
# Set configuration parameters for the model
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_features = 500
in_features=hidden_features
encoder_n_layers = 2
decoder_n_layers = 2
rnn_type = 'GRU'
dropout = 0.1
batch_size = 64

# Set training and optimization parameters
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_features)

# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_features, embedding, encoder_n_layers, dropout)
decoder = AttnDecoderRNN(attn_model, embedding, hidden_features, voc.num_words, decoder_n_layers, dropout)

# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)

# %% [markdown]
# ## Define and train model
#
# Now, we're ready to run our model!
#
# Whether we're training or testing the chatbot model, we need to initialize the encoder and decoder models. In the next block, we configure the parameters, and construct and initialize the models. You're encouraged to experiment with different model configurations to enhance performance.

# %%
# Initialize word embeddings and encoder & decoder models
# Set models to training mode
encoder.train()
decoder.train()

# Initialize optimizers for the encoder and decoder
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

# Move optimizer states to GPU if necessary
if torch.cuda.is_available():
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

# Begin the training process
train_iters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name)
# Out:
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9763
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8482
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6525
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.3554
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.0054
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.4312
# Iteration: 7; Percent complete: 0.2%; Average loss: 7.0101
# Iteration: 8; Percent complete: 0.2%; Average loss: 7.0129
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.8198
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.7058
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.1694
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.6794
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.5182
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.6660
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.4449
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.5331
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.2840
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.0400
# Iteration: 19; Percent complete: 0.5%; Average loss: 4.8997
# Iteration: 20; Percent complete: 0.5%; Average loss: 4.8995
# Iteration: 21; Percent complete: 0.5%; Average loss: 5.0851
# Iteration: 22; Percent complete: 0.5%; Average loss: 5.1186
# Iteration: 23; Percent complete: 0.6%; Average loss: 4.8688
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.9676
# Iteration: 25; Percent complete: 0.6%; Average loss: 5.0354
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.7264
# Iteration: 27; Percent complete: 0.7%; Average loss: 4.8384
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.8802
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.8628
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.9256
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.6324
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.7715
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.5463
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.6192
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.6530
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.8934
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.7494
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.8711
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.6285
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.7699
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.7634
# Iteration: 42; Percent complete: 1.1%; Average loss: 5.0154
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.6535
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.7555
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.6160
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.9194
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.8922
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.8271
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.8465
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.8182
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.6712
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.7128
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.7721
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.6365
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.9375
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.5798
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.7835
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.5973
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.6147
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.7116
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.7253
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.4287
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.7358
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.4774
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.7233
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.5612
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.8165
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.5747
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.5988
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.5572
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.4218
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.7238
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.5357
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.3430
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.3907
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.4004
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.3463
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.2842
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.6681
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.3870
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.5640
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.5650
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.4463
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.6893
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.3886
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.6786
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.1681
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.5371
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.4665
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.3235
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.4525
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.2935
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.3456
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.4678
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.3779
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.5478
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.3034
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.4213
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.3872
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.2362
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.2915
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.8285
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.5477
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.4794
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.3570
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.3533
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.3898
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.1788
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.3831
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.3109
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.5124
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.2966
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.2194
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.3910
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.4498
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.2630
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.4860
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.2061
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.3652
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.2472
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.3282
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.3429
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.4275
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.2519
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.2937
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.2292
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.2420
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.2424
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.3446
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.4174
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.6538
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.6398
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.3574
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.4192
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.2857
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.4981
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.1438
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.3705
# Iteration: 139; Percent complete: 3.5%; Average loss: 4.4961
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.2300
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.3011
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.3129
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.1692
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.1837
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.2701
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.2272
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.3056
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.2971
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.5502
# Iteration: 150; Percent complete: 3.8%; Average loss: 3.9554
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.4281
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.1566
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.4751
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.2165
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.4638
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.3926
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.3233
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.2827
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.0301
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.2662
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.1628
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.2379
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.2511
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.1243
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.5877
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.2635
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.4842
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.3480
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.5596
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.1809
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.3376
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.3677
# Iteration: 173; Percent complete: 4.3%; Average loss: 4.2603
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.4280
# Iteration: 175; Percent complete: 4.4%; Average loss: 4.1146
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.1126
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.1017
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.0172
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.2901
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.3811
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.2680
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.0996
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.2246
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.3310
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.1398
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.0694
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.3709
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.2274
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.2297
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.0772
# Iteration: 191; Percent complete: 4.8%; Average loss: 3.9684
# Iteration: 192; Percent complete: 4.8%; Average loss: 4.2355
# Iteration: 193; Percent complete: 4.8%; Average loss: 4.4049
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.1567
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.0961
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.0344
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.1434
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.0602
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.1975
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.2474
# Iteration: 201; Percent complete: 5.0%; Average loss: 3.9289
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.1372
# Iteration: 203; Percent complete: 5.1%; Average loss: 3.9216
# Iteration: 204; Percent complete: 5.1%; Average loss: 4.1464
# Iteration: 205; Percent complete: 5.1%; Average loss: 3.8578
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.1770
# Iteration: 207; Percent complete: 5.2%; Average loss: 4.1780
# Iteration: 208; Percent complete: 5.2%; Average loss: 3.9605
# Iteration: 209; Percent complete: 5.2%; Average loss: 4.0620
# Iteration: 210; Percent complete: 5.2%; Average loss: 4.1277
# Iteration: 211; Percent complete: 5.3%; Average loss: 4.0945
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.1286
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.1912
# Iteration: 214; Percent complete: 5.3%; Average loss: 3.7978
# Iteration: 215; Percent complete: 5.4%; Average loss: 4.1333
# Iteration: 216; Percent complete: 5.4%; Average loss: 4.1559
# Iteration: 217; Percent complete: 5.4%; Average loss: 3.8825
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.1957
# Iteration: 219; Percent complete: 5.5%; Average loss: 3.8890
# Iteration: 220; Percent complete: 5.5%; Average loss: 3.9631
# Iteration: 221; Percent complete: 5.5%; Average loss: 4.2837
# Iteration: 222; Percent complete: 5.5%; Average loss: 3.8971
# Iteration: 223; Percent complete: 5.6%; Average loss: 4.2366
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.1865
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.1972
# Iteration: 226; Percent complete: 5.7%; Average loss: 4.0481
# Iteration: 227; Percent complete: 5.7%; Average loss: 3.9754
# Iteration: 228; Percent complete: 5.7%; Average loss: 3.9030
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.0102
# Iteration: 230; Percent complete: 5.8%; Average loss: 4.2458
# Iteration: 231; Percent complete: 5.8%; Average loss: 3.9958
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.3629
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.0728
# Iteration: 234; Percent complete: 5.9%; Average loss: 3.8627
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.1146
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.2361
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.9306
# Iteration: 238; Percent complete: 5.9%; Average loss: 4.2662
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.1767
# Iteration: 240; Percent complete: 6.0%; Average loss: 4.0472
# Iteration: 241; Percent complete: 6.0%; Average loss: 3.9471
# Iteration: 242; Percent complete: 6.0%; Average loss: 4.2162
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.0890
# Iteration: 244; Percent complete: 6.1%; Average loss: 3.9732
# Iteration: 245; Percent complete: 6.1%; Average loss: 3.9231
# Iteration: 246; Percent complete: 6.2%; Average loss: 4.1219
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.0363
# Iteration: 248; Percent complete: 6.2%; Average loss: 3.8791
# Iteration: 249; Percent complete: 6.2%; Average loss: 4.0864
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.0818
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.9706
# Iteration: 252; Percent complete: 6.3%; Average loss: 3.8527
# Iteration: 253; Percent complete: 6.3%; Average loss: 4.0011
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.9172
# Iteration: 255; Percent complete: 6.4%; Average loss: 4.0695
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.9853
# Iteration: 257; Percent complete: 6.4%; Average loss: 3.9274
# Iteration: 258; Percent complete: 6.5%; Average loss: 3.9430
# Iteration: 259; Percent complete: 6.5%; Average loss: 4.0251
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.0031
# Iteration: 261; Percent complete: 6.5%; Average loss: 4.2680
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.9363
# Iteration: 263; Percent complete: 6.6%; Average loss: 4.1460
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.2716
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.9910
# Iteration: 266; Percent complete: 6.7%; Average loss: 3.8809
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.8797
# Iteration: 268; Percent complete: 6.7%; Average loss: 3.9401
# Iteration: 269; Percent complete: 6.7%; Average loss: 4.0112
# Iteration: 270; Percent complete: 6.8%; Average loss: 4.3639
# Iteration: 271; Percent complete: 6.8%; Average loss: 3.9035
# Iteration: 272; Percent complete: 6.8%; Average loss: 3.7797
# Iteration: 273; Percent complete: 6.8%; Average loss: 3.8362
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.7712
# Iteration: 275; Percent complete: 6.9%; Average loss: 3.9389
# Iteration: 276; Percent complete: 6.9%; Average loss: 4.0122
# Iteration: 277; Percent complete: 6.9%; Average loss: 4.0246
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.7229
# Iteration: 279; Percent complete: 7.0%; Average loss: 4.0206
# Iteration: 280; Percent complete: 7.0%; Average loss: 4.1764
# Iteration: 281; Percent complete: 7.0%; Average loss: 4.1148
# Iteration: 282; Percent complete: 7.0%; Average loss: 4.0925
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.0432
# Iteration: 284; Percent complete: 7.1%; Average loss: 4.2365
# Iteration: 285; Percent complete: 7.1%; Average loss: 4.3188
# Iteration: 286; Percent complete: 7.1%; Average loss: 4.1805
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.8444
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.9343
# Iteration: 289; Percent complete: 7.2%; Average loss: 3.8252
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.1564
# Iteration: 291; Percent complete: 7.3%; Average loss: 4.0082
# Iteration: 292; Percent complete: 7.3%; Average loss: 3.7155
# Iteration: 293; Percent complete: 7.3%; Average loss: 3.8407
# Iteration: 294; Percent complete: 7.3%; Average loss: 3.8548
# Iteration: 295; Percent complete: 7.4%; Average loss: 4.0635
# Iteration: 296; Percent complete: 7.4%; Average loss: 3.9888
# Iteration: 297; Percent complete: 7.4%; Average loss: 4.0747
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.9665
# Iteration: 299; Percent complete: 7.5%; Average loss: 3.7402
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.7376
# Iteration: 301; Percent complete: 7.5%; Average loss: 4.0060
# Iteration: 302; Percent complete: 7.5%; Average loss: 4.0784
# Iteration: 303; Percent complete: 7.6%; Average loss: 4.1466
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.8693
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.9739
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.7297
# Iteration: 307; Percent complete: 7.7%; Average loss: 4.0033
# Iteration: 308; Percent complete: 7.7%; Average loss: 3.9467
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.8836
# Iteration: 310; Percent complete: 7.8%; Average loss: 3.9044
# Iteration: 311; Percent complete: 7.8%; Average loss: 3.6893
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.8356
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.8431
# Iteration: 314; Percent complete: 7.8%; Average loss: 3.8225
# Iteration: 315; Percent complete: 7.9%; Average loss: 3.7613
# Iteration: 316; Percent complete: 7.9%; Average loss: 4.0430
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.8294
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.6494
# Iteration: 319; Percent complete: 8.0%; Average loss: 3.6944
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.5589
# Iteration: 321; Percent complete: 8.0%; Average loss: 4.1166
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.9920
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.9037
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.6080
# Iteration: 325; Percent complete: 8.1%; Average loss: 4.0731
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.8060
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.9006
# Iteration: 328; Percent complete: 8.2%; Average loss: 3.9701
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.7958
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.7130
# Iteration: 331; Percent complete: 8.3%; Average loss: 3.8339
# Iteration: 332; Percent complete: 8.3%; Average loss: 3.8877
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.9179
# Iteration: 334; Percent complete: 8.3%; Average loss: 3.7179
# Iteration: 335; Percent complete: 8.4%; Average loss: 4.0078
# Iteration: 336; Percent complete: 8.4%; Average loss: 3.7286
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.6155
# Iteration: 338; Percent complete: 8.5%; Average loss: 3.8509
# Iteration: 339; Percent complete: 8.5%; Average loss: 3.9970
# Iteration: 340; Percent complete: 8.5%; Average loss: 4.0482
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.9655
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.6746
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.9781
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.6461
# Iteration: 345; Percent complete: 8.6%; Average loss: 3.8849
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.9361
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.4898
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.7131
# Iteration: 349; Percent complete: 8.7%; Average loss: 4.0491
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.9486
# Iteration: 351; Percent complete: 8.8%; Average loss: 4.3768
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.8495
# Iteration: 353; Percent complete: 8.8%; Average loss: 4.0794
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.7925
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.9508
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.7275
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.9951
# Iteration: 358; Percent complete: 8.9%; Average loss: 3.8955
# Iteration: 359; Percent complete: 9.0%; Average loss: 3.8505
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.5987
# Iteration: 361; Percent complete: 9.0%; Average loss: 3.7997
# Iteration: 362; Percent complete: 9.0%; Average loss: 4.0358
# Iteration: 363; Percent complete: 9.1%; Average loss: 3.9818
# Iteration: 364; Percent complete: 9.1%; Average loss: 4.0010
# Iteration: 365; Percent complete: 9.1%; Average loss: 4.0836
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.9730
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.7183
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.9277
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.7496
# Iteration: 370; Percent complete: 9.2%; Average loss: 3.7389
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.5994
# Iteration: 372; Percent complete: 9.3%; Average loss: 4.3662
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.3657
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.9507
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.5867
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.6993
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.7098
# Iteration: 378; Percent complete: 9.4%; Average loss: 4.1755
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.9564
# Iteration: 380; Percent complete: 9.5%; Average loss: 4.0107
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.1218
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.8350
# Iteration: 383; Percent complete: 9.6%; Average loss: 3.8964
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.7634
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.6595
# Iteration: 386; Percent complete: 9.7%; Average loss: 3.8614
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.8032
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.7158
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.7008
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.9178
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.9512
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.8464
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.9256
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.8794
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.7859
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.9586
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.8711
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.9208
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.6622
# Iteration: 400; Percent complete: 10.0%; Average loss: 3.7787
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.7052
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.9853
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.8998
# Iteration: 404; Percent complete: 10.1%; Average loss: 4.0279
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.6071
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.8390
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.9936
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.6645
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.9136
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.8231
# Iteration: 411; Percent complete: 10.3%; Average loss: 4.0174
# Iteration: 412; Percent complete: 10.3%; Average loss: 4.0136
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.9085
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.6158
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.8225
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.8369
# Iteration: 417; Percent complete: 10.4%; Average loss: 3.5109
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.8720
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.6398
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.6966
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.8590
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.7977
# Iteration: 423; Percent complete: 10.6%; Average loss: 4.0438
# Iteration: 424; Percent complete: 10.6%; Average loss: 4.1143
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.9157
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.7976
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.6397
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.8831
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.8063
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.9530
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.8267
# Iteration: 432; Percent complete: 10.8%; Average loss: 3.4973
# Iteration: 433; Percent complete: 10.8%; Average loss: 3.9606
# Iteration: 434; Percent complete: 10.8%; Average loss: 3.8586
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.4917
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.7686
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.6830
# Iteration: 438; Percent complete: 10.9%; Average loss: 4.0393
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.4920
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.8627
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.7706
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.6730
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.7198
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.8267
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.8166
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.9482
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.7400
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.6392
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.7291
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.4754
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.8737
# Iteration: 452; Percent complete: 11.3%; Average loss: 4.0006
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.8525
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.5902
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.7639
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.8422
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.8435
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.9098
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.9686
# Iteration: 460; Percent complete: 11.5%; Average loss: 3.8785
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.6248
# Iteration: 462; Percent complete: 11.6%; Average loss: 4.0319
# Iteration: 463; Percent complete: 11.6%; Average loss: 3.9572
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.6935
# Iteration: 465; Percent complete: 11.6%; Average loss: 4.1233
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.4122
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.7954
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.9673
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.8034
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.7797
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.8644
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.6380
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.6403
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.7388
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.6357
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.8413
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.7423
# Iteration: 478; Percent complete: 11.9%; Average loss: 3.9161
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.7704
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.7375
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.9850
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.8481
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.6343
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.6110
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.8412
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.5708
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.5967
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.8037
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.8625
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.8842
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.6177
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.8175
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.7429
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.7594
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.6811
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.7426
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.7082
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.8876
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.7568
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.9340
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.7786
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.7867
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.6464
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.8478
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.7536
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.7162
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.8355
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.8161
# Iteration: 509; Percent complete: 12.7%; Average loss: 3.6547
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.3335
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.8166
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.9244
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.9046
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.8591
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.8109
# Iteration: 516; Percent complete: 12.9%; Average loss: 3.8530
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.7204
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.7511
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.6145
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.5846
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.5494
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.6199
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.6474
# Iteration: 524; Percent complete: 13.1%; Average loss: 4.0267
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.8290
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.6882
# Iteration: 527; Percent complete: 13.2%; Average loss: 4.0590
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.7960
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.6110
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.6814
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.5678
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.4195
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.9537
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.8954
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.7086
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.8514
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.8797
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.7241
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.5026
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.6581
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.7052
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.6593
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.8858
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.7265
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.6726
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.5902
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.4328
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.7019
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.7780
# Iteration: 550; Percent complete: 13.8%; Average loss: 3.5844
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.6482
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.7104
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.7344
# Iteration: 554; Percent complete: 13.9%; Average loss: 3.8066
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.4843
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.6983
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.7274
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.7578
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.6805
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.8285
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.5376
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.8325
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.4309
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.8454
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.4625
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.6134
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.8382
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.7039
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.5897
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.7713
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.7507
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.8513
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.7767
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.7127
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.6846
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.6741
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.8312
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.9204
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.6761
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.8306
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.8665
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.7571
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.6783
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.8668
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.8040
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.7484
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.6166
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.5329
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.6433
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.7434
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.7907
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.7907
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.7943
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.8435
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.5575
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.5381
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.8191
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.5499
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.6194
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.3982
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.6977
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.5561
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.5955
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.9154
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.6888
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.8553
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.7733
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.9512
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.7947
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.6835
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.5155
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.6077
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.5388
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.8846
# Iteration: 615; Percent complete: 15.4%; Average loss: 4.0215
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.7941
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.2590
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.6645
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.5820
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.7681
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.6927
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.5786
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.7488
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.8174
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.9232
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.5835
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.4747
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.5118
# Iteration: 629; Percent complete: 15.7%; Average loss: 3.8290
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.7392
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.6739
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.6623
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.9156
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.9267
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.5300
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.6406
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.5259
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.4533
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.6199
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.4351
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.6706
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.7735
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.8830
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.6588
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.5915
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.8521
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.6946
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.6780
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.6941
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.6367
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.8943
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.6371
# Iteration: 653; Percent complete: 16.3%; Average loss: 3.6492
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.5983
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.7291
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.7810
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.7753
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.7942
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.8276
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.8376
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.5764
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.4858
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.4009
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.8459
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.6160
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.6488
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.5669
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.4239
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.5047
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.4721
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.7130
# Iteration: 672; Percent complete: 16.8%; Average loss: 4.0170
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.4666
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.6355
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.5746
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.5656
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.9062
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.6967
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.5403
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.8171
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.6523
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.5561
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.4841
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.6635
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.8463
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.8327
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.6708
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.7302
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.6764
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.7100
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.7654
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.5706
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.6139
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.5463
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.7770
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.5605
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.4942
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.6804
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.6097
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.7094
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.6347
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.8301
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.4739
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.5609
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.4269
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.5044
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.8212
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.6206
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.4266
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.2252
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.4002
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.7403
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.6938
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.6732
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.6952
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.6381
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.8608
# Iteration: 718; Percent complete: 17.9%; Average loss: 4.0039
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.5401
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.8464
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.6433
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.8878
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.6346
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.4288
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.5395
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.6584
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.5630
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.8988
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.5207
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.7353
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.4965
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.3493
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.4237
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.6934
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.5069
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.5593
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.4022
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.4764
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.5970
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.5727
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.8660
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.6292
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.6720
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.6247
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.6022
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.6264
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.8023
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.6092
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.5340
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.7293
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.4231
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.7265
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.6283
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.7752
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.8209
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.6282
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.5006
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.6117
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.3773
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.7343
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.5832
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.6866
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.4987
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.4923
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.2343
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.6306
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.6149
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.4685
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.3517
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.5917
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.5770
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.4749
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.5039
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.3581
# Iteration: 775; Percent complete: 19.4%; Average loss: 3.4696
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.6812
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.7459
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.6314
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.7268
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.4226
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.4734
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 2.5980
# Iteration: 3749; Percent complete: 93.7%; Average loss: 2.6541
# Iteration: 3750; Percent complete: 93.8%; Average loss: 2.8813
# Iteration: 3751; Percent complete: 93.8%; Average loss: 2.8081
# Iteration: 3752; Percent complete: 93.8%; Average loss: 2.7314
# Iteration: 3753; Percent complete: 93.8%; Average loss: 2.7743
# Iteration: 3754; Percent complete: 93.8%; Average loss: 2.6376
# Iteration: 3755; Percent complete: 93.9%; Average loss: 2.7465
# Iteration: 3756; Percent complete: 93.9%; Average loss: 2.6784
# Iteration: 3757; Percent complete: 93.9%; Average loss: 2.5371
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.5111
# Iteration: 3759; Percent complete: 94.0%; Average loss: 2.5444
# Iteration: 3760; Percent complete: 94.0%; Average loss: 2.7390
# Iteration: 3761; Percent complete: 94.0%; Average loss: 2.7314
# Iteration: 3762; Percent complete: 94.0%; Average loss: 2.7229
# Iteration: 3763; Percent complete: 94.1%; Average loss: 2.5281
# Iteration: 3764; Percent complete: 94.1%; Average loss: 2.8754
# Iteration: 3765; Percent complete: 94.1%; Average loss: 2.5443
# Iteration: 3766; Percent complete: 94.2%; Average loss: 2.7934
# Iteration: 3767; Percent complete: 94.2%; Average loss: 2.7171
# Iteration: 3768; Percent complete: 94.2%; Average loss: 2.5972
# Iteration: 3769; Percent complete: 94.2%; Average loss: 2.9098
# Iteration: 3770; Percent complete: 94.2%; Average loss: 2.6001
# Iteration: 3771; Percent complete: 94.3%; Average loss: 2.5830
# Iteration: 3772; Percent complete: 94.3%; Average loss: 2.8663
# Iteration: 3773; Percent complete: 94.3%; Average loss: 2.6541
# Iteration: 3774; Percent complete: 94.3%; Average loss: 2.7409
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.9639
# Iteration: 3776; Percent complete: 94.4%; Average loss: 2.6723
# Iteration: 3777; Percent complete: 94.4%; Average loss: 2.5206
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.5794
# Iteration: 3779; Percent complete: 94.5%; Average loss: 2.7269
# Iteration: 3780; Percent complete: 94.5%; Average loss: 2.5718
# Iteration: 3781; Percent complete: 94.5%; Average loss: 2.7441
# Iteration: 3782; Percent complete: 94.5%; Average loss: 2.5101
# Iteration: 3783; Percent complete: 94.6%; Average loss: 2.6440
# Iteration: 3784; Percent complete: 94.6%; Average loss: 2.8316
# Iteration: 3785; Percent complete: 94.6%; Average loss: 2.4205
# Iteration: 3786; Percent complete: 94.7%; Average loss: 2.6749
# Iteration: 3787; Percent complete: 94.7%; Average loss: 2.5460
# Iteration: 3788; Percent complete: 94.7%; Average loss: 2.6305
# Iteration: 3789; Percent complete: 94.7%; Average loss: 2.7875
# Iteration: 3790; Percent complete: 94.8%; Average loss: 2.7989
# Iteration: 3791; Percent complete: 94.8%; Average loss: 2.8316
# Iteration: 3792; Percent complete: 94.8%; Average loss: 2.6726
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.5958
# Iteration: 3794; Percent complete: 94.8%; Average loss: 2.6766
# Iteration: 3795; Percent complete: 94.9%; Average loss: 2.6980
# Iteration: 3796; Percent complete: 94.9%; Average loss: 2.6995
# Iteration: 3797; Percent complete: 94.9%; Average loss: 2.6850
# Iteration: 3798; Percent complete: 95.0%; Average loss: 2.6553
# Iteration: 3799; Percent complete: 95.0%; Average loss: 2.6874
# Iteration: 3800; Percent complete: 95.0%; Average loss: 2.9957
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.7902
# Iteration: 3802; Percent complete: 95.0%; Average loss: 2.7382
# Iteration: 3803; Percent complete: 95.1%; Average loss: 2.6530
# Iteration: 3804; Percent complete: 95.1%; Average loss: 2.3788
# Iteration: 3805; Percent complete: 95.1%; Average loss: 2.6823
# Iteration: 3806; Percent complete: 95.2%; Average loss: 2.8194
# Iteration: 3807; Percent complete: 95.2%; Average loss: 2.7564
# Iteration: 3808; Percent complete: 95.2%; Average loss: 2.5379
# Iteration: 3809; Percent complete: 95.2%; Average loss: 2.8524
# Iteration: 3810; Percent complete: 95.2%; Average loss: 2.6872
# Iteration: 3811; Percent complete: 95.3%; Average loss: 2.7560
# Iteration: 3812; Percent complete: 95.3%; Average loss: 2.6333
# Iteration: 3813; Percent complete: 95.3%; Average loss: 2.9151
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.6085
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.6762
# Iteration: 3816; Percent complete: 95.4%; Average loss: 2.4786
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.5339
# Iteration: 3818; Percent complete: 95.5%; Average loss: 2.6636
# Iteration: 3819; Percent complete: 95.5%; Average loss: 2.5945
# Iteration: 3820; Percent complete: 95.5%; Average loss: 2.4390
# Iteration: 3821; Percent complete: 95.5%; Average loss: 2.6158
# Iteration: 3822; Percent complete: 95.5%; Average loss: 2.6406
# Iteration: 3823; Percent complete: 95.6%; Average loss: 2.6047
# Iteration: 3824; Percent complete: 95.6%; Average loss: 2.5549
# Iteration: 3825; Percent complete: 95.6%; Average loss: 2.4684
# Iteration: 3826; Percent complete: 95.7%; Average loss: 2.4904
# Iteration: 3827; Percent complete: 95.7%; Average loss: 2.3357
# Iteration: 3828; Percent complete: 95.7%; Average loss: 2.4940
# Iteration: 3829; Percent complete: 95.7%; Average loss: 2.8346
# Iteration: 3830; Percent complete: 95.8%; Average loss: 2.6907
# Iteration: 3831; Percent complete: 95.8%; Average loss: 2.6309
# Iteration: 3832; Percent complete: 95.8%; Average loss: 2.6251
# Iteration: 3833; Percent complete: 95.8%; Average loss: 2.5364
# Iteration: 3834; Percent complete: 95.9%; Average loss: 2.7050
# Iteration: 3835; Percent complete: 95.9%; Average loss: 2.7245
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.5200
# Iteration: 3837; Percent complete: 95.9%; Average loss: 2.5266
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.7049
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.6637
# Iteration: 3840; Percent complete: 96.0%; Average loss: 2.5406
# Iteration: 3841; Percent complete: 96.0%; Average loss: 2.8028
# Iteration: 3842; Percent complete: 96.0%; Average loss: 2.7481
# Iteration: 3843; Percent complete: 96.1%; Average loss: 2.7875
# Iteration: 3844; Percent complete: 96.1%; Average loss: 2.5244
# Iteration: 3845; Percent complete: 96.1%; Average loss: 2.7935
# Iteration: 3846; Percent complete: 96.2%; Average loss: 2.8772
# Iteration: 3847; Percent complete: 96.2%; Average loss: 2.5765
# Iteration: 3848; Percent complete: 96.2%; Average loss: 2.7612
# Iteration: 3849; Percent complete: 96.2%; Average loss: 2.6366
# Iteration: 3850; Percent complete: 96.2%; Average loss: 2.5963
# Iteration: 3851; Percent complete: 96.3%; Average loss: 2.5991
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.5420
# Iteration: 3853; Percent complete: 96.3%; Average loss: 2.7145
# Iteration: 3854; Percent complete: 96.4%; Average loss: 2.7864
# Iteration: 3855; Percent complete: 96.4%; Average loss: 2.8251
# Iteration: 3856; Percent complete: 96.4%; Average loss: 2.4693
# Iteration: 3857; Percent complete: 96.4%; Average loss: 2.5414
# Iteration: 3858; Percent complete: 96.5%; Average loss: 2.7397
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.7994
# Iteration: 3860; Percent complete: 96.5%; Average loss: 2.6343
# Iteration: 3861; Percent complete: 96.5%; Average loss: 2.6088
# Iteration: 3862; Percent complete: 96.5%; Average loss: 2.6198
# Iteration: 3863; Percent complete: 96.6%; Average loss: 2.7643
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.5844
# Iteration: 3865; Percent complete: 96.6%; Average loss: 2.7959
# Iteration: 3866; Percent complete: 96.7%; Average loss: 2.5139
# Iteration: 3867; Percent complete: 96.7%; Average loss: 2.8048
# Iteration: 3868; Percent complete: 96.7%; Average loss: 2.7614
# Iteration: 3869; Percent complete: 96.7%; Average loss: 2.6367
# Iteration: 3870; Percent complete: 96.8%; Average loss: 2.4056
# Iteration: 3871; Percent complete: 96.8%; Average loss: 2.5633
# Iteration: 3872; Percent complete: 96.8%; Average loss: 2.4901
# Iteration: 3873; Percent complete: 96.8%; Average loss: 2.7139
# Iteration: 3874; Percent complete: 96.9%; Average loss: 2.8064
# Iteration: 3875; Percent complete: 96.9%; Average loss: 2.6880
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.7937
# Iteration: 3877; Percent complete: 96.9%; Average loss: 2.7580
# Iteration: 3878; Percent complete: 97.0%; Average loss: 2.7438
# Iteration: 3879; Percent complete: 97.0%; Average loss: 2.7423
# Iteration: 3880; Percent complete: 97.0%; Average loss: 2.6707
# Iteration: 3881; Percent complete: 97.0%; Average loss: 2.7408
# Iteration: 3882; Percent complete: 97.0%; Average loss: 2.8017
# Iteration: 3883; Percent complete: 97.1%; Average loss: 2.6270
# Iteration: 3884; Percent complete: 97.1%; Average loss: 2.5917
# Iteration: 3885; Percent complete: 97.1%; Average loss: 2.8048
# Iteration: 3886; Percent complete: 97.2%; Average loss: 2.5435
# Iteration: 3887; Percent complete: 97.2%; Average loss: 2.7587
# Iteration: 3888; Percent complete: 97.2%; Average loss: 2.8786
# Iteration: 3889; Percent complete: 97.2%; Average loss: 2.9465
# Iteration: 3890; Percent complete: 97.2%; Average loss: 2.5918
# Iteration: 3891; Percent complete: 97.3%; Average loss: 2.7385
# Iteration: 3892; Percent complete: 97.3%; Average loss: 2.6806
# Iteration: 3893; Percent complete: 97.3%; Average loss: 2.5841
# Iteration: 3894; Percent complete: 97.4%; Average loss: 2.8581
# Iteration: 3895; Percent complete: 97.4%; Average loss: 2.7949
# Iteration: 3896; Percent complete: 97.4%; Average loss: 2.6695
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.5835
# Iteration: 3898; Percent complete: 97.5%; Average loss: 2.8174
# Iteration: 3899; Percent complete: 97.5%; Average loss: 2.7454
# Iteration: 3900; Percent complete: 97.5%; Average loss: 2.7720
# Iteration: 3901; Percent complete: 97.5%; Average loss: 2.6474
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.6535
# Iteration: 3903; Percent complete: 97.6%; Average loss: 2.3970
# Iteration: 3904; Percent complete: 97.6%; Average loss: 2.7014
# Iteration: 3905; Percent complete: 97.6%; Average loss: 2.5515
# Iteration: 3906; Percent complete: 97.7%; Average loss: 2.8595
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.7190
# Iteration: 3908; Percent complete: 97.7%; Average loss: 2.7801
# Iteration: 3909; Percent complete: 97.7%; Average loss: 2.6963
# Iteration: 3910; Percent complete: 97.8%; Average loss: 2.5849
# Iteration: 3911; Percent complete: 97.8%; Average loss: 2.6260
# Iteration: 3912; Percent complete: 97.8%; Average loss: 2.6572
# Iteration: 3913; Percent complete: 97.8%; Average loss: 2.4892
# Iteration: 3914; Percent complete: 97.9%; Average loss: 2.6238
# Iteration: 3915; Percent complete: 97.9%; Average loss: 2.7418
# Iteration: 3916; Percent complete: 97.9%; Average loss: 2.7251
# Iteration: 3917; Percent complete: 97.9%; Average loss: 2.6024
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.7326
# Iteration: 3919; Percent complete: 98.0%; Average loss: 2.4427
# Iteration: 3920; Percent complete: 98.0%; Average loss: 2.8512
# Iteration: 3921; Percent complete: 98.0%; Average loss: 2.5244
# Iteration: 3922; Percent complete: 98.0%; Average loss: 2.5763
# Iteration: 3923; Percent complete: 98.1%; Average loss: 2.6291
# Iteration: 3924; Percent complete: 98.1%; Average loss: 2.5134
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.7992
# Iteration: 3926; Percent complete: 98.2%; Average loss: 2.6174
# Iteration: 3927; Percent complete: 98.2%; Average loss: 2.6780
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.5547
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.6265
# Iteration: 3930; Percent complete: 98.2%; Average loss: 2.6980
# Iteration: 3931; Percent complete: 98.3%; Average loss: 2.5264
# Iteration: 3932; Percent complete: 98.3%; Average loss: 2.4278
# Iteration: 3933; Percent complete: 98.3%; Average loss: 2.5863
# Iteration: 3934; Percent complete: 98.4%; Average loss: 2.4608
# Iteration: 3935; Percent complete: 98.4%; Average loss: 2.6159
# Iteration: 3936; Percent complete: 98.4%; Average loss: 2.4004
# Iteration: 3937; Percent complete: 98.4%; Average loss: 2.6602
# Iteration: 3938; Percent complete: 98.5%; Average loss: 2.7457
# Iteration: 3939; Percent complete: 98.5%; Average loss: 2.5136
# Iteration: 3940; Percent complete: 98.5%; Average loss: 2.4845
# Iteration: 3941; Percent complete: 98.5%; Average loss: 2.7110
# Iteration: 3942; Percent complete: 98.6%; Average loss: 2.5542
# Iteration: 3943; Percent complete: 98.6%; Average loss: 2.7072
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.7032
# Iteration: 3945; Percent complete: 98.6%; Average loss: 2.7563
# Iteration: 3946; Percent complete: 98.7%; Average loss: 2.4424
# Iteration: 3947; Percent complete: 98.7%; Average loss: 2.8548
# Iteration: 3948; Percent complete: 98.7%; Average loss: 2.6551
# Iteration: 3949; Percent complete: 98.7%; Average loss: 2.6632
# Iteration: 3950; Percent complete: 98.8%; Average loss: 2.7748
# Iteration: 3951; Percent complete: 98.8%; Average loss: 2.7684
# Iteration: 3952; Percent complete: 98.8%; Average loss: 2.4379
# Iteration: 3953; Percent complete: 98.8%; Average loss: 2.5723
# Iteration: 3954; Percent complete: 98.9%; Average loss: 2.5137
# Iteration: 3955; Percent complete: 98.9%; Average loss: 2.7429
# Iteration: 3956; Percent complete: 98.9%; Average loss: 2.4571
# Iteration: 3957; Percent complete: 98.9%; Average loss: 3.0265
# Iteration: 3958; Percent complete: 99.0%; Average loss: 2.7169
# Iteration: 3959; Percent complete: 99.0%; Average loss: 2.7762
# Iteration: 3960; Percent complete: 99.0%; Average loss: 2.9049
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.5812
# Iteration: 3962; Percent complete: 99.1%; Average loss: 2.6654
# Iteration: 3963; Percent complete: 99.1%; Average loss: 2.8106
# Iteration: 3964; Percent complete: 99.1%; Average loss: 2.6834
# Iteration: 3965; Percent complete: 99.1%; Average loss: 2.5731
# Iteration: 3966; Percent complete: 99.2%; Average loss: 2.6222
# Iteration: 3967; Percent complete: 99.2%; Average loss: 2.5669
# Iteration: 3968; Percent complete: 99.2%; Average loss: 2.5974
# Iteration: 3969; Percent complete: 99.2%; Average loss: 2.5284
# Iteration: 3970; Percent complete: 99.2%; Average loss: 2.5883
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.8102
# Iteration: 3972; Percent complete: 99.3%; Average loss: 2.3586
# Iteration: 3973; Percent complete: 99.3%; Average loss: 2.5040
# Iteration: 3974; Percent complete: 99.4%; Average loss: 2.6152
# Iteration: 3975; Percent complete: 99.4%; Average loss: 2.6251
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.8505
# Iteration: 3977; Percent complete: 99.4%; Average loss: 2.5836
# Iteration: 3978; Percent complete: 99.5%; Average loss: 2.4490
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.7477
# Iteration: 3980; Percent complete: 99.5%; Average loss: 2.3220
# Iteration: 3981; Percent complete: 99.5%; Average loss: 2.5011
# Iteration: 3982; Percent complete: 99.6%; Average loss: 2.5230
# Iteration: 3983; Percent complete: 99.6%; Average loss: 2.7300
# Iteration: 3984; Percent complete: 99.6%; Average loss: 2.5295
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.7736
# Iteration: 3986; Percent complete: 99.7%; Average loss: 2.7785
# Iteration: 3987; Percent complete: 99.7%; Average loss: 2.6471
# Iteration: 3988; Percent complete: 99.7%; Average loss: 2.6907
# Iteration: 3989; Percent complete: 99.7%; Average loss: 2.6026
# Iteration: 3990; Percent complete: 99.8%; Average loss: 2.5918
# Iteration: 3991; Percent complete: 99.8%; Average loss: 2.7414
# Iteration: 3992; Percent complete: 99.8%; Average loss: 2.7364
# Iteration: 3993; Percent complete: 99.8%; Average loss: 2.7304
# Iteration: 3994; Percent complete: 99.9%; Average loss: 2.5626
# Iteration: 3995; Percent complete: 99.9%; Average loss: 2.6490
# Iteration: 3996; Percent complete: 99.9%; Average loss: 2.5444
# Iteration: 3997; Percent complete: 99.9%; Average loss: 2.6239
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.8042
# Iteration: 3999; Percent complete: 100.0%; Average loss: 2.6592
# Iteration: 4000; Percent complete: 100.0%; Average loss: 2.4959

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluate_input(encoder, decoder, searcher, voc)
# Out:
# hello
# Bot: hello . is good . .
# how are you?
# Bot: hello . is good . . .
# what do you mean?
# Bot: what about the childhood ? ? ?
# what about yo?
# Bot: what about the other day ? ? ?
# what?
# Bot: i m sorry . is something .
# what's wrong?
# Bot: i m sorry . is a car .

# %% [markdown]
# Let's review the changes made to incorporate conversation history into your chatbot model training and evaluation:
# ### Changes for Training with Conversation History
#
# create_history_pairs Function: This function creates training pairs that include the history of the conversation. For each exchange in the pairs, it appends a certain number of previous exchanges (up to MAX_HISTORY) separated by the <EOS> token. These pairs are then used for training.
#
# Batch Preparation (batch_to_train_data): The function for preparing a batch of training data remains largely the same. The only difference is that it now handles input sequences that include conversation history.
#
# Training Function (train):
#     The core training logic remains unchanged.
#     The function receives input sequences that now contain conversation history.
#     The forward pass through the encoder and the decoding steps are performed as usual, without any specific changes needed to accommodate the conversation history.
#
# Data Preparation for Training:
#     The history_pairs are generated using the create_history_pairs function.
#     These pairs are then used throughout the training process.
#
# ### Changes for Evaluation with Conversation History
#
# evaluate Function:
#     The conversation history is now considered when evaluating a new input.
#     The history is concatenated with the current input sentence, separated by spaces.
#     The concatenated string is then processed and fed into the model for generating a response.
#
# evaluate_input Function:
#     Manages interactive evaluation with the user.
#     Maintains a conversation_history list, appending each user input and the model's response to it.
#     Passes the accumulated conversation history to the evaluate function for each new input.
#
# ### Training and Evaluation Process
#
# The model is trained with input sequences that include conversation history, allowing it to learn the context of the conversation.
# During evaluation, the model uses the accumulated conversation history to generate more context-aware responses.
#
# ### General Setup
#
# Model, optimizer, and training configurations are set according to your specifications.
# The training process (train_iters) follows the standard approach but uses the modified input pairs with conversation history.
#
# ### Important Notes
#
# The effectiveness of including conversation history in the model depends on the depth of context the model can understand and how well it can handle longer input sequences.
# Fine-tuning and experimenting with the MAX_HISTORY parameter and the MAX_LENGTH of sequences may be necessary to achieve optimal performance.

# %%
MAX_LENGTH = 10  # Maximum length of a single sentence, adjust as necessary
MAX_HISTORY = 5  # Number of previous exchanges to include in the history

def create_history_pairs(pairs, max_history=MAX_HISTORY):
    history_pairs = []
    for i in range(len(pairs)):
        dialogue_history = ' EOS '.join([pairs[j][0] for j in range(max(0, i-max_history), i)])
        history_pairs.append([dialogue_history, pairs[i][1]])
    return history_pairs

def zero_padding(l, fillvalue=0):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binary_matrix(l, value=0):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == value:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

def output_var(l, voc):
    indexes_batch = [indexes_from_sentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    pad_list = zero_padding(indexes_batch)
    mask = binary_matrix(pad_list)
    mask = torch.BoolTensor(mask)
    pad_var = torch.LongTensor(pad_list)
    return pad_var, mask, max_target_len

def indexes_from_sentence(voc, sentence):
    #return [voc.word_to_index[word] for word in sentence.split(' ')] + [EOS_TOKEN]
    return [voc.word_to_index[word] for word in sentence.split()] + [EOS_TOKEN] 

def batch_to_train_data(voc, pair_batch):
    pair_batch.sort(key=lambda p: len(p[0].split()), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = input_var(input_batch, voc)
    output, mask, max_target_len = output_var(output_batch, voc)
    return inp, lengths, output, mask, max_target_len

# Input_var function needs to calculate the correct lengths for packed sequences
def input_var(l, voc):
    indexes_batch = [indexes_from_sentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    pad_list = zero_padding(indexes_batch)
    pad_var = torch.LongTensor(pad_list)
    return pad_var, lengths
# Prepare the data with history
history_pairs = create_history_pairs(pairs)

# Modify the training function to handle the dialogue history in the input sequences
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_TOKEN for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = mask_nll_loss(decoder_output, target_variable[t], mask[t],device)
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

def train_iters(model_name, voc, history_pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding,
                encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every,
                clip, corpus_name):
    """
    Run training for a set number of iterations.
    """
    # Load batches for each iteration
    training_batches = [batch_to_train_data(voc, [random.choice(history_pairs) for _ in range(batch_size)])
                        for _ in range(n_iteration)]

    print('Initializing ...')
    start_iteration = 1
    print_loss_total = 0  # Reset every print_every

    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss_total += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print(f"Iteration: {iteration}; Percent complete: {iteration / n_iteration * 100:.1f}%; Average loss: {print_loss_avg:.4f}")
            print_loss_total = 0

        # Save checkpoint
        if iteration % save_every == 0:
            directory = os.path.join(save_dir, model_name, corpus_name, f'{encoder_n_layers}-{decoder_n_layers}_{hidden_features}')
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, f'{iteration}_checkpoint.tar'))

def evaluate(searcher, voc, conversation_history, max_length=MAX_LENGTH):
    """
    Evaluate a conversation history using the encoder, decoder, and searcher provided.
    """
    # Join the conversation history into a single input and normalize
    input_sentence = ' '.join(conversation_history)
    input_sentence = normalize_string(input_sentence)

    # Prepare the input sentence as a batch of word indexes
    indexes_batch = [indexes_from_sentence(voc, input_sentence)]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1).to(device)
    lengths = lengths.to("cpu")  # Lengths need to be on CPU for pack_padded_sequence

    # Decode the sentence with the searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    decoded_words = [voc.index_to_word[token.item()] for token in tokens]

    return decoded_words


def evaluate_input(searcher, voc):
    """
    Interactively evaluate input from the user, considering the entire conversation history.
    """
    conversation_history = []
    while True:
        try:
            input_sentence = input('> ')
            if input_sentence in ('q', 'quit'):
                break

            # Normalize and add the user's input to the conversation history
            input_sentence = normalize_string(input_sentence)
            conversation_history.append(input_sentence)

            # Evaluate the conversation history
            output_words = evaluate(searcher, voc, conversation_history)
            output_words = [word for word in output_words if word not in ('EOS', 'PAD')]
            print('Bot:', ' '.join(output_words))

            # Add the bot's response to the conversation history
            conversation_history.extend(output_words)
            conversation_history=conversation_history[-MAX_HISTORY*MAX_LENGTH:]
            
        except KeyError:
            print("Error: Encountered unknown word.")

# Set training and optimization parameters
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 16000
print_every = 1
save_every = 8000

# Set models to training mode
encoder.train()
decoder.train()

# Initialize optimizers for the encoder and decoder
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

# Move optimizer states to GPU if necessary
if torch.cuda.is_available():
    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.cuda()

# %%
# Begin the training process
train_iters(model_name, voc, history_pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name)
# Out:
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 3.2997
# Iteration: 2; Percent complete: 0.0%; Average loss: 3.2339
# Iteration: 3; Percent complete: 0.0%; Average loss: 3.3681
# Iteration: 4; Percent complete: 0.0%; Average loss: 3.2856
# Iteration: 5; Percent complete: 0.0%; Average loss: 3.1305
# Iteration: 6; Percent complete: 0.0%; Average loss: 3.4898
# Iteration: 7; Percent complete: 0.0%; Average loss: 3.2535
# Iteration: 8; Percent complete: 0.1%; Average loss: 3.2968
# Iteration: 9; Percent complete: 0.1%; Average loss: 3.1891
# Iteration: 10; Percent complete: 0.1%; Average loss: 3.1738
# Iteration: 11; Percent complete: 0.1%; Average loss: 3.2188
# Iteration: 12; Percent complete: 0.1%; Average loss: 3.3612
# Iteration: 13; Percent complete: 0.1%; Average loss: 3.3279
# Iteration: 14; Percent complete: 0.1%; Average loss: 3.2490
# Iteration: 15; Percent complete: 0.1%; Average loss: 3.2294
# Iteration: 16; Percent complete: 0.1%; Average loss: 3.1398
# Iteration: 17; Percent complete: 0.1%; Average loss: 3.3206
# Iteration: 18; Percent complete: 0.1%; Average loss: 3.4183
# Iteration: 19; Percent complete: 0.1%; Average loss: 3.3428
# Iteration: 20; Percent complete: 0.1%; Average loss: 3.1501
# Iteration: 21; Percent complete: 0.1%; Average loss: 3.1220
# Iteration: 22; Percent complete: 0.1%; Average loss: 3.2663
# Iteration: 23; Percent complete: 0.1%; Average loss: 3.3336
# Iteration: 24; Percent complete: 0.1%; Average loss: 3.3747
# Iteration: 25; Percent complete: 0.2%; Average loss: 3.1646
# Iteration: 26; Percent complete: 0.2%; Average loss: 3.0428
# Iteration: 27; Percent complete: 0.2%; Average loss: 3.1919
# Iteration: 28; Percent complete: 0.2%; Average loss: 3.1666
# Iteration: 29; Percent complete: 0.2%; Average loss: 3.2768
# Iteration: 30; Percent complete: 0.2%; Average loss: 3.3289
# Iteration: 31; Percent complete: 0.2%; Average loss: 3.4969
# Iteration: 32; Percent complete: 0.2%; Average loss: 2.9953
# Iteration: 33; Percent complete: 0.2%; Average loss: 3.2980
# Iteration: 34; Percent complete: 0.2%; Average loss: 3.2714
# Iteration: 35; Percent complete: 0.2%; Average loss: 3.2103
# Iteration: 36; Percent complete: 0.2%; Average loss: 3.1665
# Iteration: 37; Percent complete: 0.2%; Average loss: 3.3350
# Iteration: 38; Percent complete: 0.2%; Average loss: 3.1411
# Iteration: 39; Percent complete: 0.2%; Average loss: 3.0063
# Iteration: 40; Percent complete: 0.2%; Average loss: 3.2578
# Iteration: 41; Percent complete: 0.3%; Average loss: 3.1807
# Iteration: 42; Percent complete: 0.3%; Average loss: 3.2942
# Iteration: 43; Percent complete: 0.3%; Average loss: 3.1742
# Iteration: 44; Percent complete: 0.3%; Average loss: 3.1871
# Iteration: 45; Percent complete: 0.3%; Average loss: 2.9902
# Iteration: 46; Percent complete: 0.3%; Average loss: 3.2843
# Iteration: 47; Percent complete: 0.3%; Average loss: 3.2973
# Iteration: 48; Percent complete: 0.3%; Average loss: 3.4319
# Iteration: 49; Percent complete: 0.3%; Average loss: 3.2712
# Iteration: 50; Percent complete: 0.3%; Average loss: 3.1394
# Iteration: 51; Percent complete: 0.3%; Average loss: 3.2778
# Iteration: 52; Percent complete: 0.3%; Average loss: 3.3564
# Iteration: 53; Percent complete: 0.3%; Average loss: 3.2782
# Iteration: 54; Percent complete: 0.3%; Average loss: 3.1055
# Iteration: 55; Percent complete: 0.3%; Average loss: 3.3584
# Iteration: 56; Percent complete: 0.4%; Average loss: 3.3737
# Iteration: 57; Percent complete: 0.4%; Average loss: 3.1995
# Iteration: 58; Percent complete: 0.4%; Average loss: 3.2609
# Iteration: 59; Percent complete: 0.4%; Average loss: 2.9706
# Iteration: 60; Percent complete: 0.4%; Average loss: 3.2843
# Iteration: 61; Percent complete: 0.4%; Average loss: 3.2811
# Iteration: 62; Percent complete: 0.4%; Average loss: 3.2484
# Iteration: 63; Percent complete: 0.4%; Average loss: 3.3680
# Iteration: 64; Percent complete: 0.4%; Average loss: 3.0683
# Iteration: 65; Percent complete: 0.4%; Average loss: 3.1157
# Iteration: 66; Percent complete: 0.4%; Average loss: 3.1101
# Iteration: 67; Percent complete: 0.4%; Average loss: 3.4516
# Iteration: 68; Percent complete: 0.4%; Average loss: 3.1661
# Iteration: 69; Percent complete: 0.4%; Average loss: 3.0354
# Iteration: 70; Percent complete: 0.4%; Average loss: 3.0571
# Iteration: 71; Percent complete: 0.4%; Average loss: 3.4317
# Iteration: 72; Percent complete: 0.4%; Average loss: 3.0707
# Iteration: 73; Percent complete: 0.5%; Average loss: 3.2478
# Iteration: 74; Percent complete: 0.5%; Average loss: 3.1138
# Iteration: 75; Percent complete: 0.5%; Average loss: 3.2400
# Iteration: 76; Percent complete: 0.5%; Average loss: 3.3180
# Iteration: 77; Percent complete: 0.5%; Average loss: 3.1235
# Iteration: 78; Percent complete: 0.5%; Average loss: 3.0817
# Iteration: 79; Percent complete: 0.5%; Average loss: 3.2239
# Iteration: 80; Percent complete: 0.5%; Average loss: 2.9658
# Iteration: 81; Percent complete: 0.5%; Average loss: 3.1327
# Iteration: 82; Percent complete: 0.5%; Average loss: 2.9349
# Iteration: 83; Percent complete: 0.5%; Average loss: 3.3608
# Iteration: 84; Percent complete: 0.5%; Average loss: 3.3040
# Iteration: 85; Percent complete: 0.5%; Average loss: 3.0157
# Iteration: 86; Percent complete: 0.5%; Average loss: 3.1289
# Iteration: 87; Percent complete: 0.5%; Average loss: 3.1357
# Iteration: 88; Percent complete: 0.5%; Average loss: 3.2242
# Iteration: 89; Percent complete: 0.6%; Average loss: 3.0924
# Iteration: 90; Percent complete: 0.6%; Average loss: 3.2787
# Iteration: 91; Percent complete: 0.6%; Average loss: 3.3228
# Iteration: 92; Percent complete: 0.6%; Average loss: 3.3481
# Iteration: 93; Percent complete: 0.6%; Average loss: 2.9855
# Iteration: 94; Percent complete: 0.6%; Average loss: 3.2281
# Iteration: 95; Percent complete: 0.6%; Average loss: 3.2254
# Iteration: 96; Percent complete: 0.6%; Average loss: 3.1394
# Iteration: 97; Percent complete: 0.6%; Average loss: 3.1546
# Iteration: 98; Percent complete: 0.6%; Average loss: 3.2097
# Iteration: 99; Percent complete: 0.6%; Average loss: 3.1034
# Iteration: 100; Percent complete: 0.6%; Average loss: 3.0645
# Iteration: 101; Percent complete: 0.6%; Average loss: 3.0818
# Iteration: 102; Percent complete: 0.6%; Average loss: 3.0247
# Iteration: 103; Percent complete: 0.6%; Average loss: 3.0900
# Iteration: 104; Percent complete: 0.7%; Average loss: 3.3761
# Iteration: 105; Percent complete: 0.7%; Average loss: 3.1491
# Iteration: 106; Percent complete: 0.7%; Average loss: 3.5906
# Iteration: 107; Percent complete: 0.7%; Average loss: 3.0979
# Iteration: 108; Percent complete: 0.7%; Average loss: 3.2392
# Iteration: 109; Percent complete: 0.7%; Average loss: 3.1852
# Iteration: 110; Percent complete: 0.7%; Average loss: 3.1447
# Iteration: 111; Percent complete: 0.7%; Average loss: 3.1798
# Iteration: 112; Percent complete: 0.7%; Average loss: 3.1557
# Iteration: 113; Percent complete: 0.7%; Average loss: 2.8880
# Iteration: 114; Percent complete: 0.7%; Average loss: 3.1651
# Iteration: 115; Percent complete: 0.7%; Average loss: 3.3573
# Iteration: 116; Percent complete: 0.7%; Average loss: 3.2163
# Iteration: 117; Percent complete: 0.7%; Average loss: 3.0849
# Iteration: 118; Percent complete: 0.7%; Average loss: 3.2188
# Iteration: 119; Percent complete: 0.7%; Average loss: 3.0051
# Iteration: 120; Percent complete: 0.8%; Average loss: 3.0489
# Iteration: 121; Percent complete: 0.8%; Average loss: 3.0946
# Iteration: 122; Percent complete: 0.8%; Average loss: 3.2797
# Iteration: 123; Percent complete: 0.8%; Average loss: 3.3393
# Iteration: 124; Percent complete: 0.8%; Average loss: 3.3045
# Iteration: 125; Percent complete: 0.8%; Average loss: 2.9443
# Iteration: 126; Percent complete: 0.8%; Average loss: 3.3638
# Iteration: 127; Percent complete: 0.8%; Average loss: 2.8312
# Iteration: 128; Percent complete: 0.8%; Average loss: 3.1576
# Iteration: 129; Percent complete: 0.8%; Average loss: 3.2846
# Iteration: 130; Percent complete: 0.8%; Average loss: 3.0810
# Iteration: 131; Percent complete: 0.8%; Average loss: 2.9802
# Iteration: 132; Percent complete: 0.8%; Average loss: 3.0218
# Iteration: 133; Percent complete: 0.8%; Average loss: 3.1457
# Iteration: 134; Percent complete: 0.8%; Average loss: 3.4339
# Iteration: 135; Percent complete: 0.8%; Average loss: 3.1187
# Iteration: 136; Percent complete: 0.9%; Average loss: 3.2650
# Iteration: 137; Percent complete: 0.9%; Average loss: 3.2543
# Iteration: 138; Percent complete: 0.9%; Average loss: 3.3090
# Iteration: 139; Percent complete: 0.9%; Average loss: 3.2244
# Iteration: 140; Percent complete: 0.9%; Average loss: 3.0424
# Iteration: 141; Percent complete: 0.9%; Average loss: 3.1061
# Iteration: 142; Percent complete: 0.9%; Average loss: 3.2338
# Iteration: 143; Percent complete: 0.9%; Average loss: 3.2241
# Iteration: 144; Percent complete: 0.9%; Average loss: 3.4002
# Iteration: 145; Percent complete: 0.9%; Average loss: 3.2353
# Iteration: 146; Percent complete: 0.9%; Average loss: 3.3167
# Iteration: 147; Percent complete: 0.9%; Average loss: 3.0518
# Iteration: 148; Percent complete: 0.9%; Average loss: 3.0908
# Iteration: 149; Percent complete: 0.9%; Average loss: 3.1873
# Iteration: 150; Percent complete: 0.9%; Average loss: 3.0639
# Iteration: 151; Percent complete: 0.9%; Average loss: 3.1129
# Iteration: 152; Percent complete: 0.9%; Average loss: 3.2470
# Iteration: 153; Percent complete: 1.0%; Average loss: 2.9002
# Iteration: 154; Percent complete: 1.0%; Average loss: 3.0664
# Iteration: 155; Percent complete: 1.0%; Average loss: 3.1286
# Iteration: 156; Percent complete: 1.0%; Average loss: 3.1843
# Iteration: 157; Percent complete: 1.0%; Average loss: 2.9566
# Iteration: 158; Percent complete: 1.0%; Average loss: 3.0572
# Iteration: 159; Percent complete: 1.0%; Average loss: 3.2823
# Iteration: 160; Percent complete: 1.0%; Average loss: 3.5010
# Iteration: 161; Percent complete: 1.0%; Average loss: 3.0853
# Iteration: 162; Percent complete: 1.0%; Average loss: 3.4343
# Iteration: 163; Percent complete: 1.0%; Average loss: 3.1796
# Iteration: 164; Percent complete: 1.0%; Average loss: 3.2699
# Iteration: 165; Percent complete: 1.0%; Average loss: 3.1400
# Iteration: 166; Percent complete: 1.0%; Average loss: 3.3796
# Iteration: 167; Percent complete: 1.0%; Average loss: 3.0940
# Iteration: 168; Percent complete: 1.1%; Average loss: 3.2268
# Iteration: 169; Percent complete: 1.1%; Average loss: 3.2097
# Iteration: 170; Percent complete: 1.1%; Average loss: 3.3878
# Iteration: 171; Percent complete: 1.1%; Average loss: 3.1932
# Iteration: 172; Percent complete: 1.1%; Average loss: 2.8748
# Iteration: 173; Percent complete: 1.1%; Average loss: 3.0206
# Iteration: 174; Percent complete: 1.1%; Average loss: 3.0559
# Iteration: 175; Percent complete: 1.1%; Average loss: 3.0753
# Iteration: 176; Percent complete: 1.1%; Average loss: 3.2048
# Iteration: 177; Percent complete: 1.1%; Average loss: 3.5323
# Iteration: 178; Percent complete: 1.1%; Average loss: 2.9513
# Iteration: 179; Percent complete: 1.1%; Average loss: 3.3021
# Iteration: 180; Percent complete: 1.1%; Average loss: 3.1975
# Iteration: 181; Percent complete: 1.1%; Average loss: 3.1457
# Iteration: 182; Percent complete: 1.1%; Average loss: 3.2531
# Iteration: 183; Percent complete: 1.1%; Average loss: 3.1457
# Iteration: 184; Percent complete: 1.1%; Average loss: 3.1857
# Iteration: 185; Percent complete: 1.2%; Average loss: 3.1665
# Iteration: 186; Percent complete: 1.2%; Average loss: 3.0806
# Iteration: 187; Percent complete: 1.2%; Average loss: 3.2520
# Iteration: 188; Percent complete: 1.2%; Average loss: 3.0452
# Iteration: 189; Percent complete: 1.2%; Average loss: 3.1601
# Iteration: 190; Percent complete: 1.2%; Average loss: 2.9882
# Iteration: 191; Percent complete: 1.2%; Average loss: 3.1673
# Iteration: 192; Percent complete: 1.2%; Average loss: 2.9666
# Iteration: 193; Percent complete: 1.2%; Average loss: 3.4617
# Iteration: 194; Percent complete: 1.2%; Average loss: 3.1840
# Iteration: 195; Percent complete: 1.2%; Average loss: 2.8942
# Iteration: 196; Percent complete: 1.2%; Average loss: 3.0322
# Iteration: 197; Percent complete: 1.2%; Average loss: 3.1427
# Iteration: 198; Percent complete: 1.2%; Average loss: 3.0535
# Iteration: 199; Percent complete: 1.2%; Average loss: 3.1446
# Iteration: 200; Percent complete: 1.2%; Average loss: 3.1057
# Iteration: 201; Percent complete: 1.3%; Average loss: 3.0394
# Iteration: 202; Percent complete: 1.3%; Average loss: 3.0280
# Iteration: 203; Percent complete: 1.3%; Average loss: 3.2879
# Iteration: 204; Percent complete: 1.3%; Average loss: 3.2003
# Iteration: 205; Percent complete: 1.3%; Average loss: 3.4075
# Iteration: 206; Percent complete: 1.3%; Average loss: 2.9984
# Iteration: 207; Percent complete: 1.3%; Average loss: 3.0711
# Iteration: 208; Percent complete: 1.3%; Average loss: 3.1273
# Iteration: 209; Percent complete: 1.3%; Average loss: 3.1058
# Iteration: 210; Percent complete: 1.3%; Average loss: 3.1384
# Iteration: 211; Percent complete: 1.3%; Average loss: 3.1911
# Iteration: 212; Percent complete: 1.3%; Average loss: 3.1827
# Iteration: 213; Percent complete: 1.3%; Average loss: 2.9118
# Iteration: 214; Percent complete: 1.3%; Average loss: 3.1273
# Iteration: 215; Percent complete: 1.3%; Average loss: 3.2955
# Iteration: 216; Percent complete: 1.4%; Average loss: 3.3943
# Iteration: 217; Percent complete: 1.4%; Average loss: 3.3209
# Iteration: 218; Percent complete: 1.4%; Average loss: 3.1874
# Iteration: 219; Percent complete: 1.4%; Average loss: 3.2009
# Iteration: 220; Percent complete: 1.4%; Average loss: 3.0873
# Iteration: 221; Percent complete: 1.4%; Average loss: 3.0046
# Iteration: 222; Percent complete: 1.4%; Average loss: 3.2820
# Iteration: 223; Percent complete: 1.4%; Average loss: 3.2393
# Iteration: 224; Percent complete: 1.4%; Average loss: 2.9392
# Iteration: 225; Percent complete: 1.4%; Average loss: 2.9332
# Iteration: 226; Percent complete: 1.4%; Average loss: 3.0527
# Iteration: 227; Percent complete: 1.4%; Average loss: 3.0847
# Iteration: 228; Percent complete: 1.4%; Average loss: 3.3441
# Iteration: 229; Percent complete: 1.4%; Average loss: 3.1169
# Iteration: 230; Percent complete: 1.4%; Average loss: 3.0598
# Iteration: 231; Percent complete: 1.4%; Average loss: 2.7990
# Iteration: 232; Percent complete: 1.5%; Average loss: 3.4081
# Iteration: 233; Percent complete: 1.5%; Average loss: 3.0604
# Iteration: 234; Percent complete: 1.5%; Average loss: 3.2963
# Iteration: 235; Percent complete: 1.5%; Average loss: 3.1641
# Iteration: 236; Percent complete: 1.5%; Average loss: 2.8883
# Iteration: 237; Percent complete: 1.5%; Average loss: 2.9802
# Iteration: 238; Percent complete: 1.5%; Average loss: 3.1174
# Iteration: 239; Percent complete: 1.5%; Average loss: 3.1497
# Iteration: 240; Percent complete: 1.5%; Average loss: 3.0398
# Iteration: 241; Percent complete: 1.5%; Average loss: 3.3498
# Iteration: 242; Percent complete: 1.5%; Average loss: 3.2054
# Iteration: 243; Percent complete: 1.5%; Average loss: 3.0579
# Iteration: 244; Percent complete: 1.5%; Average loss: 3.1439
# Iteration: 245; Percent complete: 1.5%; Average loss: 3.1560
# Iteration: 246; Percent complete: 1.5%; Average loss: 3.2129
# Iteration: 247; Percent complete: 1.5%; Average loss: 3.0987
# Iteration: 248; Percent complete: 1.6%; Average loss: 3.0257
# Iteration: 249; Percent complete: 1.6%; Average loss: 3.0396
# Iteration: 250; Percent complete: 1.6%; Average loss: 3.0226
# Iteration: 251; Percent complete: 1.6%; Average loss: 3.1822
# Iteration: 252; Percent complete: 1.6%; Average loss: 3.1494
# Iteration: 253; Percent complete: 1.6%; Average loss: 2.8048
# Iteration: 254; Percent complete: 1.6%; Average loss: 3.1137
# Iteration: 255; Percent complete: 1.6%; Average loss: 3.1290
# Iteration: 256; Percent complete: 1.6%; Average loss: 3.2299
# Iteration: 257; Percent complete: 1.6%; Average loss: 3.2550
# Iteration: 258; Percent complete: 1.6%; Average loss: 3.1369
# Iteration: 259; Percent complete: 1.6%; Average loss: 3.0001
# Iteration: 260; Percent complete: 1.6%; Average loss: 3.0906
# Iteration: 261; Percent complete: 1.6%; Average loss: 3.0605
# Iteration: 262; Percent complete: 1.6%; Average loss: 3.2077
# Iteration: 263; Percent complete: 1.6%; Average loss: 3.2303
# Iteration: 264; Percent complete: 1.7%; Average loss: 3.3462
# Iteration: 265; Percent complete: 1.7%; Average loss: 3.3518
# Iteration: 266; Percent complete: 1.7%; Average loss: 3.1173
# Iteration: 267; Percent complete: 1.7%; Average loss: 3.2081
# Iteration: 268; Percent complete: 1.7%; Average loss: 3.1328
# Iteration: 269; Percent complete: 1.7%; Average loss: 3.0291
# Iteration: 270; Percent complete: 1.7%; Average loss: 3.0561
# Iteration: 271; Percent complete: 1.7%; Average loss: 3.2053
# Iteration: 272; Percent complete: 1.7%; Average loss: 3.2192
# Iteration: 273; Percent complete: 1.7%; Average loss: 3.1400
# Iteration: 274; Percent complete: 1.7%; Average loss: 3.0316
# Iteration: 275; Percent complete: 1.7%; Average loss: 3.0903
# Iteration: 276; Percent complete: 1.7%; Average loss: 3.4202
# Iteration: 277; Percent complete: 1.7%; Average loss: 2.9860
# Iteration: 278; Percent complete: 1.7%; Average loss: 3.2116
# Iteration: 279; Percent complete: 1.7%; Average loss: 3.1581
# Iteration: 280; Percent complete: 1.8%; Average loss: 3.1492
# Iteration: 281; Percent complete: 1.8%; Average loss: 3.2836
# Iteration: 282; Percent complete: 1.8%; Average loss: 3.2187
# Iteration: 283; Percent complete: 1.8%; Average loss: 3.0413
# Iteration: 284; Percent complete: 1.8%; Average loss: 3.0401
# Iteration: 285; Percent complete: 1.8%; Average loss: 3.0931
# Iteration: 286; Percent complete: 1.8%; Average loss: 3.1021
# Iteration: 287; Percent complete: 1.8%; Average loss: 3.3101
# Iteration: 288; Percent complete: 1.8%; Average loss: 3.2369
# Iteration: 289; Percent complete: 1.8%; Average loss: 2.9353
# Iteration: 290; Percent complete: 1.8%; Average loss: 3.2294
# Iteration: 291; Percent complete: 1.8%; Average loss: 3.2914
# Iteration: 292; Percent complete: 1.8%; Average loss: 3.2361
# Iteration: 293; Percent complete: 1.8%; Average loss: 3.1229
# Iteration: 294; Percent complete: 1.8%; Average loss: 2.8997
# Iteration: 295; Percent complete: 1.8%; Average loss: 2.8116
# Iteration: 296; Percent complete: 1.8%; Average loss: 2.8821
# Iteration: 297; Percent complete: 1.9%; Average loss: 3.3116
# Iteration: 298; Percent complete: 1.9%; Average loss: 3.1029
# Iteration: 299; Percent complete: 1.9%; Average loss: 2.9814
# Iteration: 300; Percent complete: 1.9%; Average loss: 3.2698
# Iteration: 301; Percent complete: 1.9%; Average loss: 3.0659
# Iteration: 302; Percent complete: 1.9%; Average loss: 3.2388
# Iteration: 303; Percent complete: 1.9%; Average loss: 2.9839
# Iteration: 304; Percent complete: 1.9%; Average loss: 3.0471
# Iteration: 305; Percent complete: 1.9%; Average loss: 3.1641
# Iteration: 306; Percent complete: 1.9%; Average loss: 3.1634
# Iteration: 307; Percent complete: 1.9%; Average loss: 3.2348
# Iteration: 308; Percent complete: 1.9%; Average loss: 2.9390
# Iteration: 309; Percent complete: 1.9%; Average loss: 3.0155
# Iteration: 310; Percent complete: 1.9%; Average loss: 2.9423
# Iteration: 311; Percent complete: 1.9%; Average loss: 3.0565
# Iteration: 312; Percent complete: 1.9%; Average loss: 2.9915
# Iteration: 313; Percent complete: 2.0%; Average loss: 3.3316
# Iteration: 314; Percent complete: 2.0%; Average loss: 3.0211
# Iteration: 315; Percent complete: 2.0%; Average loss: 3.1942
# Iteration: 316; Percent complete: 2.0%; Average loss: 3.0754
# Iteration: 317; Percent complete: 2.0%; Average loss: 2.8809
# Iteration: 318; Percent complete: 2.0%; Average loss: 2.9923
# Iteration: 319; Percent complete: 2.0%; Average loss: 3.0661
# Iteration: 320; Percent complete: 2.0%; Average loss: 2.8414
# Iteration: 321; Percent complete: 2.0%; Average loss: 2.9461
# Iteration: 322; Percent complete: 2.0%; Average loss: 3.1633
# Iteration: 323; Percent complete: 2.0%; Average loss: 3.2241
# Iteration: 324; Percent complete: 2.0%; Average loss: 3.1311
# Iteration: 325; Percent complete: 2.0%; Average loss: 2.9733
# Iteration: 326; Percent complete: 2.0%; Average loss: 3.0184
# Iteration: 327; Percent complete: 2.0%; Average loss: 3.2488
# Iteration: 328; Percent complete: 2.1%; Average loss: 3.2589
# Iteration: 329; Percent complete: 2.1%; Average loss: 2.9828
# Iteration: 330; Percent complete: 2.1%; Average loss: 2.9392
# Iteration: 331; Percent complete: 2.1%; Average loss: 3.0915
# Iteration: 332; Percent complete: 2.1%; Average loss: 3.3880
# Iteration: 333; Percent complete: 2.1%; Average loss: 3.1026
# Iteration: 334; Percent complete: 2.1%; Average loss: 3.1021
# Iteration: 335; Percent complete: 2.1%; Average loss: 3.0660
# Iteration: 336; Percent complete: 2.1%; Average loss: 3.1229
# Iteration: 337; Percent complete: 2.1%; Average loss: 3.1880
# Iteration: 338; Percent complete: 2.1%; Average loss: 3.1566
# Iteration: 339; Percent complete: 2.1%; Average loss: 3.2163
# Iteration: 340; Percent complete: 2.1%; Average loss: 3.1808
# Iteration: 341; Percent complete: 2.1%; Average loss: 2.9778
# Iteration: 342; Percent complete: 2.1%; Average loss: 3.3907
# Iteration: 343; Percent complete: 2.1%; Average loss: 2.9048
# Iteration: 344; Percent complete: 2.1%; Average loss: 3.0249
# Iteration: 345; Percent complete: 2.2%; Average loss: 3.1352
# Iteration: 346; Percent complete: 2.2%; Average loss: 2.9471
# Iteration: 347; Percent complete: 2.2%; Average loss: 3.2122
# Iteration: 348; Percent complete: 2.2%; Average loss: 3.1650
# Iteration: 349; Percent complete: 2.2%; Average loss: 2.9941
# Iteration: 350; Percent complete: 2.2%; Average loss: 2.8668
# Iteration: 351; Percent complete: 2.2%; Average loss: 3.2742
# Iteration: 352; Percent complete: 2.2%; Average loss: 3.0606
# Iteration: 353; Percent complete: 2.2%; Average loss: 3.1878
# Iteration: 354; Percent complete: 2.2%; Average loss: 3.3295
# Iteration: 355; Percent complete: 2.2%; Average loss: 3.1375
# Iteration: 356; Percent complete: 2.2%; Average loss: 3.3075
# Iteration: 357; Percent complete: 2.2%; Average loss: 3.4137
# Iteration: 358; Percent complete: 2.2%; Average loss: 2.9205
# Iteration: 359; Percent complete: 2.2%; Average loss: 2.9832
# Iteration: 360; Percent complete: 2.2%; Average loss: 2.8306
# Iteration: 361; Percent complete: 2.3%; Average loss: 3.0579
# Iteration: 362; Percent complete: 2.3%; Average loss: 3.4646
# Iteration: 363; Percent complete: 2.3%; Average loss: 2.8819
# Iteration: 364; Percent complete: 2.3%; Average loss: 2.8535
# Iteration: 365; Percent complete: 2.3%; Average loss: 3.1885
# Iteration: 366; Percent complete: 2.3%; Average loss: 2.9609
# Iteration: 367; Percent complete: 2.3%; Average loss: 3.3804
# Iteration: 368; Percent complete: 2.3%; Average loss: 3.2748
# Iteration: 369; Percent complete: 2.3%; Average loss: 3.0885
# Iteration: 370; Percent complete: 2.3%; Average loss: 2.7969
# Iteration: 371; Percent complete: 2.3%; Average loss: 3.0878
# Iteration: 372; Percent complete: 2.3%; Average loss: 3.2182
# Iteration: 373; Percent complete: 2.3%; Average loss: 2.9770
# Iteration: 374; Percent complete: 2.3%; Average loss: 3.1824
# Iteration: 375; Percent complete: 2.3%; Average loss: 3.0225
# Iteration: 376; Percent complete: 2.4%; Average loss: 2.8718
# Iteration: 377; Percent complete: 2.4%; Average loss: 3.1334
# Iteration: 378; Percent complete: 2.4%; Average loss: 3.0375
# Iteration: 379; Percent complete: 2.4%; Average loss: 3.1658
# Iteration: 380; Percent complete: 2.4%; Average loss: 3.1157
# Iteration: 381; Percent complete: 2.4%; Average loss: 3.2138
# Iteration: 382; Percent complete: 2.4%; Average loss: 2.9478
# Iteration: 383; Percent complete: 2.4%; Average loss: 3.2092
# Iteration: 384; Percent complete: 2.4%; Average loss: 3.1228
# Iteration: 385; Percent complete: 2.4%; Average loss: 3.1355
# Iteration: 386; Percent complete: 2.4%; Average loss: 2.9408
# Iteration: 387; Percent complete: 2.4%; Average loss: 3.2819
# Iteration: 388; Percent complete: 2.4%; Average loss: 3.1372
# Iteration: 389; Percent complete: 2.4%; Average loss: 3.1570
# Iteration: 390; Percent complete: 2.4%; Average loss: 2.9628
# Iteration: 391; Percent complete: 2.4%; Average loss: 2.9688
# Iteration: 392; Percent complete: 2.5%; Average loss: 3.1729
# Iteration: 393; Percent complete: 2.5%; Average loss: 3.0364
# Iteration: 394; Percent complete: 2.5%; Average loss: 3.1178
# Iteration: 395; Percent complete: 2.5%; Average loss: 3.1692
# Iteration: 396; Percent complete: 2.5%; Average loss: 2.9448
# Iteration: 397; Percent complete: 2.5%; Average loss: 3.0612
# Iteration: 398; Percent complete: 2.5%; Average loss: 2.9207
# Iteration: 399; Percent complete: 2.5%; Average loss: 3.0989
# Iteration: 400; Percent complete: 2.5%; Average loss: 3.0037
# Iteration: 401; Percent complete: 2.5%; Average loss: 3.1251
# Iteration: 402; Percent complete: 2.5%; Average loss: 2.9161
# Iteration: 403; Percent complete: 2.5%; Average loss: 2.9561
# Iteration: 404; Percent complete: 2.5%; Average loss: 2.6104
# Iteration: 405; Percent complete: 2.5%; Average loss: 2.9546
# Iteration: 406; Percent complete: 2.5%; Average loss: 3.0748
# Iteration: 407; Percent complete: 2.5%; Average loss: 3.1735
# Iteration: 408; Percent complete: 2.5%; Average loss: 2.9987
# Iteration: 409; Percent complete: 2.6%; Average loss: 3.0674
# Iteration: 410; Percent complete: 2.6%; Average loss: 3.0596
# Iteration: 411; Percent complete: 2.6%; Average loss: 3.0458
# Iteration: 412; Percent complete: 2.6%; Average loss: 3.1889
# Iteration: 413; Percent complete: 2.6%; Average loss: 2.9907
# Iteration: 414; Percent complete: 2.6%; Average loss: 3.0322
# Iteration: 415; Percent complete: 2.6%; Average loss: 2.7658
# Iteration: 416; Percent complete: 2.6%; Average loss: 3.0183
# Iteration: 417; Percent complete: 2.6%; Average loss: 2.9426
# Iteration: 418; Percent complete: 2.6%; Average loss: 3.3727
# Iteration: 419; Percent complete: 2.6%; Average loss: 3.0937
# Iteration: 420; Percent complete: 2.6%; Average loss: 2.9958
# Iteration: 421; Percent complete: 2.6%; Average loss: 3.0729
# Iteration: 422; Percent complete: 2.6%; Average loss: 3.1141
# Iteration: 423; Percent complete: 2.6%; Average loss: 3.1424
# Iteration: 424; Percent complete: 2.6%; Average loss: 3.3453
# Iteration: 425; Percent complete: 2.7%; Average loss: 2.8914
# Iteration: 426; Percent complete: 2.7%; Average loss: 2.9018
# Iteration: 427; Percent complete: 2.7%; Average loss: 3.0536
# Iteration: 428; Percent complete: 2.7%; Average loss: 2.7965
# Iteration: 429; Percent complete: 2.7%; Average loss: 3.0214
# Iteration: 430; Percent complete: 2.7%; Average loss: 3.2376
# Iteration: 431; Percent complete: 2.7%; Average loss: 3.2215
# Iteration: 432; Percent complete: 2.7%; Average loss: 3.0727
# Iteration: 433; Percent complete: 2.7%; Average loss: 2.9990
# Iteration: 434; Percent complete: 2.7%; Average loss: 3.1032
# Iteration: 435; Percent complete: 2.7%; Average loss: 2.9196
# Iteration: 436; Percent complete: 2.7%; Average loss: 3.1614
# Iteration: 437; Percent complete: 2.7%; Average loss: 2.9713
# Iteration: 438; Percent complete: 2.7%; Average loss: 3.0165
# Iteration: 439; Percent complete: 2.7%; Average loss: 2.9715
# Iteration: 440; Percent complete: 2.8%; Average loss: 3.1259
# Iteration: 441; Percent complete: 2.8%; Average loss: 3.0425
# Iteration: 442; Percent complete: 2.8%; Average loss: 3.0571
# Iteration: 443; Percent complete: 2.8%; Average loss: 3.0474
# Iteration: 444; Percent complete: 2.8%; Average loss: 2.9083
# Iteration: 445; Percent complete: 2.8%; Average loss: 3.0677
# Iteration: 446; Percent complete: 2.8%; Average loss: 3.0469
# Iteration: 447; Percent complete: 2.8%; Average loss: 3.2786
# Iteration: 448; Percent complete: 2.8%; Average loss: 3.0614
# Iteration: 449; Percent complete: 2.8%; Average loss: 3.1272
# Iteration: 450; Percent complete: 2.8%; Average loss: 2.7689
# Iteration: 451; Percent complete: 2.8%; Average loss: 2.8288
# Iteration: 452; Percent complete: 2.8%; Average loss: 3.2178
# Iteration: 453; Percent complete: 2.8%; Average loss: 2.8290
# Iteration: 454; Percent complete: 2.8%; Average loss: 3.0124
# Iteration: 455; Percent complete: 2.8%; Average loss: 3.0765
# Iteration: 456; Percent complete: 2.9%; Average loss: 3.1864
# Iteration: 457; Percent complete: 2.9%; Average loss: 3.1169
# Iteration: 458; Percent complete: 2.9%; Average loss: 3.0321
# Iteration: 459; Percent complete: 2.9%; Average loss: 2.7728
# Iteration: 460; Percent complete: 2.9%; Average loss: 3.1607
# Iteration: 461; Percent complete: 2.9%; Average loss: 3.0719
# Iteration: 462; Percent complete: 2.9%; Average loss: 2.9885
# Iteration: 463; Percent complete: 2.9%; Average loss: 3.0665
# Iteration: 464; Percent complete: 2.9%; Average loss: 2.9184
# Iteration: 465; Percent complete: 2.9%; Average loss: 2.7762
# Iteration: 466; Percent complete: 2.9%; Average loss: 3.1453
# Iteration: 467; Percent complete: 2.9%; Average loss: 3.1420
# Iteration: 468; Percent complete: 2.9%; Average loss: 2.8609
# Iteration: 469; Percent complete: 2.9%; Average loss: 3.2105
# Iteration: 470; Percent complete: 2.9%; Average loss: 3.2205
# Iteration: 471; Percent complete: 2.9%; Average loss: 2.9128
# Iteration: 472; Percent complete: 2.9%; Average loss: 3.1610
# Iteration: 473; Percent complete: 3.0%; Average loss: 3.0421
# Iteration: 474; Percent complete: 3.0%; Average loss: 3.1713
# Iteration: 475; Percent complete: 3.0%; Average loss: 2.9168
# Iteration: 476; Percent complete: 3.0%; Average loss: 3.1004
# Iteration: 477; Percent complete: 3.0%; Average loss: 3.1527
# Iteration: 478; Percent complete: 3.0%; Average loss: 3.0073
# Iteration: 479; Percent complete: 3.0%; Average loss: 3.1052
# Iteration: 480; Percent complete: 3.0%; Average loss: 3.2722
# Iteration: 481; Percent complete: 3.0%; Average loss: 3.2348
# Iteration: 482; Percent complete: 3.0%; Average loss: 3.1974
# Iteration: 483; Percent complete: 3.0%; Average loss: 3.4012
# Iteration: 484; Percent complete: 3.0%; Average loss: 2.9858
# Iteration: 485; Percent complete: 3.0%; Average loss: 2.9886
# Iteration: 486; Percent complete: 3.0%; Average loss: 2.9279
# Iteration: 487; Percent complete: 3.0%; Average loss: 3.1874
# Iteration: 488; Percent complete: 3.0%; Average loss: 2.9274
# Iteration: 489; Percent complete: 3.1%; Average loss: 2.9387
# Iteration: 490; Percent complete: 3.1%; Average loss: 2.9941
# Iteration: 491; Percent complete: 3.1%; Average loss: 3.2391
# Iteration: 492; Percent complete: 3.1%; Average loss: 2.8891
# Iteration: 493; Percent complete: 3.1%; Average loss: 3.0956
# Iteration: 494; Percent complete: 3.1%; Average loss: 3.2024
# Iteration: 495; Percent complete: 3.1%; Average loss: 3.1242
# Iteration: 496; Percent complete: 3.1%; Average loss: 3.0301
# Iteration: 497; Percent complete: 3.1%; Average loss: 2.8750
# Iteration: 498; Percent complete: 3.1%; Average loss: 2.9113
# Iteration: 499; Percent complete: 3.1%; Average loss: 3.0137
# Iteration: 500; Percent complete: 3.1%; Average loss: 3.0425
# Iteration: 501; Percent complete: 3.1%; Average loss: 3.3764
# Iteration: 502; Percent complete: 3.1%; Average loss: 3.2853
# Iteration: 503; Percent complete: 3.1%; Average loss: 3.1026
# Iteration: 504; Percent complete: 3.1%; Average loss: 3.0427
# Iteration: 505; Percent complete: 3.2%; Average loss: 3.0821
# Iteration: 506; Percent complete: 3.2%; Average loss: 2.9367
# Iteration: 507; Percent complete: 3.2%; Average loss: 2.9914
# Iteration: 508; Percent complete: 3.2%; Average loss: 2.8859
# Iteration: 509; Percent complete: 3.2%; Average loss: 2.9293
# Iteration: 510; Percent complete: 3.2%; Average loss: 2.9908
# Iteration: 511; Percent complete: 3.2%; Average loss: 3.1852
# Iteration: 512; Percent complete: 3.2%; Average loss: 2.7719
# Iteration: 513; Percent complete: 3.2%; Average loss: 2.8404
# Iteration: 514; Percent complete: 3.2%; Average loss: 3.3353
# Iteration: 515; Percent complete: 3.2%; Average loss: 2.9460
# Iteration: 516; Percent complete: 3.2%; Average loss: 2.9891
# Iteration: 517; Percent complete: 3.2%; Average loss: 3.0015
# Iteration: 518; Percent complete: 3.2%; Average loss: 2.8570
# Iteration: 519; Percent complete: 3.2%; Average loss: 3.2113
# Iteration: 520; Percent complete: 3.2%; Average loss: 3.3347
# Iteration: 521; Percent complete: 3.3%; Average loss: 2.8765
# Iteration: 522; Percent complete: 3.3%; Average loss: 3.1583
# Iteration: 523; Percent complete: 3.3%; Average loss: 2.9645
# Iteration: 524; Percent complete: 3.3%; Average loss: 2.8833
# Iteration: 525; Percent complete: 3.3%; Average loss: 3.2111
# Iteration: 526; Percent complete: 3.3%; Average loss: 3.2130
# Iteration: 527; Percent complete: 3.3%; Average loss: 3.0083
# Iteration: 528; Percent complete: 3.3%; Average loss: 2.8060
# Iteration: 529; Percent complete: 3.3%; Average loss: 3.2173
# Iteration: 530; Percent complete: 3.3%; Average loss: 3.1447
# Iteration: 531; Percent complete: 3.3%; Average loss: 2.9723
# Iteration: 532; Percent complete: 3.3%; Average loss: 3.0284
# Iteration: 533; Percent complete: 3.3%; Average loss: 3.0194
# Iteration: 534; Percent complete: 3.3%; Average loss: 2.9664
# Iteration: 535; Percent complete: 3.3%; Average loss: 2.8848
# Iteration: 536; Percent complete: 3.4%; Average loss: 2.8653
# Iteration: 537; Percent complete: 3.4%; Average loss: 2.8994
# Iteration: 538; Percent complete: 3.4%; Average loss: 3.0307
# Iteration: 539; Percent complete: 3.4%; Average loss: 2.9422
# Iteration: 540; Percent complete: 3.4%; Average loss: 3.0331
# Iteration: 541; Percent complete: 3.4%; Average loss: 3.1021
# Iteration: 542; Percent complete: 3.4%; Average loss: 3.0164
# Iteration: 543; Percent complete: 3.4%; Average loss: 3.2583
# Iteration: 544; Percent complete: 3.4%; Average loss: 3.0090
# Iteration: 545; Percent complete: 3.4%; Average loss: 3.0797
# Iteration: 546; Percent complete: 3.4%; Average loss: 2.8372
# Iteration: 547; Percent complete: 3.4%; Average loss: 3.0916
# Iteration: 548; Percent complete: 3.4%; Average loss: 3.3132
# Iteration: 549; Percent complete: 3.4%; Average loss: 2.9765
# Iteration: 550; Percent complete: 3.4%; Average loss: 3.1319
# Iteration: 551; Percent complete: 3.4%; Average loss: 3.2519
# Iteration: 552; Percent complete: 3.5%; Average loss: 3.0008
# Iteration: 553; Percent complete: 3.5%; Average loss: 2.8435
# Iteration: 554; Percent complete: 3.5%; Average loss: 3.0955
# Iteration: 555; Percent complete: 3.5%; Average loss: 3.1460
# Iteration: 556; Percent complete: 3.5%; Average loss: 3.0391
# Iteration: 557; Percent complete: 3.5%; Average loss: 2.8721
# Iteration: 558; Percent complete: 3.5%; Average loss: 3.0198
# Iteration: 559; Percent complete: 3.5%; Average loss: 3.1167
# Iteration: 560; Percent complete: 3.5%; Average loss: 3.0240
# Iteration: 561; Percent complete: 3.5%; Average loss: 2.9804
# Iteration: 562; Percent complete: 3.5%; Average loss: 2.8455
# Iteration: 563; Percent complete: 3.5%; Average loss: 2.9450
# Iteration: 564; Percent complete: 3.5%; Average loss: 3.2741
# Iteration: 565; Percent complete: 3.5%; Average loss: 2.9369
# Iteration: 566; Percent complete: 3.5%; Average loss: 3.0306
# Iteration: 567; Percent complete: 3.5%; Average loss: 2.9312
# Iteration: 568; Percent complete: 3.5%; Average loss: 3.0913
# Iteration: 569; Percent complete: 3.6%; Average loss: 2.9384
# Iteration: 570; Percent complete: 3.6%; Average loss: 3.1305
# Iteration: 571; Percent complete: 3.6%; Average loss: 3.0761
# Iteration: 572; Percent complete: 3.6%; Average loss: 2.9100
# Iteration: 573; Percent complete: 3.6%; Average loss: 3.0344
# Iteration: 574; Percent complete: 3.6%; Average loss: 3.0048
# Iteration: 575; Percent complete: 3.6%; Average loss: 2.9528
# Iteration: 576; Percent complete: 3.6%; Average loss: 3.0241
# Iteration: 577; Percent complete: 3.6%; Average loss: 2.9135
# Iteration: 578; Percent complete: 3.6%; Average loss: 2.8680
# Iteration: 579; Percent complete: 3.6%; Average loss: 3.0115
# Iteration: 580; Percent complete: 3.6%; Average loss: 3.1189
# Iteration: 581; Percent complete: 3.6%; Average loss: 2.9647
# Iteration: 582; Percent complete: 3.6%; Average loss: 2.9307
# Iteration: 583; Percent complete: 3.6%; Average loss: 2.7761
# Iteration: 584; Percent complete: 3.6%; Average loss: 3.2150
# Iteration: 585; Percent complete: 3.7%; Average loss: 2.9555
# Iteration: 586; Percent complete: 3.7%; Average loss: 2.9035
# Iteration: 587; Percent complete: 3.7%; Average loss: 3.1152
# Iteration: 588; Percent complete: 3.7%; Average loss: 3.1467
# Iteration: 589; Percent complete: 3.7%; Average loss: 2.8728
# Iteration: 590; Percent complete: 3.7%; Average loss: 2.9674
# Iteration: 591; Percent complete: 3.7%; Average loss: 2.9289
# Iteration: 592; Percent complete: 3.7%; Average loss: 3.0130
# Iteration: 593; Percent complete: 3.7%; Average loss: 2.9620
# Iteration: 594; Percent complete: 3.7%; Average loss: 3.1759
# Iteration: 595; Percent complete: 3.7%; Average loss: 2.8334
# Iteration: 596; Percent complete: 3.7%; Average loss: 2.9732
# Iteration: 597; Percent complete: 3.7%; Average loss: 3.1220
# Iteration: 598; Percent complete: 3.7%; Average loss: 2.8835
# Iteration: 599; Percent complete: 3.7%; Average loss: 2.7534
# Iteration: 600; Percent complete: 3.8%; Average loss: 3.1097
# Iteration: 601; Percent complete: 3.8%; Average loss: 2.7582
# Iteration: 602; Percent complete: 3.8%; Average loss: 3.0378
# Iteration: 603; Percent complete: 3.8%; Average loss: 3.1409
# Iteration: 604; Percent complete: 3.8%; Average loss: 2.7602
# Iteration: 605; Percent complete: 3.8%; Average loss: 2.9290
# Iteration: 606; Percent complete: 3.8%; Average loss: 3.0716
# Iteration: 607; Percent complete: 3.8%; Average loss: 3.0939
# Iteration: 608; Percent complete: 3.8%; Average loss: 3.0624
# Iteration: 609; Percent complete: 3.8%; Average loss: 3.0845
# Iteration: 610; Percent complete: 3.8%; Average loss: 3.0196
# Iteration: 611; Percent complete: 3.8%; Average loss: 2.9202
# Iteration: 612; Percent complete: 3.8%; Average loss: 2.7339
# Iteration: 613; Percent complete: 3.8%; Average loss: 3.1539
# Iteration: 614; Percent complete: 3.8%; Average loss: 3.0427
# Iteration: 615; Percent complete: 3.8%; Average loss: 2.8314
# Iteration: 616; Percent complete: 3.9%; Average loss: 3.0799
# Iteration: 617; Percent complete: 3.9%; Average loss: 3.1465
# Iteration: 618; Percent complete: 3.9%; Average loss: 2.9594
# Iteration: 619; Percent complete: 3.9%; Average loss: 2.8879
# Iteration: 620; Percent complete: 3.9%; Average loss: 2.9337
# Iteration: 621; Percent complete: 3.9%; Average loss: 2.8753
# Iteration: 622; Percent complete: 3.9%; Average loss: 2.8310
# Iteration: 623; Percent complete: 3.9%; Average loss: 2.9534
# Iteration: 624; Percent complete: 3.9%; Average loss: 2.8828
# Iteration: 625; Percent complete: 3.9%; Average loss: 2.9398
# Iteration: 626; Percent complete: 3.9%; Average loss: 3.0220
# Iteration: 627; Percent complete: 3.9%; Average loss: 3.1257
# Iteration: 628; Percent complete: 3.9%; Average loss: 2.9961
# Iteration: 629; Percent complete: 3.9%; Average loss: 3.0812
# Iteration: 630; Percent complete: 3.9%; Average loss: 3.1493
# Iteration: 631; Percent complete: 3.9%; Average loss: 3.0738
# Iteration: 632; Percent complete: 4.0%; Average loss: 2.8876
# Iteration: 633; Percent complete: 4.0%; Average loss: 2.8908
# Iteration: 634; Percent complete: 4.0%; Average loss: 2.9504
# Iteration: 635; Percent complete: 4.0%; Average loss: 3.0202
# Iteration: 636; Percent complete: 4.0%; Average loss: 2.6803
# Iteration: 637; Percent complete: 4.0%; Average loss: 2.9666
# Iteration: 638; Percent complete: 4.0%; Average loss: 2.9168
# Iteration: 639; Percent complete: 4.0%; Average loss: 3.2074
# Iteration: 640; Percent complete: 4.0%; Average loss: 2.9521
# Iteration: 641; Percent complete: 4.0%; Average loss: 3.0222
# Iteration: 642; Percent complete: 4.0%; Average loss: 3.2653
# Iteration: 643; Percent complete: 4.0%; Average loss: 3.0379
# Iteration: 644; Percent complete: 4.0%; Average loss: 3.1370
# Iteration: 645; Percent complete: 4.0%; Average loss: 2.9981
# Iteration: 646; Percent complete: 4.0%; Average loss: 3.1614
# Iteration: 647; Percent complete: 4.0%; Average loss: 3.0854
# Iteration: 648; Percent complete: 4.0%; Average loss: 2.9205
# Iteration: 649; Percent complete: 4.1%; Average loss: 3.1766
# Iteration: 650; Percent complete: 4.1%; Average loss: 2.8262
# Iteration: 651; Percent complete: 4.1%; Average loss: 2.6848
# Iteration: 652; Percent complete: 4.1%; Average loss: 3.1145
# Iteration: 653; Percent complete: 4.1%; Average loss: 2.9594
# Iteration: 654; Percent complete: 4.1%; Average loss: 2.8922
# Iteration: 655; Percent complete: 4.1%; Average loss: 3.0051
# Iteration: 656; Percent complete: 4.1%; Average loss: 3.1389
# Iteration: 657; Percent complete: 4.1%; Average loss: 2.9201
# Iteration: 658; Percent complete: 4.1%; Average loss: 3.0398
# Iteration: 659; Percent complete: 4.1%; Average loss: 2.9514
# Iteration: 660; Percent complete: 4.1%; Average loss: 2.9613
# Iteration: 661; Percent complete: 4.1%; Average loss: 2.9825
# Iteration: 662; Percent complete: 4.1%; Average loss: 3.0274
# Iteration: 663; Percent complete: 4.1%; Average loss: 3.2581
# Iteration: 664; Percent complete: 4.2%; Average loss: 2.7881
# Iteration: 665; Percent complete: 4.2%; Average loss: 3.1184
# Iteration: 666; Percent complete: 4.2%; Average loss: 3.1946
# Iteration: 667; Percent complete: 4.2%; Average loss: 2.9432
# Iteration: 668; Percent complete: 4.2%; Average loss: 3.0270
# Iteration: 669; Percent complete: 4.2%; Average loss: 2.9480
# Iteration: 670; Percent complete: 4.2%; Average loss: 3.0860
# Iteration: 671; Percent complete: 4.2%; Average loss: 3.1763
# Iteration: 672; Percent complete: 4.2%; Average loss: 2.9406
# Iteration: 673; Percent complete: 4.2%; Average loss: 2.8293
# Iteration: 674; Percent complete: 4.2%; Average loss: 2.8326
# Iteration: 675; Percent complete: 4.2%; Average loss: 2.7035
# Iteration: 676; Percent complete: 4.2%; Average loss: 3.1977
# Iteration: 677; Percent complete: 4.2%; Average loss: 3.1230
# Iteration: 678; Percent complete: 4.2%; Average loss: 3.0000
# Iteration: 679; Percent complete: 4.2%; Average loss: 2.8362
# Iteration: 680; Percent complete: 4.2%; Average loss: 3.2403
# Iteration: 681; Percent complete: 4.3%; Average loss: 2.7849
# Iteration: 682; Percent complete: 4.3%; Average loss: 3.0315
# Iteration: 683; Percent complete: 4.3%; Average loss: 2.9271
# Iteration: 684; Percent complete: 4.3%; Average loss: 2.9428
# Iteration: 685; Percent complete: 4.3%; Average loss: 2.9562
# Iteration: 686; Percent complete: 4.3%; Average loss: 2.9093
# Iteration: 687; Percent complete: 4.3%; Average loss: 2.9150
# Iteration: 688; Percent complete: 4.3%; Average loss: 3.1236
# Iteration: 689; Percent complete: 4.3%; Average loss: 2.7749
# Iteration: 690; Percent complete: 4.3%; Average loss: 2.8821
# Iteration: 691; Percent complete: 4.3%; Average loss: 2.9930
# Iteration: 692; Percent complete: 4.3%; Average loss: 2.9379
# Iteration: 693; Percent complete: 4.3%; Average loss: 3.0414
# Iteration: 694; Percent complete: 4.3%; Average loss: 2.7653
# Iteration: 695; Percent complete: 4.3%; Average loss: 2.6994
# Iteration: 696; Percent complete: 4.3%; Average loss: 3.1250
# Iteration: 697; Percent complete: 4.4%; Average loss: 2.9290
# Iteration: 698; Percent complete: 4.4%; Average loss: 2.9689
# Iteration: 699; Percent complete: 4.4%; Average loss: 3.0554
# Iteration: 700; Percent complete: 4.4%; Average loss: 2.9129
# Iteration: 701; Percent complete: 4.4%; Average loss: 3.0160
# Iteration: 702; Percent complete: 4.4%; Average loss: 3.0397
# Iteration: 703; Percent complete: 4.4%; Average loss: 3.0112
# Iteration: 704; Percent complete: 4.4%; Average loss: 3.1265
# Iteration: 705; Percent complete: 4.4%; Average loss: 2.9162
# Iteration: 706; Percent complete: 4.4%; Average loss: 2.9975
# Iteration: 707; Percent complete: 4.4%; Average loss: 2.9509
# Iteration: 708; Percent complete: 4.4%; Average loss: 2.9845
# Iteration: 709; Percent complete: 4.4%; Average loss: 2.9117
# Iteration: 710; Percent complete: 4.4%; Average loss: 3.0611
# Iteration: 711; Percent complete: 4.4%; Average loss: 2.9826
# Iteration: 712; Percent complete: 4.5%; Average loss: 3.0259
# Iteration: 713; Percent complete: 4.5%; Average loss: 3.0682
# Iteration: 714; Percent complete: 4.5%; Average loss: 2.9475
# Iteration: 715; Percent complete: 4.5%; Average loss: 2.9480
# Iteration: 716; Percent complete: 4.5%; Average loss: 3.0201
# Iteration: 717; Percent complete: 4.5%; Average loss: 2.9287
# Iteration: 718; Percent complete: 4.5%; Average loss: 2.9936
# Iteration: 719; Percent complete: 4.5%; Average loss: 3.1168
# Iteration: 720; Percent complete: 4.5%; Average loss: 3.0481
# Iteration: 721; Percent complete: 4.5%; Average loss: 2.8035
# Iteration: 722; Percent complete: 4.5%; Average loss: 3.0844
# Iteration: 723; Percent complete: 4.5%; Average loss: 3.0265
# Iteration: 724; Percent complete: 4.5%; Average loss: 3.1010
# Iteration: 725; Percent complete: 4.5%; Average loss: 2.8612
# Iteration: 726; Percent complete: 4.5%; Average loss: 3.0637
# Iteration: 727; Percent complete: 4.5%; Average loss: 2.7845
# Iteration: 728; Percent complete: 4.5%; Average loss: 2.9633
# Iteration: 729; Percent complete: 4.6%; Average loss: 2.9592
# Iteration: 730; Percent complete: 4.6%; Average loss: 2.8711
# Iteration: 731; Percent complete: 4.6%; Average loss: 3.1813
# Iteration: 732; Percent complete: 4.6%; Average loss: 2.8521
# Iteration: 733; Percent complete: 4.6%; Average loss: 3.2017
# Iteration: 734; Percent complete: 4.6%; Average loss: 2.9971
# Iteration: 735; Percent complete: 4.6%; Average loss: 2.8795
# Iteration: 736; Percent complete: 4.6%; Average loss: 2.9063
# Iteration: 737; Percent complete: 4.6%; Average loss: 2.7342
# Iteration: 738; Percent complete: 4.6%; Average loss: 2.9476
# Iteration: 739; Percent complete: 4.6%; Average loss: 2.9264
# Iteration: 740; Percent complete: 4.6%; Average loss: 3.2580
# Iteration: 741; Percent complete: 4.6%; Average loss: 3.1479
# Iteration: 742; Percent complete: 4.6%; Average loss: 3.0880
# Iteration: 743; Percent complete: 4.6%; Average loss: 2.9756
# Iteration: 744; Percent complete: 4.7%; Average loss: 2.9801
# Iteration: 745; Percent complete: 4.7%; Average loss: 3.0511
# Iteration: 746; Percent complete: 4.7%; Average loss: 2.7949
# Iteration: 747; Percent complete: 4.7%; Average loss: 3.0074
# Iteration: 748; Percent complete: 4.7%; Average loss: 2.7951
# Iteration: 749; Percent complete: 4.7%; Average loss: 3.1126
# Iteration: 750; Percent complete: 4.7%; Average loss: 2.8045
# Iteration: 751; Percent complete: 4.7%; Average loss: 2.8888
# Iteration: 752; Percent complete: 4.7%; Average loss: 3.0912
# Iteration: 753; Percent complete: 4.7%; Average loss: 2.9239
# Iteration: 754; Percent complete: 4.7%; Average loss: 3.0731
# Iteration: 755; Percent complete: 4.7%; Average loss: 3.1230
# Iteration: 756; Percent complete: 4.7%; Average loss: 2.7387
# Iteration: 757; Percent complete: 4.7%; Average loss: 3.0859
# Iteration: 758; Percent complete: 4.7%; Average loss: 2.7028
# Iteration: 759; Percent complete: 4.7%; Average loss: 2.9125
# Iteration: 760; Percent complete: 4.8%; Average loss: 3.1711
# Iteration: 761; Percent complete: 4.8%; Average loss: 2.8589
# Iteration: 762; Percent complete: 4.8%; Average loss: 2.8549
# Iteration: 763; Percent complete: 4.8%; Average loss: 2.7313
# Iteration: 764; Percent complete: 4.8%; Average loss: 2.8873
# Iteration: 765; Percent complete: 4.8%; Average loss: 2.6862
# Iteration: 766; Percent complete: 4.8%; Average loss: 2.7655
# Iteration: 767; Percent complete: 4.8%; Average loss: 3.1017
# Iteration: 768; Percent complete: 4.8%; Average loss: 3.0488
# Iteration: 769; Percent complete: 4.8%; Average loss: 2.9766
# Iteration: 770; Percent complete: 4.8%; Average loss: 3.0750
# Iteration: 771; Percent complete: 4.8%; Average loss: 2.9475
# Iteration: 772; Percent complete: 4.8%; Average loss: 3.0161
# Iteration: 773; Percent complete: 4.8%; Average loss: 2.9630
# Iteration: 774; Percent complete: 4.8%; Average loss: 2.8621
# Iteration: 775; Percent complete: 4.8%; Average loss: 2.8499
# Iteration: 776; Percent complete: 4.9%; Average loss: 3.0357
# Iteration: 777; Percent complete: 4.9%; Average loss: 2.9458
# Iteration: 778; Percent complete: 4.9%; Average loss: 2.7722
# Iteration: 779; Percent complete: 4.9%; Average loss: 3.0455
# Iteration: 780; Percent complete: 4.9%; Average loss: 3.1929
# Iteration: 781; Percent complete: 4.9%; Average loss: 3.1317
# Iteration: 782; Percent complete: 4.9%; Average loss: 2.8105
# Iteration: 783; Percent complete: 4.9%; Average loss: 2.8280
# Iteration: 784; Percent complete: 4.9%; Average loss: 2.9661
# Iteration: 785; Percent complete: 4.9%; Average loss: 2.9599
# Iteration: 786; Percent complete: 4.9%; Average loss: 3.2449
# Iteration: 787; Percent complete: 4.9%; Average loss: 3.1819
# Iteration: 788; Percent complete: 4.9%; Average loss: 3.0060
# ...
# Iteration: 15752; Percent complete: 98.5%; Average loss: 0.5946
# Iteration: 15753; Percent complete: 98.5%; Average loss: 0.4787
# Iteration: 15754; Percent complete: 98.5%; Average loss: 0.4506
# Iteration: 15755; Percent complete: 98.5%; Average loss: 0.4054
# Iteration: 15756; Percent complete: 98.5%; Average loss: 0.4756
# Iteration: 15757; Percent complete: 98.5%; Average loss: 0.4773
# Iteration: 15758; Percent complete: 98.5%; Average loss: 0.3712
# Iteration: 15759; Percent complete: 98.5%; Average loss: 0.4327
# Iteration: 15760; Percent complete: 98.5%; Average loss: 0.4905
# Iteration: 15761; Percent complete: 98.5%; Average loss: 0.4969
# Iteration: 15762; Percent complete: 98.5%; Average loss: 0.4292
# Iteration: 15763; Percent complete: 98.5%; Average loss: 0.4949
# Iteration: 15764; Percent complete: 98.5%; Average loss: 0.4581
# Iteration: 15765; Percent complete: 98.5%; Average loss: 0.5329
# Iteration: 15766; Percent complete: 98.5%; Average loss: 0.5100
# Iteration: 15767; Percent complete: 98.5%; Average loss: 0.4865
# Iteration: 15768; Percent complete: 98.6%; Average loss: 0.4584
# Iteration: 15769; Percent complete: 98.6%; Average loss: 0.6251
# Iteration: 15770; Percent complete: 98.6%; Average loss: 0.4086
# Iteration: 15771; Percent complete: 98.6%; Average loss: 0.4504
# Iteration: 15772; Percent complete: 98.6%; Average loss: 0.4905
# Iteration: 15773; Percent complete: 98.6%; Average loss: 0.4996
# Iteration: 15774; Percent complete: 98.6%; Average loss: 0.3794
# Iteration: 15775; Percent complete: 98.6%; Average loss: 0.4653
# Iteration: 15776; Percent complete: 98.6%; Average loss: 0.4224
# Iteration: 15777; Percent complete: 98.6%; Average loss: 0.4983
# Iteration: 15778; Percent complete: 98.6%; Average loss: 0.4068
# Iteration: 15779; Percent complete: 98.6%; Average loss: 0.4326
# Iteration: 15780; Percent complete: 98.6%; Average loss: 0.4948
# Iteration: 15781; Percent complete: 98.6%; Average loss: 0.3588
# Iteration: 15782; Percent complete: 98.6%; Average loss: 0.4621
# Iteration: 15783; Percent complete: 98.6%; Average loss: 0.5062
# Iteration: 15784; Percent complete: 98.7%; Average loss: 0.3863
# Iteration: 15785; Percent complete: 98.7%; Average loss: 0.4965
# Iteration: 15786; Percent complete: 98.7%; Average loss: 0.4626
# Iteration: 15787; Percent complete: 98.7%; Average loss: 0.4305
# Iteration: 15788; Percent complete: 98.7%; Average loss: 0.4070
# Iteration: 15789; Percent complete: 98.7%; Average loss: 0.5334
# Iteration: 15790; Percent complete: 98.7%; Average loss: 0.4716
# Iteration: 15791; Percent complete: 98.7%; Average loss: 0.4873
# Iteration: 15792; Percent complete: 98.7%; Average loss: 0.5017
# Iteration: 15793; Percent complete: 98.7%; Average loss: 0.4613
# Iteration: 15794; Percent complete: 98.7%; Average loss: 0.4973
# Iteration: 15795; Percent complete: 98.7%; Average loss: 0.4642
# Iteration: 15796; Percent complete: 98.7%; Average loss: 0.4684
# Iteration: 15797; Percent complete: 98.7%; Average loss: 0.4642
# Iteration: 15798; Percent complete: 98.7%; Average loss: 0.5557
# Iteration: 15799; Percent complete: 98.7%; Average loss: 0.5477
# Iteration: 15800; Percent complete: 98.8%; Average loss: 0.5519
# Iteration: 15801; Percent complete: 98.8%; Average loss: 0.5152
# Iteration: 15802; Percent complete: 98.8%; Average loss: 0.4230
# Iteration: 15803; Percent complete: 98.8%; Average loss: 0.5032
# Iteration: 15804; Percent complete: 98.8%; Average loss: 0.4486
# Iteration: 15805; Percent complete: 98.8%; Average loss: 0.5441
# Iteration: 15806; Percent complete: 98.8%; Average loss: 0.5359
# Iteration: 15807; Percent complete: 98.8%; Average loss: 0.3472
# Iteration: 15808; Percent complete: 98.8%; Average loss: 0.4231
# Iteration: 15809; Percent complete: 98.8%; Average loss: 0.4320
# Iteration: 15810; Percent complete: 98.8%; Average loss: 0.5200
# Iteration: 15811; Percent complete: 98.8%; Average loss: 0.4945
# Iteration: 15812; Percent complete: 98.8%; Average loss: 0.4554
# Iteration: 15813; Percent complete: 98.8%; Average loss: 0.4023
# Iteration: 15814; Percent complete: 98.8%; Average loss: 0.4662
# Iteration: 15815; Percent complete: 98.8%; Average loss: 0.4526
# Iteration: 15816; Percent complete: 98.9%; Average loss: 0.4152
# Iteration: 15817; Percent complete: 98.9%; Average loss: 0.4175
# Iteration: 15818; Percent complete: 98.9%; Average loss: 0.4582
# Iteration: 15819; Percent complete: 98.9%; Average loss: 0.6436
# Iteration: 15820; Percent complete: 98.9%; Average loss: 0.4482
# Iteration: 15821; Percent complete: 98.9%; Average loss: 0.5319
# Iteration: 15822; Percent complete: 98.9%; Average loss: 0.4162
# Iteration: 15823; Percent complete: 98.9%; Average loss: 0.5226
# Iteration: 15824; Percent complete: 98.9%; Average loss: 0.4159
# Iteration: 15825; Percent complete: 98.9%; Average loss: 0.4156
# Iteration: 15826; Percent complete: 98.9%; Average loss: 0.4036
# Iteration: 15827; Percent complete: 98.9%; Average loss: 0.4780
# Iteration: 15828; Percent complete: 98.9%; Average loss: 0.3866
# Iteration: 15829; Percent complete: 98.9%; Average loss: 0.5675
# Iteration: 15830; Percent complete: 98.9%; Average loss: 0.4756
# Iteration: 15831; Percent complete: 98.9%; Average loss: 0.4989
# Iteration: 15832; Percent complete: 99.0%; Average loss: 0.4846
# Iteration: 15833; Percent complete: 99.0%; Average loss: 0.4068
# Iteration: 15834; Percent complete: 99.0%; Average loss: 0.5018
# Iteration: 15835; Percent complete: 99.0%; Average loss: 0.3954
# Iteration: 15836; Percent complete: 99.0%; Average loss: 0.4445
# Iteration: 15837; Percent complete: 99.0%; Average loss: 0.4673
# Iteration: 15838; Percent complete: 99.0%; Average loss: 0.4676
# Iteration: 15839; Percent complete: 99.0%; Average loss: 0.6265
# Iteration: 15840; Percent complete: 99.0%; Average loss: 0.5017
# Iteration: 15841; Percent complete: 99.0%; Average loss: 0.4359
# Iteration: 15842; Percent complete: 99.0%; Average loss: 0.4909
# Iteration: 15843; Percent complete: 99.0%; Average loss: 0.3599
# Iteration: 15844; Percent complete: 99.0%; Average loss: 0.3754
# Iteration: 15845; Percent complete: 99.0%; Average loss: 0.4207
# Iteration: 15846; Percent complete: 99.0%; Average loss: 0.4446
# Iteration: 15847; Percent complete: 99.0%; Average loss: 0.4861
# Iteration: 15848; Percent complete: 99.1%; Average loss: 0.4762
# Iteration: 15849; Percent complete: 99.1%; Average loss: 0.4485
# Iteration: 15850; Percent complete: 99.1%; Average loss: 0.4374
# Iteration: 15851; Percent complete: 99.1%; Average loss: 0.4622
# Iteration: 15852; Percent complete: 99.1%; Average loss: 0.4266
# Iteration: 15853; Percent complete: 99.1%; Average loss: 0.6077
# Iteration: 15854; Percent complete: 99.1%; Average loss: 0.5063
# Iteration: 15855; Percent complete: 99.1%; Average loss: 0.4880
# Iteration: 15856; Percent complete: 99.1%; Average loss: 0.4379
# Iteration: 15857; Percent complete: 99.1%; Average loss: 0.4169
# Iteration: 15858; Percent complete: 99.1%; Average loss: 0.4583
# Iteration: 15859; Percent complete: 99.1%; Average loss: 0.4552
# Iteration: 15860; Percent complete: 99.1%; Average loss: 0.4430
# Iteration: 15861; Percent complete: 99.1%; Average loss: 0.5055
# Iteration: 15862; Percent complete: 99.1%; Average loss: 0.4999
# Iteration: 15863; Percent complete: 99.1%; Average loss: 0.4403
# Iteration: 15864; Percent complete: 99.2%; Average loss: 0.4707
# Iteration: 15865; Percent complete: 99.2%; Average loss: 0.4509
# Iteration: 15866; Percent complete: 99.2%; Average loss: 0.4439
# Iteration: 15867; Percent complete: 99.2%; Average loss: 0.4676
# Iteration: 15868; Percent complete: 99.2%; Average loss: 0.4384
# Iteration: 15869; Percent complete: 99.2%; Average loss: 0.5581
# Iteration: 15870; Percent complete: 99.2%; Average loss: 0.6247
# Iteration: 15871; Percent complete: 99.2%; Average loss: 0.5466
# Iteration: 15872; Percent complete: 99.2%; Average loss: 0.5064
# Iteration: 15873; Percent complete: 99.2%; Average loss: 0.4118
# Iteration: 15874; Percent complete: 99.2%; Average loss: 0.4262
# Iteration: 15875; Percent complete: 99.2%; Average loss: 0.4720
# Iteration: 15876; Percent complete: 99.2%; Average loss: 0.5461
# Iteration: 15877; Percent complete: 99.2%; Average loss: 0.3629
# Iteration: 15878; Percent complete: 99.2%; Average loss: 0.4836
# Iteration: 15879; Percent complete: 99.2%; Average loss: 0.4950
# Iteration: 15880; Percent complete: 99.2%; Average loss: 0.4250
# Iteration: 15881; Percent complete: 99.3%; Average loss: 0.5015
# Iteration: 15882; Percent complete: 99.3%; Average loss: 0.5566
# Iteration: 15883; Percent complete: 99.3%; Average loss: 0.4515
# Iteration: 15884; Percent complete: 99.3%; Average loss: 0.4626
# Iteration: 15885; Percent complete: 99.3%; Average loss: 0.5345
# Iteration: 15886; Percent complete: 99.3%; Average loss: 0.5936
# Iteration: 15887; Percent complete: 99.3%; Average loss: 0.5231
# Iteration: 15888; Percent complete: 99.3%; Average loss: 0.4857
# Iteration: 15889; Percent complete: 99.3%; Average loss: 0.4300
# Iteration: 15890; Percent complete: 99.3%; Average loss: 0.3971
# Iteration: 15891; Percent complete: 99.3%; Average loss: 0.4253
# Iteration: 15892; Percent complete: 99.3%; Average loss: 0.4111
# Iteration: 15893; Percent complete: 99.3%; Average loss: 0.4753
# Iteration: 15894; Percent complete: 99.3%; Average loss: 0.4464
# Iteration: 15895; Percent complete: 99.3%; Average loss: 0.5998
# Iteration: 15896; Percent complete: 99.4%; Average loss: 0.5218
# Iteration: 15897; Percent complete: 99.4%; Average loss: 0.4085
# Iteration: 15898; Percent complete: 99.4%; Average loss: 0.4899
# Iteration: 15899; Percent complete: 99.4%; Average loss: 0.5512
# Iteration: 15900; Percent complete: 99.4%; Average loss: 0.4945
# Iteration: 15901; Percent complete: 99.4%; Average loss: 0.3899
# Iteration: 15902; Percent complete: 99.4%; Average loss: 0.4881
# Iteration: 15903; Percent complete: 99.4%; Average loss: 0.4051
# Iteration: 15904; Percent complete: 99.4%; Average loss: 0.5113
# Iteration: 15905; Percent complete: 99.4%; Average loss: 0.4052
# Iteration: 15906; Percent complete: 99.4%; Average loss: 0.3930
# Iteration: 15907; Percent complete: 99.4%; Average loss: 0.4576
# Iteration: 15908; Percent complete: 99.4%; Average loss: 0.3752
# Iteration: 15909; Percent complete: 99.4%; Average loss: 0.5796
# Iteration: 15910; Percent complete: 99.4%; Average loss: 0.4393
# Iteration: 15911; Percent complete: 99.4%; Average loss: 0.4355
# Iteration: 15912; Percent complete: 99.5%; Average loss: 0.4532
# Iteration: 15913; Percent complete: 99.5%; Average loss: 0.5172
# Iteration: 15914; Percent complete: 99.5%; Average loss: 0.5311
# Iteration: 15915; Percent complete: 99.5%; Average loss: 0.5663
# Iteration: 15916; Percent complete: 99.5%; Average loss: 0.5228
# Iteration: 15917; Percent complete: 99.5%; Average loss: 0.5014
# Iteration: 15918; Percent complete: 99.5%; Average loss: 0.4271
# Iteration: 15919; Percent complete: 99.5%; Average loss: 0.4595
# Iteration: 15920; Percent complete: 99.5%; Average loss: 0.4042
# Iteration: 15921; Percent complete: 99.5%; Average loss: 0.4836
# Iteration: 15922; Percent complete: 99.5%; Average loss: 0.3369
# Iteration: 15923; Percent complete: 99.5%; Average loss: 0.5034
# Iteration: 15924; Percent complete: 99.5%; Average loss: 0.5808
# Iteration: 15925; Percent complete: 99.5%; Average loss: 0.4450
# Iteration: 15926; Percent complete: 99.5%; Average loss: 0.3669
# Iteration: 15927; Percent complete: 99.5%; Average loss: 0.4789
# Iteration: 15928; Percent complete: 99.6%; Average loss: 0.4391
# Iteration: 15929; Percent complete: 99.6%; Average loss: 0.4186
# Iteration: 15930; Percent complete: 99.6%; Average loss: 0.5101
# Iteration: 15931; Percent complete: 99.6%; Average loss: 0.3693
# Iteration: 15932; Percent complete: 99.6%; Average loss: 0.4297
# Iteration: 15933; Percent complete: 99.6%; Average loss: 0.4405
# Iteration: 15934; Percent complete: 99.6%; Average loss: 0.4435
# Iteration: 15935; Percent complete: 99.6%; Average loss: 0.4685
# Iteration: 15936; Percent complete: 99.6%; Average loss: 0.3643
# Iteration: 15937; Percent complete: 99.6%; Average loss: 0.4726
# Iteration: 15938; Percent complete: 99.6%; Average loss: 0.3975
# Iteration: 15939; Percent complete: 99.6%; Average loss: 0.4840
# Iteration: 15940; Percent complete: 99.6%; Average loss: 0.4747
# Iteration: 15941; Percent complete: 99.6%; Average loss: 0.5224
# Iteration: 15942; Percent complete: 99.6%; Average loss: 0.4450
# Iteration: 15943; Percent complete: 99.6%; Average loss: 0.4509
# Iteration: 15944; Percent complete: 99.7%; Average loss: 0.4925
# Iteration: 15945; Percent complete: 99.7%; Average loss: 0.4194
# Iteration: 15946; Percent complete: 99.7%; Average loss: 0.4188
# Iteration: 15947; Percent complete: 99.7%; Average loss: 0.4689
# Iteration: 15948; Percent complete: 99.7%; Average loss: 0.4011
# Iteration: 15949; Percent complete: 99.7%; Average loss: 0.5712
# Iteration: 15950; Percent complete: 99.7%; Average loss: 0.4930
# Iteration: 15951; Percent complete: 99.7%; Average loss: 0.5212
# Iteration: 15952; Percent complete: 99.7%; Average loss: 0.5030
# Iteration: 15953; Percent complete: 99.7%; Average loss: 0.3412
# Iteration: 15954; Percent complete: 99.7%; Average loss: 0.4555
# Iteration: 15955; Percent complete: 99.7%; Average loss: 0.4467
# Iteration: 15956; Percent complete: 99.7%; Average loss: 0.4086
# Iteration: 15957; Percent complete: 99.7%; Average loss: 0.3938
# Iteration: 15958; Percent complete: 99.7%; Average loss: 0.5052
# Iteration: 15959; Percent complete: 99.7%; Average loss: 0.4182
# Iteration: 15960; Percent complete: 99.8%; Average loss: 0.4887
# Iteration: 15961; Percent complete: 99.8%; Average loss: 0.4227
# Iteration: 15962; Percent complete: 99.8%; Average loss: 0.5312
# Iteration: 15963; Percent complete: 99.8%; Average loss: 0.4532
# Iteration: 15964; Percent complete: 99.8%; Average loss: 0.4486
# Iteration: 15965; Percent complete: 99.8%; Average loss: 0.5491
# Iteration: 15966; Percent complete: 99.8%; Average loss: 0.4473
# Iteration: 15967; Percent complete: 99.8%; Average loss: 0.5647
# Iteration: 15968; Percent complete: 99.8%; Average loss: 0.5230
# Iteration: 15969; Percent complete: 99.8%; Average loss: 0.4227
# Iteration: 15970; Percent complete: 99.8%; Average loss: 0.4759
# Iteration: 15971; Percent complete: 99.8%; Average loss: 0.4646
# Iteration: 15972; Percent complete: 99.8%; Average loss: 0.4584
# Iteration: 15973; Percent complete: 99.8%; Average loss: 0.4679
# Iteration: 15974; Percent complete: 99.8%; Average loss: 0.4984
# Iteration: 15975; Percent complete: 99.8%; Average loss: 0.4770
# Iteration: 15976; Percent complete: 99.9%; Average loss: 0.4319
# Iteration: 15977; Percent complete: 99.9%; Average loss: 0.4175
# Iteration: 15978; Percent complete: 99.9%; Average loss: 0.4977
# Iteration: 15979; Percent complete: 99.9%; Average loss: 0.4639
# Iteration: 15980; Percent complete: 99.9%; Average loss: 0.4535
# Iteration: 15981; Percent complete: 99.9%; Average loss: 0.4874
# Iteration: 15982; Percent complete: 99.9%; Average loss: 0.4472
# Iteration: 15983; Percent complete: 99.9%; Average loss: 0.5152
# Iteration: 15984; Percent complete: 99.9%; Average loss: 0.4063
# Iteration: 15985; Percent complete: 99.9%; Average loss: 0.4458
# Iteration: 15986; Percent complete: 99.9%; Average loss: 0.4126
# Iteration: 15987; Percent complete: 99.9%; Average loss: 0.4394
# Iteration: 15988; Percent complete: 99.9%; Average loss: 0.5568
# Iteration: 15989; Percent complete: 99.9%; Average loss: 0.4326
# Iteration: 15990; Percent complete: 99.9%; Average loss: 0.4857
# Iteration: 15991; Percent complete: 99.9%; Average loss: 0.4133
# Iteration: 15992; Percent complete: 100.0%; Average loss: 0.4454
# Iteration: 15993; Percent complete: 100.0%; Average loss: 0.4409
# Iteration: 15994; Percent complete: 100.0%; Average loss: 0.5501
# Iteration: 15995; Percent complete: 100.0%; Average loss: 0.5979
# Iteration: 15996; Percent complete: 100.0%; Average loss: 0.5181
# Iteration: 15997; Percent complete: 100.0%; Average loss: 0.4087
# Iteration: 15998; Percent complete: 100.0%; Average loss: 0.4145
# Iteration: 15999; Percent complete: 100.0%; Average loss: 0.4802
# Iteration: 16000; Percent complete: 100.0%; Average loss: 0.3986

# %%
def evaluate(searcher, voc, conversation_history, max_length=MAX_LENGTH):
    """
    Evaluate a conversation history using the encoder, decoder, and searcher provided.
    """
    # Join the conversation history into a single input and normalize
    input_sentence = ' '.join(conversation_history)
    input_sentence = normalize_string(input_sentence)
    input_sentence=input_sentence.replace("eos","EOS")
    
    # Prepare the input sentence as a batch of word indexes
    indexes_batch = [indexes_from_sentence(voc, input_sentence)]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1).to(device)
    lengths = lengths.to("cpu")  # Lengths need to be on CPU for pack_padded_sequence

    # Decode the sentence with the searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    decoded_words = [voc.index_to_word[token.item()] for token in tokens]

    return decoded_words

def evaluate_input(searcher, voc):
    """
    Interactively evaluate input from the user, considering the entire conversation history.
    """
    conversation_history = []
    while True:
        try:
            input_sentence = input('> ')
            if input_sentence in ('q', 'quit'):
                break

            # Normalize and add the user's input to the conversation history
            print(input_sentence)
            input_sentence = normalize_string(input_sentence)
            conversation_history.append(input_sentence)
            conversation_history.append("EOS")


            # Evaluate the conversation history
            output_words = evaluate(searcher, voc, conversation_history)
            print('Bot:', ' '.join([word for word in output_words if word not in ('EOS', 'PAD')]))

            # Add the bot's response to the conversation history
            conversation_history.extend(output_words)
            conversation_history=conversation_history[-MAX_HISTORY*MAX_LENGTH:]
            

        except KeyError:
            print("Error: Encountered unknown word.")

# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluate_input(searcher, voc)
# Out:
# what's up?
# Bot: what is it ? s been fired ?
# yes you are fired
# Bot: you want me to see you again ? ?
# no, never
# Bot: yeah . .
# yeah..
# Bot: i can t . . .
# just leave
# Bot: they killed him . .
# and you'll be next
# Bot: oh my . . .
