# %% [markdown]
# # Generating New MNIST Digits with a GAN
#
# This notebook provides you with a complete code example to generate MNIST digits with a GAN.

# %% [markdown]
# ## Loading the MNIST Dataset with PyTorch
#
# Implement the digit transformations ...

# %%
from torchvision import transforms as trans

transform = trans.Compose([
    trans.Resize((64, 64)), trans.ToTensor(),
    trans.Normalize(mean=[0.5], std=[0.5], inplace=True)
])

# %% [markdown]
# ... import the MNIST digits ...

# %%
from torchvision.datasets import MNIST

trainset = MNIST(root="data", train=True, transform=transform, download=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:04<00:00, 2042507.46it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 280798.65it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 1850749.38it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 1106174.01it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# ... and plot some of the transformed MNIST digits.

# %%
import torch
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 8, figsize=(15, 3))
for ax in axs.ravel():
    img, label = trainset[torch.randint(0, len(trainset), (1,)).squeeze()]
    ax.imshow(img.squeeze(), cmap="gray")
    ax.set_title(f"Label: {label}", fontsize=16)
    ax.axis("off")
plt.tight_layout()
plt.savefig("fig_09_02.pdf", bbox_inches="tight")  ### plt.show()

# %% [markdown]
# ## Defining the Generator and Discriminator
#
# Determine the device to be used in the computations ...

# %%
def get_device():
    """Select device where to perform computations."""
    if torch.cuda.is_available():
        return torch.device("cuda:0")
    elif torch.backends.mps.is_available():
        return torch.device("mps")
    else:
        return torch.device("cpu")

device = get_device()

# %% [markdown]
# ... instantiating the generator ...

# %%
import deeplay as dl

latent_dim = 100

gen = dl.DCGANGenerator(
    latent_dim=latent_dim, features_dim=64, output_channels=1,
)
gen.build()
gen.to(device);

print(gen)
# Out:
# DCGANGenerator(
#   (blocks): LayerList(
#     (0): Conv2dBlock(
#       (layer): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(1, 1))
#       (activation): ReLU()
#       (normalization): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Conv2dBlock(
#       (layer): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): ReLU()
#       (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Conv2dBlock(
#       (layer): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): ReLU()
#       (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Conv2dBlock(
#       (layer): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): ReLU()
#       (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Conv2dBlock(
#       (layer): ConvTranspose2d(128, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): Tanh()
#     )
#   )
#   (preprocess): Identity()
#   (label_embedding): Identity()
# )

# %% [markdown]
# ... and instantiate the discriminator.

# %%
disc = dl.DCGANDiscriminator(input_channels=1, features_dim=64)
disc.build()
disc.to(device);

print(disc)
# Out:
# DCGANDiscriminator(
#   (blocks): LayerList(
#     (0): Conv2dBlock(
#       (layer): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (1): Conv2dBlock(
#       (layer): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): LeakyReLU(negative_slope=0.2)
#       (normalization): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Conv2dBlock(
#       (layer): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): LeakyReLU(negative_slope=0.2)
#       (normalization): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Conv2dBlock(
#       (layer): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (activation): LeakyReLU(negative_slope=0.2)
#       (normalization): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Conv2dBlock(
#       (layer): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#       (activation): Sigmoid()
#     )
#   )
#   (postprocess): Identity()
#   (label_embedding): Identity()
# )

# %% [markdown]
# ## Training the GAN
#
# Define the data loader ...

# %%
from torch.utils.data import DataLoader

loader = DataLoader(trainset, batch_size=128, shuffle=True, num_workers=4)

# %% [markdown]
# ... define the loss function ...

# %%
loss = torch.nn.BCELoss()

# %% [markdown]
# ... define the optimizers ...

# %%
optim_gen = torch.optim.Adam(gen.parameters(), lr=0.0002, betas=(0.5, 0.999))
optim_disc = torch.optim.Adam(disc.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %% [markdown]
# ... implement the adversarial training ...

# %%
import time
from datetime import timedelta

epochs = 20

num_batches = len(loader)
gen_losses_avg, disc_losses_avg = [], []
fix_latent_vector = torch.randn(30, latent_dim, 1, 1).to(device)
for epoch in range(epochs):
    gen.train(), disc.train()
    
    print("\n" + f"Epoch {epoch + 1}/{epochs}" + "\n" + "-" * 10)
    start_time = time.time()

    running_gen_loss, running_disc_loss = 0.0, 0.0    
    for batch_idx, (real_images, class_labels) in enumerate(loader, start=0):
        real_images = real_images.to(device)

        noise = torch.randn(loader.batch_size, latent_dim, 1, 1).to(device)
        fake_images = gen(noise)

        # 1.  Discriminator training: minimize - log(D(x)) - log(1 - D(G(z))).
        real_output = disc(real_images).reshape(-1)
        fake_output = disc(fake_images).reshape(-1)

        real_loss = loss(real_output, torch.ones_like(real_output))
        fake_loss = loss(fake_output, torch.zeros_like(fake_output))

        disc_loss = (real_loss + fake_loss) / 2

        optim_disc.zero_grad()
        disc_loss.backward(retain_graph=True)
        optim_disc.step()

        # 2.  Generator training: minimize - log(D(G(z))).
        fake_output = disc(fake_images).reshape(-1)
        gen_loss = loss(fake_output, torch.ones_like(fake_output))

        optim_gen.zero_grad()
        gen_loss.backward()
        optim_gen.step()
        
        if batch_idx % 100 == 0:
            print(f"Batch {batch_idx + 1}/{num_batches}: " 
                  + f"Generator Loss: {gen_loss.item():.4f}, " 
                  + f"Discriminator Loss: {disc_loss.item():.4f}")

        running_gen_loss += gen_loss.item()
        running_disc_loss += disc_loss.item()

    gen_losses_avg.append(running_gen_loss / num_batches)
    disc_losses_avg.append(running_disc_loss / num_batches)
    end_time = time.time()

    print("-" * 10 + "\n"
          + f"Epoch {epoch + 1}/{epochs}: " 
          + f"Generator Loss: {gen_losses_avg[-1]:.4f}, "
          + f"Discriminator Loss: {disc_losses_avg[-1]:.4f}, "
          + f"Time taken: {timedelta(seconds=end_time - start_time)}")
    
    gen.eval(), disc.eval()
    fake_images = gen(fix_latent_vector).detach().cpu().numpy()
    
    if epoch == 0:
        fig, axs = plt.subplots(3, 10, figsize=(20, 6))
        for i, ax in enumerate(axs.ravel()):
            ax.imshow(fake_images[i][0], cmap="gray")
            ax.axis("off")
        plt.tight_layout()
        plt.savefig("fig_09_03.pdf", bbox_inches="tight")  ### plt.show()
        plt.close(fig)
        
    if epoch == 19:
        fig, axs = plt.subplots(3, 10, figsize=(20, 6))
        for i, ax in enumerate(axs.ravel()):
            ax.imshow(fake_images[i][0], cmap="gray")
            ax.axis("off")
        plt.tight_layout()
        plt.savefig("fig_09_04.pdf", bbox_inches="tight")  ### plt.show()
        plt.close(fig)
# Out:
# Epoch 1/20
# ----------
# Batch 1/469: Generator Loss: 0.8238, Discriminator Loss: 0.7021
# Batch 101/469: Generator Loss: 3.3888, Discriminator Loss: 0.0458
# Batch 201/469: Generator Loss: 1.0169, Discriminator Loss: 0.5149
# Batch 301/469: Generator Loss: 1.0657, Discriminator Loss: 0.6754
# Batch 401/469: Generator Loss: 0.8547, Discriminator Loss: 0.7997
# ----------
# Epoch 1/20: Generator Loss: 1.5133, Discriminator Loss: 0.5037, Time taken: 0:07:45.664349
#
# Epoch 2/20
# ----------
# Batch 1/469: Generator Loss: 0.7650, Discriminator Loss: 0.6011
# Batch 101/469: Generator Loss: 1.0772, Discriminator Loss: 0.6513
# Batch 201/469: Generator Loss: 1.0850, Discriminator Loss: 0.5241
# Batch 301/469: Generator Loss: 0.7131, Discriminator Loss: 0.5588
# Batch 401/469: Generator Loss: 1.6821, Discriminator Loss: 0.5065
# ----------
# Epoch 2/20: Generator Loss: 1.0685, Discriminator Loss: 0.5731, Time taken: 0:07:43.082731
#
# Epoch 3/20
# ----------
# Batch 1/469: Generator Loss: 1.7482, Discriminator Loss: 0.5219
# Batch 101/469: Generator Loss: 2.1216, Discriminator Loss: 0.2975
# Batch 201/469: Generator Loss: 1.7597, Discriminator Loss: 0.2506
# Batch 301/469: Generator Loss: 4.1499, Discriminator Loss: 0.4715
# Batch 401/469: Generator Loss: 2.7384, Discriminator Loss: 0.1554
# ----------
# Epoch 3/20: Generator Loss: 2.1278, Discriminator Loss: 0.3176, Time taken: 0:07:44.762572
#
# Epoch 4/20
# ----------
# Batch 1/469: Generator Loss: 2.6261, Discriminator Loss: 0.2173
# Batch 101/469: Generator Loss: 2.5660, Discriminator Loss: 0.1430
# Batch 201/469: Generator Loss: 3.1948, Discriminator Loss: 0.0597
# Batch 301/469: Generator Loss: 3.6828, Discriminator Loss: 0.0388
# Batch 401/469: Generator Loss: 3.2889, Discriminator Loss: 0.0624
# ----------
# Epoch 4/20: Generator Loss: 2.9118, Discriminator Loss: 0.2113, Time taken: 0:07:41.679398
#
# Epoch 5/20
# ----------
# Batch 1/469: Generator Loss: 1.0645, Discriminator Loss: 0.5662
# Batch 101/469: Generator Loss: 2.7645, Discriminator Loss: 0.1196
# Batch 201/469: Generator Loss: 3.8986, Discriminator Loss: 0.0316
# Batch 301/469: Generator Loss: 2.9348, Discriminator Loss: 0.0629
# Batch 401/469: Generator Loss: 3.8904, Discriminator Loss: 0.0236
# ----------
# Epoch 5/20: Generator Loss: 3.0877, Discriminator Loss: 0.2079, Time taken: 0:07:43.215958
#
# Epoch 6/20
# ----------
# Batch 1/469: Generator Loss: 1.3826, Discriminator Loss: 0.3098
# Batch 101/469: Generator Loss: 3.8407, Discriminator Loss: 0.0433
# Batch 201/469: Generator Loss: 4.0338, Discriminator Loss: 0.0295
# Batch 301/469: Generator Loss: 3.9833, Discriminator Loss: 0.0282
# Batch 401/469: Generator Loss: 2.7086, Discriminator Loss: 0.1746
# ----------
# Epoch 6/20: Generator Loss: 3.2314, Discriminator Loss: 0.1865, Time taken: 0:07:16.677984
#
# Epoch 7/20
# ----------
# Batch 1/469: Generator Loss: 4.2090, Discriminator Loss: 0.0451
# Batch 101/469: Generator Loss: 3.6186, Discriminator Loss: 0.0414
# Batch 201/469: Generator Loss: 4.1730, Discriminator Loss: 0.0220
# Batch 301/469: Generator Loss: 4.8230, Discriminator Loss: 0.0132
# Batch 401/469: Generator Loss: 2.7405, Discriminator Loss: 0.3183
# ----------
# Epoch 7/20: Generator Loss: 3.6838, Discriminator Loss: 0.1418, Time taken: 0:03:51.421140
#
# Epoch 8/20
# ----------
# Batch 1/469: Generator Loss: 1.0995, Discriminator Loss: 0.2874
# Batch 101/469: Generator Loss: 2.6986, Discriminator Loss: 0.0758
# Batch 201/469: Generator Loss: 2.0075, Discriminator Loss: 0.2115
# Batch 301/469: Generator Loss: 2.2154, Discriminator Loss: 0.1776
# Batch 401/469: Generator Loss: 4.0361, Discriminator Loss: 0.0196
# ----------
# Epoch 8/20: Generator Loss: 3.1038, Discriminator Loss: 0.2106, Time taken: 0:03:52.717139
#
# Epoch 9/20
# ----------
# Batch 1/469: Generator Loss: 4.5294, Discriminator Loss: 0.0214
# Batch 101/469: Generator Loss: 4.4477, Discriminator Loss: 0.0160
# Batch 201/469: Generator Loss: 4.4650, Discriminator Loss: 0.0194
# Batch 301/469: Generator Loss: 5.3624, Discriminator Loss: 0.0116
# Batch 401/469: Generator Loss: 4.9491, Discriminator Loss: 0.0071
# ----------
# Epoch 9/20: Generator Loss: 4.9252, Discriminator Loss: 0.0135, Time taken: 0:03:53.087037
#
# Epoch 10/20
# ----------
# Batch 1/469: Generator Loss: 5.5392, Discriminator Loss: 0.0076
# Batch 101/469: Generator Loss: 4.8405, Discriminator Loss: 0.0086
# Batch 201/469: Generator Loss: 4.9174, Discriminator Loss: 0.0090
# Batch 301/469: Generator Loss: 16.1864, Discriminator Loss: 1.4391
# Batch 401/469: Generator Loss: 0.3303, Discriminator Loss: 0.7721
# ----------
# Epoch 10/20: Generator Loss: 3.8865, Discriminator Loss: 0.2393, Time taken: 0:03:58.753703
#
# Epoch 11/20
# ----------
# Batch 1/469: Generator Loss: 1.7070, Discriminator Loss: 0.4420
# Batch 101/469: Generator Loss: 2.3805, Discriminator Loss: 0.3765
# Batch 201/469: Generator Loss: 2.2594, Discriminator Loss: 0.3231
# Batch 301/469: Generator Loss: 4.9835, Discriminator Loss: 0.5351
# Batch 401/469: Generator Loss: 4.5109, Discriminator Loss: 0.2608
# ----------
# Epoch 11/20: Generator Loss: 2.2374, Discriminator Loss: 0.3524, Time taken: 0:04:00.212045
#
# Epoch 12/20
# ----------
# Batch 1/469: Generator Loss: 3.6305, Discriminator Loss: 0.2318
# Batch 101/469: Generator Loss: 4.0507, Discriminator Loss: 0.0387
# Batch 201/469: Generator Loss: 4.7495, Discriminator Loss: 0.0165
# Batch 301/469: Generator Loss: 3.6404, Discriminator Loss: 0.1459
# Batch 401/469: Generator Loss: 5.3293, Discriminator Loss: 0.0109
# ----------
# Epoch 12/20: Generator Loss: 3.8450, Discriminator Loss: 0.0980, Time taken: 0:04:00.051345
#
# Epoch 13/20
# ----------
# Batch 1/469: Generator Loss: 5.4798, Discriminator Loss: 0.0085
# Batch 101/469: Generator Loss: 4.9513, Discriminator Loss: 0.0177
# Batch 201/469: Generator Loss: 4.7916, Discriminator Loss: 0.0172
# Batch 301/469: Generator Loss: 5.5820, Discriminator Loss: 0.0504
# Batch 401/469: Generator Loss: 2.1275, Discriminator Loss: 0.2375
# ----------
# Epoch 13/20: Generator Loss: 4.1137, Discriminator Loss: 0.1551, Time taken: 0:04:00.440194
#
# Epoch 14/20
# ----------
# Batch 1/469: Generator Loss: 3.9765, Discriminator Loss: 0.1722
# Batch 101/469: Generator Loss: 3.5571, Discriminator Loss: 0.0423
# Batch 201/469: Generator Loss: 1.9108, Discriminator Loss: 0.4061
# Batch 301/469: Generator Loss: 2.6106, Discriminator Loss: 0.1224
# Batch 401/469: Generator Loss: 3.7231, Discriminator Loss: 0.0385
# ----------
# Epoch 14/20: Generator Loss: 3.2389, Discriminator Loss: 0.1626, Time taken: 0:04:00.447732
#
# Epoch 15/20
# ----------
# Batch 1/469: Generator Loss: 4.2255, Discriminator Loss: 0.0146
# Batch 101/469: Generator Loss: 5.2071, Discriminator Loss: 0.0112
# Batch 201/469: Generator Loss: 5.1875, Discriminator Loss: 0.0096
# Batch 301/469: Generator Loss: 4.1591, Discriminator Loss: 0.4047
# Batch 401/469: Generator Loss: 1.7925, Discriminator Loss: 0.1698
# ----------
# Epoch 15/20: Generator Loss: 3.9767, Discriminator Loss: 0.1770, Time taken: 0:04:00.336064
#
# Epoch 16/20
# ----------
# Batch 1/469: Generator Loss: 3.2498, Discriminator Loss: 0.0444
# Batch 101/469: Generator Loss: 3.7174, Discriminator Loss: 0.0417
# Batch 201/469: Generator Loss: 3.7631, Discriminator Loss: 0.0299
# Batch 301/469: Generator Loss: 4.8500, Discriminator Loss: 0.0090
# Batch 401/469: Generator Loss: 4.6748, Discriminator Loss: 0.0156
# ----------
# Epoch 16/20: Generator Loss: 4.4148, Discriminator Loss: 0.0741, Time taken: 0:04:00.406950
#
# Epoch 17/20
# ----------
# Batch 1/469: Generator Loss: 6.3073, Discriminator Loss: 0.0045
# Batch 101/469: Generator Loss: 4.8051, Discriminator Loss: 0.0116
# Batch 201/469: Generator Loss: 5.3195, Discriminator Loss: 0.0089
# Batch 301/469: Generator Loss: 6.2098, Discriminator Loss: 0.0038
# Batch 401/469: Generator Loss: 5.4669, Discriminator Loss: 0.0082
# ----------
# Epoch 17/20: Generator Loss: 5.4056, Discriminator Loss: 0.0456, Time taken: 0:03:59.626520
#
# Epoch 18/20
# ----------
# Batch 1/469: Generator Loss: 1.9444, Discriminator Loss: 0.2929
# Batch 101/469: Generator Loss: 3.3485, Discriminator Loss: 0.3030
# Batch 201/469: Generator Loss: 1.4618, Discriminator Loss: 0.4530
# Batch 301/469: Generator Loss: 3.5375, Discriminator Loss: 0.0506
# Batch 401/469: Generator Loss: 4.2280, Discriminator Loss: 0.0268
# ----------
# Epoch 18/20: Generator Loss: 3.5627, Discriminator Loss: 0.1723, Time taken: 0:03:59.120975
#
# Epoch 19/20
# ----------
# Batch 1/469: Generator Loss: 4.6577, Discriminator Loss: 0.0245
# Batch 101/469: Generator Loss: 1.4923, Discriminator Loss: 0.4028
# Batch 201/469: Generator Loss: 0.5898, Discriminator Loss: 0.4798
# Batch 301/469: Generator Loss: 5.1986, Discriminator Loss: 0.0081
# Batch 401/469: Generator Loss: 5.4040, Discriminator Loss: 0.0081
# ----------
# Epoch 19/20: Generator Loss: 4.2033, Discriminator Loss: 0.1418, Time taken: 0:04:00.484572
#
# Epoch 20/20
# ----------
# Batch 1/469: Generator Loss: 2.7011, Discriminator Loss: 0.1956
# Batch 101/469: Generator Loss: 4.6217, Discriminator Loss: 0.0410
# Batch 201/469: Generator Loss: 6.2235, Discriminator Loss: 1.1499
# Batch 301/469: Generator Loss: 2.0312, Discriminator Loss: 0.3021
# Batch 401/469: Generator Loss: 4.4534, Discriminator Loss: 0.0206
# ----------
# Epoch 20/20: Generator Loss: 3.7338, Discriminator Loss: 0.1633, Time taken: 0:03:59.291557

# %% [markdown]
# ## Plotting the Training Losses

# %%
import numpy as np

plt.plot(np.arange(len(gen_losses_avg)), gen_losses_avg, "g--o",
         label="Generator Loss")
plt.plot(np.arange(len(disc_losses_avg)), disc_losses_avg, "r-o",
         label="Discriminator Loss")
plt.xlabel("Epoch", fontsize=16)
plt.ylabel("Loss", fontsize=16)
plt.legend()
plt.savefig("fig_09_05.pdf", bbox_inches="tight")  ### plt.show()
