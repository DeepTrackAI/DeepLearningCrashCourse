# %% [markdown]
# # Virtual Staining with Conditional GAN
#
# In this example, we will build a conditional GAN to transform brightfield microscopy images of human motor neurons to fluorescent images. The application is known as virtual staining as once trained the model can be used to generate fluorescent images without actually performing chemical staining of the cells.

# %% [markdown]
# ## Human motor neurons dataset
#
# The dataset used in this example is part of the article [*In silico* Labelling: Predicting Fluorescent Labels in Unlabeled Images](https://www.cell.com/cell/fulltext/S0092-8674(18)30364-7). We will be using the human motor neurons dataset that is designated as **Condition A** in the article.
#
# The dataset contains 22 brightfield images and the corresponding spatially registered fluorescent images with 2 fluorescent channels, Hoechst (blue stain representing nuceli) and anti-Tuj1 (red stain representing neurons). Each brightfield image contains z-stack of 13 images representing different focal planes. The dataset can be downloaded using the following instructions.

# %% [markdown]
# ### Download the dataset
#
# We will download the dataset using the `gsutil` command line tool. The dataset is stored in a public Google Cloud Storage bucket by the authors of the article. The dataset is about 10 GB in size and will take a few minutes to download depending on your internet connection.
#
# 1. Install `gsutil` command line tool using the following command.
#     ```bash
#     pip install gsutil
#     ```
#
# 2. Download the train and test datasets using the following commands. Notice that the path string contains two paths separated by space. The first path is the path to the dataset in the Google Cloud Storage bucket and the second path is the path to the directory where you want to download the dataset. The dataset will be downloaded to the `train` and `test` subdirectories of the path you specify.
#     ```bash
#     # Download the train dataset
#     gsutil -m cp -r gs://in-silico-labeling/paper_data/train/Rubin/scott_1_0 /VirtualStainingDataset/train
#     # Download the test dataset
#     gsutil -m cp -r gs://in-silico-labeling/paper_data/test/Rubin/scott_1_0 /VirtualStainingDataset/test
#     ```
#
# Once downloaded, we will use the custom dataset class `VirtualStainingDataset` that is available in the python file `dataset.py`. The dataset class works like a regular PyTorch dataset class which can load train and test datasets, and apply transformations to the images.
#
# Before we import the dataset class, we will define the augmentations, transformations, and the normalization that we are going to apply to the images using the `torchvision` library.
#
# Firstly, we will crop the images to the size of `256x256` pixels. Then we will apply random horizontal and vertical flips to the images. Finally, we will normalize the images using the mean and standard deviation of the images in the training dataset.

# %%
from torchvision import transforms

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomCrop((256,256)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
])

normalize = [
    transforms.Normalize(mean=[0.5] * 13, std=[0.5] * 13), # Input
    transforms.Normalize(mean=[0.5] * 3, std=[0.5] * 3) # Target
]

# %% [markdown]
# We will now import the `VirtualStainingDataset` class from `dataset.py` and create the train and test datasets. The `VirtualStainingDataset` class takes the following arguments, `root`, `train`, `transform`, `normalize` and `preload`.
#
# Here, `root` is the path to the dataset folder. The `train` argument is a boolean value that indicates whether to load the train or test datasets.
#
# The `transform` and `normalize` arguments accept the transforms and the normalizations that we created in the above cell.
#
# By setting the `preload` argument to `True`, we can preload the entire dataset into memory to speed up the training. If you have enough memory, it is recommended to set this argument to `True`.

# %%
import sys
sys.path.insert(0, '/workspace/virtual_staining') # adjust the path accodingly

from dataset import VirtualStainingDataset

root = "/workspace/virtual_staining/NewDataset" # adjust the path accodingly

train_dataset = VirtualStainingDataset(root, train=True, transform=transform, normalize=normalize, preload=True)
test_dataset = VirtualStainingDataset(root, train=False, transform=transform, normalize=normalize, preload=True)
# Out:
# Preloading images: 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 22/22 [01:27<00:00,  3.98s/it]
# Preloading images: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:12<00:00,  4.13s/it]

# %% [markdown]
# We can now visualize some images from the train dataset using the `matplotlib` library. We will visualize the brightfield image averaged over all the focal planes and the corresponding fluorescent images. We will use `numpy` to randomly sample the images from the dataset.
#
# Since we have normalized the images to be in the range of `[-1, 1]`, we will create a small function `denormalize` to convert the images back to the range of `[0, 1]` for visualization.

# %%
import numpy as np
import matplotlib.pyplot as plt

brightfield_img, fluorescence_img = train_dataset[np.random.randint(0, len(train_dataset))]

def denormalize(image):
    return image * 0.5 + 0.5

plt.figure()
plt.subplot(1, 2, 1)
plt.imshow(brightfield_img.mean(axis=0), cmap='gray')
plt.title('Brightfield')
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(denormalize(fluorescence_img.permute(1, 2, 0)))
plt.title('Fluorescence')
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Let us now visualize the fluorescent image channel wise, i.e., Hoechst (representing neurons) and anti-Tuj1 (representing motor neurons) channels for blue and green channels respectively. Note that the red channel is empty as the fluorescent images do not contain any red channel.
#
# Let us create the function `process_label` to achieve this.

# %%
import numpy as np
from skimage.exposure import rescale_intensity

def process_label(label, channel='G'):
    # Create zero arrays for the other two channels
    zero_channel = np.zeros_like(label)

    # Map the channels to their corresponding arrays
    channels = {
        'R': [label if channel == 'R' else zero_channel, 
              zero_channel, 
              zero_channel],
        'G': [zero_channel, 
              label if channel == 'G' else zero_channel, 
              zero_channel],
        'B': [zero_channel, 
              zero_channel, 
              label if channel == 'B' else zero_channel]
    }

    # Create the stack using the specified channel order
    stack = [rescale_intensity(channels[channel][i], out_range="float") for i in range(3)]

    return np.stack(stack, axis=-1)

# %%
plt.figure(figsize=(16, 5))

plt.subplot(1, 4, 1)
plt.imshow(denormalize(fluorescence_img.permute(1, 2, 0)))
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(process_label(denormalize(fluorescence_img.permute(1, 2, 0).numpy()[:,:,0]), channel="R"))
plt.title("R")
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(process_label(denormalize(fluorescence_img.permute(1, 2, 0).numpy()[:,:,1]), channel="G"))
plt.title("G")
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(process_label(denormalize(fluorescence_img.permute(1, 2, 0).numpy()[:,:,2]), channel="B"))
plt.title("B")
plt.axis('off')

plt.show()

# %% [markdown]
# We now define the `device` that we are going to use for training. We will use the GPU if available, else we will use the CPU.

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Generator and Discriminator
#
# In this section, we will define the generator and discriminator networks that we will be using to train a conditional GAN. We will be using the `deeplay` library to define the networks.

# %% [markdown]
# ### Generator
#
# We will use the class `UNet2d` from `deeplay` to define the generator network. We will set the `in_channels` to be 13 as the brightfield images contain 13 focal planes. We will set the `out_channels` to be 3. The generator will take the brightfield image as input and output the fluorescent image. We will define the number of filters in the hidden layers using the `channels` parameter.
#
# We will also be modifying the activations of hidden layers to `LeakyReLU` and the activation of the output layer to `Tanh`. We will also be using `InstanceNorm2d` instead of `BatchNorm2d` as it is known to perform better in image-to-image translation tasks.

# %%
import deeplay as dl
import torch.nn as nn

generator = dl.UNet2d(
    in_channels=13,
    # channels=[32, 64, 128, 256], # This works well already
    channels=[32, 64, 128, 256, 512], # Just to give generator more capacity
    out_channels=3,
)

# Modify the activations for the encoder and decoder networks in UNet
generator.encoder.activation.configure(nn.LeakyReLU, negative_slope=0.2)
generator.decoder.activation[:-1].configure(nn.LeakyReLU, negative_slope=0.2)

# Change the output activation
generator.decoder.activation[-1].configure(nn.Tanh)

# Change normalization to InstanceNorm2d
generator.decoder.normalization[:-1].configure(nn.InstanceNorm2d)

# Change the order of the normalization and activation in the encoder and decoder
generator.encoder.blocks.configure(order=["layer", "normalization", "activation"])
generator.decoder.blocks.configure(order=["layer", "normalization", "activation"])

# Build the network
generator.build()

# Send to device
generator.to(device)
# Out:
# UNet2d(
#   (encoder): ConvolutionalEncoder2d(
#     (blocks): LayerList(
#       (0): PoolLayerActivationNormalization(
#         (layer): Conv2d(13, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): Identity()
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (1): PoolLayerActivationNormalization(
#         (layer): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): Identity()
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (2): PoolLayerActivationNormalization(
#         (layer): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): Identity()
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (3): PoolLayerActivationNormalization(
#         (layer): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): Identity()
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (4): PoolLayerActivationNormalization(
#         (layer): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): Identity()
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (5): PoolLayerActivationNormalization(
#         (layer): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): Identity()
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#     )
#     (postprocess): Identity()
#   )
#   (decoder): ConvolutionalDecoder2d(
#     (preprocess): Identity()
#     (blocks): LayerList(
#       (0): LayerActivationNormalizationUpsample(
#         (layer): LazyConv2d(0, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (1): LayerActivationNormalizationUpsample(
#         (layer): LazyConv2d(0, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (2): LayerActivationNormalizationUpsample(
#         (layer): LazyConv2d(0, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (3): LayerActivationNormalizationUpsample(
#         (layer): LazyConv2d(0, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (4): LayerActivationNormalizationUpsample(
#         (layer): LazyConv2d(0, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (activation): LeakyReLU(negative_slope=0.2)
#       )
#       (5): LayerActivationNormalizationUpsample(
#         (layer): LazyConv2d(0, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (normalization): Identity()
#         (activation): Tanh()
#       )
#     )
#   )
#   (blocks): ModuleList(
#     (0): PoolLayerActivationNormalization(
#       (layer): Conv2d(13, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): Identity()
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (1): PoolLayerActivationNormalization(
#       (layer): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): Identity()
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (2): PoolLayerActivationNormalization(
#       (layer): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): Identity()
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (3): PoolLayerActivationNormalization(
#       (layer): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): Identity()
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (4): PoolLayerActivationNormalization(
#       (layer): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): Identity()
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (5): PoolLayerActivationNormalization(
#       (layer): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): Identity()
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (6): LayerActivationNormalizationUpsample(
#       (layer): LazyConv2d(0, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (7): LayerActivationNormalizationUpsample(
#       (layer): LazyConv2d(0, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (8): LayerActivationNormalizationUpsample(
#       (layer): LazyConv2d(0, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (9): LayerActivationNormalizationUpsample(
#       (layer): LazyConv2d(0, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (10): LayerActivationNormalizationUpsample(
#       (layer): LazyConv2d(0, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (11): LayerActivationNormalizationUpsample(
#       (layer): LazyConv2d(0, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (normalization): Identity()
#       (activation): Tanh()
#     )
#   )
#   (skip): concat()
# )

# %% [markdown]
# ### Discriminator
#
# Now we will define the discriminator network for the conditional GAN. The network will the take the fluorescent image (either generated by the generator or the label), along the brightfield image (which acts as a condition) as inputs and outputs a single value representing the probability of the image being real or fake.
#
# We will use the class `ConvolutionalNeuralNetwork` from `deeplay` to define the discriminator network. Since we have 13 channels in the brightfield image and 3 channels in the fluorescent image, we will set the `in_channels` to be 16. We will set the `out_channels` to be 1 as the discriminator will output a single value. We will define the number of filters in the hidden layers using the `channels` parameter.
#
# We will also be modifying the activations of hidden layers to `LeakyReLU` and the activation of the output layer to `Sigmoid`. We will also be using `InstanceNorm2d` instead of `BatchNorm2d` as it is known to perform better in image-to-image translation tasks.

# %%
discriminator = dl.ConvolutionalNeuralNetwork(
    in_channels=16,
    # hidden_channels=[16, 32, 64, 128], # This works well too
    hidden_channels=[8, 16, 32, 64], # Making the discriminator more weak
    out_channels=1,
)

# Change convolutional layer parameters
discriminator.blocks.layer.configure(kernel_size=4, stride=2, padding=1)

# Change activation
discriminator.blocks.activation[:-1].configure(nn.LeakyReLU, negative_slope=0.2)

# Change the output activation
discriminator.blocks.activation[-1].configure(nn.Sigmoid)

# Change normalization
discriminator.blocks.normalization[1:-1].configure(nn.InstanceNorm2d)

# Change the order of layer, activation, normalization
discriminator.blocks.configure(order=["layer", "normalization", "activation"])

# Build the network
discriminator.build()

# Send to the device
discriminator.to(device)
# Out:
# ConvolutionalNeuralNetwork(
#   (blocks): LayerList(
#     (0): PoolLayerActivationNormalization(
#       (layer): Conv2d(16, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (normalization): Identity()
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (1): PoolLayerActivationNormalization(
#       (layer): Conv2d(8, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (normalization): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (2): PoolLayerActivationNormalization(
#       (layer): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (normalization): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (3): PoolLayerActivationNormalization(
#       (layer): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (normalization): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (activation): LeakyReLU(negative_slope=0.2)
#     )
#     (4): PoolLayerActivationNormalization(
#       (layer): Conv2d(64, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (normalization): Identity()
#       (activation): Sigmoid()
#     )
#   )
# )

# %% [markdown]
# ## Loss functions
#
# We will define three loss functions for the training of the conditional GAN for virtual staining.
#
# 1. _*Adversarial loss*_: The loss function that is used to train the GAN part. It is represented as `loss_D`. Here, we will be using the mean squared error loss function.
# 2. _*Reconstruction loss*_: The loss function that is used to train the generator part. Here, we will directly comparing the generated fluorescent image with the label using the mean absolute error loss function. This loss function is also known as the L1 loss.
# 3. _*Perceptual loss*_: The perceptual loss ensures that the generated fluorescent image is perceptually similar to the label. We will be using the `torchmetrics` library to compute the perceptual loss. We will be using the `LPIPS` metric to compute the perceptual loss. The LPIPS metric which stands for Learned Perceptual Image Patch Similarity is a perceptual loss function that is based on the VGG16 network. The LPIPS metric is known to correlate well with human perceptual judgments.

# %%
# Loss functions
loss_D = torch.nn.MSELoss()
loss_G = torch.nn.L1Loss()

# Perceptual loss
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity
loss_LPIPS = LearnedPerceptualImagePatchSimilarity(net_type="vgg").to(device)

# %% [markdown]
# ## Optimizers
# We now define the optimizers for the generator and the discriminator networks. We will be using the `Adam` optimizer for both the networks.
#
# Notice that we are using different learning rates for the generator and the discriminator networks. The choice of the learning rates is learnt through experimentation whether the generator or the discriminator is dominating the training.

# %%
generator_optimizer = torch.optim.Adam(
    generator.parameters(), lr=0.0002, betas=(0.5, 0.999)
)
discriminator_optimizer = torch.optim.Adam(
    discriminator.parameters(), lr=0.00005, betas=(0.5, 0.999)
)

# %% [markdown]
# ## Dataloaders
# We now define the dataloaders for the training and test datasets. We will use a batch size of 2 as defined by the `batch_size` variable. We will also set the `shuffle` argument to `True` for the training and testing dataloaders.

# %%
BATCH_SIZE = 2
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# ## Training procedure
#
# We will now define the training procedure for the conditional GAN. We will first define the functions, `train_discriminator`, `train_generator`, and `evaluate_model` to train the discriminator, generator, and evaluate the model respectively every epoch.
#
# Finally, we will define the training loop where we will use the functions mentioned above to train the model.
#
# First we will define the function, `train_discriminator` to train the discriminator network. The function takes inputs (brightfield image) and labels (fluorescent image) and outputs the loss of the discriminator network.

# %%
# Function to train the discriminator
def train_discriminator(inputs, targets, optimizer, Loss_D=loss_D):

    # Set the generator to training model
    generator.train()
    
    # Zero the parameter gradients
    optimizer.zero_grad()

    # Forward + backward + optimize

    # Compute real loss
    output_real = discriminator(torch.cat([inputs, targets], dim=1))
    label_real = torch.ones_like(output_real)
    loss_real = Loss_D(output_real, label_real)

    # Compute fake loss
    output_fake = discriminator(torch.cat([inputs, generator(inputs)], dim=1))
    label_fake = torch.zeros_like(output_fake)

    loss_fake = Loss_D(output_fake, label_fake)

    # Average loss
    loss = (loss_real + loss_fake) / 2  # average loss

    # Backpropagation
    loss.backward()

    # Update weights
    optimizer.step()

    return loss

# %% [markdown]
# We will now define the function, `train_generator` to train the generator network. The function takes inputs (brightfield image) and labels (fluorescent image) and outputs the different loss functions that we defined above.
#
# The function additionally takes the parameters, `L1_Lambda` and `LPIPS_Lambda` which are the weights for the reconstruction loss and the perceptual loss respectively.

# %%
# Function to train the generator
def train_generator(inputs, targets, optimizer, Loss_D=loss_D, Loss_G=loss_G, Loss_P=loss_LPIPS, L1_Lambda=100, LPIPS_Lambda=10):
    
    # Zero the parameter gradients
    optimizer.zero_grad()

    # Passing real image (training images) to the generator
    generator_output = generator(inputs)
    discriminator_output = discriminator(torch.cat([inputs, generator_output], dim=1))
    label = torch.ones_like(discriminator_output)

    # Calculate adversarial loss
    loss_GAN = Loss_D(discriminator_output, label)

    # Calculate L1 loss
    loss_L1 = Loss_G(generator_output, targets)

    # Calculate LPIPS loss (perceptual loss)
    loss_P = Loss_P(generator_output, targets)

    # Combine all the losses and calculate total loss
    loss = loss_GAN + L1_Lambda * loss_L1 + LPIPS_Lambda * loss_P

    # Backpropagation
    loss.backward()

    # Update weights
    optimizer.step()

    return loss_GAN, loss_L1, loss_P

# %% [markdown]
# We will now define the function `evaluate_model` to evaluate the model on the test dataset. The function takes the input image and processes it through the generator and returns a figure containing the input image, the generated fluorescent image, and the label.

# %%
def evaluate_model(image, label):
    generator.eval()

    with torch.no_grad():
        prediction = generator(image)

    fig, ax = plt.subplots(1, 3, figsize=(10, 5))

    # Input image
    ax[0].imshow(denormalize(image[0].permute(1, 2, 0).cpu().numpy().mean(axis=-1)), cmap="gray")
    ax[0].axis("off")
    ax[0].set_title("Input")

    # Prediction
    ax[1].imshow(denormalize(prediction[0].permute(1, 2, 0).cpu().numpy()))
    ax[1].axis("off")
    ax[1].set_title("Prediction")

    # Ground truth
    ax[2].imshow(denormalize(label[0].permute(1, 2, 0).cpu().numpy()))
    ax[2].axis("off")
    ax[2].set_title("Ground truth")

    plt.tight_layout()

    return fig

# %% [markdown]
# Now, we will define the training loop where we will use the functions defined above. Before that, let us initiate empty lists to store different losses.

# %%
Generator_losses = []
Discriminator_losses = []
Reconstruction_losses = []
Perceptual_losses = []

# %% [markdown]
# ### Training loop
#
# We will now define the training loop. We will define the number of epochs using the `EPOCHS` variable. We will control the weights of reconstruction loss and perceptual loss using the `L1_Lambda` and `LPIPS_Lambda` variables respectively.
#
# Here, we will set the `L1_Lambda` to be `100` and `LPIPS_Lambda` to be `10`, and train the model for `500`. Every `50` epochs, we will evaluate the model on the test dataset by plotting the input image, the generated fluorescent image, and the label.

# %%
# Train the cGAN
EPOCHS = 500
L1_Lambda = 100
LPIPS_Lambda = 10

# Import the packages required for checking the time taken for each epoch
import time
from datetime import timedelta

for epoch in range(EPOCHS+1):
    # Record the start time of each epoch
    start_time = time.time()

    n_batches = len(trainloader)

    print("\n")
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print("-" * 10)

    # Loooping over batches
    G_loss_epochs = []
    D_loss_epochs = []
    Recon_loss_epochs = []
    Percep_loss_epochs = []

    for i, data in enumerate(trainloader, 0):

        # Get the inputs and labels for each batch
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # Train the discriminator
        disc_loss = train_discriminator(inputs=inputs, targets=labels, optimizer=discriminator_optimizer)

        # Train the generator
        for _ in range(2):
            adv_loss, rec_loss, percep_loss = train_generator(inputs=inputs, targets=labels, optimizer=generator_optimizer, L1_Lambda=L1_Lambda, LPIPS_Lambda=LPIPS_Lambda)

        gen_loss = adv_loss + rec_loss + percep_loss

        # Print the loss for this batch
        if i % 5 == 0:
            print(
                f"Batch {i+1}/{n_batches} : Generator Loss: {gen_loss.item():.4f}, Discriminator Loss: {disc_loss.item():.4f}"
            )

        # Save the loss for this batch
        G_loss_epochs.append(adv_loss.item())
        D_loss_epochs.append(disc_loss.item())
        Recon_loss_epochs.append(rec_loss.item())
        Percep_loss_epochs.append(percep_loss.item())

    # Record the end time of each epoch
    end_time = time.time()

    # Print the loss for this epoch
    print("-" * 10)
    print(
        f"Epoch {epoch+1}/{EPOCHS} : Gen loss: {np.mean(G_loss_epochs):.4f}, Disc Loss: {np.mean(D_loss_epochs):.4f}, Recon Loss: {np.mean(Recon_loss_epochs):.4f}, Percep loss: {np.mean(Percep_loss_epochs):.4f}"
    )
    print(f"Time taken: {timedelta(seconds=end_time-start_time)}")


    # Evaluate model every epoch
    if epoch % 50 == 0:
        for i, data, in enumerate(testloader, 0):
            # Get the inputs and labels for each batch
            test_inputs, test_labels = data
            test_inputs, test_labels = test_inputs.to(device), test_labels.to(device)

            break

        # Evaluate the model
        fig = evaluate_model(test_inputs, test_labels)
        plt.show()

    # Save the loss for this epoch
    Generator_losses.append(np.mean(G_loss_epochs))
    Discriminator_losses.append(np.mean(D_loss_epochs))
    Reconstruction_losses.append(np.mean(Recon_loss_epochs))
    Perceptual_losses.append(np.mean(Percep_loss_epochs))
# Out:
# Epoch 1/500
# ----------
# Batch 1/11 : Generator Loss: 1.6495, Discriminator Loss: 0.2556
# Batch 6/11 : Generator Loss: 1.2618, Discriminator Loss: 0.2569
# Batch 11/11 : Generator Loss: 1.0948, Discriminator Loss: 0.2604
# ----------
# Epoch 1/500 : Gen loss: 0.2284, Disc Loss: 0.2569, Recon Loss: 0.3948, Percep loss: 0.6595
# Time taken: 0:00:05.508170
# Epoch 2/500
# ----------
# Batch 1/11 : Generator Loss: 1.0948, Discriminator Loss: 0.2564
# Batch 6/11 : Generator Loss: 0.9330, Discriminator Loss: 0.2543
# Batch 11/11 : Generator Loss: 0.8480, Discriminator Loss: 0.2548
# ----------
# Epoch 2/500 : Gen loss: 0.2397, Disc Loss: 0.2559, Recon Loss: 0.2040, Percep loss: 0.5254
# Time taken: 0:00:05.441289
#
#
# Epoch 3/500
# ----------
# Batch 1/11 : Generator Loss: 0.9295, Discriminator Loss: 0.2557
# Batch 6/11 : Generator Loss: 0.8566, Discriminator Loss: 0.2550
# Batch 11/11 : Generator Loss: 0.8068, Discriminator Loss: 0.2563
# ----------
# Epoch 3/500 : Gen loss: 0.2523, Disc Loss: 0.2554, Recon Loss: 0.1408, Percep loss: 0.4708
# Time taken: 0:00:05.396248
#
#
# Epoch 4/500
# ----------
# Batch 1/11 : Generator Loss: 0.8556, Discriminator Loss: 0.2553
# Batch 6/11 : Generator Loss: 0.8383, Discriminator Loss: 0.2540
# Batch 11/11 : Generator Loss: 0.7722, Discriminator Loss: 0.2553
# ----------
# Epoch 4/500 : Gen loss: 0.2538, Disc Loss: 0.2549, Recon Loss: 0.1139, Percep loss: 0.4418
# Time taken: 0:00:05.372069
#
#
# Epoch 5/500
# ----------
# Batch 1/11 : Generator Loss: 0.7766, Discriminator Loss: 0.2529
# Batch 6/11 : Generator Loss: 0.7836, Discriminator Loss: 0.2525
# Batch 11/11 : Generator Loss: 0.8037, Discriminator Loss: 0.2531
# ----------
# Epoch 5/500 : Gen loss: 0.2579, Disc Loss: 0.2526, Recon Loss: 0.1025, Percep loss: 0.4298
# Time taken: 0:00:05.382553
#
#
# Epoch 6/500
# ----------
# Batch 1/11 : Generator Loss: 0.7343, Discriminator Loss: 0.2586
# Batch 6/11 : Generator Loss: 0.7672, Discriminator Loss: 0.2558
# Batch 11/11 : Generator Loss: 0.7707, Discriminator Loss: 0.2568
# ----------
# Epoch 6/500 : Gen loss: 0.2515, Disc Loss: 0.2566, Recon Loss: 0.0900, Percep loss: 0.3996
# Time taken: 0:00:05.364326
#
#
# Epoch 7/500
# ----------
# Batch 1/11 : Generator Loss: 0.7576, Discriminator Loss: 0.2554
# Batch 6/11 : Generator Loss: 0.7319, Discriminator Loss: 0.2568
# Batch 11/11 : Generator Loss: 0.7129, Discriminator Loss: 0.2558
# ----------
# Epoch 7/500 : Gen loss: 0.2530, Disc Loss: 0.2559, Recon Loss: 0.0861, Percep loss: 0.3919
# Time taken: 0:00:05.393087
#
#
# Epoch 8/500
# ----------
# Batch 1/11 : Generator Loss: 0.7452, Discriminator Loss: 0.2545
# Batch 6/11 : Generator Loss: 0.7261, Discriminator Loss: 0.2566
# Batch 11/11 : Generator Loss: 0.7634, Discriminator Loss: 0.2564
# ----------
# Epoch 8/500 : Gen loss: 0.2538, Disc Loss: 0.2561, Recon Loss: 0.0873, Percep loss: 0.4002
# Time taken: 0:00:05.373227
#
#
# Epoch 9/500
# ----------
# Batch 1/11 : Generator Loss: 0.7522, Discriminator Loss: 0.2553
# Batch 6/11 : Generator Loss: 0.7208, Discriminator Loss: 0.2540
# Batch 11/11 : Generator Loss: 0.7124, Discriminator Loss: 0.2520
# ----------
# Epoch 9/500 : Gen loss: 0.2559, Disc Loss: 0.2551, Recon Loss: 0.0824, Percep loss: 0.3940
# Time taken: 0:00:05.405060
#
#
# Epoch 10/500
# ----------
# Batch 1/11 : Generator Loss: 0.6845, Discriminator Loss: 0.2557
# Batch 6/11 : Generator Loss: 0.7181, Discriminator Loss: 0.2544
# Batch 11/11 : Generator Loss: 0.6963, Discriminator Loss: 0.2550
# ----------
# Epoch 10/500 : Gen loss: 0.2530, Disc Loss: 0.2551, Recon Loss: 0.0743, Percep loss: 0.3676
# Time taken: 0:00:05.405761
#
#
# Epoch 11/500
# ----------
# Batch 1/11 : Generator Loss: 0.7076, Discriminator Loss: 0.2553
# Batch 6/11 : Generator Loss: 0.7386, Discriminator Loss: 0.2555
# Batch 11/11 : Generator Loss: 0.6617, Discriminator Loss: 0.2534
# ----------
# Epoch 11/500 : Gen loss: 0.2571, Disc Loss: 0.2550, Recon Loss: 0.0774, Percep loss: 0.3737
# Time taken: 0:00:05.474712
#
#
# Epoch 12/500
# ----------
# Batch 1/11 : Generator Loss: 0.6692, Discriminator Loss: 0.2549
# Batch 6/11 : Generator Loss: 0.7222, Discriminator Loss: 0.2548
# Batch 11/11 : Generator Loss: 0.6778, Discriminator Loss: 0.2579
# ----------
# Epoch 12/500 : Gen loss: 0.2541, Disc Loss: 0.2548, Recon Loss: 0.0768, Percep loss: 0.3667
# Time taken: 0:00:05.474515
#
#
# Epoch 13/500
# ----------
# Batch 1/11 : Generator Loss: 0.6725, Discriminator Loss: 0.2555
# Batch 6/11 : Generator Loss: 0.7858, Discriminator Loss: 0.2538
# Batch 11/11 : Generator Loss: 0.6817, Discriminator Loss: 0.2549
# ----------
# Epoch 13/500 : Gen loss: 0.2568, Disc Loss: 0.2543, Recon Loss: 0.0767, Percep loss: 0.3693
# Time taken: 0:00:05.431336
#
#
# Epoch 14/500
# ----------
# Batch 1/11 : Generator Loss: 0.6878, Discriminator Loss: 0.2520
# Batch 6/11 : Generator Loss: 0.6613, Discriminator Loss: 0.2536
# Batch 11/11 : Generator Loss: 0.7049, Discriminator Loss: 0.2564
# ----------
# Epoch 14/500 : Gen loss: 0.2534, Disc Loss: 0.2545, Recon Loss: 0.0707, Percep loss: 0.3535
# Time taken: 0:00:05.394659
#
#
# Epoch 15/500
# ----------
# Batch 1/11 : Generator Loss: 0.6491, Discriminator Loss: 0.2535
# Batch 6/11 : Generator Loss: 0.6880, Discriminator Loss: 0.2547
# Batch 11/11 : Generator Loss: 0.6774, Discriminator Loss: 0.2553
# ----------
# Epoch 15/500 : Gen loss: 0.2549, Disc Loss: 0.2537, Recon Loss: 0.0705, Percep loss: 0.3478
# Time taken: 0:00:05.388405
#
#
# Epoch 16/500
# ----------
# Batch 1/11 : Generator Loss: 0.6776, Discriminator Loss: 0.2548
# Batch 6/11 : Generator Loss: 0.7117, Discriminator Loss: 0.2543
# Batch 11/11 : Generator Loss: 0.6898, Discriminator Loss: 0.2521
# ----------
# Epoch 16/500 : Gen loss: 0.2520, Disc Loss: 0.2537, Recon Loss: 0.0704, Percep loss: 0.3601
# Time taken: 0:00:05.385618
#
#
# Epoch 17/500
# ----------
# Batch 1/11 : Generator Loss: 0.6103, Discriminator Loss: 0.2543
# Batch 6/11 : Generator Loss: 0.6703, Discriminator Loss: 0.2527
# Batch 11/11 : Generator Loss: 0.7131, Discriminator Loss: 0.2538
# ----------
# Epoch 17/500 : Gen loss: 0.2563, Disc Loss: 0.2535, Recon Loss: 0.0691, Percep loss: 0.3455
# Time taken: 0:00:05.447491
#
#
# Epoch 18/500
# ----------
# Batch 1/11 : Generator Loss: 0.6779, Discriminator Loss: 0.2531
# Batch 6/11 : Generator Loss: 0.6895, Discriminator Loss: 0.2536
# Batch 11/11 : Generator Loss: 0.6613, Discriminator Loss: 0.2501
# ----------
# Epoch 18/500 : Gen loss: 0.2548, Disc Loss: 0.2532, Recon Loss: 0.0716, Percep loss: 0.3388
# Time taken: 0:00:05.473370
#
#
# Epoch 19/500
# ----------
# Batch 1/11 : Generator Loss: 0.6305, Discriminator Loss: 0.2507
# Batch 6/11 : Generator Loss: 0.6275, Discriminator Loss: 0.2505
# Batch 11/11 : Generator Loss: 0.6492, Discriminator Loss: 0.2512
# ----------
# Epoch 19/500 : Gen loss: 0.2544, Disc Loss: 0.2529, Recon Loss: 0.0642, Percep loss: 0.3297
# Time taken: 0:00:05.444580
#
#
# Epoch 20/500
# ----------
# Batch 1/11 : Generator Loss: 0.6863, Discriminator Loss: 0.2522
# Batch 6/11 : Generator Loss: 0.7443, Discriminator Loss: 0.2515
# Batch 11/11 : Generator Loss: 0.6677, Discriminator Loss: 0.2514
# ----------
# Epoch 20/500 : Gen loss: 0.2559, Disc Loss: 0.2522, Recon Loss: 0.0702, Percep loss: 0.3535
# Time taken: 0:00:05.443599
#
#
# Epoch 21/500
# ----------
# Batch 1/11 : Generator Loss: 0.6770, Discriminator Loss: 0.2528
# Batch 6/11 : Generator Loss: 0.6385, Discriminator Loss: 0.2515
# Batch 11/11 : Generator Loss: 0.6820, Discriminator Loss: 0.2516
# ----------
# Epoch 21/500 : Gen loss: 0.2561, Disc Loss: 0.2521, Recon Loss: 0.0659, Percep loss: 0.3365
# Time taken: 0:00:05.443156
#
#
# Epoch 22/500
# ----------
# Batch 1/11 : Generator Loss: 0.6842, Discriminator Loss: 0.2512
# Batch 6/11 : Generator Loss: 0.6765, Discriminator Loss: 0.2509
# Batch 11/11 : Generator Loss: 0.6697, Discriminator Loss: 0.2521
# ----------
# Epoch 22/500 : Gen loss: 0.2566, Disc Loss: 0.2520, Recon Loss: 0.0702, Percep loss: 0.3449
# Time taken: 0:00:05.422316
#
#
# Epoch 23/500
# ----------
# Batch 1/11 : Generator Loss: 0.6378, Discriminator Loss: 0.2536
# Batch 6/11 : Generator Loss: 0.6790, Discriminator Loss: 0.2518
# Batch 11/11 : Generator Loss: 0.6217, Discriminator Loss: 0.2510
# ----------
# Epoch 23/500 : Gen loss: 0.2556, Disc Loss: 0.2513, Recon Loss: 0.0672, Percep loss: 0.3367
# Time taken: 0:00:05.466817
#
#
# Epoch 24/500
# ----------
# Batch 1/11 : Generator Loss: 0.6450, Discriminator Loss: 0.2523
# Batch 6/11 : Generator Loss: 0.6040, Discriminator Loss: 0.2516
# Batch 11/11 : Generator Loss: 0.6668, Discriminator Loss: 0.2524
# ----------
# Epoch 24/500 : Gen loss: 0.2545, Disc Loss: 0.2515, Recon Loss: 0.0659, Percep loss: 0.3339
# Time taken: 0:00:05.471417
#
#
# Epoch 25/500
# ----------
# Batch 1/11 : Generator Loss: 0.6383, Discriminator Loss: 0.2528
# Batch 6/11 : Generator Loss: 0.6355, Discriminator Loss: 0.2512
# Batch 11/11 : Generator Loss: 0.6408, Discriminator Loss: 0.2512
# ----------
# Epoch 25/500 : Gen loss: 0.2575, Disc Loss: 0.2514, Recon Loss: 0.0654, Percep loss: 0.3327
# Time taken: 0:00:05.443684
#
#
# Epoch 26/500
# ----------
# Batch 1/11 : Generator Loss: 0.6219, Discriminator Loss: 0.2499
# Batch 6/11 : Generator Loss: 0.6521, Discriminator Loss: 0.2508
# Batch 11/11 : Generator Loss: 0.6202, Discriminator Loss: 0.2526
# ----------
# Epoch 26/500 : Gen loss: 0.2569, Disc Loss: 0.2506, Recon Loss: 0.0608, Percep loss: 0.3165
# Time taken: 0:00:05.494254
#
#
# Epoch 27/500
# ----------
# Batch 1/11 : Generator Loss: 0.6619, Discriminator Loss: 0.2498
# Batch 6/11 : Generator Loss: 0.6371, Discriminator Loss: 0.2513
# Batch 11/11 : Generator Loss: 0.6463, Discriminator Loss: 0.2516
# ----------
# Epoch 27/500 : Gen loss: 0.2567, Disc Loss: 0.2503, Recon Loss: 0.0664, Percep loss: 0.3298
# Time taken: 0:00:05.531363
#
#
# Epoch 28/500
# ----------
# Batch 1/11 : Generator Loss: 0.6360, Discriminator Loss: 0.2482
# Batch 6/11 : Generator Loss: 0.7196, Discriminator Loss: 0.2537
# Batch 11/11 : Generator Loss: 0.6006, Discriminator Loss: 0.2474
# ----------
# Epoch 28/500 : Gen loss: 0.2601, Disc Loss: 0.2494, Recon Loss: 0.0675, Percep loss: 0.3357
# Time taken: 0:00:05.537547
#
#
# Epoch 29/500
# ----------
# Batch 1/11 : Generator Loss: 0.6295, Discriminator Loss: 0.2487
# Batch 6/11 : Generator Loss: 0.6120, Discriminator Loss: 0.2504
# Batch 11/11 : Generator Loss: 0.6504, Discriminator Loss: 0.2441
# ----------
# Epoch 29/500 : Gen loss: 0.2587, Disc Loss: 0.2484, Recon Loss: 0.0663, Percep loss: 0.3276
# Time taken: 0:00:05.522209
#
#
# Epoch 30/500
# ----------
# Batch 1/11 : Generator Loss: 0.5751, Discriminator Loss: 0.2507
# Batch 6/11 : Generator Loss: 0.6579, Discriminator Loss: 0.2472
# Batch 11/11 : Generator Loss: 0.6582, Discriminator Loss: 0.2469
# ----------
# Epoch 30/500 : Gen loss: 0.2627, Disc Loss: 0.2476, Recon Loss: 0.0652, Percep loss: 0.3211
# Time taken: 0:00:05.545046
#
#
# Epoch 31/500
# ----------
# Batch 1/11 : Generator Loss: 0.7022, Discriminator Loss: 0.2481
# Batch 6/11 : Generator Loss: 0.6655, Discriminator Loss: 0.2516
# Batch 11/11 : Generator Loss: 0.6233, Discriminator Loss: 0.2439
# ----------
# Epoch 31/500 : Gen loss: 0.2617, Disc Loss: 0.2469, Recon Loss: 0.0651, Percep loss: 0.3349
# Time taken: 0:00:05.550481
#
#
# Epoch 32/500
# ----------
# Batch 1/11 : Generator Loss: 0.7062, Discriminator Loss: 0.2475
# Batch 6/11 : Generator Loss: 0.6565, Discriminator Loss: 0.2448
# Batch 11/11 : Generator Loss: 0.6424, Discriminator Loss: 0.2532
# ----------
# Epoch 32/500 : Gen loss: 0.2611, Disc Loss: 0.2466, Recon Loss: 0.0645, Percep loss: 0.3256
# Time taken: 0:00:05.501393
#
#
# Epoch 33/500
# ----------
# Batch 1/11 : Generator Loss: 0.7126, Discriminator Loss: 0.2454
# Batch 6/11 : Generator Loss: 0.6956, Discriminator Loss: 0.2489
# Batch 11/11 : Generator Loss: 0.6427, Discriminator Loss: 0.2434
# ----------
# Epoch 33/500 : Gen loss: 0.2640, Disc Loss: 0.2458, Recon Loss: 0.0666, Percep loss: 0.3315
# Time taken: 0:00:05.436819
#
#
# Epoch 34/500
# ----------
# Batch 1/11 : Generator Loss: 0.6708, Discriminator Loss: 0.2483
# Batch 6/11 : Generator Loss: 0.6326, Discriminator Loss: 0.2407
# Batch 11/11 : Generator Loss: 0.6473, Discriminator Loss: 0.2481
# ----------
# Epoch 34/500 : Gen loss: 0.2662, Disc Loss: 0.2437, Recon Loss: 0.0656, Percep loss: 0.3226
# Time taken: 0:00:05.429415
#
#
# Epoch 35/500
# ----------
# Batch 1/11 : Generator Loss: 0.6486, Discriminator Loss: 0.2385
# Batch 6/11 : Generator Loss: 0.6756, Discriminator Loss: 0.2400
# Batch 11/11 : Generator Loss: 0.6790, Discriminator Loss: 0.2359
# ----------
# Epoch 35/500 : Gen loss: 0.2727, Disc Loss: 0.2408, Recon Loss: 0.0608, Percep loss: 0.3149
# Time taken: 0:00:05.456183
#
#
# Epoch 36/500
# ----------
# Batch 1/11 : Generator Loss: 0.5599, Discriminator Loss: 0.2399
# Batch 6/11 : Generator Loss: 0.6486, Discriminator Loss: 0.2413
# Batch 11/11 : Generator Loss: 0.7024, Discriminator Loss: 0.2395
# ----------
# Epoch 36/500 : Gen loss: 0.2675, Disc Loss: 0.2413, Recon Loss: 0.0632, Percep loss: 0.3128
# Time taken: 0:00:05.444913
#
#
# Epoch 37/500
# ----------
# Batch 1/11 : Generator Loss: 0.6714, Discriminator Loss: 0.2364
# Batch 6/11 : Generator Loss: 0.6113, Discriminator Loss: 0.2368
# Batch 11/11 : Generator Loss: 0.6658, Discriminator Loss: 0.2346
# ----------
# Epoch 37/500 : Gen loss: 0.2734, Disc Loss: 0.2389, Recon Loss: 0.0602, Percep loss: 0.3124
# Time taken: 0:00:05.446343
#
#
# Epoch 38/500
# ----------
# Batch 1/11 : Generator Loss: 0.6570, Discriminator Loss: 0.2388
# Batch 6/11 : Generator Loss: 0.6388, Discriminator Loss: 0.2315
# Batch 11/11 : Generator Loss: 0.6289, Discriminator Loss: 0.2261
# ----------
# Epoch 38/500 : Gen loss: 0.2832, Disc Loss: 0.2360, Recon Loss: 0.0594, Percep loss: 0.3161
# Time taken: 0:00:05.434835
#
#
# Epoch 39/500
# ----------
# Batch 1/11 : Generator Loss: 0.6426, Discriminator Loss: 0.2381
# Batch 6/11 : Generator Loss: 0.6385, Discriminator Loss: 0.2339
# Batch 11/11 : Generator Loss: 0.6135, Discriminator Loss: 0.2222
# ----------
# Epoch 39/500 : Gen loss: 0.2807, Disc Loss: 0.2331, Recon Loss: 0.0614, Percep loss: 0.3047
# Time taken: 0:00:05.435507
#
#
# Epoch 40/500
# ----------
# Batch 1/11 : Generator Loss: 0.7261, Discriminator Loss: 0.2329
# Batch 6/11 : Generator Loss: 0.7183, Discriminator Loss: 0.2298
# Batch 11/11 : Generator Loss: 0.6753, Discriminator Loss: 0.2235
# ----------
# Epoch 40/500 : Gen loss: 0.2848, Disc Loss: 0.2327, Recon Loss: 0.0621, Percep loss: 0.3131
# Time taken: 0:00:05.449353
#
#
# Epoch 41/500
# ----------
# Batch 1/11 : Generator Loss: 0.6212, Discriminator Loss: 0.2292
# Batch 6/11 : Generator Loss: 0.6771, Discriminator Loss: 0.2315
# Batch 11/11 : Generator Loss: 0.6561, Discriminator Loss: 0.2316
# ----------
# Epoch 41/500 : Gen loss: 0.2833, Disc Loss: 0.2307, Recon Loss: 0.0568, Percep loss: 0.3028
# Time taken: 0:00:05.462400
#
#
# Epoch 42/500
# ----------
# Batch 1/11 : Generator Loss: 0.7108, Discriminator Loss: 0.2166
# Batch 6/11 : Generator Loss: 0.6864, Discriminator Loss: 0.2187
# Batch 11/11 : Generator Loss: 0.6500, Discriminator Loss: 0.2285
# ----------
# Epoch 42/500 : Gen loss: 0.2915, Disc Loss: 0.2231, Recon Loss: 0.0643, Percep loss: 0.3159
# Time taken: 0:00:05.420083
#
#
# Epoch 43/500
# ----------
# Batch 1/11 : Generator Loss: 0.6734, Discriminator Loss: 0.2316
# Batch 6/11 : Generator Loss: 0.6612, Discriminator Loss: 0.2161
# Batch 11/11 : Generator Loss: 0.6449, Discriminator Loss: 0.2263
# ----------
# Epoch 43/500 : Gen loss: 0.2995, Disc Loss: 0.2179, Recon Loss: 0.0600, Percep loss: 0.3031
# Time taken: 0:00:05.478035
#
#
# Epoch 44/500
# ----------
# Batch 1/11 : Generator Loss: 0.6079, Discriminator Loss: 0.2352
# Batch 6/11 : Generator Loss: 0.7260, Discriminator Loss: 0.2240
# Batch 11/11 : Generator Loss: 0.7268, Discriminator Loss: 0.2298
# ----------
# Epoch 44/500 : Gen loss: 0.3040, Disc Loss: 0.2225, Recon Loss: 0.0630, Percep loss: 0.3165
# Time taken: 0:00:05.428049
#
#
# Epoch 45/500
# ----------
# Batch 1/11 : Generator Loss: 0.6058, Discriminator Loss: 0.1958
# Batch 6/11 : Generator Loss: 0.8004, Discriminator Loss: 0.2076
# Batch 11/11 : Generator Loss: 0.7121, Discriminator Loss: 0.2099
# ----------
# Epoch 45/500 : Gen loss: 0.3126, Disc Loss: 0.2102, Recon Loss: 0.0634, Percep loss: 0.3171
# Time taken: 0:00:05.484668
#
#
# Epoch 46/500
# ----------
# Batch 1/11 : Generator Loss: 0.7569, Discriminator Loss: 0.2276
# Batch 6/11 : Generator Loss: 0.6735, Discriminator Loss: 0.2242
# Batch 11/11 : Generator Loss: 0.6380, Discriminator Loss: 0.2299
# ----------
# Epoch 46/500 : Gen loss: 0.3055, Disc Loss: 0.2087, Recon Loss: 0.0608, Percep loss: 0.3151
# Time taken: 0:00:05.493186
#
#
# Epoch 47/500
# ----------
# Batch 1/11 : Generator Loss: 0.6751, Discriminator Loss: 0.2070
# Batch 6/11 : Generator Loss: 0.6381, Discriminator Loss: 0.2169
# Batch 11/11 : Generator Loss: 0.6588, Discriminator Loss: 0.2403
# ----------
# Epoch 47/500 : Gen loss: 0.3194, Disc Loss: 0.2112, Recon Loss: 0.0556, Percep loss: 0.2989
# Time taken: 0:00:05.464589
#
#
# Epoch 48/500
# ----------
# Batch 1/11 : Generator Loss: 0.7265, Discriminator Loss: 0.1910
# Batch 6/11 : Generator Loss: 0.7102, Discriminator Loss: 0.2130
# Batch 11/11 : Generator Loss: 0.5929, Discriminator Loss: 0.1919
# ----------
# Epoch 48/500 : Gen loss: 0.3188, Disc Loss: 0.1986, Recon Loss: 0.0565, Percep loss: 0.2945
# Time taken: 0:00:05.507602
#
#
# Epoch 49/500
# ----------
# Batch 1/11 : Generator Loss: 0.6795, Discriminator Loss: 0.2064
# Batch 6/11 : Generator Loss: 0.6924, Discriminator Loss: 0.1929
# Batch 11/11 : Generator Loss: 0.7526, Discriminator Loss: 0.2084
# ----------
# Epoch 49/500 : Gen loss: 0.3156, Disc Loss: 0.2053, Recon Loss: 0.0597, Percep loss: 0.3042
# Time taken: 0:00:05.495814
#
#
# Epoch 50/500
# ----------
# Batch 1/11 : Generator Loss: 0.7679, Discriminator Loss: 0.2133
# Batch 6/11 : Generator Loss: 0.7029, Discriminator Loss: 0.1906
# Batch 11/11 : Generator Loss: 0.6756, Discriminator Loss: 0.1756
# ----------
# Epoch 50/500 : Gen loss: 0.3388, Disc Loss: 0.1861, Recon Loss: 0.0629, Percep loss: 0.3240
# Time taken: 0:00:05.506630
#
#
# Epoch 51/500
# ----------
# Batch 1/11 : Generator Loss: 0.7040, Discriminator Loss: 0.1724
# Batch 6/11 : Generator Loss: 0.7155, Discriminator Loss: 0.2240
# Batch 11/11 : Generator Loss: 0.6679, Discriminator Loss: 0.2136
# ----------
# Epoch 51/500 : Gen loss: 0.3204, Disc Loss: 0.1887, Recon Loss: 0.0618, Percep loss: 0.3138
# Time taken: 0:00:05.509867
# Epoch 52/500
# ----------
# Batch 1/11 : Generator Loss: 0.6845, Discriminator Loss: 0.1766
# Batch 6/11 : Generator Loss: 0.8193, Discriminator Loss: 0.1669
# Batch 11/11 : Generator Loss: 0.6157, Discriminator Loss: 0.1917
# ----------
# Epoch 52/500 : Gen loss: 0.3413, Disc Loss: 0.1817, Recon Loss: 0.0634, Percep loss: 0.3056
# Time taken: 0:00:05.527385
#
#
# Epoch 53/500
# ----------
# Batch 1/11 : Generator Loss: 0.7474, Discriminator Loss: 0.2299
# Batch 6/11 : Generator Loss: 0.6947, Discriminator Loss: 0.1641
# Batch 11/11 : Generator Loss: 0.6564, Discriminator Loss: 0.2447
# ----------
# Epoch 53/500 : Gen loss: 0.3475, Disc Loss: 0.1900, Recon Loss: 0.0650, Percep loss: 0.3152
# Time taken: 0:00:05.514663
#
#
# Epoch 54/500
# ----------
# Batch 1/11 : Generator Loss: 0.7729, Discriminator Loss: 0.2162
# Batch 6/11 : Generator Loss: 0.6552, Discriminator Loss: 0.1724
# Batch 11/11 : Generator Loss: 0.6485, Discriminator Loss: 0.1791
# ----------
# Epoch 54/500 : Gen loss: 0.3223, Disc Loss: 0.1947, Recon Loss: 0.0575, Percep loss: 0.3007
# Time taken: 0:00:05.528055
#
#
# Epoch 55/500
# ----------
# Batch 1/11 : Generator Loss: 0.8259, Discriminator Loss: 0.2379
# Batch 6/11 : Generator Loss: 0.6873, Discriminator Loss: 0.1532
# Batch 11/11 : Generator Loss: 0.6358, Discriminator Loss: 0.2165
# ----------
# Epoch 55/500 : Gen loss: 0.3591, Disc Loss: 0.1854, Recon Loss: 0.0640, Percep loss: 0.3126
# Time taken: 0:00:05.529288
#
#
# Epoch 56/500
# ----------
# Batch 1/11 : Generator Loss: 0.7175, Discriminator Loss: 0.1766
# Batch 6/11 : Generator Loss: 0.7253, Discriminator Loss: 0.1726
# Batch 11/11 : Generator Loss: 0.6721, Discriminator Loss: 0.2317
# ----------
# Epoch 56/500 : Gen loss: 0.3346, Disc Loss: 0.1860, Recon Loss: 0.0594, Percep loss: 0.2989
# Time taken: 0:00:05.490897
#
#
# Epoch 57/500
# ----------
# Batch 1/11 : Generator Loss: 0.9039, Discriminator Loss: 0.2037
# Batch 6/11 : Generator Loss: 0.6159, Discriminator Loss: 0.2472
# Batch 11/11 : Generator Loss: 0.7908, Discriminator Loss: 0.2105
# ----------
# Epoch 57/500 : Gen loss: 0.3429, Disc Loss: 0.1934, Recon Loss: 0.0603, Percep loss: 0.3020
# Time taken: 0:00:05.566412
#
#
# Epoch 58/500
# ----------
# Batch 1/11 : Generator Loss: 0.8562, Discriminator Loss: 0.1931
# Batch 6/11 : Generator Loss: 0.6752, Discriminator Loss: 0.1489
# Batch 11/11 : Generator Loss: 0.7608, Discriminator Loss: 0.1938
# ----------
# Epoch 58/500 : Gen loss: 0.3616, Disc Loss: 0.1793, Recon Loss: 0.0612, Percep loss: 0.3014
# Time taken: 0:00:05.560365
#
#
# Epoch 59/500
# ----------
# Batch 1/11 : Generator Loss: 0.6984, Discriminator Loss: 0.1820
# Batch 6/11 : Generator Loss: 0.8512, Discriminator Loss: 0.1639
# Batch 11/11 : Generator Loss: 0.7033, Discriminator Loss: 0.2142
# ----------
# Epoch 59/500 : Gen loss: 0.2974, Disc Loss: 0.1866, Recon Loss: 0.0572, Percep loss: 0.3027
# Time taken: 0:00:05.534093
#
#
# Epoch 60/500
# ----------
# Batch 1/11 : Generator Loss: 0.8042, Discriminator Loss: 0.1795
# Batch 6/11 : Generator Loss: 0.7167, Discriminator Loss: 0.2339
# Batch 11/11 : Generator Loss: 0.9286, Discriminator Loss: 0.1057
# ----------
# Epoch 60/500 : Gen loss: 0.3887, Disc Loss: 0.1707, Recon Loss: 0.0638, Percep loss: 0.3128
# Time taken: 0:00:05.508021
#
#
# Epoch 61/500
# ----------
# Batch 1/11 : Generator Loss: 0.8345, Discriminator Loss: 0.1618
# Batch 6/11 : Generator Loss: 0.4845, Discriminator Loss: 0.1480
# Batch 11/11 : Generator Loss: 0.6472, Discriminator Loss: 0.2026
# ----------
# Epoch 61/500 : Gen loss: 0.3334, Disc Loss: 0.1857, Recon Loss: 0.0595, Percep loss: 0.2885
# Time taken: 0:00:05.500092
#
#
# Epoch 62/500
# ----------
# Batch 1/11 : Generator Loss: 0.8472, Discriminator Loss: 0.1794
# Batch 6/11 : Generator Loss: 0.5937, Discriminator Loss: 0.1887
# Batch 11/11 : Generator Loss: 0.5908, Discriminator Loss: 0.1836
# ----------
# Epoch 62/500 : Gen loss: 0.3400, Disc Loss: 0.1937, Recon Loss: 0.0601, Percep loss: 0.3005
# Time taken: 0:00:05.464761
#
#
# Epoch 63/500
# ----------
# Batch 1/11 : Generator Loss: 0.6448, Discriminator Loss: 0.2423
# Batch 6/11 : Generator Loss: 0.8782, Discriminator Loss: 0.1883
# Batch 11/11 : Generator Loss: 0.6307, Discriminator Loss: 0.2822
# ----------
# Epoch 63/500 : Gen loss: 0.3611, Disc Loss: 0.2078, Recon Loss: 0.0602, Percep loss: 0.3020
# Time taken: 0:00:05.484734
#
#
# Epoch 64/500
# ----------
# Batch 1/11 : Generator Loss: 0.7627, Discriminator Loss: 0.1811
# Batch 6/11 : Generator Loss: 0.8476, Discriminator Loss: 0.2992
# Batch 11/11 : Generator Loss: 0.6534, Discriminator Loss: 0.2009
# ----------
# Epoch 64/500 : Gen loss: 0.3206, Disc Loss: 0.1976, Recon Loss: 0.0616, Percep loss: 0.2939
# Time taken: 0:00:05.433136
#
#
# Epoch 65/500
# ----------
# Batch 1/11 : Generator Loss: 0.8618, Discriminator Loss: 0.2237
# Batch 6/11 : Generator Loss: 0.6588, Discriminator Loss: 0.2272
# Batch 11/11 : Generator Loss: 0.8262, Discriminator Loss: 0.1981
# ----------
# Epoch 65/500 : Gen loss: 0.3545, Disc Loss: 0.1818, Recon Loss: 0.0588, Percep loss: 0.2888
# Time taken: 0:00:05.421197
#
#
# Epoch 66/500
# ----------
# Batch 1/11 : Generator Loss: 0.5620, Discriminator Loss: 0.1199
# Batch 6/11 : Generator Loss: 0.8542, Discriminator Loss: 0.1294
# Batch 11/11 : Generator Loss: 0.6436, Discriminator Loss: 0.1592
# ----------
# Epoch 66/500 : Gen loss: 0.3478, Disc Loss: 0.1725, Recon Loss: 0.0607, Percep loss: 0.2926
# Time taken: 0:00:05.421952
#
#
# Epoch 67/500
# ----------
# Batch 1/11 : Generator Loss: 0.6905, Discriminator Loss: 0.2451
# Batch 6/11 : Generator Loss: 0.8040, Discriminator Loss: 0.2788
# Batch 11/11 : Generator Loss: 0.7215, Discriminator Loss: 0.2056
# ----------
# Epoch 67/500 : Gen loss: 0.3362, Disc Loss: 0.2149, Recon Loss: 0.0599, Percep loss: 0.3025
# Time taken: 0:00:05.417292
#
#
# Epoch 68/500
# ----------
# Batch 1/11 : Generator Loss: 0.7731, Discriminator Loss: 0.1870
# Batch 6/11 : Generator Loss: 0.6732, Discriminator Loss: 0.2719
# Batch 11/11 : Generator Loss: 0.7812, Discriminator Loss: 0.1677
# ----------
# Epoch 68/500 : Gen loss: 0.3279, Disc Loss: 0.1877, Recon Loss: 0.0595, Percep loss: 0.2918
# Time taken: 0:00:05.426190
#
#
# Epoch 69/500
# ----------
# Batch 1/11 : Generator Loss: 0.5707, Discriminator Loss: 0.2144
# Batch 6/11 : Generator Loss: 0.7316, Discriminator Loss: 0.1995
# Batch 11/11 : Generator Loss: 0.6211, Discriminator Loss: 0.1699
# ----------
# Epoch 69/500 : Gen loss: 0.3105, Disc Loss: 0.1950, Recon Loss: 0.0587, Percep loss: 0.2908
# Time taken: 0:00:05.426037
#
#
# Epoch 70/500
# ----------
# Batch 1/11 : Generator Loss: 0.5947, Discriminator Loss: 0.2487
# Batch 6/11 : Generator Loss: 0.6230, Discriminator Loss: 0.2704
# Batch 11/11 : Generator Loss: 0.7768, Discriminator Loss: 0.2285
# ----------
# Epoch 70/500 : Gen loss: 0.3555, Disc Loss: 0.2004, Recon Loss: 0.0585, Percep loss: 0.2908
# Time taken: 0:00:05.423370
#
#
# Epoch 71/500
# ----------
# Batch 1/11 : Generator Loss: 0.6413, Discriminator Loss: 0.2078
# Batch 6/11 : Generator Loss: 0.8311, Discriminator Loss: 0.1343
# Batch 11/11 : Generator Loss: 0.6947, Discriminator Loss: 0.1588
# ----------
# Epoch 71/500 : Gen loss: 0.3288, Disc Loss: 0.1819, Recon Loss: 0.0630, Percep loss: 0.3033
# Time taken: 0:00:05.428036
#
#
# Epoch 72/500
# ----------
# Batch 1/11 : Generator Loss: 0.6865, Discriminator Loss: 0.1342
# Batch 6/11 : Generator Loss: 0.5938, Discriminator Loss: 0.1755
# Batch 11/11 : Generator Loss: 0.6933, Discriminator Loss: 0.1792
# ----------
# Epoch 72/500 : Gen loss: 0.3379, Disc Loss: 0.1968, Recon Loss: 0.0579, Percep loss: 0.2944
# Time taken: 0:00:05.455796
#
#
# Epoch 73/500
# ----------
# Batch 1/11 : Generator Loss: 0.8023, Discriminator Loss: 0.1812
# Batch 6/11 : Generator Loss: 0.6654, Discriminator Loss: 0.2082
# Batch 11/11 : Generator Loss: 0.7266, Discriminator Loss: 0.1621
# ----------
# Epoch 73/500 : Gen loss: 0.3453, Disc Loss: 0.1972, Recon Loss: 0.0592, Percep loss: 0.2894
# Time taken: 0:00:05.451868
#
#
# Epoch 74/500
# ----------
# Batch 1/11 : Generator Loss: 0.7194, Discriminator Loss: 0.1722
# Batch 6/11 : Generator Loss: 0.7399, Discriminator Loss: 0.1551
# Batch 11/11 : Generator Loss: 0.7546, Discriminator Loss: 0.1580
# ----------
# Epoch 74/500 : Gen loss: 0.3306, Disc Loss: 0.1805, Recon Loss: 0.0600, Percep loss: 0.2969
# Time taken: 0:00:05.450396
#
#
# Epoch 75/500
# ----------
# Batch 1/11 : Generator Loss: 0.6286, Discriminator Loss: 0.1279
# Batch 6/11 : Generator Loss: 0.6948, Discriminator Loss: 0.2409
# Batch 11/11 : Generator Loss: 0.7322, Discriminator Loss: 0.2263
# ----------
# Epoch 75/500 : Gen loss: 0.3025, Disc Loss: 0.1900, Recon Loss: 0.0616, Percep loss: 0.3021
# Time taken: 0:00:05.460787
#
#
# Epoch 76/500
# ----------
# Batch 1/11 : Generator Loss: 0.7192, Discriminator Loss: 0.1741
# Batch 6/11 : Generator Loss: 0.8210, Discriminator Loss: 0.1850
# Batch 11/11 : Generator Loss: 0.4776, Discriminator Loss: 0.1725
# ----------
# Epoch 76/500 : Gen loss: 0.3479, Disc Loss: 0.1793, Recon Loss: 0.0627, Percep loss: 0.3022
# Time taken: 0:00:05.439589
#
#
# Epoch 77/500
# ----------
# Batch 1/11 : Generator Loss: 0.7403, Discriminator Loss: 0.2204
# Batch 6/11 : Generator Loss: 0.7459, Discriminator Loss: 0.2091
# Batch 11/11 : Generator Loss: 0.5824, Discriminator Loss: 0.2519
# ----------
# Epoch 77/500 : Gen loss: 0.3214, Disc Loss: 0.2017, Recon Loss: 0.0574, Percep loss: 0.2829
# Time taken: 0:00:05.461182
#
#
# Epoch 78/500
# ----------
# Batch 1/11 : Generator Loss: 0.7581, Discriminator Loss: 0.2521
# Batch 6/11 : Generator Loss: 0.6418, Discriminator Loss: 0.2256
# Batch 11/11 : Generator Loss: 0.8793, Discriminator Loss: 0.1974
# ----------
# Epoch 78/500 : Gen loss: 0.3485, Disc Loss: 0.2021, Recon Loss: 0.0577, Percep loss: 0.2950
# Time taken: 0:00:05.398865
#
#
# Epoch 79/500
# ----------
# Batch 1/11 : Generator Loss: 0.5582, Discriminator Loss: 0.1334
# Batch 6/11 : Generator Loss: 0.7049, Discriminator Loss: 0.1320
# Batch 11/11 : Generator Loss: 0.7788, Discriminator Loss: 0.2337
# ----------
# Epoch 79/500 : Gen loss: 0.3266, Disc Loss: 0.2009, Recon Loss: 0.0568, Percep loss: 0.2878
# Time taken: 0:00:05.404722
#
#
# Epoch 80/500
# ----------
# Batch 1/11 : Generator Loss: 0.6795, Discriminator Loss: 0.1898
# Batch 6/11 : Generator Loss: 0.7669, Discriminator Loss: 0.1744
# Batch 11/11 : Generator Loss: 0.5864, Discriminator Loss: 0.2071
# ----------
# Epoch 80/500 : Gen loss: 0.3401, Disc Loss: 0.1796, Recon Loss: 0.0547, Percep loss: 0.2801
# Time taken: 0:00:05.391169
#
#
# Epoch 81/500
# ----------
# Batch 1/11 : Generator Loss: 0.7361, Discriminator Loss: 0.1340
# Batch 6/11 : Generator Loss: 0.6556, Discriminator Loss: 0.1458
# Batch 11/11 : Generator Loss: 0.9373, Discriminator Loss: 0.1391
# ----------
# Epoch 81/500 : Gen loss: 0.3687, Disc Loss: 0.1878, Recon Loss: 0.0571, Percep loss: 0.2809
# Time taken: 0:00:05.416481
#
#
# Epoch 82/500
# ----------
# Batch 1/11 : Generator Loss: 0.6561, Discriminator Loss: 0.1094
# Batch 6/11 : Generator Loss: 0.5714, Discriminator Loss: 0.2240
# Batch 11/11 : Generator Loss: 0.7287, Discriminator Loss: 0.2255
# ----------
# Epoch 82/500 : Gen loss: 0.3099, Disc Loss: 0.1953, Recon Loss: 0.0574, Percep loss: 0.2822
# Time taken: 0:00:05.418499
#
#
# Epoch 83/500
# ----------
# Batch 1/11 : Generator Loss: 0.4746, Discriminator Loss: 0.2585
# Batch 6/11 : Generator Loss: 0.7214, Discriminator Loss: 0.1987
# Batch 11/11 : Generator Loss: 0.6998, Discriminator Loss: 0.2876
# ----------
# Epoch 83/500 : Gen loss: 0.2991, Disc Loss: 0.2206, Recon Loss: 0.0541, Percep loss: 0.2806
# Time taken: 0:00:05.478080
#
#
# Epoch 84/500
# ----------
# Batch 1/11 : Generator Loss: 0.9307, Discriminator Loss: 0.0994
# Batch 6/11 : Generator Loss: 0.7236, Discriminator Loss: 0.1357
# Batch 11/11 : Generator Loss: 0.7301, Discriminator Loss: 0.2778
# ----------
# Epoch 84/500 : Gen loss: 0.3639, Disc Loss: 0.1944, Recon Loss: 0.0601, Percep loss: 0.2945
# Time taken: 0:00:05.465755
#
#
# Epoch 85/500
# ----------
# Batch 1/11 : Generator Loss: 0.6998, Discriminator Loss: 0.2139
# Batch 6/11 : Generator Loss: 0.6103, Discriminator Loss: 0.1688
# Batch 11/11 : Generator Loss: 0.6554, Discriminator Loss: 0.1312
# ----------
# Epoch 85/500 : Gen loss: 0.3638, Disc Loss: 0.1871, Recon Loss: 0.0562, Percep loss: 0.2819
# Time taken: 0:00:05.496511
#
#
# Epoch 86/500
# ----------
# Batch 1/11 : Generator Loss: 0.6594, Discriminator Loss: 0.1105
# Batch 6/11 : Generator Loss: 0.8340, Discriminator Loss: 0.2941
# Batch 11/11 : Generator Loss: 0.6727, Discriminator Loss: 0.2092
# ----------
# Epoch 86/500 : Gen loss: 0.3623, Disc Loss: 0.1733, Recon Loss: 0.0585, Percep loss: 0.2912
# Time taken: 0:00:05.494234
#
#
# Epoch 87/500
# ----------
# Batch 1/11 : Generator Loss: 0.7421, Discriminator Loss: 0.1648
# Batch 6/11 : Generator Loss: 0.5979, Discriminator Loss: 0.1331
# Batch 11/11 : Generator Loss: 0.8630, Discriminator Loss: 0.2121
# ----------
# Epoch 87/500 : Gen loss: 0.3360, Disc Loss: 0.1989, Recon Loss: 0.0572, Percep loss: 0.2804
# Time taken: 0:00:05.515106
#
#
# Epoch 88/500
# ----------
# Batch 1/11 : Generator Loss: 0.6764, Discriminator Loss: 0.2298
# Batch 6/11 : Generator Loss: 0.5991, Discriminator Loss: 0.2597
# Batch 11/11 : Generator Loss: 0.6205, Discriminator Loss: 0.2108
# ----------
# Epoch 88/500 : Gen loss: 0.3477, Disc Loss: 0.1836, Recon Loss: 0.0600, Percep loss: 0.2940
# Time taken: 0:00:05.528488
#
#
# Epoch 89/500
# ----------
# Batch 1/11 : Generator Loss: 0.7122, Discriminator Loss: 0.1484
# Batch 6/11 : Generator Loss: 0.6369, Discriminator Loss: 0.2301
# Batch 11/11 : Generator Loss: 0.6538, Discriminator Loss: 0.2172
# ----------
# Epoch 89/500 : Gen loss: 0.2930, Disc Loss: 0.2097, Recon Loss: 0.0561, Percep loss: 0.2737
# Time taken: 0:00:05.490307
#
#
# Epoch 90/500
# ----------
# Batch 1/11 : Generator Loss: 0.5867, Discriminator Loss: 0.1808
# Batch 6/11 : Generator Loss: 0.6653, Discriminator Loss: 0.1832
# Batch 11/11 : Generator Loss: 0.7392, Discriminator Loss: 0.2310
# ----------
# Epoch 90/500 : Gen loss: 0.3277, Disc Loss: 0.1907, Recon Loss: 0.0580, Percep loss: 0.2892
# Time taken: 0:00:05.450433
#
#
# Epoch 91/500
# ----------
# Batch 1/11 : Generator Loss: 0.7245, Discriminator Loss: 0.1938
# Batch 6/11 : Generator Loss: 0.6900, Discriminator Loss: 0.2375
# Batch 11/11 : Generator Loss: 0.7035, Discriminator Loss: 0.1402
# ----------
# Epoch 91/500 : Gen loss: 0.3616, Disc Loss: 0.1811, Recon Loss: 0.0600, Percep loss: 0.2927
# Time taken: 0:00:05.471690
#
#
# Epoch 92/500
# ----------
# Batch 1/11 : Generator Loss: 0.5209, Discriminator Loss: 0.2083
# Batch 6/11 : Generator Loss: 0.6309, Discriminator Loss: 0.1550
# Batch 11/11 : Generator Loss: 0.6309, Discriminator Loss: 0.1682
# ----------
# Epoch 92/500 : Gen loss: 0.3252, Disc Loss: 0.1886, Recon Loss: 0.0597, Percep loss: 0.2939
# Time taken: 0:00:05.467693
#
#
# Epoch 93/500
# ----------
# Batch 1/11 : Generator Loss: 0.6194, Discriminator Loss: 0.2847
# Batch 6/11 : Generator Loss: 0.6069, Discriminator Loss: 0.1789
# Batch 11/11 : Generator Loss: 0.8305, Discriminator Loss: 0.1923
# ----------
# Epoch 93/500 : Gen loss: 0.3223, Disc Loss: 0.2050, Recon Loss: 0.0597, Percep loss: 0.2993
# Time taken: 0:00:05.490790
#
#
# Epoch 94/500
# ----------
# Batch 1/11 : Generator Loss: 0.7023, Discriminator Loss: 0.1184
# Batch 6/11 : Generator Loss: 0.7147, Discriminator Loss: 0.1803
# Batch 11/11 : Generator Loss: 0.7205, Discriminator Loss: 0.1488
# ----------
# Epoch 94/500 : Gen loss: 0.3580, Disc Loss: 0.1890, Recon Loss: 0.0608, Percep loss: 0.2874
# Time taken: 0:00:05.470143
#
#
# Epoch 95/500
# ----------
# Batch 1/11 : Generator Loss: 0.7053, Discriminator Loss: 0.2301
# Batch 6/11 : Generator Loss: 0.9119, Discriminator Loss: 0.1445
# Batch 11/11 : Generator Loss: 0.6736, Discriminator Loss: 0.1086
# ----------
# Epoch 95/500 : Gen loss: 0.3365, Disc Loss: 0.1887, Recon Loss: 0.0580, Percep loss: 0.2850
# Time taken: 0:00:05.465066
#
#
# Epoch 96/500
# ----------
# Batch 1/11 : Generator Loss: 0.5261, Discriminator Loss: 0.2352
# Batch 6/11 : Generator Loss: 0.8987, Discriminator Loss: 0.1190
# Batch 11/11 : Generator Loss: 0.5368, Discriminator Loss: 0.2368
# ----------
# Epoch 96/500 : Gen loss: 0.3334, Disc Loss: 0.2094, Recon Loss: 0.0590, Percep loss: 0.2922
# Time taken: 0:00:05.441424
#
#
# Epoch 97/500
# ----------
# Batch 1/11 : Generator Loss: 0.6343, Discriminator Loss: 0.2710
# Batch 6/11 : Generator Loss: 0.7036, Discriminator Loss: 0.1420
# Batch 11/11 : Generator Loss: 0.6344, Discriminator Loss: 0.2036
# ----------
# Epoch 97/500 : Gen loss: 0.3332, Disc Loss: 0.2029, Recon Loss: 0.0574, Percep loss: 0.2917
# Time taken: 0:00:05.495953
#
#
# Epoch 98/500
# ----------
# Batch 1/11 : Generator Loss: 0.7852, Discriminator Loss: 0.2144
# Batch 6/11 : Generator Loss: 0.7336, Discriminator Loss: 0.1518
# Batch 11/11 : Generator Loss: 0.6205, Discriminator Loss: 0.1710
# ----------
# Epoch 98/500 : Gen loss: 0.3496, Disc Loss: 0.1829, Recon Loss: 0.0586, Percep loss: 0.2920
# Time taken: 0:00:05.517964
#
#
# Epoch 99/500
# ----------
# Batch 1/11 : Generator Loss: 0.5652, Discriminator Loss: 0.2345
# Batch 6/11 : Generator Loss: 0.6287, Discriminator Loss: 0.2095
# Batch 11/11 : Generator Loss: 0.7586, Discriminator Loss: 0.1397
# ----------
# Epoch 99/500 : Gen loss: 0.3286, Disc Loss: 0.2359, Recon Loss: 0.0552, Percep loss: 0.2728
# Time taken: 0:00:05.457523
#
#
# Epoch 100/500
# ----------
# Batch 1/11 : Generator Loss: 0.7302, Discriminator Loss: 0.1692
# Batch 6/11 : Generator Loss: 0.7107, Discriminator Loss: 0.2779
# Batch 11/11 : Generator Loss: 0.6316, Discriminator Loss: 0.2213
# ----------
# Epoch 100/500 : Gen loss: 0.3359, Disc Loss: 0.2000, Recon Loss: 0.0570, Percep loss: 0.2888
# Time taken: 0:00:05.468488
#
#
# Epoch 101/500
# ----------
# Batch 1/11 : Generator Loss: 0.6085, Discriminator Loss: 0.1671
# Batch 6/11 : Generator Loss: 0.6365, Discriminator Loss: 0.1354
# Batch 11/11 : Generator Loss: 0.7081, Discriminator Loss: 0.2453
# ----------
# Epoch 101/500 : Gen loss: 0.3573, Disc Loss: 0.1987, Recon Loss: 0.0573, Percep loss: 0.2809
# Time taken: 0:00:05.517374
# Epoch 102/500
# ----------
# Batch 1/11 : Generator Loss: 0.5793, Discriminator Loss: 0.1973
# Batch 6/11 : Generator Loss: 0.7840, Discriminator Loss: 0.1333
# Batch 11/11 : Generator Loss: 0.5820, Discriminator Loss: 0.2309
# ----------
# Epoch 102/500 : Gen loss: 0.3222, Disc Loss: 0.1703, Recon Loss: 0.0609, Percep loss: 0.2940
# Time taken: 0:00:05.430171
#
#
# Epoch 103/500
# ----------
# Batch 1/11 : Generator Loss: 0.5735, Discriminator Loss: 0.2704
# Batch 6/11 : Generator Loss: 0.7398, Discriminator Loss: 0.1607
# Batch 11/11 : Generator Loss: 0.6173, Discriminator Loss: 0.1397
# ----------
# Epoch 103/500 : Gen loss: 0.3246, Disc Loss: 0.2040, Recon Loss: 0.0587, Percep loss: 0.2945
# Time taken: 0:00:05.423287
#
#
# Epoch 104/500
# ----------
# Batch 1/11 : Generator Loss: 0.6538, Discriminator Loss: 0.1407
# Batch 6/11 : Generator Loss: 0.7241, Discriminator Loss: 0.2139
# Batch 11/11 : Generator Loss: 0.5177, Discriminator Loss: 0.2047
# ----------
# Epoch 104/500 : Gen loss: 0.3643, Disc Loss: 0.2033, Recon Loss: 0.0559, Percep loss: 0.2748
# Time taken: 0:00:05.414910
#
#
# Epoch 105/500
# ----------
# Batch 1/11 : Generator Loss: 0.7240, Discriminator Loss: 0.2128
# Batch 6/11 : Generator Loss: 0.6635, Discriminator Loss: 0.1994
# Batch 11/11 : Generator Loss: 0.5798, Discriminator Loss: 0.2553
# ----------
# Epoch 105/500 : Gen loss: 0.3250, Disc Loss: 0.2193, Recon Loss: 0.0543, Percep loss: 0.2745
# Time taken: 0:00:05.426655
#
#
# Epoch 106/500
# ----------
# Batch 1/11 : Generator Loss: 0.7249, Discriminator Loss: 0.2215
# Batch 6/11 : Generator Loss: 0.6988, Discriminator Loss: 0.1801
# Batch 11/11 : Generator Loss: 0.5697, Discriminator Loss: 0.1834
# ----------
# Epoch 106/500 : Gen loss: 0.3418, Disc Loss: 0.1855, Recon Loss: 0.0586, Percep loss: 0.2870
# Time taken: 0:00:05.431091
#
#
# Epoch 107/500
# ----------
# Batch 1/11 : Generator Loss: 0.7921, Discriminator Loss: 0.2365
# Batch 6/11 : Generator Loss: 0.6558, Discriminator Loss: 0.2164
# Batch 11/11 : Generator Loss: 0.8954, Discriminator Loss: 0.1136
# ----------
# Epoch 107/500 : Gen loss: 0.3921, Disc Loss: 0.1846, Recon Loss: 0.0585, Percep loss: 0.2933
# Time taken: 0:00:05.469220
#
#
# Epoch 108/500
# ----------
# Batch 1/11 : Generator Loss: 0.6389, Discriminator Loss: 0.2538
# Batch 6/11 : Generator Loss: 0.5768, Discriminator Loss: 0.2385
# Batch 11/11 : Generator Loss: 0.5466, Discriminator Loss: 0.1304
# ----------
# Epoch 108/500 : Gen loss: 0.3371, Disc Loss: 0.1872, Recon Loss: 0.0562, Percep loss: 0.2792
# Time taken: 0:00:05.436744
#
#
# Epoch 109/500
# ----------
# Batch 1/11 : Generator Loss: 0.6524, Discriminator Loss: 0.1920
# Batch 6/11 : Generator Loss: 0.9392, Discriminator Loss: 0.1528
# Batch 11/11 : Generator Loss: 0.7480, Discriminator Loss: 0.1343
# ----------
# Epoch 109/500 : Gen loss: 0.3547, Disc Loss: 0.1829, Recon Loss: 0.0605, Percep loss: 0.2944
# Time taken: 0:00:05.441979
#
#
# Epoch 110/500
# ----------
# Batch 1/11 : Generator Loss: 0.6767, Discriminator Loss: 0.2867
# Batch 6/11 : Generator Loss: 0.6803, Discriminator Loss: 0.1546
# Batch 11/11 : Generator Loss: 0.7188, Discriminator Loss: 0.1579
# ----------
# Epoch 110/500 : Gen loss: 0.3932, Disc Loss: 0.1974, Recon Loss: 0.0575, Percep loss: 0.2862
# Time taken: 0:00:05.434255
#
#
# Epoch 111/500
# ----------
# Batch 1/11 : Generator Loss: 0.5501, Discriminator Loss: 0.1136
# Batch 6/11 : Generator Loss: 0.7755, Discriminator Loss: 0.1325
# Batch 11/11 : Generator Loss: 0.8604, Discriminator Loss: 0.1890
# ----------
# Epoch 111/500 : Gen loss: 0.3183, Disc Loss: 0.1837, Recon Loss: 0.0589, Percep loss: 0.2806
# Time taken: 0:00:05.526334
#
#
# Epoch 112/500
# ----------
# Batch 1/11 : Generator Loss: 0.5229, Discriminator Loss: 0.1531
# Batch 6/11 : Generator Loss: 0.8453, Discriminator Loss: 0.2305
# Batch 11/11 : Generator Loss: 0.5480, Discriminator Loss: 0.2415
# ----------
# Epoch 112/500 : Gen loss: 0.3417, Disc Loss: 0.1995, Recon Loss: 0.0564, Percep loss: 0.2835
# Time taken: 0:00:05.491141
#
#
# Epoch 113/500
# ----------
# Batch 1/11 : Generator Loss: 0.7332, Discriminator Loss: 0.1608
# Batch 6/11 : Generator Loss: 0.7315, Discriminator Loss: 0.2120
# Batch 11/11 : Generator Loss: 0.5292, Discriminator Loss: 0.1674
# ----------
# Epoch 113/500 : Gen loss: 0.3091, Disc Loss: 0.1999, Recon Loss: 0.0575, Percep loss: 0.2756
# Time taken: 0:00:05.500608
#
#
# Epoch 114/500
# ----------
# Batch 1/11 : Generator Loss: 0.7739, Discriminator Loss: 0.2215
# Batch 6/11 : Generator Loss: 0.6418, Discriminator Loss: 0.2059
# Batch 11/11 : Generator Loss: 0.6982, Discriminator Loss: 0.1874
# ----------
# Epoch 114/500 : Gen loss: 0.3614, Disc Loss: 0.1938, Recon Loss: 0.0561, Percep loss: 0.2827
# Time taken: 0:00:05.412621
#
#
# Epoch 115/500
# ----------
# Batch 1/11 : Generator Loss: 0.6668, Discriminator Loss: 0.2552
# Batch 6/11 : Generator Loss: 0.6476, Discriminator Loss: 0.2231
# Batch 11/11 : Generator Loss: 0.7890, Discriminator Loss: 0.1166
# ----------
# Epoch 115/500 : Gen loss: 0.3633, Disc Loss: 0.1801, Recon Loss: 0.0573, Percep loss: 0.2979
# Time taken: 0:00:05.420160
#
#
# Epoch 116/500
# ----------
# Batch 1/11 : Generator Loss: 0.6413, Discriminator Loss: 0.1895
# Batch 6/11 : Generator Loss: 0.6997, Discriminator Loss: 0.1718
# Batch 11/11 : Generator Loss: 0.6676, Discriminator Loss: 0.1306
# ----------
# Epoch 116/500 : Gen loss: 0.3672, Disc Loss: 0.1832, Recon Loss: 0.0581, Percep loss: 0.2831
# Time taken: 0:00:05.476739
#
#
# Epoch 117/500
# ----------
# Batch 1/11 : Generator Loss: 0.5883, Discriminator Loss: 0.1163
# Batch 6/11 : Generator Loss: 0.6690, Discriminator Loss: 0.1459
# Batch 11/11 : Generator Loss: 0.8476, Discriminator Loss: 0.1077
# ----------
# Epoch 117/500 : Gen loss: 0.3561, Disc Loss: 0.1981, Recon Loss: 0.0605, Percep loss: 0.2848
# Time taken: 0:00:05.489026
#
#
# Epoch 118/500
# ----------
# Batch 1/11 : Generator Loss: 0.7733, Discriminator Loss: 0.1767
# Batch 6/11 : Generator Loss: 0.6029, Discriminator Loss: 0.3171
# Batch 11/11 : Generator Loss: 0.6421, Discriminator Loss: 0.2579
# ----------
# Epoch 118/500 : Gen loss: 0.3079, Disc Loss: 0.2203, Recon Loss: 0.0524, Percep loss: 0.2601
# Time taken: 0:00:05.428359
#
#
# Epoch 119/500
# ----------
# Batch 1/11 : Generator Loss: 0.7632, Discriminator Loss: 0.1650
# Batch 6/11 : Generator Loss: 0.6609, Discriminator Loss: 0.1793
# Batch 11/11 : Generator Loss: 0.7003, Discriminator Loss: 0.2257
# ----------
# Epoch 119/500 : Gen loss: 0.3490, Disc Loss: 0.1872, Recon Loss: 0.0591, Percep loss: 0.2812
# Time taken: 0:00:05.419446
#
#
# Epoch 120/500
# ----------
# Batch 1/11 : Generator Loss: 0.7981, Discriminator Loss: 0.2947
# Batch 6/11 : Generator Loss: 0.6473, Discriminator Loss: 0.1425
# Batch 11/11 : Generator Loss: 0.6482, Discriminator Loss: 0.1662
# ----------
# Epoch 120/500 : Gen loss: 0.3711, Disc Loss: 0.1847, Recon Loss: 0.0580, Percep loss: 0.2816
# Time taken: 0:00:05.450361
#
#
# Epoch 121/500
# ----------
# Batch 1/11 : Generator Loss: 0.7333, Discriminator Loss: 0.1878
# Batch 6/11 : Generator Loss: 0.7718, Discriminator Loss: 0.1452
# Batch 11/11 : Generator Loss: 0.5438, Discriminator Loss: 0.2089
# ----------
# Epoch 121/500 : Gen loss: 0.3456, Disc Loss: 0.1871, Recon Loss: 0.0566, Percep loss: 0.2683
# Time taken: 0:00:05.410800
#
#
# Epoch 122/500
# ----------
# Batch 1/11 : Generator Loss: 0.6045, Discriminator Loss: 0.2088
# Batch 6/11 : Generator Loss: 0.7165, Discriminator Loss: 0.2591
# Batch 11/11 : Generator Loss: 0.7283, Discriminator Loss: 0.1998
# ----------
# Epoch 122/500 : Gen loss: 0.3320, Disc Loss: 0.2175, Recon Loss: 0.0547, Percep loss: 0.2732
# Time taken: 0:00:05.398375
#
#
# Epoch 123/500
# ----------
# Batch 1/11 : Generator Loss: 0.7059, Discriminator Loss: 0.2149
# Batch 6/11 : Generator Loss: 0.6802, Discriminator Loss: 0.2916
# Batch 11/11 : Generator Loss: 0.6658, Discriminator Loss: 0.2350
# ----------
# Epoch 123/500 : Gen loss: 0.3405, Disc Loss: 0.1948, Recon Loss: 0.0576, Percep loss: 0.2791
# Time taken: 0:00:05.429965
#
#
# Epoch 124/500
# ----------
# Batch 1/11 : Generator Loss: 0.5314, Discriminator Loss: 0.1567
# Batch 6/11 : Generator Loss: 0.6110, Discriminator Loss: 0.1548
# Batch 11/11 : Generator Loss: 0.6739, Discriminator Loss: 0.2328
# ----------
# Epoch 124/500 : Gen loss: 0.3417, Disc Loss: 0.2345, Recon Loss: 0.0516, Percep loss: 0.2581
# Time taken: 0:00:05.471150
#
#
# Epoch 125/500
# ----------
# Batch 1/11 : Generator Loss: 0.7924, Discriminator Loss: 0.1109
# Batch 6/11 : Generator Loss: 0.7505, Discriminator Loss: 0.1474
# Batch 11/11 : Generator Loss: 0.6783, Discriminator Loss: 0.2113
# ----------
# Epoch 125/500 : Gen loss: 0.3629, Disc Loss: 0.1773, Recon Loss: 0.0577, Percep loss: 0.2764
# Time taken: 0:00:05.444189
#
#
# Epoch 126/500
# ----------
# Batch 1/11 : Generator Loss: 0.8220, Discriminator Loss: 0.1093
# Batch 6/11 : Generator Loss: 0.6906, Discriminator Loss: 0.2968
# Batch 11/11 : Generator Loss: 0.6568, Discriminator Loss: 0.1422
# ----------
# Epoch 126/500 : Gen loss: 0.3487, Disc Loss: 0.1990, Recon Loss: 0.0551, Percep loss: 0.2648
# Time taken: 0:00:05.484681
#
#
# Epoch 127/500
# ----------
# Batch 1/11 : Generator Loss: 0.4004, Discriminator Loss: 0.2790
# Batch 6/11 : Generator Loss: 0.7459, Discriminator Loss: 0.2221
# Batch 11/11 : Generator Loss: 0.7092, Discriminator Loss: 0.1930
# ----------
# Epoch 127/500 : Gen loss: 0.3359, Disc Loss: 0.2094, Recon Loss: 0.0544, Percep loss: 0.2637
# Time taken: 0:00:05.458345
#
#
# Epoch 128/500
# ----------
# Batch 1/11 : Generator Loss: 0.5902, Discriminator Loss: 0.1137
# Batch 6/11 : Generator Loss: 0.5940, Discriminator Loss: 0.1500
# Batch 11/11 : Generator Loss: 0.8335, Discriminator Loss: 0.1794
# ----------
# Epoch 128/500 : Gen loss: 0.3703, Disc Loss: 0.1832, Recon Loss: 0.0571, Percep loss: 0.2861
# Time taken: 0:00:05.411502
#
#
# Epoch 129/500
# ----------
# Batch 1/11 : Generator Loss: 0.6964, Discriminator Loss: 0.1580
# Batch 6/11 : Generator Loss: 0.6872, Discriminator Loss: 0.3409
# Batch 11/11 : Generator Loss: 0.8213, Discriminator Loss: 0.2528
# ----------
# Epoch 129/500 : Gen loss: 0.3605, Disc Loss: 0.2038, Recon Loss: 0.0566, Percep loss: 0.2865
# Time taken: 0:00:05.433138
#
#
# Epoch 130/500
# ----------
# Batch 1/11 : Generator Loss: 0.8518, Discriminator Loss: 0.1376
# Batch 6/11 : Generator Loss: 0.6301, Discriminator Loss: 0.1910
# Batch 11/11 : Generator Loss: 0.7842, Discriminator Loss: 0.2638
# ----------
# Epoch 130/500 : Gen loss: 0.3515, Disc Loss: 0.1887, Recon Loss: 0.0531, Percep loss: 0.2669
# Time taken: 0:00:05.456190
#
#
# Epoch 131/500
# ----------
# Batch 1/11 : Generator Loss: 0.7742, Discriminator Loss: 0.1244
# Batch 6/11 : Generator Loss: 0.5753, Discriminator Loss: 0.2414
# Batch 11/11 : Generator Loss: 0.6230, Discriminator Loss: 0.2770
# ----------
# Epoch 131/500 : Gen loss: 0.3326, Disc Loss: 0.1826, Recon Loss: 0.0583, Percep loss: 0.2774
# Time taken: 0:00:05.533400
#
#
# Epoch 132/500
# ----------
# Batch 1/11 : Generator Loss: 0.7052, Discriminator Loss: 0.2309
# Batch 6/11 : Generator Loss: 0.5613, Discriminator Loss: 0.1575
# Batch 11/11 : Generator Loss: 0.5454, Discriminator Loss: 0.1831
# ----------
# Epoch 132/500 : Gen loss: 0.3573, Disc Loss: 0.1814, Recon Loss: 0.0568, Percep loss: 0.2810
# Time taken: 0:00:05.480868
#
#
# Epoch 133/500
# ----------
# Batch 1/11 : Generator Loss: 0.6629, Discriminator Loss: 0.3757
# Batch 6/11 : Generator Loss: 0.6113, Discriminator Loss: 0.2401
# Batch 11/11 : Generator Loss: 0.7745, Discriminator Loss: 0.1068
# ----------
# Epoch 133/500 : Gen loss: 0.3416, Disc Loss: 0.2036, Recon Loss: 0.0551, Percep loss: 0.2709
# Time taken: 0:00:05.409307
#
#
# Epoch 134/500
# ----------
# Batch 1/11 : Generator Loss: 0.6257, Discriminator Loss: 0.1881
# Batch 6/11 : Generator Loss: 0.8246, Discriminator Loss: 0.1470
# Batch 11/11 : Generator Loss: 0.7217, Discriminator Loss: 0.2421
# ----------
# Epoch 134/500 : Gen loss: 0.3777, Disc Loss: 0.1948, Recon Loss: 0.0596, Percep loss: 0.2853
# Time taken: 0:00:05.422751
#
#
# Epoch 135/500
# ----------
# Batch 1/11 : Generator Loss: 0.7612, Discriminator Loss: 0.2038
# Batch 6/11 : Generator Loss: 0.6227, Discriminator Loss: 0.1454
# Batch 11/11 : Generator Loss: 0.8186, Discriminator Loss: 0.1876
# ----------
# Epoch 135/500 : Gen loss: 0.3860, Disc Loss: 0.2001, Recon Loss: 0.0552, Percep loss: 0.2730
# Time taken: 0:00:05.502114
#
#
# Epoch 136/500
# ----------
# Batch 1/11 : Generator Loss: 0.8177, Discriminator Loss: 0.1681
# Batch 6/11 : Generator Loss: 0.9160, Discriminator Loss: 0.1163
# Batch 11/11 : Generator Loss: 0.4700, Discriminator Loss: 0.1474
# ----------
# Epoch 136/500 : Gen loss: 0.3276, Disc Loss: 0.1883, Recon Loss: 0.0562, Percep loss: 0.2753
# Time taken: 0:00:05.465707
#
#
# Epoch 137/500
# ----------
# Batch 1/11 : Generator Loss: 0.5557, Discriminator Loss: 0.3937
# Batch 6/11 : Generator Loss: 0.6791, Discriminator Loss: 0.1700
# Batch 11/11 : Generator Loss: 0.5782, Discriminator Loss: 0.1414
# ----------
# Epoch 137/500 : Gen loss: 0.3365, Disc Loss: 0.1981, Recon Loss: 0.0558, Percep loss: 0.2750
# Time taken: 0:00:05.475667
#
#
# Epoch 138/500
# ----------
# Batch 1/11 : Generator Loss: 0.5595, Discriminator Loss: 0.3196
# ...
#
# Epoch 358/500
# ----------
# Batch 1/11 : Generator Loss: 0.8949, Discriminator Loss: 0.2655
# Batch 6/11 : Generator Loss: 0.4919, Discriminator Loss: 0.1186
# Batch 11/11 : Generator Loss: 0.6257, Discriminator Loss: 0.2682
# ----------
# Epoch 358/500 : Gen loss: 0.3890, Disc Loss: 0.1902, Recon Loss: 0.0533, Percep loss: 0.2526
# Time taken: 0:00:05.434247
#
#
# Epoch 359/500
# ----------
# Batch 1/11 : Generator Loss: 0.8971, Discriminator Loss: 0.1734
# Batch 6/11 : Generator Loss: 0.5032, Discriminator Loss: 0.3016
# Batch 11/11 : Generator Loss: 0.5810, Discriminator Loss: 0.2427
# ----------
# Epoch 359/500 : Gen loss: 0.3482, Disc Loss: 0.1822, Recon Loss: 0.0518, Percep loss: 0.2615
# Time taken: 0:00:05.401980
#
#
# Epoch 360/500
# ----------
# Batch 1/11 : Generator Loss: 0.7325, Discriminator Loss: 0.2097
# Batch 6/11 : Generator Loss: 0.6294, Discriminator Loss: 0.1597
# Batch 11/11 : Generator Loss: 0.7628, Discriminator Loss: 0.1263
# ----------
# Epoch 360/500 : Gen loss: 0.3665, Disc Loss: 0.1924, Recon Loss: 0.0524, Percep loss: 0.2646
# Time taken: 0:00:05.384642
#
#
# Epoch 361/500
# ----------
# Batch 1/11 : Generator Loss: 0.6472, Discriminator Loss: 0.1833
# Batch 6/11 : Generator Loss: 0.8327, Discriminator Loss: 0.1624
# Batch 11/11 : Generator Loss: 0.7011, Discriminator Loss: 0.1311
# ----------
# Epoch 361/500 : Gen loss: 0.3434, Disc Loss: 0.2152, Recon Loss: 0.0509, Percep loss: 0.2558
# Time taken: 0:00:05.378576
#
#
# Epoch 362/500
# ----------
# Batch 1/11 : Generator Loss: 0.6613, Discriminator Loss: 0.1135
# Batch 6/11 : Generator Loss: 0.5364, Discriminator Loss: 0.3283
# Batch 11/11 : Generator Loss: 0.7505, Discriminator Loss: 0.2641
# ----------
# Epoch 362/500 : Gen loss: 0.3459, Disc Loss: 0.1814, Recon Loss: 0.0516, Percep loss: 0.2422
# Time taken: 0:00:05.379683
#
#
# Epoch 363/500
# ----------
# Batch 1/11 : Generator Loss: 0.8032, Discriminator Loss: 0.1968
# Batch 6/11 : Generator Loss: 0.6640, Discriminator Loss: 0.0911
# Batch 11/11 : Generator Loss: 0.7496, Discriminator Loss: 0.2119
# ----------
# Epoch 363/500 : Gen loss: 0.3942, Disc Loss: 0.1846, Recon Loss: 0.0552, Percep loss: 0.2652
# Time taken: 0:00:05.388796
#
#
# Epoch 364/500
# ----------
# Batch 1/11 : Generator Loss: 0.6609, Discriminator Loss: 0.1772
# Batch 6/11 : Generator Loss: 0.5758, Discriminator Loss: 0.2590
# Batch 11/11 : Generator Loss: 0.5835, Discriminator Loss: 0.2145
# ----------
# Epoch 364/500 : Gen loss: 0.3427, Disc Loss: 0.2034, Recon Loss: 0.0477, Percep loss: 0.2429
# Time taken: 0:00:05.403370
#
#
# Epoch 365/500
# ----------
# Batch 1/11 : Generator Loss: 0.6952, Discriminator Loss: 0.0867
# Batch 6/11 : Generator Loss: 0.7189, Discriminator Loss: 0.2333
# Batch 11/11 : Generator Loss: 0.5507, Discriminator Loss: 0.2079
# ----------
# Epoch 365/500 : Gen loss: 0.3570, Disc Loss: 0.1921, Recon Loss: 0.0518, Percep loss: 0.2520
# Time taken: 0:00:05.400950
#
#
# Epoch 366/500
# ----------
# Batch 1/11 : Generator Loss: 0.7165, Discriminator Loss: 0.2310
# Batch 6/11 : Generator Loss: 0.6774, Discriminator Loss: 0.1481
# Batch 11/11 : Generator Loss: 0.7631, Discriminator Loss: 0.1590
# ----------
# Epoch 366/500 : Gen loss: 0.3396, Disc Loss: 0.1879, Recon Loss: 0.0554, Percep loss: 0.2583
# Time taken: 0:00:05.418027
#
#
# Epoch 367/500
# ----------
# Batch 1/11 : Generator Loss: 0.6901, Discriminator Loss: 0.2595
# Batch 6/11 : Generator Loss: 0.7853, Discriminator Loss: 0.2238
# Batch 11/11 : Generator Loss: 0.6196, Discriminator Loss: 0.1568
# ----------
# Epoch 367/500 : Gen loss: 0.3637, Disc Loss: 0.1934, Recon Loss: 0.0525, Percep loss: 0.2545
# Time taken: 0:00:05.449821
#
#
# Epoch 368/500
# ----------
# Batch 1/11 : Generator Loss: 0.5487, Discriminator Loss: 0.2067
# Batch 6/11 : Generator Loss: 0.5462, Discriminator Loss: 0.2063
# Batch 11/11 : Generator Loss: 0.5959, Discriminator Loss: 0.1670
# ----------
# Epoch 368/500 : Gen loss: 0.3323, Disc Loss: 0.1958, Recon Loss: 0.0497, Percep loss: 0.2463
# Time taken: 0:00:05.446558
#
#
# Epoch 369/500
# ----------
# Batch 1/11 : Generator Loss: 0.6910, Discriminator Loss: 0.2472
# Batch 6/11 : Generator Loss: 0.5807, Discriminator Loss: 0.2242
# Batch 11/11 : Generator Loss: 0.7515, Discriminator Loss: 0.1351
# ----------
# Epoch 369/500 : Gen loss: 0.3479, Disc Loss: 0.2201, Recon Loss: 0.0501, Percep loss: 0.2454
# Time taken: 0:00:05.424560
#
#
# Epoch 370/500
# ----------
# Batch 1/11 : Generator Loss: 0.3520, Discriminator Loss: 0.2397
# Batch 6/11 : Generator Loss: 0.7316, Discriminator Loss: 0.1100
# Batch 11/11 : Generator Loss: 0.6177, Discriminator Loss: 0.1950
# ----------
# Epoch 370/500 : Gen loss: 0.3150, Disc Loss: 0.1804, Recon Loss: 0.0539, Percep loss: 0.2524
# Time taken: 0:00:05.391216
#
#
# Epoch 371/500
# ----------
# Batch 1/11 : Generator Loss: 0.7722, Discriminator Loss: 0.1540
# Batch 6/11 : Generator Loss: 0.4983, Discriminator Loss: 0.1816
# Batch 11/11 : Generator Loss: 0.7810, Discriminator Loss: 0.1726
# ----------
# Epoch 371/500 : Gen loss: 0.3582, Disc Loss: 0.1852, Recon Loss: 0.0521, Percep loss: 0.2541
# Time taken: 0:00:05.407047
#
#
# Epoch 372/500
# ----------
# Batch 1/11 : Generator Loss: 0.4910, Discriminator Loss: 0.2722
# Batch 6/11 : Generator Loss: 0.6872, Discriminator Loss: 0.0946
# Batch 11/11 : Generator Loss: 0.5911, Discriminator Loss: 0.2603
# ----------
# Epoch 372/500 : Gen loss: 0.3512, Disc Loss: 0.2061, Recon Loss: 0.0566, Percep loss: 0.2634
# Time taken: 0:00:05.416406
#
#
# Epoch 373/500
# ----------
# Batch 1/11 : Generator Loss: 0.8006, Discriminator Loss: 0.1738
# Batch 6/11 : Generator Loss: 0.9484, Discriminator Loss: 0.0929
# Batch 11/11 : Generator Loss: 0.4939, Discriminator Loss: 0.2411
# ----------
# Epoch 373/500 : Gen loss: 0.4071, Disc Loss: 0.1930, Recon Loss: 0.0537, Percep loss: 0.2568
# Time taken: 0:00:05.435068
#
#
# Epoch 374/500
# ----------
# Batch 1/11 : Generator Loss: 0.4883, Discriminator Loss: 0.3355
# Batch 6/11 : Generator Loss: 0.5316, Discriminator Loss: 0.2146
# Batch 11/11 : Generator Loss: 0.8087, Discriminator Loss: 0.3115
# ----------
# Epoch 374/500 : Gen loss: 0.3334, Disc Loss: 0.2304, Recon Loss: 0.0538, Percep loss: 0.2596
# Time taken: 0:00:05.406188
#
#
# Epoch 375/500
# ----------
# Batch 1/11 : Generator Loss: 0.8255, Discriminator Loss: 0.2570
# Batch 6/11 : Generator Loss: 0.5512, Discriminator Loss: 0.1324
# Batch 11/11 : Generator Loss: 0.7961, Discriminator Loss: 0.1996
# ----------
# Epoch 375/500 : Gen loss: 0.3734, Disc Loss: 0.2004, Recon Loss: 0.0483, Percep loss: 0.2470
# Time taken: 0:00:05.512527
#
#
# Epoch 376/500
# ----------
# Batch 1/11 : Generator Loss: 0.7087, Discriminator Loss: 0.2599
# Batch 6/11 : Generator Loss: 0.6033, Discriminator Loss: 0.1551
# Batch 11/11 : Generator Loss: 0.8260, Discriminator Loss: 0.1794
# ----------
# Epoch 376/500 : Gen loss: 0.3673, Disc Loss: 0.1964, Recon Loss: 0.0535, Percep loss: 0.2578
# Time taken: 0:00:05.515410
#
#
# Epoch 377/500
# ----------
# Batch 1/11 : Generator Loss: 0.6835, Discriminator Loss: 0.1697
# Batch 6/11 : Generator Loss: 0.6123, Discriminator Loss: 0.2299
# Batch 11/11 : Generator Loss: 0.6944, Discriminator Loss: 0.1267
# ----------
# Epoch 377/500 : Gen loss: 0.3535, Disc Loss: 0.1719, Recon Loss: 0.0555, Percep loss: 0.2614
# Time taken: 0:00:05.521236
#
#
# Epoch 378/500
# ----------
# Batch 1/11 : Generator Loss: 0.6529, Discriminator Loss: 0.1949
# Batch 6/11 : Generator Loss: 0.5450, Discriminator Loss: 0.1258
# Batch 11/11 : Generator Loss: 0.5682, Discriminator Loss: 0.2195
# ----------
# Epoch 378/500 : Gen loss: 0.3358, Disc Loss: 0.2042, Recon Loss: 0.0535, Percep loss: 0.2565
# Time taken: 0:00:05.462919
#
#
# Epoch 379/500
# ----------
# Batch 1/11 : Generator Loss: 0.6988, Discriminator Loss: 0.1242
# Batch 6/11 : Generator Loss: 0.7038, Discriminator Loss: 0.2118
# Batch 11/11 : Generator Loss: 0.6747, Discriminator Loss: 0.1337
# ----------
# Epoch 379/500 : Gen loss: 0.3705, Disc Loss: 0.1914, Recon Loss: 0.0537, Percep loss: 0.2605
# Time taken: 0:00:05.434534
#
#
# Epoch 380/500
# ----------
# Batch 1/11 : Generator Loss: 0.6376, Discriminator Loss: 0.1669
# Batch 6/11 : Generator Loss: 0.7029, Discriminator Loss: 0.2101
# Batch 11/11 : Generator Loss: 0.8966, Discriminator Loss: 0.2534
# ----------
# Epoch 380/500 : Gen loss: 0.3601, Disc Loss: 0.2139, Recon Loss: 0.0534, Percep loss: 0.2588
# Time taken: 0:00:05.388811
#
#
# Epoch 381/500
# ----------
# Batch 1/11 : Generator Loss: 0.9035, Discriminator Loss: 0.2801
# Batch 6/11 : Generator Loss: 0.6536, Discriminator Loss: 0.1077
# Batch 11/11 : Generator Loss: 0.7173, Discriminator Loss: 0.1556
# ----------
# Epoch 381/500 : Gen loss: 0.3788, Disc Loss: 0.1905, Recon Loss: 0.0524, Percep loss: 0.2536
# Time taken: 0:00:05.415583
#
#
# Epoch 382/500
# ----------
# Batch 1/11 : Generator Loss: 0.7487, Discriminator Loss: 0.1338
# Batch 6/11 : Generator Loss: 0.5986, Discriminator Loss: 0.1090
# Batch 11/11 : Generator Loss: 0.4334, Discriminator Loss: 0.1889
# ----------
# Epoch 382/500 : Gen loss: 0.3561, Disc Loss: 0.1988, Recon Loss: 0.0519, Percep loss: 0.2483
# Time taken: 0:00:05.383151
#
#
# Epoch 383/500
# ----------
# Batch 1/11 : Generator Loss: 0.6302, Discriminator Loss: 0.2918
# Batch 6/11 : Generator Loss: 0.6747, Discriminator Loss: 0.2246
# Batch 11/11 : Generator Loss: 0.8961, Discriminator Loss: 0.1788
# ----------
# Epoch 383/500 : Gen loss: 0.3585, Disc Loss: 0.2091, Recon Loss: 0.0550, Percep loss: 0.2601
# Time taken: 0:00:05.432274
#
#
# Epoch 384/500
# ----------
# Batch 1/11 : Generator Loss: 0.5691, Discriminator Loss: 0.1589
# Batch 6/11 : Generator Loss: 0.8650, Discriminator Loss: 0.2009
# Batch 11/11 : Generator Loss: 0.5524, Discriminator Loss: 0.1378
# ----------
# Epoch 384/500 : Gen loss: 0.3608, Disc Loss: 0.1863, Recon Loss: 0.0541, Percep loss: 0.2543
# Time taken: 0:00:05.395173
#
#
# Epoch 385/500
# ----------
# Batch 1/11 : Generator Loss: 0.6135, Discriminator Loss: 0.2638
# Batch 6/11 : Generator Loss: 0.6651, Discriminator Loss: 0.1585
# Batch 11/11 : Generator Loss: 0.5398, Discriminator Loss: 0.2052
# ----------
# Epoch 385/500 : Gen loss: 0.3400, Disc Loss: 0.1951, Recon Loss: 0.0504, Percep loss: 0.2507
# Time taken: 0:00:05.401478
#
#
# Epoch 386/500
# ----------
# Batch 1/11 : Generator Loss: 0.6333, Discriminator Loss: 0.1462
# Batch 6/11 : Generator Loss: 0.8198, Discriminator Loss: 0.1828
# Batch 11/11 : Generator Loss: 0.6976, Discriminator Loss: 0.2154
# ----------
# Epoch 386/500 : Gen loss: 0.3726, Disc Loss: 0.1924, Recon Loss: 0.0525, Percep loss: 0.2528
# Time taken: 0:00:05.517983
#
#
# Epoch 387/500
# ----------
# Batch 1/11 : Generator Loss: 0.6495, Discriminator Loss: 0.1788
# Batch 6/11 : Generator Loss: 0.4373, Discriminator Loss: 0.3360
# Batch 11/11 : Generator Loss: 0.6130, Discriminator Loss: 0.1274
# ----------
# Epoch 387/500 : Gen loss: 0.3414, Disc Loss: 0.2010, Recon Loss: 0.0517, Percep loss: 0.2406
# Time taken: 0:00:05.455977
#
#
# Epoch 388/500
# ----------
# Batch 1/11 : Generator Loss: 0.6430, Discriminator Loss: 0.1621
# Batch 6/11 : Generator Loss: 0.8095, Discriminator Loss: 0.1881
# Batch 11/11 : Generator Loss: 0.5783, Discriminator Loss: 0.2515
# ----------
# Epoch 388/500 : Gen loss: 0.3566, Disc Loss: 0.1908, Recon Loss: 0.0536, Percep loss: 0.2544
# Time taken: 0:00:05.414363
#
#
# Epoch 389/500
# ----------
# Batch 1/11 : Generator Loss: 0.7908, Discriminator Loss: 0.0857
# Batch 6/11 : Generator Loss: 0.6246, Discriminator Loss: 0.2340
# Batch 11/11 : Generator Loss: 0.6101, Discriminator Loss: 0.1642
# ----------
# Epoch 389/500 : Gen loss: 0.3683, Disc Loss: 0.1674, Recon Loss: 0.0533, Percep loss: 0.2614
# Time taken: 0:00:05.525410
#
#
# Epoch 390/500
# ----------
# Batch 1/11 : Generator Loss: 0.5358, Discriminator Loss: 0.2032
# Batch 6/11 : Generator Loss: 0.7435, Discriminator Loss: 0.1470
# Batch 11/11 : Generator Loss: 0.5175, Discriminator Loss: 0.2272
# ----------
# Epoch 390/500 : Gen loss: 0.3330, Disc Loss: 0.2113, Recon Loss: 0.0535, Percep loss: 0.2535
# Time taken: 0:00:05.510404
#
#
# Epoch 391/500
# ----------
# Batch 1/11 : Generator Loss: 0.7282, Discriminator Loss: 0.2567
# Batch 6/11 : Generator Loss: 0.5426, Discriminator Loss: 0.2369
# Batch 11/11 : Generator Loss: 0.8226, Discriminator Loss: 0.1388
# ----------
# Epoch 391/500 : Gen loss: 0.3866, Disc Loss: 0.2033, Recon Loss: 0.0500, Percep loss: 0.2500
# Time taken: 0:00:05.495668
#
#
# Epoch 392/500
# ----------
# Batch 1/11 : Generator Loss: 0.6424, Discriminator Loss: 0.1150
# Batch 6/11 : Generator Loss: 0.6237, Discriminator Loss: 0.1700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 37
#      35 # Train the generator
#      36 for _ in range(2):
# ---> 37     adv_loss, rec_loss, percep_loss = train_generator(inputs=inputs, targets=labels, optimizer=generator_optimizer, L1_Lambda=L1_Lambda, LPIPS_Lambda=LPIPS_Lambda)
#      39 gen_loss = adv_loss + rec_loss + percep_loss
#      41 # Print the loss for this batch
#
# Cell In[27], line 19, in train_generator(inputs, targets, optimizer, Loss_D, Loss_G, Loss_P, L1_Lambda, LPIPS_Lambda)
#      16 loss_L1 = Loss_G(generator_output, targets)
#      18 # Calculate LPIPS loss (perceptual loss)
# ---> 19 loss_P = Loss_P(generator_output, targets)
#      21 # Combine all the losses and calculate total loss
#      22 loss = loss_GAN + L1_Lambda * loss_L1 + LPIPS_Lambda * loss_P
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.8/dist-packages/torchmetrics/metric.py:298, in Metric.forward(self, *args, **kwargs)
#     296     self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     297 else:
# --> 298     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     300 return self._forward_cache
#
# File /usr/local/lib/python3.8/dist-packages/torchmetrics/metric.py:367, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#     364 self._enable_grad = True  # allow grads for batch computation
#     366 # calculate batch state and compute batch value
# --> 367 self.update(*args, **kwargs)
#     368 batch_val = self.compute()
#     370 # reduce batch and global state
#
# File /usr/local/lib/python3.8/dist-packages/torchmetrics/metric.py:460, in Metric._wrap_update.<locals>.wrapped_func(*args, **kwargs)
#     458 with torch.set_grad_enabled(self._enable_grad):
#     459     try:
# --> 460         update(*args, **kwargs)
#     461     except RuntimeError as err:
#     462         if "Expected all tensors to be on" in str(err):
#
# File /usr/local/lib/python3.8/dist-packages/torchmetrics/image/lpip.py:139, in LearnedPerceptualImagePatchSimilarity.update(self, img1, img2)
#     137 def update(self, img1: Tensor, img2: Tensor) -> None:
#     138     """Update internal states with lpips score."""
# --> 139     loss, total = _lpips_update(img1, img2, net=self.net, normalize=self.normalize)
#     140     self.sum_scores += loss.sum()
#     141     self.total += total
#
# File /usr/local/lib/python3.8/dist-packages/torchmetrics/functional/image/lpips.py:380, in _lpips_update(img1, img2, net, normalize)
#     379 def _lpips_update(img1: Tensor, img2: Tensor, net: nn.Module, normalize: bool) -> Tuple[Tensor, Union[int, Tensor]]:
# --> 380     if not (_valid_img(img1, normalize) and _valid_img(img2, normalize)):
#     381         raise ValueError(
#     382             "Expected both input arguments to be normalized tensors with shape [N, 3, H, W]."
#     383             f" Got input with shape {img1.shape} and {img2.shape} and values in range"
#     384             f" {[img1.min(), img1.max()]} and {[img2.min(), img2.max()]} when all values are"
#     385             f" expected to be in the {[0,1] if normalize else [-1,1]} range."
#     386         )
#     387     loss = net(img1, img2, normalize=normalize).squeeze()
#
# KeyboardInterrupt:

# %% [markdown]
# Let us now visualize different losses.

# %%
plt.figure()
plt.plot(Generator_losses, label="Generator Loss")
plt.plot(Discriminator_losses, label="Discriminator Loss")
plt.plot(Reconstruction_losses, label="Reconstruction Loss")
plt.plot(Perceptual_losses, label="Perceptual Loss")
plt.legend()

# %% [markdown]
# Let us now evaluate the model. We will also measure the `SSIM` score (Structural Similarity Index) between the generated fluorescent image and the label. The SSIM score is a perceptual metric that is used to measure the similarity between two images. The SSIM score ranges from `-1` to `1` with `1` being the highest similarity. We will use the `torchmetrics` library to compute the SSIM score.

# %%
from torchmetrics.image import StructuralSimilarityIndexMeasure as SSIM

transform_eval = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomCrop((512))
])

eval_dataset = VirtualStainingDataset(root, train=False, transform=transform_eval, normalize=normalize, preload=True)

img, target = eval_dataset[np.random.randint(0, len(test_dataset))]

generator.eval()

fig = evaluate_model(img.unsqueeze(0).to(device), target.unsqueeze(0).to(device))
plt.show()

# Calculate the SSIM score
ssim = SSIM().to(device)
ssim_score = ssim(generator(img.unsqueeze(0).to(device)), target.unsqueeze(0).to(device))
print(ssim_score)
